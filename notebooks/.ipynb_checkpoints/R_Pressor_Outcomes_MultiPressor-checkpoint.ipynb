# %% [markdown]
# # Pressor Distributions
# - Ruoyi Jiang
# - July 19, 2019
# - Evaluation of the different pressor combinations used in MIMIC

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(fasttime)

# RR analysis
library(epitools)

# ROC (and plotting)
library(boot)
library(pROC)

# imputation
library(randomForest)

# VIF analysis
library(car)

library(glmnet)
library(pls)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Type 'citation("pROC")' for a citation.
#
# Attaching package: ‘pROC’
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Loading required package: carData
#
# Attaching package: ‘car’
#
# The following object is masked from ‘package:boot’:
#
#     logit
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
# Loading required package: Matrix
#
# Attaching package: ‘Matrix’
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# Loading required package: foreach
# Loaded glmnet 2.0-18
#
#
# Attaching package: ‘glmnet’
#
# The following object is masked from ‘package:pROC’:
#
#     auc
#
#
# Attaching package: ‘pls’
#
# The following object is masked from ‘package:stats’:
#
#     loadings

# %%
sessionInfo()
# Out:
# R version 3.6.0 (2019-04-26)
# Platform: x86_64-apple-darwin18.5.0 (64-bit)
# Running under: macOS Mojave 10.14.3
#
# Matrix products: default
# BLAS/LAPACK: /usr/local/Cellar/openblas/0.3.6_1/lib/libopenblasp-r0.3.6.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] pls_2.7-1           glmnet_2.0-18       foreach_1.4.7
#  [4] Matrix_1.2-17       car_3.0-3           carData_3.0-2
#  [7] randomForest_4.6-14 pROC_1.15.3         boot_1.3-22
# [10] epitools_0.5-10     fasttime_1.0-2      ggplot2_3.2.0
# [13] tidyr_0.8.3         dplyr_0.8.1
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-3      tidyselect_0.2.5  repr_1.0.1        purrr_0.3.2
#  [5] haven_2.1.1       lattice_0.20-38   colorspace_1.4-1  vctrs_0.2.0
#  [9] htmltools_0.3.6   base64enc_0.1-3   rlang_0.4.0       pillar_1.4.0
# [13] foreign_0.8-71    glue_1.3.1        withr_2.1.2       readxl_1.3.1
# [17] uuid_0.1-2        plyr_1.8.4        munsell_0.5.0     gtable_0.3.0
# [21] cellranger_1.1.0  zip_2.0.4         codetools_0.2-16  evaluate_0.13
# [25] rio_0.5.16        forcats_0.4.0     curl_4.0          IRdisplay_0.7.0
# [29] Rcpp_1.0.1        scales_1.0.0      backports_1.1.4   IRkernel_1.0.1
# [33] jsonlite_1.6      abind_1.4-5       hms_0.5.0         digest_0.6.18
# [37] openxlsx_4.1.0.1  grid_3.6.0        tools_3.6.0       magrittr_1.5
# [41] lazyeval_0.2.2    tibble_2.1.1      crayon_1.3.4      pkgconfig_2.0.2
# [45] zeallot_0.1.0     data.table_1.12.2 assertthat_0.2.1  iterators_1.0.12
# [49] R6_2.4.0          compiler_3.6.0

# %%
### Plotting base_theme
base_theme <- function(){ theme_bw() + 
            theme(text=element_text(size=8)) +
            theme(plot.title=element_text(size=8)) +
            theme(plot.background=element_blank(),
                  panel.grid.major=element_blank(), 
                  panel.grid.minor=element_blank()) +
            theme(strip.background=element_blank(),
                  strip.text=element_text(size=7, face='bold')) +
            theme(axis.title=element_text(size=8, vjust=0.25),
                  axis.text.x=element_text(size=8, vjust=0.5, hjust=0.5),
                  axis.text.y=element_text(size=8)) +
            theme(legend.text=element_text(size=7),
                  legend.title=element_text(size=7),
                  legend.key.height=grid::unit(10, "points"), 
                  legend.key.width=grid::unit(10, "points"))}

# %% [markdown]
# ### Load data and take quick peek at select "pressors"  (e.g. vent and central line)

# %%
pressors_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/pressors.csv')

# %%
dim(pressors_df)
# Out:
# [1] 227645     11

# %%
pressors_df %>%
    filter(pressor == "central_line_durations") %>% head()
# Out:
#   X     level_0                level_1 duration_hours endtime
# 1 30584 central_line_durations 0        70.91667      2181-11-28 20:59:00
# 2 30585 central_line_durations 1       134.00000      2199-08-08 15:00:00
# 3 30586 central_line_durations 2        37.75000      2189-12-02 08:00:00
# 4 30587 central_line_durations 3        19.68333      2132-08-05 20:36:00
# 5 30588 central_line_durations 4        23.76667      2114-12-27 22:46:00
# 6 30589 central_line_durations 5         9.30000      2127-03-04 01:18:00
#   icustay_id num pressor                starttime           vasonum ventnum
# 1 200001     NA  central_line_durations 2181-11-25 22:04:00 NA      NA
# 2 200003     NA  central_line_durations 2199-08-03 01:00:00 NA      NA
# 3 200009     NA  central_line_durations 2189-11-30 18:15:00 NA      NA
# 4 200010     NA  central_line_durations 2132-08-05 00:55:00 NA      NA
# 5 200021     NA  central_line_durations 2114-12-26 23:00:00 NA      NA
# 6 200024     NA  central_line_durations 2127-03-03 16:00:00 NA      NA

# %%
pressors_df %>%
    filter(pressor == "ventdurations") %>% head()
# Out:
#   X      level_0       level_1 duration_hours endtime             icustay_id
# 1 189130 ventdurations 0       91.00000       2199-08-07 13:00:00 200003
# 2 189131 ventdurations 1       14.83333       2159-09-04 03:50:00 200006
# 3 189132 ventdurations 2       15.83333       2189-12-01 10:00:00 200009
# 4 189133 ventdurations 3        3.00000       2188-08-06 04:00:00 200011
# 5 189134 ventdurations 4       18.75000       2105-02-17 18:00:00 200014
# 6 189135 ventdurations 5       83.00000       2138-03-21 09:00:00 200017
#   num pressor       starttime           vasonum ventnum
# 1 NA  ventdurations 2199-08-03 18:00:00 NA      1
# 2 NA  ventdurations 2159-09-03 13:00:00 NA      1
# 3 NA  ventdurations 2189-11-30 18:10:00 NA      1
# 4 NA  ventdurations 2188-08-06 01:00:00 NA      1
# 5 NA  ventdurations 2105-02-16 23:15:00 NA      1
# 6 NA  ventdurations 2138-03-17 22:00:00 NA      1

# %%
pressors_df %>%
    group_by(pressor) %>%
    summarize(COUNT = n())
# Out:
#    pressor                 COUNT
# 1  adenosinedurations        160
# 2  arterial_line_durations 30424
# 3  central_line_durations  38211
# 4  crrtdurations            5918
# 5  dobutaminedurations      1792
# 6  dopaminedurations        6524
# 7  epinephrinedurations     3126
# 8  isupreldurations           24
# 9  milrinonedurations       3600
# 10 norepinephrinedurations 23188
# 11 phenylephrinedurations  33141
# 12 vasopressindurations     4190
# 13 vasopressordurations    38832
# 14 ventdurations           38515

# %% [markdown]
# ### Available pressor (and other infusions) choices
# - Make choices
# - Quick check of dataset balancing

# %%
pressor_choices <- c("norepinephrinedurations", "dopaminedurations", 
                     "phenylephrinedurations", "vasopressindurations", 'epinephrinedurations', 'dobutaminedurations')

# %%
FANCY_PRESSOR_ORDER <- c("Norepinephrine", "Dopamine", "Phenylephrine", "Vasopressin", "Epinephrine", "Dobutamine")

# %%
FANCY_PRESSOR_DICT <- c(
'dopaminedurations' = 'Dopamine',
'norepinephrinedurations' = 'Norepinephrine',  
'phenylephrinedurations' = 'Phenylephrine',
"vasopressindurations" = "Vasopressin",
'epinephrinedurations' = "Epinephrine",
'dobutaminedurations' = "Dobutamine"
)

# %%
PLOT_DIR <- "~/Google Drive/vasopressors/figures_v2"

# %%
pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    filter((pressor == 'phenylephrinedurations' & duration_hours > 0.5) |
           (pressor == 'epinephrinedurations' & duration_hours > 0.5) |
           !(pressor %in% c('phenylephrinedurations', 'phenylephrinedurations'))
          ) %>%
    mutate(MORETHAN24HOURS = duration_hours > 24) %>%
    group_by(MORETHAN24HOURS, pressor) %>% 
    summarize(COUNT = n())
# Out:
#    MORETHAN24HOURS pressor                 COUNT
# 1  FALSE           dobutaminedurations      1412
# 2  FALSE           dopaminedurations        5422
# 3  FALSE           epinephrinedurations     2797
# 4  FALSE           norepinephrinedurations 19811
# 5  FALSE           phenylephrinedurations  26872
# 6  FALSE           vasopressindurations     2537
# 7   TRUE           dobutaminedurations       380
# 8   TRUE           dopaminedurations        1102
# 9   TRUE           epinephrinedurations      329
# 10  TRUE           norepinephrinedurations  3377
# 11  TRUE           phenylephrinedurations   2711
# 12  TRUE           vasopressindurations     1653

# %% [markdown]
# ### Histograms of pressor durations for all 5 pressors of interest

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    mutate(DIFF = 
              difftime(fastPOSIXct(endtime), 
               fastPOSIXct(starttime), units="hours")) %>%
    ggplot(aes(x=DIFF)) +
        geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6)+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="Histogram",x="Hours", y = "Density")+
        theme_classic()
plot(p)
# Out:
# Don't know how to automatically pick scale for object of type difftime. Defaulting to continuous.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# “Removed 1254 rows containing non-finite values (stat_bin).”Warning message:
# “Removed 1254 rows containing non-finite values (stat_density).”
# plot without title

# %% [markdown]
# ### Join with icustay metadata (pressors_df + lengthstay_df -> input_df)
# ### Also remove <0.5 hr epinephrine and phenyelphrine doses

# %%
lengthstay_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/length_stay.csv') %>%
    rename(icustarttime = START, icuendtime = END)

# %%
lengthstay_df %>% head()
# Out:
#   X icustay_id icustarttime        icuendtime          DIFF
# 1 1 200001     2181-11-25 19:06:00 2181-11-28 20:00:00  72.90000
# 2 2 200003     2199-08-02 19:15:00 2199-08-08 15:00:00 139.75000
# 3 3 200006     2159-09-03 12:30:00 2159-09-04 17:00:00  28.50000
# 4 4 200007     2109-02-17 09:00:00 2109-02-18 09:15:00  24.25000
# 5 5 200009     2189-11-30 11:43:00 2189-12-02 13:00:00  49.28333
# 6 6 200010     2132-08-05 00:39:00 2132-08-05 21:17:00  20.63333

# %%
# filter by pressor and left join with lengthstay_df
input_df <- pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    filter((pressor == 'phenylephrinedurations' & duration_hours > 0.5) |
           (pressor == 'epinephrinedurations' & duration_hours > 0.5) |
           !(pressor %in% c('phenylephrinedurations', 'epinephrinedurations'))
          ) %>%
    left_join(lengthstay_df, by = "icustay_id") %>%
    mutate(starttime = fastPOSIXct(starttime), endtime = fastPOSIXct(endtime), 
           icustarttime = fastPOSIXct(icustarttime), icuendtime = fastPOSIXct(icuendtime))

# %% [markdown]
# # Filters

# %% [markdown]
# #### Collapse pressor courses based on length of intervening time (<24 hrs)
# - Any two courses with less than intervening 24 hours will be collapsed into a single course within an icustay

# %%
max_intervening_hrs <- 24

# find the intervening time between courses (endtime of next course - endtime of course - duration of course)
# then determine if that length of time is >24 or <24 and mark it with a 0 if true, else a 1
# use a cumsum to create a new id separating courses that are separated by more than >24

input_df <- input_df %>%
        group_by(icustay_id) %>%
        mutate(intervening_hours = difftime(endtime, lag(endtime), units="hours") - duration_hours) %>%
        rowwise() %>%
        mutate(increasing = if(intervening_hours < max_intervening_hrs | is.na(intervening_hours)){0}else(1)) %>%
        ungroup() %>%
        group_by(icustay_id) %>%
        mutate(continuous_course = cumsum(increasing)) %>% select(-intervening_hours, -increasing)

# %%
# max_intervening_hrs <- 24

# # find the intervening time between courses (endtime of next course - endtime of course - duration of course)
# # then determine if that length of time is >24 or <24 and mark it with a 0 if true, else a 1
# # use a cumsum to create a new id separating courses that are separated by more than >24
# input_list <- list()
# for(pressor_choice in pressor_choices){
#     input_list[[pressor_choice]] <- input_df %>%
#         filter(pressor == pressor_choice) %>%
#         group_by(icustay_id) %>%
#         mutate(intervening_hours = difftime(endtime, lag(endtime), units="hours") - duration_hours) %>%
#         rowwise() %>%
#         mutate(increasing = if(intervening_hours < max_intervening_hrs | is.na(intervening_hours)){0}else(1)) %>%
#         ungroup() %>%
#         group_by(icustay_id) %>%
#         mutate(continuous_course = cumsum(increasing)) %>% select(-intervening_hours, -increasing)
#     cat(pressor_choice, '\n')
# }

# %%
# input_df <- bind_rows(input_list, .id="pressor_choice")

# %% [markdown]
# - the combination of **continuous course** and **icustay_id** (e.g. 200024, 0 for first row) now defines each pressor course

# %% [markdown]
# - assign boolean assessments after <24 hour intervals between pressors are removed
#     1. more or less than 24 hours of pressor duration?
#     2. is this the first pressor course?
#     3. are pressors administered <1 hr of the icustay?

# %%
# 1. more or less than 24 hours?
input_df <- input_df %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(MORETHAN24HOURS = sum(duration_hours) > 24, 
           STATUS = if(sum(duration_hours) > 24){"MORETHAN24HOURS"}
           else if(sum(duration_hours) <= 24 & sum(duration_hours) > 6){"LESSTHAN24HOURS"}
           else if(sum(duration_hours) <= 6){"LESSTHAN6HOURS"}
               )

# %%
# 2. first pressor course? (groupby icustay, filter min starttime == starttime)
input_df <- input_df %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(coursestarttime = min(starttime)) %>%
    group_by(icustay_id) %>%
    mutate(FIRSTCOURSE = min(coursestarttime) == coursestarttime)

# %%
# 3. pressors within 1 hr of icustay_id? (groupby icustay, filter max starttime - unique icustarttime > 1)
input_df <- input_df %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(coursestarttime = min(starttime)) %>%
    group_by(icustay_id) %>%
    mutate(LESS1HOUR = difftime(min(coursestarttime), 
                         min(icustarttime)) < 1)

# %%
# grouped by icustay_id + continuous_course + separate_course
input_df %>%
    group_by(LESS1HOUR, FIRSTCOURSE, MORETHAN24HOURS) %>%
    summarize(COUNT = n())
# Out:
#    LESS1HOUR FIRSTCOURSE MORETHAN24HOURS COUNT
# 1  FALSE     FALSE       FALSE            2320
# 2  FALSE     FALSE        TRUE            9239
# 3  FALSE      TRUE       FALSE           14591
# 4  FALSE      TRUE        TRUE           35462
# 5   TRUE     FALSE       FALSE             110
# 6   TRUE     FALSE        TRUE             316
# 7   TRUE      TRUE       FALSE             904
# 8   TRUE      TRUE        TRUE            1966
# 9     NA     FALSE       FALSE             148
# 10    NA     FALSE        TRUE             661
# 11    NA      TRUE       FALSE             197
# 12    NA      TRUE        TRUE             990
# 13    NA        NA       FALSE             302
# 14    NA        NA        TRUE            1058

# %%
# With filters grouped by icustay_id + continuous_course
input_df %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(LESS1HOUR, FIRSTCOURSE, MORETHAN24HOURS) %>%
    summarize(COUNT = length(unique(course_id)))
# Out:
#    LESS1HOUR FIRSTCOURSE MORETHAN24HOURS COUNT
# 1  FALSE     FALSE       FALSE           1486
# 2  FALSE     FALSE        TRUE           1786
# 3  FALSE      TRUE       FALSE           8653
# 4  FALSE      TRUE        TRUE           6846
# 5   TRUE     FALSE       FALSE             68
# 6   TRUE     FALSE        TRUE             77
# 7   TRUE      TRUE       FALSE            587
# 8   TRUE      TRUE        TRUE            434
# 9     NA     FALSE       FALSE            105
# 10    NA     FALSE        TRUE            142
# 11    NA      TRUE       FALSE            114
# 12    NA      TRUE        TRUE            185
# 13    NA        NA       FALSE            178
# 14    NA        NA        TRUE            143

# %% [markdown]
# ### Introduce other predictor values for each course (like RACE, Diagnosis type) -> nonvitals_predictor_df

# %%
races <- c("ASIAN", "BLACK", "HISPANIC", "WHITE", "OTHER")

simplifyRace <- function(ethnicity){
    if(grepl("ASIAN", ethnicity)){return("ASIAN")}
    else if(grepl("BLACK", ethnicity)){return("BLACK")}
    else if(grepl("HISPANIC", ethnicity)){return("HISPANIC")}
    else if(grepl("WHITE", ethnicity)){return("WHITE")}
    else{return("OTHER")}
}

# %%
sepsis_regex <- c('SEPSIS', 'SEPTIC', 'CHOLANGITIS', 'UROSEPSIS')

infection_regex <- c('PNEUMONIA', 'INFECTION',  
  'CELULLITIS', 'FASCITIS', 'INFECTED', 'BACTER', 'PNEMONIA', 'ABSCESS', 'NEPHRITIS')

cardiac_regex <- c('HEART', 'CORONARY', 'VENTRICULAR')

simplifyDiagnosis <- function(diagnosis){
    if(any(sapply(sepsis_regex, function(x) grepl(x, diagnosis)))){return("SEPSIS")}
    else if(any(sapply(infection_regex, function(x) grepl(x, diagnosis)))){return("INFECTION")}
    else if(any(sapply(cardiac_regex, function(x) grepl(x, diagnosis)))){return("CARDIAC")}
    else{return("OTHER DIAGNOSIS")}
}

# %%
icustays_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/icustays.csv')

# %%
admissions_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/admissions.csv')

# %%
patients_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/patients.csv')

# %%
intub_df <- pressors_df %>%
    filter(pressor == "ventdurations") 

cvc_df <- pressors_df %>%
    filter(pressor == "central_line_durations")

# %%
nonvitals_predictor_df <- icustays_df %>%
    select(hadm_id, icustay_id, first_careunit, last_careunit) %>%
    left_join(admissions_df, by = 'hadm_id') %>%
    left_join(patients_df, by = 'subject_id') %>%
    mutate(intub = icustay_id %in% intub_df$icustay_id, cvc = icustay_id %in% cvc_df$icustay_id) %>%
    mutate(deathtime = fastPOSIXct(deathtime), admittime = fastPOSIXct(admittime), dob = fastPOSIXct(dob)) %>%
    mutate(age = difftime(admittime, dob, units="weeks")/52.25, 
           age_cohort = as.numeric(round(age, digits = -1))) %>% 
    rowwise() %>%
    mutate(simple_race = simplifyRace(ethnicity)) %>%
    mutate(simple_diagnosis = simplifyDiagnosis(diagnosis))

# %% [markdown]
# ### Mortality filter
# - Remove patients who stopped using pressors because death (merge with pressors_df by icustay_id, filter if pressor course end time == or is close to deathtime)
# - Also quantify some unusual cases of death documentation

# %%
#NA means the stay did not end in death
#ICUSTAYS where patient was discharged after death? (TRUE)
nonvitals_predictor_df  %>%
    mutate(MORTALITYERROR = difftime(deathtime, dischtime, units = "mins") < 0) %>%
    group_by(MORTALITYERROR) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   MORTALITYERROR COUNT
# 1 FALSE             40
# 2  TRUE           6422
# 3    NA          55070

# %%
#NA means the stay did not end in death
#ICUSTAYS where patient was admitted after death? (TRUE)
nonvitals_predictor_df  %>%
    mutate(MORTALITYERROR = difftime(deathtime, admittime, units = "mins") < 0) %>%
    group_by(MORTALITYERROR) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   MORTALITYERROR COUNT
# 1 FALSE           6384
# 2  TRUE             78
# 3    NA          55070

# %%
#Examples (admitted after death)
nonvitals_predictor_df  %>%
    filter(difftime(deathtime, admittime, units = "mins") < 0) %>%
    head(5)
# Out:
#   hadm_id icustay_id first_careunit last_careunit X.x  row_id.x subject_id
# 1 102631  246694     CSRU           CSRU           456  237      181
# 2 138015  298263     NICU           NICU          1911 1640     1334
# 3 181430  291798     SICU           SICU          1970 1699     1381
# 4 187482  213831     MICU           MICU           693  644      516
# 5 190088  293048     CCU            CCU           3624 3447     2858
#   admittime           dischtime           deathtime           ⋯ dod
# 1 2153-10-12 05:49:00 2153-10-12 06:29:00 2153-10-12 02:29:00 ⋯ 2153-10-12
# 2 2137-09-02 10:43:00 2137-09-02 12:00:00 2137-09-02 08:00:00 ⋯ 2137-09-02
# 3 2189-01-02 09:25:00 2189-01-02 12:00:00 2189-01-02 07:00:00 ⋯ 2189-01-02
# 4 2197-07-31 16:18:00 2197-07-31 01:10:00 2197-07-30 21:10:00 ⋯ 2197-07-31
# 5 2108-09-25 11:29:00 2108-09-25 12:00:00 2108-09-25 08:00:00 ⋯ 2108-09-25
#   dod_hosp   dod_ssn    expire_flag intub cvc   age               age_cohort
# 1 2153-10-12 2153-10-12 1           FALSE FALSE 65.12757082 weeks 70
# 2 2137-09-02            1            TRUE FALSE  0.00167654 weeks  0
# 3 2189-01-02 2189-01-02 1            TRUE FALSE 81.36049404 weeks 80
# 4 2197-07-31 2197-07-31 1           FALSE FALSE 70.88679654 weeks 70
# 5 2108-09-25 2108-09-25 1            TRUE FALSE 82.42418356 weeks 80
#   simple_race simple_diagnosis
# 1 WHITE       OTHER DIAGNOSIS
# 2 WHITE       OTHER DIAGNOSIS
# 3 WHITE       OTHER DIAGNOSIS
# 4 OTHER       OTHER DIAGNOSIS
# 5 WHITE       OTHER DIAGNOSIS

# %%
# Icustays where patients received pressors after death (TRUE)
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    mutate(STOPMORTALITY = difftime(deathtime, endtime, units = "mins")) %>% 
    group_by(STOPMORTALITY < 0) %>%
    summarize(COUNT = length(unique(icustay_id)))
# Out:
#   STOPMORTALITY < 0 COUNT
# 1 FALSE              3439
# 2  TRUE               694
# 3    NA             13368

# %% [markdown]
# ### Test out some mortality filters

# %%
### if I do not ignore for unusual cases (pressors after death)
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = STOPMORTALITY < 5) %>%
    group_by(STOPMORTALITY) %>%
    summarize(COUNT = n())
# Out:
#   STOPMORTALITY COUNT
# 1 FALSE         19010
# 2  TRUE          4290
# 3    NA         44964

# %%
### if I do ignore these unusual cases
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = STOPMORTALITY > 0 &  STOPMORTALITY < 5) %>%
    group_by(STOPMORTALITY) %>%
    summarize(COUNT = n())
# Out:
#   STOPMORTALITY COUNT
# 1 FALSE         23068
# 2  TRUE           232
# 3    NA         44964

# %% [markdown]
# ### Create filters for mortality: input_df -> input_death_df

# %%
# # ignore NAs (patient did not die), or patient death did not correspond to end of pressor course
# # do not remove unusual cases
# input_death_df <- input_df %>%
#     ungroup() %>%
#     left_join(nonvitals_predictor_df, by = "icustay_id") %>%
#     group_by(icustay_id, continuous_course, pressor) %>%
#     mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
#     mutate(STOPMORTALITY = !(!(STOPMORTALITY < 5) | is.na(STOPMORTALITY)))

# %%
# ignore NAs (patient did not die), or patient death did not correspond to end of pressor course
# remove unusual cases
input_death_df <- input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = !(!(STOPMORTALITY > 0 &  STOPMORTALITY < 5) | is.na(STOPMORTALITY)))

# %% [markdown]
# ### Exclude NICU (all NICU was already excluded by pressor usage): : input_death_df -> input_death_df

# %%
input_death_df %>%
    mutate(NICUSTAY = first_careunit == "NICU") %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(LESS1HOUR, FIRSTCOURSE, STOPMORTALITY, MORETHAN24HOURS, NICUSTAY) %>%
    summarize(COUNT = length(unique(course_id)))
# Out:
#    LESS1HOUR FIRSTCOURSE STOPMORTALITY MORETHAN24HOURS NICUSTAY COUNT
# 1  FALSE     FALSE       FALSE         FALSE           FALSE    1479
# 2  FALSE     FALSE       FALSE         FALSE            TRUE       5
# 3  FALSE     FALSE       FALSE          TRUE           FALSE    1752
# 4  FALSE     FALSE       FALSE          TRUE            TRUE      22
# 5  FALSE     FALSE        TRUE         FALSE           FALSE       2
# 6  FALSE     FALSE        TRUE          TRUE           FALSE      12
# 7  FALSE      TRUE       FALSE         FALSE           FALSE    8550
# 8  FALSE      TRUE       FALSE         FALSE            TRUE      87
# 9  FALSE      TRUE       FALSE          TRUE           FALSE    6714
# 10 FALSE      TRUE       FALSE          TRUE            TRUE     115
# 11 FALSE      TRUE        TRUE         FALSE           FALSE      15
# 12 FALSE      TRUE        TRUE         FALSE            TRUE       1
# 13 FALSE      TRUE        TRUE          TRUE           FALSE      17
# 14  TRUE     FALSE       FALSE         FALSE           FALSE      68
# 15  TRUE     FALSE       FALSE          TRUE           FALSE      77
# 16  TRUE      TRUE       FALSE         FALSE           FALSE     584
# 17  TRUE      TRUE       FALSE         FALSE            TRUE       1
# 18  TRUE      TRUE       FALSE          TRUE           FALSE     431
# 19  TRUE      TRUE       FALSE          TRUE            TRUE       2
# 20  TRUE      TRUE        TRUE         FALSE           FALSE       2
# 21  TRUE      TRUE        TRUE          TRUE           FALSE       1
# 22    NA     FALSE       FALSE         FALSE           FALSE     104
# 23    NA     FALSE       FALSE         FALSE            TRUE       1
# 24    NA     FALSE       FALSE          TRUE           FALSE     137
# 25    NA     FALSE       FALSE          TRUE            TRUE       3
# 26    NA     FALSE       FALSE          TRUE              NA       2
# 27    NA      TRUE       FALSE         FALSE           FALSE     111
# 28    NA      TRUE       FALSE         FALSE            TRUE       3
# 29    NA      TRUE       FALSE          TRUE           FALSE     167
# 30    NA      TRUE       FALSE          TRUE            TRUE      16
# 31    NA      TRUE       FALSE          TRUE              NA       1
# 32    NA      TRUE        TRUE          TRUE           FALSE       1
# 33    NA        NA       FALSE         FALSE           FALSE     177
# 34    NA        NA       FALSE         FALSE            TRUE       1
# 35    NA        NA       FALSE          TRUE           FALSE     140
# 36    NA        NA       FALSE          TRUE            TRUE       3

# %%
input_death_df <- input_death_df %>%
    filter(first_careunit != "NICU")

# %% [markdown]
# ### Use filters, clean predictors: input_death_df -> output_df

# %%
output_df <- input_death_df %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(course_id) %>%
    mutate(starttime = min(starttime), endtime = max(endtime)) %>%
    filter(!LESS1HOUR, FIRSTCOURSE, !STOPMORTALITY)

# %%
# collapse so each row is a course_id
output_df <- output_df %>%
    group_by(course_id) %>%
    summarize(
            PATIENT = unique(subject_id)[1],
            STATUS = unique(STATUS)[1], 
            MORETHAN24HOURS = unique(MORETHAN24HOURS)[1], 
            simple_diagnosis = unique(simple_diagnosis)[1], 
            simple_race = unique(simple_race)[1], 
            age = unique(age)[1], 
            age_cohort = unique(age_cohort)[1], 
            cvc = unique(cvc)[1],
            intub = unique(intub)[1],
            first_careunit = unique(first_careunit)[1],
            gender = unique(gender)[1],
            icustay_id = unique(icustay_id)[1],
            starttime = min(starttime), 
            endtime = max(endtime),
            pressor = paste(unique(pressor), collapse=",")
    ) %>% 
    mutate(duration = difftime(endtime, 
                       starttime, units="hours"))

# %%
dim(output_df)
# Out:
# [1] 15264    17

# %%
output_df %>%
    group_by(pressor) %>%
    summarize(COUNT = n())
# Out:
#    pressor
# 1  dobutaminedurations
# 2  dobutaminedurations,dopaminedurations
# 3  dobutaminedurations,dopaminedurations,epinephrinedurations
# 4  dobutaminedurations,dopaminedurations,epinephrinedurations,norepinephrinedurations
# 5  dobutaminedurations,dopaminedurations,epinephrinedurations,norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 6  dobutaminedurations,dopaminedurations,epinephrinedurations,norepinephrinedurations,vasopressindurations
# 7  dobutaminedurations,dopaminedurations,epinephrinedurations,phenylephrinedurations
# 8  dobutaminedurations,dopaminedurations,norepinephrinedurations
# 9  dobutaminedurations,dopaminedurations,norepinephrinedurations,phenylephrinedurations
# 10 dobutaminedurations,dopaminedurations,norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 11 dobutaminedurations,dopaminedurations,norepinephrinedurations,vasopressindurations
# 12 dobutaminedurations,dopaminedurations,phenylephrinedurations
# 13 dobutaminedurations,dopaminedurations,phenylephrinedurations,vasopressindurations
# 14 dobutaminedurations,dopaminedurations,vasopressindurations
# 15 dobutaminedurations,epinephrinedurations
# 16 dobutaminedurations,epinephrinedurations,norepinephrinedurations
# 17 dobutaminedurations,epinephrinedurations,norepinephrinedurations,phenylephrinedurations
# 18 dobutaminedurations,epinephrinedurations,norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 19 dobutaminedurations,epinephrinedurations,norepinephrinedurations,vasopressindurations
# 20 dobutaminedurations,epinephrinedurations,phenylephrinedurations
# 21 dobutaminedurations,epinephrinedurations,phenylephrinedurations,vasopressindurations
# 22 dobutaminedurations,norepinephrinedurations
# 23 dobutaminedurations,norepinephrinedurations,phenylephrinedurations
# 24 dobutaminedurations,norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 25 dobutaminedurations,norepinephrinedurations,vasopressindurations
# 26 dobutaminedurations,phenylephrinedurations
# 27 dobutaminedurations,phenylephrinedurations,vasopressindurations
# 28 dobutaminedurations,vasopressindurations
# 29 dopaminedurations
# 30 dopaminedurations,epinephrinedurations
# 31 dopaminedurations,epinephrinedurations,norepinephrinedurations
# 32 dopaminedurations,epinephrinedurations,norepinephrinedurations,phenylephrinedurations
# 33 dopaminedurations,epinephrinedurations,norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 34 dopaminedurations,epinephrinedurations,norepinephrinedurations,vasopressindurations
# 35 dopaminedurations,epinephrinedurations,phenylephrinedurations
# 36 dopaminedurations,epinephrinedurations,phenylephrinedurations,vasopressindurations
# 37 dopaminedurations,norepinephrinedurations
# 38 dopaminedurations,norepinephrinedurations,phenylephrinedurations
# 39 dopaminedurations,norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 40 dopaminedurations,norepinephrinedurations,vasopressindurations
# 41 dopaminedurations,phenylephrinedurations
# 42 dopaminedurations,phenylephrinedurations,vasopressindurations
# 43 dopaminedurations,vasopressindurations
# 44 epinephrinedurations
# 45 epinephrinedurations,norepinephrinedurations
# 46 epinephrinedurations,norepinephrinedurations,phenylephrinedurations
# 47 epinephrinedurations,norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 48 epinephrinedurations,norepinephrinedurations,vasopressindurations
# 49 epinephrinedurations,phenylephrinedurations
# 50 epinephrinedurations,phenylephrinedurations,vasopressindurations
# 51 epinephrinedurations,vasopressindurations
# 52 norepinephrinedurations
# 53 norepinephrinedurations,phenylephrinedurations
# 54 norepinephrinedurations,phenylephrinedurations,vasopressindurations
# 55 norepinephrinedurations,vasopressindurations
# 56 phenylephrinedurations
# 57 phenylephrinedurations,vasopressindurations
# 58 vasopressindurations
#    COUNT
# 1   165
# 2   119
# 3     3
# 4     4
# 5     3
# 6     2
# 7     2
# 8    67
# 9    27
# 10   13
# 11   24
# 12   27
# 13    2
# 14    3
# 15   11
# 16   13
# 17   14
# 18    9
# 19    4
# 20   17
# 21    1
# 22  102
# 23   55
# 24   31
# 25   26
# 26   82
# 27    5
# 28    1
# 29 1184
# 30   21
# 31   28
# 32   23
# 33   25
# 34   10
# 35   22
# 36    1
# 37  490
# 38  155
# 39  105
# 40  112
# 41  279
# 42   19
# 43   19
# 44  231
# 45  195
# 46  130
# 47   83
# 48   72
# 49  696
# 50   32
# 51    3
# 52 2598
# 53 1182
# 54  380
# 55  320
# 56 5831
# 57  135
# 58   51

# %% [markdown]
# ### If more than 1 pressor is used, MORETHAN24HOURS is TRUE

# %%
output_df <- output_df %>%
    rowwise() %>%
    mutate(RESPONSE = MORETHAN24HOURS | grepl(",", pressor))

# %% [markdown]
# # Analysis

# %% [markdown]
# ### For text, description of meta-data

# %%
length(unique(output_df$PATIENT))
# Out:
# [1] 13510

# %%
length(unique(output_df$icustay_id))
# Out:
# [1] 15156

# %%
# minimum age
min(output_df$age, na.rm=TRUE)
# Out:
# [1] 15.15073

# %%
sum(output_df$age < 17.99999, na.rm=TRUE)
# Out:
# [1] 20

# %%
output_df %>%
    mutate(MINOR = age < 18) %>%
    group_by(MINOR, first_careunit) %>%
# Out:
# Error in parse(text = x, srcfile = src): <text>:4:0: unexpected end of input
# 2:     mutate(MINOR = age < 18) %>%
# 3:     group_by(MINOR, first_careunit) %>%
#   ^
# Traceback:

# %%
dim(output_df)
# Out:
# [1] 15264    18

# %%
output_df %>%
    group_by(STATUS) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   STATUS          COUNT
# 1 LESSTHAN24HOURS 5060
# 2 LESSTHAN6HOURS  3490
# 3 MORETHAN24HOURS 6714

# %%
output_df %>%
    group_by(STATUS, pressor) %>%
    summarize(COUNT = length(unique(PATIENT))) %>%
    filter(!grepl(",", pressor))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    STATUS          pressor                 COUNT
# 1  LESSTHAN24HOURS dobutaminedurations       61
# 2  LESSTHAN24HOURS dopaminedurations        396
# 3  LESSTHAN24HOURS epinephrinedurations     128
# 4  LESSTHAN24HOURS norepinephrinedurations  929
# 5  LESSTHAN24HOURS phenylephrinedurations  2309
# 6  LESSTHAN24HOURS vasopressindurations      15
# 7  LESSTHAN6HOURS  dobutaminedurations       42
# 8  LESSTHAN6HOURS  dopaminedurations        419
# 9  LESSTHAN6HOURS  epinephrinedurations      76
# 10 LESSTHAN6HOURS  norepinephrinedurations  682
# 11 LESSTHAN6HOURS  phenylephrinedurations  1998
# 12 LESSTHAN6HOURS  vasopressindurations      12
# 13 MORETHAN24HOURS dobutaminedurations       62
# 14 MORETHAN24HOURS dopaminedurations        339
# 15 MORETHAN24HOURS epinephrinedurations      27
# 16 MORETHAN24HOURS norepinephrinedurations  917
# 17 MORETHAN24HOURS phenylephrinedurations  1451
# 18 MORETHAN24HOURS vasopressindurations      24

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS" & !grepl(",", pressor)) %>%
    summarize(COUNT =n()) %>% 
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE COUNT FREQ
# 1 FALSE    12006 0.7865566
# 2  TRUE     3258 0.2134434

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS" & !grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE  754  0.2314303
# 2 TRUE      TRUE 2504  0.7685697

# %%
# Less than 24 hours AND only one vasopressor
output_df %>%
    group_by(RESPONSE = STATUS != "MORETHAN24HOURS" & !grepl(",", pressor)) %>%
    summarize(COUNT = n()) %>% 
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE COUNT FREQ
# 1 FALSE    8114  0.5315776
# 2  TRUE    7150  0.4684224

# %%
output_df %>%
    group_by(RESPONSE = STATUS != "MORETHAN24HOURS" & !grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE 1582  0.2212587
# 2 TRUE      TRUE 5568  0.7787413

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "MORETHAN24HOURS", cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE  546  0.08132261
# 2 TRUE      TRUE 6168  0.91867739

# %%
output_df %>%
    group_by(RESPONSE = grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE  462  0.08877786
# 2 TRUE      TRUE 4742  0.91122214

# %% [markdown]
# #### All courses

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- output_df %>%
    filter(!grepl(',', pressor)) %>%
    ggplot(aes(x=duration)) +
        base_theme() +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6, fill="gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Density")+
        xlim(0, 72) +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="#2F4F4F")
plot(p)
# Out:
# Warning message:
# “Removed 682 rows containing non-finite values (stat_density).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "histo_durations.pdf"), 2, 2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 682 rows containing non-finite values (stat_density).”
# pdf
#   2

# %% [markdown]
# #### Courses involving any of these pressors

# %%
options(repr.plot.width=4.5, repr.plot.height=4)
p <- output_df %>%
    filter(!grepl(',', pressor)) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=duration)) +
        base_theme() +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6, fill="gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Density")+
        xlim(0, 72) +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="#2F4F4F") +
        facet_wrap(. ~fancy_pressor, nrow=2, ncol=3)
plot(p)
# Out:
# Warning message:
# “Removed 682 rows containing non-finite values (stat_density).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "histo_individual_durations.pdf"), 4.5, 4)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 682 rows containing non-finite values (stat_density).”
# pdf
#   2

# %% [markdown]
# ### Figure X. CVC associated with longer pressor courses

# %%
CVC_COLORS <- c(
"CVC" = '#2F4F4F',
"No CVC" = '#D3D3D3'
)

# %%
# <6 hour course
output_df %>%
    filter(!grepl(",", pressor)) %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS", cvc) %>%
    summarize(COUNT = n(), DURATION = mean(duration)) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT DURATION        FREQ
# 1 FALSE    FALSE 1120  23.094449 hours 0.1648756
# 2 FALSE     TRUE 5673  38.395828 hours 0.8351244
# 3  TRUE    FALSE  758   2.945295 hours 0.2318752
# 4  TRUE     TRUE 2511   3.381481 hours 0.7681248

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "MORETHAN24HOURS", cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 FALSE    FALSE 1798  0.20975268
# 2 FALSE     TRUE 6774  0.79024732
# 3  TRUE    FALSE  546  0.08133472
# 4  TRUE     TRUE 6167  0.91866528

# %%
output_df %>%
    group_by(RESPONSE = grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 FALSE    FALSE 1878  0.18664281
# 2 FALSE     TRUE 8184  0.81335719
# 3  TRUE    FALSE  466  0.08922075
# 4  TRUE     TRUE 4757  0.91077925

# %%
pairwise.wilcox.test(as.numeric(output_df$duration), output_df$cvc)
# Out:
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(output_df$duration) and output_df$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- output_df %>%
    rowwise() %>%
    mutate(cvc_fancy = if(cvc){"CVC"}else{"No CVC"}) %>%
    mutate(cvc_fancy = factor(cvc_fancy, levels = names(CVC_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=cvc_fancy, y=duration)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("Duration (hours)") +
        geom_violin(aes(fill=cvc_fancy), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,72)) +
        geom_boxplot(width=0.05, outlier.shape = NA)+
        stat_summary(fun.y=median, geom="point", size=2, color="firebrick")
        #+ facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Warning message:
# “Removed 2354 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 2354 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 2354 rows containing non-finite values (stat_summary).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "cvcduration.pdf"), 2,2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 2354 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 2354 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 2354 rows containing non-finite values (stat_summary).”
# pdf
#   2

# %%
for(presor_choice in pressor_choices){
    pairwise.wilcox.test(as.numeric(filter(output_df,pressor==pressor_choice)$duration), 
                     filter(output_df,pressor==pressor_choice)$cvc) %>% 
    print()
}
# Out:
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm
#
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm
#
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm
#
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm
#
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm

# %%
options(repr.plot.width=7, repr.plot.height=2)
p <- output_df %>%
    filter(!grepl(",", pressor)) %>%
    rowwise() %>%
    mutate(cvc_fancy = if(cvc){"CVC"}else{"No CVC"}) %>%
    mutate(cvc_fancy = factor(cvc_fancy, levels = names(CVC_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=cvc_fancy, y=duration)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("Duration (hours)") +
        geom_violin(aes(fill=cvc_fancy), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,72)) +
        geom_boxplot(width=0.05, outlier.shape = NA) +
        stat_summary(fun.y=median, geom="point", size=2, color="firebrick") +
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Warning message:
# “Removed 678 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 678 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 678 rows containing non-finite values (stat_summary).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "cvcduration_eachpressor.pdf"), 4,2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 1354 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_summary).”
# pdf
#   2

# %% [markdown]
# ### Table 1 Demographics

# %%
(20/nrow(output_df)) %>% round(2)
# Out:
# [1] 0

# %%
t1_df <- output_df %>% 
    group_by(STATUS) %>%
    summarize(n = paste(round(as.numeric(n()),2), paste0('(', (n()/nrow(output_df)) %>% round(3), ')')), 
            Age = paste(round(as.numeric(mean(age, na.rm=TRUE)),2), paste('±', sd(age, na.rm=TRUE) %>% round(2))), 
            Male = paste(sum(gender == 'M'), paste0('(',round(sum(gender == 'M')/n(),2),')')),
            MICU = paste(sum(first_careunit == 'MICU'), paste0('(',round(sum(first_careunit == 'MICU')/n(),2),')')),
            SICU = paste(sum(first_careunit == 'SICU'), paste0('(',round(sum(first_careunit == 'SICU')/n(),2),')')),
            CCU = paste(sum(first_careunit == 'CCU'), paste0('(',round(sum(first_careunit == 'CCU')/n(),2),')')),
            TSICU = paste(sum(first_careunit == 'TSICU'), paste0('(',round(sum(first_careunit == 'TSICU')/n(),2),')')),
            CSRU = paste(sum(first_careunit == 'CSRU'), paste0('(',round(sum(first_careunit == 'CSRU')/n(),2),')')),
            Sepsis = paste(sum(simple_diagnosis == "SEPSIS"), paste0('(',round(sum(simple_diagnosis == "SEPSIS")/n(),2),')')),
            Infectious = paste(sum(simple_diagnosis == "INFECTION"), paste0('(',round(sum(simple_diagnosis == "INFECTION")/n(),2),')')),
            Cardiac = paste(sum(simple_diagnosis == "CARDIAC"), paste0('(',round(sum(simple_diagnosis == "CARDIAC")/n(),2),')')),
            CVC = paste(sum(cvc == "TRUE"), paste0('(',round(sum(cvc == "TRUE")/n(),2),')')),
            Intubated = paste(sum(intub == "TRUE"), paste0('(',round(sum(intub == "TRUE")/n(),2),')'))
             ) %>% t()
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
colnames(t1_df) <- t1_df[1,]

# %%
t1_df
# Out:
#            LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# STATUS     LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# n          5060 (0.331)    3490 (0.229)   6714 (0.44)
# Age        65.52 ± 13.88   66.21 ± 13.9   65.72 ± 14.27
# Male       3096 (0.61)     2070 (0.59)    3977 (0.59)
# MICU       1267 (0.25)     782 (0.22)     2102 (0.31)
# SICU       583 (0.12)      382 (0.11)     849 (0.13)
# CCU        657 (0.13)      458 (0.13)     985 (0.15)
# TSICU      427 (0.08)      291 (0.08)     603 (0.09)
# CSRU       2126 (0.42)     1577 (0.45)    2175 (0.32)
# Sepsis     340 (0.07)      149 (0.04)     528 (0.08)
# Infectious 249 (0.05)      162 (0.05)     438 (0.07)
# Cardiac    1254 (0.25)     913 (0.26)     1371 (0.2)
# CVC        4079 (0.81)     2679 (0.77)    6168 (0.92)
# Intubated  4054 (0.8)      2736 (0.78)    5793 (0.86)

# %%
t1_multi_df <- output_df %>% 
    rowwise() %>%
    mutate(MULTI = if(grepl(",", pressor)){'MULTI'}else{'NOT MULTI'}) %>%
    group_by(MULTI) %>%
    summarize(n = paste(round(as.numeric(n()),2), paste0('(', (n()/nrow(output_df)) %>% round(3), ')')), 
            Age = paste(round(as.numeric(mean(age, na.rm=TRUE)),2), paste('±', sd(age, na.rm=TRUE) %>% round(2))), 
            Male = paste(sum(gender == 'M'), paste0('(',round(sum(gender == 'M')/n(),2),')')),
            MICU = paste(sum(first_careunit == 'MICU'), paste0('(',round(sum(first_careunit == 'MICU')/n(),2),')')),
            SICU = paste(sum(first_careunit == 'SICU'), paste0('(',round(sum(first_careunit == 'SICU')/n(),2),')')),
            CCU = paste(sum(first_careunit == 'CCU'), paste0('(',round(sum(first_careunit == 'CCU')/n(),2),')')),
            TSICU = paste(sum(first_careunit == 'TSICU'), paste0('(',round(sum(first_careunit == 'TSICU')/n(),2),')')),
            CSRU = paste(sum(first_careunit == 'CSRU'), paste0('(',round(sum(first_careunit == 'CSRU')/n(),2),')')),
            Sepsis = paste(sum(simple_diagnosis == "SEPSIS"), paste0('(',round(sum(simple_diagnosis == "SEPSIS")/n(),2),')')),
            Infectious = paste(sum(simple_diagnosis == "INFECTION"), paste0('(',round(sum(simple_diagnosis == "INFECTION")/n(),2),')')),
            Cardiac = paste(sum(simple_diagnosis == "CARDIAC"), paste0('(',round(sum(simple_diagnosis == "CARDIAC")/n(),2),')')),
            CVC = paste(sum(cvc == "TRUE"), paste0('(',round(sum(cvc == "TRUE")/n(),2),')')),
            Intubated = paste(sum(intub == "TRUE"), paste0('(',round(sum(intub == "TRUE")/n(),2),')'))
             ) %>% t()
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
colnames(t1_multi_df) <- t1_multi_df[1,]

# %%
t1_multi_df
# Out:
#            MULTI         NOT MULTI
# MULTI      MULTI         NOT MULTI
# n          5204 (0.341)  10060 (0.659)
# Age        66.32 ± 14.31 65.48 ± 13.92
# Male       3111 (0.6)    6032 (0.6)
# MICU       1622 (0.31)   2529 (0.25)
# SICU       586 (0.11)    1228 (0.12)
# CCU        825 (0.16)    1275 (0.13)
# TSICU      421 (0.08)    900 (0.09)
# CSRU       1750 (0.34)   4128 (0.41)
# Sepsis     413 (0.08)    604 (0.06)
# Infectious 296 (0.06)    553 (0.05)
# Cardiac    1065 (0.2)    2473 (0.25)
# CVC        4742 (0.91)   8184 (0.81)
# Intubated  4639 (0.89)   7944 (0.79)

# %%
cbind(t1_df, t1_multi_df) %>% write.csv(file.path(PLOT_DIR, "response_demographics.csv"))

# %% [markdown]
# ### Supplement Table (solo agents)

# %%
s1_3_df <- output_df %>% 
    filter(!grepl(",", pressor)) %>%
    group_by(STATUS, pressor) %>%
    summarize(n = n(), 
            Age = paste(round(as.numeric(mean(age, na.rm=TRUE)),2), paste('±', sd(age, na.rm=TRUE) %>% round(2))), 
            Male = paste(sum(gender == 'M'), paste0('(',round(sum(gender == 'M')/n(),2),')')),
            MICU = paste(sum(first_careunit == 'MICU'), paste0('(',round(sum(first_careunit == 'MICU')/n(),2),')')),
            SICU = paste(sum(first_careunit == 'SICU'), paste0('(',round(sum(first_careunit == 'SICU')/n(),2),')')),
            CCU = paste(sum(first_careunit == 'CCU'), paste0('(',round(sum(first_careunit == 'CCU')/n(),2),')')),
            TSICU = paste(sum(first_careunit == 'TSICU'), paste0('(',round(sum(first_careunit == 'TSICU')/n(),2),')')),
            CSRU = paste(sum(first_careunit == 'CSRU'), paste0('(',round(sum(first_careunit == 'CSRU')/n(),2),')')),
            Sepsis = paste(sum(simple_diagnosis == "SEPSIS"), paste0('(',round(sum(simple_diagnosis == "SEPSIS")/n(),2),')')),
            Infectious = paste(sum(simple_diagnosis == "INFECTION"), paste0('(',round(sum(simple_diagnosis == "INFECTION")/n(),2),')')),
            Cardiac = paste(sum(simple_diagnosis == "CARDIAC"), paste0('(',round(sum(simple_diagnosis == "CARDIAC")/n(),2),')')),
            CVC = paste(sum(cvc == "TRUE"), paste0('(',round(sum(cvc == "TRUE")/n(),2),')')),
            Intubated = paste(sum(intub == "TRUE"), paste0('(',round(sum(intub == "TRUE")/n(),2),')'))
             )

# %%
for(pressor_choice in pressor_choices){
    out_df <- s1_3_df %>%
        filter(pressor == pressor_choice) %>%
        ungroup() %>%
        mutate(n = paste0(n, ' (', (n/sum(n)) %>% round(2), ')')) %>%
        t()
    colnames(out_df) <- out_df[1,]
    out_df %>% 
        data.frame() %>%
        select(LESSTHAN6HOURS, LESSTHAN24HOURS, MORETHAN24HOURS) %>%
        write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_demographics.csv")))
}

# %% [markdown]
# # Categorical Predictors

# %%
# This function, given a dataframe with the appropriate columns, will compute RR statistics and return as a table 
calculatePredictors <- function(df){
    all_rr_list <- list()

    # gender
    output <- df %>%
        group_by(RESPONSE, gender) %>%
        summarize(COUNT = n()) %>%
        spread(RESPONSE, COUNT) %>%
        tibble::column_to_rownames("gender") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['MALE_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'M') %>%
            mutate(ID = "M", p = output$p.value["M","fisher.exact"])


#     # race
#     rr_list <- list()
#     for(race in races){
#        output <- df %>%
#             rowwise() %>%
#             group_by(RESPONSE, simple_race) %>%
#             summarize(COUNT = n()) %>%
#             mutate(RACE_BOOL = simple_race == race) %>%
#             group_by(RACE_BOOL, RESPONSE) %>%
#             summarize(COUNT = sum(COUNT)) %>%
#             spread(RESPONSE, COUNT) %>%
#             tibble::column_to_rownames("RACE_BOOL") %>%
#             as.matrix() %>% riskratio() 
#         rr_list[[race]] <- output$measure %>%
#             data.frame() %>%
#             tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
#             mutate(ID = race, p = output$p.value["TRUE","fisher.exact"])
#     }


#     all_rr_list[['RACE_RR']] <- bind_rows(rr_list)


    # age
    age_df <- df %>%
        group_by(RESPONSE, age_cohort) %>%
        summarize(COUNT = n()) %>%
        drop_na(age_cohort)

    rr_list <- list()
    for(ac in unique(age_df$age_cohort)){
       if(ac != 0){
           output <- age_df %>%
                mutate(AGE_BOOL = age_cohort == ac) %>%
                group_by(AGE_BOOL, RESPONSE) %>%
                summarize(COUNT = sum(COUNT)) %>%
                spread(RESPONSE, COUNT) %>%
                tibble::column_to_rownames("AGE_BOOL") %>%
                as.matrix() %>% riskratio() 

            rr_list[[ac]] <- output$measure %>%
                data.frame() %>%
                tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
                mutate(ID = as.character(ac), p = output$p.value["TRUE","fisher.exact"])
       }  
    }

    all_rr_list[['AGE_RR']] <- bind_rows(rr_list)


    # diagnosis
    diagnosis_df <- df %>%
        rowwise() %>%
        group_by(simple_diagnosis, RESPONSE) %>%
        summarize(COUNT = n()) 

    rr_list <- list()
    for(s_d in unique(diagnosis_df$simple_diagnosis)){
       output <- diagnosis_df %>%
            mutate(DX_BOOL = simple_diagnosis == s_d) %>%
            group_by(DX_BOOL, RESPONSE) %>%
            summarize(COUNT = sum(COUNT)) %>%
            spread(RESPONSE, COUNT) %>%
            tibble::column_to_rownames("DX_BOOL") %>%
            as.matrix() %>% riskratio() 
        rr_list[[s_d]] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = s_d, p = output$p.value["TRUE","fisher.exact"])
    }

    all_rr_list[['DIAGNOSIS_RR']] <- bind_rows(rr_list)


    # careunit
    careunit_df <- df %>%
        group_by(RESPONSE, first_careunit) %>%
        summarize(COUNT = n())

    rr_list <- list()
    for(cu in unique(careunit_df$first_careunit)){
       output <- careunit_df%>%
            mutate(CU_BOOL = first_careunit == cu) %>%
            group_by(CU_BOOL, RESPONSE) %>%
            summarize(COUNT = sum(COUNT)) %>%
            spread(RESPONSE, COUNT) %>%
            tibble::column_to_rownames("CU_BOOL") %>%
            as.matrix() %>% riskratio() 
        rr_list[[cu]] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = cu, p = output$p.value["TRUE","fisher.exact"])
    }

    all_rr_list[['CAREUNIT_RR']] <- bind_rows(rr_list)


    # intub
    output <- df %>%
        group_by(RESPONSE, intub) %>%
        summarize(COUNT = n()) %>%
        spread(RESPONSE, COUNT) %>%
        tibble::column_to_rownames("intub") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['INTUB_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = "INTUB", p = output$p.value["TRUE","fisher.exact"])

    # cvc
    output <- df %>%
        group_by(RESPONSE, cvc) %>%
        summarize(COUNT = n()) %>%
        spread(RESPONSE, COUNT) %>%
        tibble::column_to_rownames("cvc") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['CVC_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = "CVC", p = output$p.value["TRUE","fisher.exact"])


    # combined
    all_rr_df <- bind_rows(all_rr_list, .id="TYPE") %>%
        mutate(significant = p < 0.05)
    
    return(all_rr_df)
}

# %% [markdown]
# # Table 1 (RR significance)

# %%
rr_df <- calculatePredictors(output_df) %>%
    rowwise() %>%
    mutate(ID = if(ID == "M"){"MALE"}else{ID}) %>% select(-FILTER)
rr_df
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    TYPE         estimate  lower     upper     ID              p
# 1  MALE_RR      0.9619837 0.9334474 0.9913924 MALE             1.251451e-02
# 2  AGE_RR       1.0232508 0.8871223 1.1802682 20               8.112433e-01
# 3  AGE_RR       1.0262155 0.9259281 1.1373649 30               6.456563e-01
# 4  AGE_RR       1.0708553 1.0014896 1.1450255 40               5.567368e-02
# 5  AGE_RR       0.9602825 0.9168750 1.0057452 50               8.308530e-02
# 6  AGE_RR       0.9719828 0.9365458 1.0087608 60               1.307216e-01
# 7  AGE_RR       0.9800910 0.9465626 1.0148069 70               2.602350e-01
# 8  AGE_RR       1.0557031 1.0202500 1.0923881 80               2.189679e-03
# 9  AGE_RR       0.9819059 0.9148168 1.0539150 90               6.225386e-01
# 10 DIAGNOSIS_RR 0.8669354 0.8344036 0.9007355 CARDIAC          2.383657e-14
# 11 DIAGNOSIS_RR 1.1201316 1.0570911 1.1869316 INFECTION        3.069828e-04
# 12 DIAGNOSIS_RR 1.0398952 1.0076590 1.0731626 OTHER DIAGNOSIS  1.467475e-02
# 13 DIAGNOSIS_RR 1.1511037 1.0928747 1.2124352 SEPSIS           8.820824e-07
# 14 CAREUNIT_RR  1.0931358 1.0500063 1.1380368 CCU              3.072483e-05
# 15 CAREUNIT_RR  0.7862658 0.7609029 0.8124741 CSRU             1.793353e-50
# 16 CAREUNIT_RR  1.2028922 1.1665688 1.2403467 MICU             1.399990e-29
# 17 CAREUNIT_RR  1.0350967 0.9898529 1.0824086 SICU             1.393647e-01
# 18 CAREUNIT_RR  1.0326682 0.9809131 1.0871539 TSICU            2.371202e-01
# 19 INTUB_RR     1.3079111 1.2481343 1.3705509 INTUB            1.023768e-34
# 20 CVC_RR       1.7562435 1.6534160 1.8654660 CVC             3.839674e-107
#    significant
# 1   TRUE
# 2  FALSE
# 3  FALSE
# 4  FALSE
# 5  FALSE
# 6  FALSE
# 7  FALSE
# 8   TRUE
# 9  FALSE
# 10  TRUE
# 11  TRUE
# 12  TRUE
# 13  TRUE
# 14  TRUE
# 15  TRUE
# 16  TRUE
# 17 FALSE
# 18 FALSE
# 19  TRUE
# 20  TRUE

# %%
rr_df %>% 
    write.csv(file.path(PLOT_DIR, "relativerisk.csv"))

# %% [markdown]
# ### Supplement (single agents)
# - Insufficient numbers for RR analysis for epinephrine and vasopressin

# %%
pressor_rr_list <- list()
for(pressor_choice in c('norepinephrinedurations', 'dopaminedurations', 'phenylephrinedurations')){
    pressor_rr_list[[pressor_choice]] <- output_df %>%
        filter(grepl(pressor_choice, pressor)) %>%
        calculatePredictors()
}
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message in chisq.test(xx, correct = correction):
# “Chi-squared approximation may be incorrect”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
pressor_rr_df <- bind_rows(pressor_rr_list, .id="pressor")  %>% select(-FILTER)

# %%
pressor_rr_df
# Out:
#    pressor                 TYPE         estimate  lower     upper
# 1  norepinephrinedurations MALE_RR      1.0190057 0.9891411 1.0497720
# 2  norepinephrinedurations AGE_RR       0.9375607 0.8078868 1.0880486
# 3  norepinephrinedurations AGE_RR       1.0182311 0.9302911 1.1144841
# 4  norepinephrinedurations AGE_RR       1.0337854 0.9703307 1.1013897
# 5  norepinephrinedurations AGE_RR       1.0049333 0.9627929 1.0489182
# 6  norepinephrinedurations AGE_RR       0.9856754 0.9498223 1.0228817
# 7  norepinephrinedurations AGE_RR       1.0145757 0.9805363 1.0497967
# 8  norepinephrinedurations AGE_RR       1.0006974 0.9670886 1.0354742
# 9  norepinephrinedurations AGE_RR       0.9570152 0.8935094 1.0250346
# 10 norepinephrinedurations DIAGNOSIS_RR 1.1427193 1.1014253 1.1855614
# 11 norepinephrinedurations DIAGNOSIS_RR 0.9036004 0.8523041 0.9579839
# 12 norepinephrinedurations DIAGNOSIS_RR 1.0455786 1.0127539 1.0794672
# 13 norepinephrinedurations DIAGNOSIS_RR 0.8651061 0.8212096 0.9113491
# 14 norepinephrinedurations CAREUNIT_RR  1.0695510 1.0280334 1.1127454
# 15 norepinephrinedurations CAREUNIT_RR  1.1299110 1.0937180 1.1673016
# 16 norepinephrinedurations CAREUNIT_RR  0.8771612 0.8511499 0.9039675
# 17 norepinephrinedurations CAREUNIT_RR  1.0354623 0.9941570 1.0784837
# 18 norepinephrinedurations CAREUNIT_RR  1.0258954 0.9785544 1.0755266
# 19 norepinephrinedurations INTUB_RR     1.4579819 1.3812009 1.5390311
# 20 norepinephrinedurations CVC_RR       1.2308844 1.1483381 1.3193644
# 21 dopaminedurations       MALE_RR      1.0494281 0.9995047 1.1018451
# 22 dopaminedurations       AGE_RR       1.0793637 0.8006107 1.4551717
# 23 dopaminedurations       AGE_RR       1.0082300 0.8106355 1.2539887
# 24 dopaminedurations       AGE_RR       1.0001288 0.8882584 1.1260884
# 25 dopaminedurations       AGE_RR       0.9790080 0.9043097 1.0598767
# 26 dopaminedurations       AGE_RR       0.9596073 0.8993193 1.0239369
# 27 dopaminedurations       AGE_RR       0.9833787 0.9289361 1.0410121
# 28 dopaminedurations       AGE_RR       1.0489708 0.9962624 1.1044679
# 29 dopaminedurations       AGE_RR       1.0135778 0.9239999 1.1118399
# 30 dopaminedurations       DIAGNOSIS_RR 1.0269871 0.9651809 1.0927510
# 31 dopaminedurations       DIAGNOSIS_RR 1.0291244 0.9347384 1.1330410
# 32 dopaminedurations       DIAGNOSIS_RR 0.9604512 0.9126576 1.0107475
# 33 dopaminedurations       DIAGNOSIS_RR 1.0481328 0.9596613 1.1447605
# 34 dopaminedurations       CAREUNIT_RR  0.8559217 0.8116678 0.9025883
# 35 dopaminedurations       CAREUNIT_RR  1.2119553 1.1450739 1.2827431
# 36 dopaminedurations       CAREUNIT_RR  1.0152682 0.9665074 1.0664891
# 37 dopaminedurations       CAREUNIT_RR  1.0741346 0.9885742 1.1671001
# 38 dopaminedurations       CAREUNIT_RR  1.1343789 1.0448632 1.2315637
# 39 dopaminedurations       INTUB_RR     1.6397495 1.5253769 1.7626976
# 40 dopaminedurations       CVC_RR       1.6689111 1.5215392 1.8305570
# 41 phenylephrinedurations  MALE_RR      0.9236532 0.8892255 0.9594137
# 42 phenylephrinedurations  AGE_RR       1.0320561 0.8678826 1.2272857
# 43 phenylephrinedurations  AGE_RR       0.9923988 0.8623601 1.1420466
# 44 phenylephrinedurations  AGE_RR       1.1042921 1.0178946 1.1980228
# 45 phenylephrinedurations  AGE_RR       0.9474338 0.8938577 1.0042211
# 46 phenylephrinedurations  AGE_RR       0.9593444 0.9156341 1.0051414
# 47 phenylephrinedurations  AGE_RR       0.9724376 0.9312754 1.0154192
# 48 phenylephrinedurations  AGE_RR       1.0779565 1.0325936 1.1253122
# 49 phenylephrinedurations  AGE_RR       1.0055518 0.9155713 1.1043755
# 50 phenylephrinedurations  DIAGNOSIS_RR 0.7755016 0.7398689 0.8128503
# 51 phenylephrinedurations  DIAGNOSIS_RR 1.2924678 1.1998483 1.3922367
# 52 phenylephrinedurations  DIAGNOSIS_RR 1.0919980 1.0488046 1.1369703
# 53 phenylephrinedurations  DIAGNOSIS_RR 1.5806782 1.4996634 1.6660696
# 54 phenylephrinedurations  CAREUNIT_RR  1.2411304 1.1753505 1.3105918
# 55 phenylephrinedurations  CAREUNIT_RR  0.6931998 0.6671911 0.7202224
# 56 phenylephrinedurations  CAREUNIT_RR  1.5205808 1.4663509 1.5768163
# 57 phenylephrinedurations  CAREUNIT_RR  1.0536408 0.9993505 1.1108804
# 58 phenylephrinedurations  CAREUNIT_RR  1.0114803 0.9491347 1.0779212
# 59 phenylephrinedurations  INTUB_RR     1.0729811 1.0059228 1.1445097
# 60 phenylephrinedurations  CVC_RR       1.8158445 1.6792649 1.9635326
#    ID              p            significant
# 1  M               2.226992e-01 FALSE
# 2  20              3.563539e-01 FALSE
# 3  30              7.806508e-01 FALSE
# 4  40              3.495062e-01 FALSE
# 5  50              8.638935e-01 FALSE
# 6  60              4.468820e-01 FALSE
# 7  70              4.289038e-01 FALSE
# 8  80              1.000000e+00 FALSE
# 9  90              2.040189e-01 FALSE
# 10 CARDIAC         8.504497e-10  TRUE
# 11 INFECTION       2.332581e-04  TRUE
# 12 OTHER DIAGNOSIS 5.622658e-03  TRUE
# 13 SEPSIS          1.384458e-09  TRUE
# 14 CCU             1.919101e-03  TRUE
# 15 CSRU            3.238851e-11  TRUE
# 16 MICU            3.792471e-18  TRUE
# 17 SICU            1.103677e-01 FALSE
# 18 TSICU           3.110272e-01 FALSE
# 19 INTUB           1.508288e-63  TRUE
# 20 CVC             9.126769e-12  TRUE
# 21 M               5.516711e-02 FALSE
# 22 20              7.683781e-01 FALSE
# 23 30              1.000000e+00 FALSE
# 24 40              1.000000e+00 FALSE
# 25 50              5.839595e-01 FALSE
# 26 60              2.042259e-01 FALSE
# 27 70              5.830738e-01 FALSE
# 28 80              7.988809e-02 FALSE
# 29 90              8.667125e-01 FALSE
# 30 CARDIAC         4.397928e-01 FALSE
# 31 INFECTION       6.037107e-01 FALSE
# 32 OTHER DIAGNOSIS 1.354178e-01 FALSE
# 33 SEPSIS          3.684680e-01 FALSE
# 34 CCU             2.085604e-09  TRUE
# 35 CSRU            5.074836e-08  TRUE
# 36 MICU            5.786601e-01 FALSE
# 37 SICU            1.284579e-01 FALSE
# 38 TSICU           1.038712e-02  TRUE
# 39 INTUB           1.191326e-59  TRUE
# 40 CVC             3.764507e-43  TRUE
# 41 M               5.365401e-05  TRUE
# 42 20              7.682701e-01 FALSE
# 43 30              9.390835e-01 FALSE
# 44 40              2.576411e-02  TRUE
# 45 50              6.584998e-02 FALSE
# 46 60              8.019923e-02 FALSE
# 47 70              2.057850e-01 FALSE
# 48 80              8.841419e-04  TRUE
# 49 90              9.176459e-01 FALSE
# 50 CARDIAC         1.627009e-29  TRUE
# 51 INFECTION       1.224958e-08  TRUE
# 52 OTHER DIAGNOSIS 1.522979e-05  TRUE
# 53 SEPSIS          9.793611e-30  TRUE
# 54 CCU             4.874223e-12  TRUE
# 55 CSRU            1.430574e-81  TRUE
# 56 MICU            2.804120e-80  TRUE
# 57 SICU            5.929692e-02 FALSE
# 58 TSICU           7.497881e-01 FALSE
# 59 INTUB           2.910021e-02  TRUE
# 60 CVC             5.962662e-74  TRUE

# %%
pressor_rr_df %>% 
    write.csv(file.path(PLOT_DIR, "relativerisk_eachpressor.csv"))

# %% [markdown]
# # Figure 1 Plotting RR

# %%
SIGNIFICANT_COLORS <- c(
"Significant" = '#2F4F4F',
"Not Significant" = '#D3D3D3'
)

# %%
ID_DICT <- c(
'M' = "Male Gender",
'INTUB' = "Intubated",
'CVC' = "CVC Placed",
'20' = "Age 15-25",
'30' = "Age 25-35",
'40' = "Age 35-45",
'50' = "Age 45-55",
'60' = "Age 55-65",
'70' = "Age 65-75",
'80' = "Age 75-85",
'90' = "Age 85-95",
'CARDIAC' = "Cardiac Diagnosis",
'INFECTION' = "Infectious Diagnosis",
'SEPSIS' = "Sepsis Diagnosis",
'OTHER DIAGNOSIS' = "Other Diagnosis",
'CCU' = 'CCU',
'CSRU' = 'CSRU',
'MICU' = 'MICU',
'SICU' = 'SICU',
'TSICU' = 'TSICU'
)

# %%
options(repr.plot.width=3.5, repr.plot.height=4)
p <- calculatePredictors(output_df)  %>%
    rowwise() %>%
    mutate(ID = ID_DICT[ID]) %>% 
    mutate(ID = factor(ID, levels=rev(ID_DICT))) %>%
    mutate(significant = if(significant){'Significant'}else{'Not Significant'}) %>%
    mutate(legend = factor(significant, levels=names(SIGNIFICANT_COLORS))) %>%
    ggplot(aes(x = ID,y = estimate, ymin = lower, ymax = upper ))+
        base_theme() +
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Risk Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=significant),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "relativerisk.pdf"), 3.5,4)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
options(repr.plot.width=7, repr.plot.height=4)
p <- pressor_rr_df  %>%
    rowwise() %>%
    mutate(ID = ID_DICT[ID]) %>% 
    mutate(ID = factor(ID, levels=rev(ID_DICT))) %>%
    mutate(significant = if(significant){'Significant'}else{'Not Significant'}) %>%
    mutate(legend = factor(significant, levels=names(SIGNIFICANT_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x = ID,y = estimate, ymin = lower, ymax = upper ))+
        base_theme() +
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Risk Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=significant),width=0.5,cex=1)+ 
        coord_flip() + 
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, "relativerisk_eachpressor.pdf"), 7,4)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # Vitals

# %% [markdown]
# ### Pre-processing (30 minutes): read in vitals_df, join with output_df of courses and compute mean vitals information each hour -> results_df

# %%
vitals_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/vitals.csv')

# %%
# takes 6 mins to run (because of difftime)

vitals_merged_df <- vitals_df %>%
    mutate(charttime = fastPOSIXct(charttime)) %>%
    filter(icustay_id %in% output_df$icustay_id) %>%
    left_join(select(output_df, icustay_id, course_id, pressor, starttime, endtime, MORETHAN24HOURS, RESPONSE, STATUS), by = "icustay_id") %>%
    rowwise() %>%
    mutate(diff = difftime(charttime, 
                       starttime, units="hours"))

# %%
# for 10 hours prior to pressor initiation
intervals <- 1:10

# %%
results_list <- list()

# %%
# takes 40 mins to run overall
for(interval in intervals){
    # 4 mins to run each
    results_list[[interval]] <- vitals_merged_df %>%
        filter(diff < 0) %>%
        filter(diff < -(interval - 1) & diff > -interval) %>%
        group_by(MORETHAN24HOURS, RESPONSE, STATUS, course_id, pressor) %>%
        summarize(mean_heartrate = mean(heartrate, na.rm=T), 
                  mean_sysbp = mean(sysbp, na.rm=T),
                  mean_diasbp = mean(diasbp, na.rm=T),
                  mean_meanbp = mean(meanbp, na.rm=T), 
                  mean_resprate = mean(resprate, na.rm=T), 
                  mean_tempc = mean(tempc, na.rm=T), 
                  mean_spo2 = mean(spo2, na.rm=T), 
                  mean_glucose = mean(glucose, na.rm=T), 

                  median_heartrate = median(heartrate, na.rm=T), 
                  median_sysbp = median(sysbp, na.rm=T),
                  median_diasbp = median(diasbp, na.rm=T),
                  median_meanbp = median(meanbp, na.rm=T), 
                  median_resprate = median(resprate, na.rm=T), 
                  median_tempc = median(tempc, na.rm=T), 
                  median_spo2 = median(spo2, na.rm=T), 
                  median_glucose = median(glucose, na.rm=T),

                 ) %>%
        mutate(INTERVAL = interval)

}

# %%
results_df <- bind_rows(results_list)

# %%
melt_results_df <- results_df %>% 
    gather("ID", "VALUE", -course_id, -pressor, -MORETHAN24HOURS, -INTERVAL, -STATUS, -RESPONSE)

# %%
melt_results_df %>% write.csv('~/Projects/Haimovich_Pressors/collection/out/melt_summarized_vitals.csv')

# %%
melt_results_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/melt_summarized_vitals.csv')

# %% [markdown]
# ### ANCOVA analysis using intervals
# - MORETHAN24HOURS P-value tells you if this vital sign is a predictor (BP, HR, RR, TEMP)
# - INTERVAL P-value tells you if these values change depending on the interval being measured (most values)
# - MORETHAN24HOURS:INTERVAL P-value tells you if vital sign interacts with the interval being measured, that is, the extent of predictive value differs with time (BP especially, others are borderline significant)

# %%
computeANCOVA <- function(df) {
    vitals_result_list <- list()
    for(vital in unique(melt_results_df$ID)){
        #cat("####", vital, "####")
        totest <- df %>%
             filter(ID == vital)
        test <- summary(aov(VALUE ~ RESPONSE*INTERVAL, data = totest))[[1]]

        vitals_result_list[[vital]] <- data.frame(RESPONSE = test["RESPONSE ", "Pr(>F)"], 
                                                 INTERACTION = test["RESPONSE:INTERVAL", "Pr(>F)"])
    }
    vitals_result_df <- bind_rows(vitals_result_list, .id="ID")
    
    return(vitals_result_df)
}

# %% [markdown]
# # Table 2 (Wilcox and ANCOVA Vitals)

# %%
computeTest <- function(d, value="VALUE", comparison="GROUP"){
    paired_df <- d %>% 
        select(!!rlang::sym(comparison), !!rlang::sym(value)) 
    
    items <- unique(unlist(d[,comparison]))

    result_unpair <- t.test(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, 
       filter(d, !!rlang::sym(comparison) == items[2])$VALUE, paired = FALSE)
    result_wilcox <- wilcox.test(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, 
       filter(d, !!rlang::sym(comparison) == items[2])$VALUE, paired = FALSE)
    
    diff = mean(filter(d, !!rlang::sym(comparison) == items[1])$VALUE) -  
        mean(filter(d, !!rlang::sym(comparison) == items[2])$VALUE)
    
    return(data.frame(list(
                           'P_UNPAIR' = result_unpair$p.value, 
                           'P_WILCOX' = result_wilcox$p.value,
                            'GROUP1' = mean(filter(d, !!rlang::sym(comparison) == items[1])$VALUE),
                            'GROUP2' = mean(filter(d, !!rlang::sym(comparison) == items[2])$VALUE),
                            'DIFF' = diff,
                            'COMPARE' = paste(items[1], items[2], sep ='-'))))
}

# %% [markdown]
# ### Table 2. mean and standard deviation of vitals  for different time status

# %%
# means
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS) %>%
    summarize(MEAN = mean(VALUE)) %>%
    spread(STATUS, MEAN)
# Out:
#    ID               LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# 1  mean_diasbp       55.37023        56.99650       54.93355
# 2  mean_glucose     146.06641       144.46735      153.15957
# 3  mean_heartrate    87.87453        85.61411       91.85647
# 4  mean_meanbp       71.70073        73.68811       70.60429
# 5  mean_resprate     17.36197        17.14523       18.46265
# 6  mean_spo2         97.54037        97.78287       97.10865
# 7  mean_sysbp       106.10209       109.61410      103.94547
# 8  mean_tempc        36.44315        36.37354       36.44021
# 9  median_diasbp     55.22337        56.76997       54.73521
# 10 median_glucose   146.05314       144.43225      153.18050
# 11 median_heartrate  87.84058        85.59988       91.82597
# 12 median_meanbp     71.36790        73.33615       70.30624
# 13 median_resprate   17.29040        17.05895       18.39744
# 14 median_spo2       97.64305        97.88791       97.23224
# 15 median_sysbp     105.86293       109.32813      103.73174
# 16 median_tempc      36.44385        36.37321       36.44027

# %%
# standard deviations
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS) %>%
    summarize(SD = sd(VALUE)) %>%
    spread(STATUS, SD)
# Out:
#    ID               LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# 1  mean_diasbp      12.561892       13.779953      13.401969
# 2  mean_glucose     58.667660       57.857145      69.701030
# 3  mean_heartrate   18.834364       18.682948      20.745076
# 4  mean_meanbp      14.287962       15.269939      15.393831
# 5  mean_resprate     5.697430        5.469036       6.063065
# 6  mean_spo2         4.974435        4.422410       4.743563
# 7  mean_sysbp       18.813130       20.643224      20.088076
# 8  mean_tempc        1.099717        1.140719       1.167412
# 9  median_diasbp    12.731813       13.937027      13.564979
# 10 median_glucose   58.685787       57.872404      69.708234
# 11 median_heartrate 19.034681       18.984539      20.865503
# 12 median_meanbp    14.335506       15.489778      15.549974
# 13 median_resprate   5.782951        5.539065       6.165619
# 14 median_spo2       4.930518        4.347819       4.696539
# 15 median_sysbp     19.380683       21.071123      20.565426
# 16 median_tempc      1.100187        1.141691       1.168624

# %%
# means
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    filter(!grepl(",", pressor)) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS, pressor) %>%
    summarize(MEAN = mean(VALUE)) %>%
    ungroup() %>%
    filter(pressor %in% pressor_choices) %>%
    spread(STATUS, MEAN) %>% arrange(pressor)
# Out:
#    ID               pressor                LESSTHAN24HOURS LESSTHAN6HOURS
# 1  mean_diasbp      dobutaminedurations     59.41122        58.66173
# 2  mean_glucose     dobutaminedurations    153.00000       177.70000
# 3  mean_heartrate   dobutaminedurations     93.11535        92.03482
# 4  mean_meanbp      dobutaminedurations     78.58543        75.35625
# 5  mean_resprate    dobutaminedurations     17.96560        19.27232
# 6  mean_spo2        dobutaminedurations     97.71396        96.94921
# 7  mean_sysbp       dobutaminedurations    118.48107       108.78549
# 8  mean_tempc       dobutaminedurations     36.37134        36.40770
# 9  median_diasbp    dobutaminedurations     59.39103        58.52778
# 10 median_glucose   dobutaminedurations    153.00000       177.70000
# 11 median_heartrate dobutaminedurations     93.06579        91.78571
# 12 median_meanbp    dobutaminedurations     78.60965        75.24703
# 13 median_resprate  dobutaminedurations     18.02564        19.26786
# 14 median_spo2      dobutaminedurations     97.82432        97.00000
# 15 median_sysbp     dobutaminedurations    118.78846       108.72222
# 16 median_tempc     dobutaminedurations     36.37551        36.40505
# 17 mean_diasbp      dopaminedurations       52.53439        54.20228
# 18 mean_glucose     dopaminedurations      182.55769       152.15326
# 19 mean_heartrate   dopaminedurations       80.90746        82.19748
# 20 mean_meanbp      dopaminedurations       69.69977        70.32993
# 21 mean_resprate    dopaminedurations       18.46030        18.86223
# 22 mean_spo2        dopaminedurations       96.27112        96.19783
# 23 mean_sysbp       dopaminedurations      107.48906       107.05429
# 24 mean_tempc       dopaminedurations       36.44029        36.31857
# 25 median_diasbp    dopaminedurations       52.36713        53.83892
# 26 median_glucose   dopaminedurations      182.55769       152.15326
# 27 median_heartrate dopaminedurations       80.77649        82.07209
# 28 median_meanbp    dopaminedurations       69.37105        70.09539
# 29 median_resprate  dopaminedurations       18.35654        18.75152
# 30 median_spo2      dopaminedurations       96.38676        96.43311
# ⋮  ⋮                ⋮                      ⋮               ⋮
# 67 mean_heartrate   phenylephrinedurations  86.58974        84.50412
# 68 mean_meanbp      phenylephrinedurations  73.57685        74.77915
# 69 mean_resprate    phenylephrinedurations  15.99774        15.94075
# 70 mean_spo2        phenylephrinedurations  98.42184        98.59735
# 71 mean_sysbp       phenylephrinedurations 107.50988       110.74625
# 72 mean_tempc       phenylephrinedurations  36.44172        36.39483
# 73 median_diasbp    phenylephrinedurations  56.24985        57.35489
# 74 median_glucose   phenylephrinedurations 136.02221       136.68937
# 75 median_heartrate phenylephrinedurations  86.56542        84.45903
# 76 median_meanbp    phenylephrinedurations  73.23423        74.52307
# 77 median_resprate  phenylephrinedurations  15.90773        15.85811
# 78 median_spo2      phenylephrinedurations  98.52585        98.67038
# 79 median_sysbp     phenylephrinedurations 107.31809       110.65095
# 80 median_tempc     phenylephrinedurations  36.44252        36.39431
# 81 mean_diasbp      vasopressindurations    52.13258        56.25000
# 82 mean_glucose     vasopressindurations   115.66667       165.50000
# 83 mean_heartrate   vasopressindurations    90.76515        89.70833
# 84 mean_meanbp      vasopressindurations    67.03536        71.89167
# 85 mean_resprate    vasopressindurations    18.63333        17.82576
# 86 mean_spo2        vasopressindurations    98.02273        98.00000
# 87 mean_sysbp       vasopressindurations   100.41288       112.68333
# 88 mean_tempc       vasopressindurations    36.89444        36.99074
# 89 median_diasbp    vasopressindurations    52.45455        55.35000
# 90 median_glucose   vasopressindurations   115.66667       165.50000
# 91 median_heartrate vasopressindurations    90.77273        89.70000
# 92 median_meanbp    vasopressindurations    67.18183        71.90000
# 93 median_resprate  vasopressindurations    18.70000        17.81818
# 94 median_spo2      vasopressindurations    98.04545        98.05000
# 95 median_sysbp     vasopressindurations   100.40909       112.02500
# 96 median_tempc     vasopressindurations    36.88333        36.99074
#    MORETHAN24HOURS
# 1   62.37027
# 2  170.64706
# 3   87.64487
# 4   78.86065
# 5   19.13462
# 6   96.81532
# 7  112.85901
# 8   36.65876
# 9   62.39865
# 10 170.64706
# 11  87.65385
# 12  78.95495
# 13  19.08333
# 14  96.82432
# 15 113.33108
# 16  36.65306
# 17  53.15433
# 18 178.99802
# 19  80.49933
# 20  69.44362
# 21  18.65386
# 22  96.36623
# 23 105.05806
# 24  36.21335
# 25  52.86600
# 26 178.99802
# 27  80.42490
# 28  68.90054
# 29  18.59943
# 30  96.48577
# ⋮  ⋮
# 67  87.46379
# 68  74.40752
# 69  16.62107
# 70  98.32276
# 71 108.03067
# 72  36.47425
# 73  57.00810
# 74 131.96296
# 75  87.42518
# 76  74.05765
# 77  16.53996
# 78  98.43710
# 79 107.91389
# 80  36.47474
# 81  51.99206
# 82 148.70000
# 83  91.68417
# 84  69.75615
# 85  20.31579
# 86  96.15833
# 87 109.40159
# 88  36.67361
# 89  52.50000
# 90 148.70000
# 91  92.32500
# 92  69.94738
# 93  20.25000
# 94  96.02500
# 95 109.16667
# 96  36.67361

# %%
# standard deviations
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    filter(!grepl(",", pressor)) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS, pressor) %>%
    summarize(SD = sd(VALUE)) %>%
    ungroup() %>%
    filter(pressor %in% pressor_choices) %>%
    spread(STATUS, SD) %>% arrange(pressor)
# Out:
#    ID               pressor                LESSTHAN24HOURS LESSTHAN6HOURS
# 1  mean_diasbp      dobutaminedurations    13.2121293      12.3186727
# 2  mean_glucose     dobutaminedurations    70.2890856      56.9640237
# 3  mean_heartrate   dobutaminedurations    19.2109650      20.7838561
# 4  mean_meanbp      dobutaminedurations    12.9471320      16.7683928
# 5  mean_resprate    dobutaminedurations     6.1972842       5.3561011
# 6  mean_spo2        dobutaminedurations     2.5189514       3.0642106
# 7  mean_sysbp       dobutaminedurations    14.0865003      23.7966779
# 8  mean_tempc       dobutaminedurations     0.9577694       0.6543347
# 9  median_diasbp    dobutaminedurations    13.1056932      12.4387602
# 10 median_glucose   dobutaminedurations    70.2890856      56.9640237
# 11 median_heartrate dobutaminedurations    19.1925419      20.9290816
# 12 median_meanbp    dobutaminedurations    12.7591626      17.0026847
# 13 median_resprate  dobutaminedurations     6.3203397       5.3515006
# 14 median_spo2      dobutaminedurations     2.4726735       3.1017237
# 15 median_sysbp     dobutaminedurations    14.3973840      24.1335759
# 16 median_tempc     dobutaminedurations     0.9598062       0.6555814
# 17 mean_diasbp      dopaminedurations      12.6981575      15.7414862
# 18 mean_glucose     dopaminedurations      88.1267528      62.5069000
# 19 mean_heartrate   dopaminedurations      20.4372250      20.8521077
# 20 mean_meanbp      dopaminedurations      13.9471450      16.8154433
# 21 mean_resprate    dopaminedurations       4.9760396       5.1708550
# 22 mean_spo2        dopaminedurations       5.1070321       5.6676417
# 23 mean_sysbp       dopaminedurations      21.3835041      22.2415951
# 24 mean_tempc       dopaminedurations       1.0030549       1.0259190
# 25 median_diasbp    dopaminedurations      12.7539400      15.7443318
# 26 median_glucose   dopaminedurations      88.1267528      62.5069000
# 27 median_heartrate dopaminedurations      20.7841432      21.1964479
# 28 median_meanbp    dopaminedurations      14.1772097      17.2781083
# 29 median_resprate  dopaminedurations       5.0571414       5.2887289
# 30 median_spo2      dopaminedurations       5.1258872       5.4107035
# ⋮  ⋮                ⋮                      ⋮               ⋮
# 67 mean_heartrate   phenylephrinedurations 16.919962       16.3036477
# 68 mean_meanbp      phenylephrinedurations 12.953287       13.6815388
# 69 mean_resprate    phenylephrinedurations  5.164883        4.8847757
# 70 mean_spo2        phenylephrinedurations  3.824494        2.8531783
# 71 mean_sysbp       phenylephrinedurations 16.896423       18.8634551
# 72 mean_tempc       phenylephrinedurations  1.004268        1.0749473
# 73 median_diasbp    phenylephrinedurations 11.113137       11.8904560
# 74 median_glucose   phenylephrinedurations 43.217669       41.2620486
# 75 median_heartrate phenylephrinedurations 17.111790       16.4604118
# 76 median_meanbp    phenylephrinedurations 12.858801       13.8556676
# 77 median_resprate  phenylephrinedurations  5.240939        4.9066007
# 78 median_spo2      phenylephrinedurations  3.739053        2.8247994
# 79 median_sysbp     phenylephrinedurations 17.596199       19.3223879
# 80 median_tempc     phenylephrinedurations  1.006029        1.0762722
# 81 mean_diasbp      vasopressindurations   10.994519       12.8116700
# 82 mean_glucose     vasopressindurations   13.428825       29.9624765
# 83 mean_heartrate   vasopressindurations   17.546479       29.3714832
# 84 mean_meanbp      vasopressindurations   13.384647       13.6787447
# 85 mean_resprate    vasopressindurations    6.273991        5.6043701
# 86 mean_spo2        vasopressindurations    2.020070        1.9578900
# 87 mean_sysbp       vasopressindurations   19.888932       21.2229785
# 88 mean_tempc       vasopressindurations    1.057790        0.6180581
# 89 median_diasbp    vasopressindurations   10.631215       13.2624156
# 90 median_glucose   vasopressindurations   13.428825       29.9624765
# 91 median_heartrate vasopressindurations   17.561839       29.3874501
# 92 median_meanbp    vasopressindurations   13.231783       14.4737310
# 93 median_resprate  vasopressindurations    6.236986        5.6580594
# 94 median_spo2      vasopressindurations    2.030450        2.0062403
# 95 median_sysbp     vasopressindurations   19.855501       21.3880970
# 96 median_tempc     vasopressindurations    1.072999        0.6180581
#    MORETHAN24HOURS
# 1  11.350842
# 2  87.109982
# 3  16.564982
# 4  14.357230
# 5   6.376745
# 6   2.423453
# 7  23.766242
# 8   1.336907
# 9  11.189879
# 10 87.109982
# 11 16.599046
# 12 14.461071
# 13  6.403724
# 14  2.415851
# 15 23.919429
# 16  1.343570
# 17 15.164823
# 18 96.148084
# 19 19.952438
# 20 15.066432
# 21  5.397314
# 22  5.163844
# 23 21.487341
# 24  1.037487
# 25 15.229257
# 26 96.148084
# 27 20.164214
# 28 15.240791
# 29  5.412615
# 30  5.204668
# ⋮  ⋮
# 67 18.9333302
# 68 14.8542605
# 69  5.3544315
# 70  3.1320240
# 71 19.1253800
# 72  0.9794823
# 73 11.7520133
# 74 38.7587374
# 75 19.0616128
# 76 14.9776459
# 77  5.4568913
# 78  3.0710014
# 79 19.7766840
# 80  0.9792394
# 81 12.5303494
# 82 55.3868215
# 83 16.5187555
# 84 13.0521376
# 85  5.4961111
# 86  4.4319002
# 87 20.2971275
# 88  0.3382171
# 89 13.1937485
# 90 55.3868215
# 91 17.6696849
# 92 13.0606430
# 93  5.4128191
# 94  4.7751412
# 95 19.9695602
# 96  0.3382171

# %% [markdown]
# ### Wilcox for significant difference at <1 hr before start of pressors

# %% [markdown]
# All pressors

# %%
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID) %>%
    do(computeTest(.,value="VALUE", comparison="RESPONSE")) %>%
    mutate(significant = P_WILCOX < 0.05)
# Out:
#    ID               P_UNPAIR     P_WILCOX     GROUP1    GROUP2    DIFF
# 1  mean_diasbp      1.101452e-08 3.261272e-12  56.31367  54.87639   1.43727392
# 2  mean_glucose     6.839439e-13 1.393181e-08 142.76269 154.13758 -11.37488696
# 3  mean_heartrate   2.545628e-56 1.031978e-55  86.00262  91.85977  -5.85714792
# 4  mean_meanbp      9.042397e-18 1.581916e-24  72.97114  70.52538   2.44576033
# 5  mean_resprate    2.045813e-44 5.037580e-42  17.00707  18.48530  -1.47823868
# 6  mean_spo2        8.426036e-28 3.891507e-33  97.92432  96.94168   0.98263968
# 7  mean_sysbp       3.096190e-32 5.683846e-42 108.32635 103.86175   4.46460288
# 8  mean_tempc       5.603909e-01 3.707439e-01  36.43498  36.41712   0.01785834
# 9  median_diasbp    3.557355e-09 1.194926e-12  56.16053  54.65767   1.50285421
# 10 median_glucose   5.756899e-13 1.263025e-08 142.73817 154.15278 -11.41460483
# 11 median_heartrate 1.898496e-55 4.911637e-55  85.97032  91.83575  -5.86543446
# 12 median_meanbp    6.014213e-18 2.450548e-25  72.66735  70.18741   2.47993966
# 13 median_resprate  6.359650e-44 9.049473e-41  16.92771  18.41940  -1.49168780
# 14 median_spo2      1.016370e-26 2.428482e-31  98.02029  97.06882   0.95146318
# 15 median_sysbp     2.275351e-31 2.827854e-41 108.11121 103.60197   4.50924040
# 16 median_tempc     5.627781e-01 3.723168e-01  36.43512  36.41736   0.01776408
#    COMPARE    significant
# 1  FALSE-TRUE  TRUE
# 2  FALSE-TRUE  TRUE
# 3  FALSE-TRUE  TRUE
# 4  FALSE-TRUE  TRUE
# 5  FALSE-TRUE  TRUE
# 6  FALSE-TRUE  TRUE
# 7  FALSE-TRUE  TRUE
# 8  FALSE-TRUE FALSE
# 9  FALSE-TRUE  TRUE
# 10 FALSE-TRUE  TRUE
# 11 FALSE-TRUE  TRUE
# 12 FALSE-TRUE  TRUE
# 13 FALSE-TRUE  TRUE
# 14 FALSE-TRUE  TRUE
# 15 FALSE-TRUE  TRUE
# 16 FALSE-TRUE FALSE

# %% [markdown]
# Pressors by type

# %%
melt_results_df %>%
    filter(!grepl(",", pressor)) %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    mutate(pressor = factor(pressor, levels=pressor_choices)) %>%
    group_by(ID, pressor) %>%
    do(computeTest(.,value="VALUE", comparison="RESPONSE")) %>%
    mutate(significant = P_WILCOX < 0.05) %>%
    arrange(pressor)
# Out:
# Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”
#    ID               pressor                 P_UNPAIR     P_WILCOX     GROUP1
# 1  mean_diasbp      norepinephrinedurations 2.380075e-03 3.252469e-04  55.81099
# 2  mean_glucose     norepinephrinedurations 4.793384e-02 5.977964e-02 162.70839
# 3  mean_heartrate   norepinephrinedurations 3.060525e-03 1.202861e-03  88.75726
# 4  mean_meanbp      norepinephrinedurations 5.996111e-05 4.914404e-07  70.55805
# 5  mean_resprate    norepinephrinedurations 4.954806e-06 2.567574e-06  19.20021
# 6  mean_spo2        norepinephrinedurations 6.730529e-02 8.750777e-03  97.12409
# 7  mean_sysbp       norepinephrinedurations 8.843570e-07 5.817102e-09 105.60703
# 8  mean_tempc       norepinephrinedurations 3.409375e-01 3.954186e-01  36.55410
# 9  median_diasbp    norepinephrinedurations 2.309440e-03 3.882486e-04  55.64669
# 10 median_glucose   norepinephrinedurations 4.723087e-02 5.799217e-02 162.74066
# 11 median_heartrate norepinephrinedurations 3.033372e-03 1.028850e-03  88.74682
# 12 median_meanbp    norepinephrinedurations 9.709552e-05 1.060597e-06  70.23343
# 13 median_resprate  norepinephrinedurations 5.009329e-06 2.191448e-06  19.15313
# 14 median_spo2      norepinephrinedurations 6.392836e-02 4.981474e-03  97.20017
# 15 median_sysbp     norepinephrinedurations 2.874969e-06 2.460876e-08 105.28854
# 16 median_tempc     norepinephrinedurations 3.504322e-01 3.975570e-01  36.55420
# 17 mean_diasbp      dopaminedurations       8.231099e-01 5.393348e-01  53.40592
# 18 mean_glucose     dopaminedurations       3.037491e-01 6.774531e-01 166.52626
# 19 mean_heartrate   dopaminedurations       4.730140e-01 5.961324e-01  81.57712
# 20 mean_meanbp      dopaminedurations       6.106695e-01 4.152978e-01  70.02859
# 21 mean_resprate    dopaminedurations       9.644712e-01 7.284319e-01  18.67120
# 22 mean_spo2        dopaminedurations       7.390888e-01 8.161740e-01  96.23373
# 23 mean_sysbp       dopaminedurations       1.757279e-01 9.623370e-02 107.26153
# 24 mean_tempc       dopaminedurations       2.263770e-01 1.499710e-01  36.37911
# 25 median_diasbp    dopaminedurations       8.109134e-01 5.649526e-01  53.13620
# 26 median_glucose   dopaminedurations       3.037491e-01 6.774531e-01 166.52626
# 27 median_heartrate dopaminedurations       5.006281e-01 6.478980e-01  81.44904
# 28 median_meanbp    dopaminedurations       4.670319e-01 3.238045e-01  69.74902
# 29 median_resprate  dopaminedurations       9.276263e-01 8.868165e-01  18.56380
# 30 median_spo2      dopaminedurations       8.494668e-01 8.088968e-01  96.41041
# ⋮  ⋮                ⋮                       ⋮            ⋮            ⋮
# 67 mean_heartrate   epinephrinedurations    0.0177089179 0.008419644   85.57752
# 68 mean_meanbp      epinephrinedurations    0.0004648869 0.001340571   79.73992
# 69 mean_resprate    epinephrinedurations    0.0643059426 0.012767725   13.95287
# 70 mean_spo2        epinephrinedurations    0.4565820541 0.692038176   99.22426
# 71 mean_sysbp       epinephrinedurations    0.0051058879 0.002121824  119.91791
# 72 mean_tempc       epinephrinedurations    0.1642799864 0.215305784   36.01757
# 73 median_diasbp    epinephrinedurations    0.0125867700 0.027484729   59.41729
# 74 median_glucose   epinephrinedurations    0.1025344754 0.056922871  139.83939
# 75 median_heartrate epinephrinedurations    0.0220700991 0.011441525   85.87218
# 76 median_meanbp    epinephrinedurations    0.0032215458 0.006409470   79.30702
# 77 median_resprate  epinephrinedurations    0.0825531173 0.029439365   13.81447
# 78 median_spo2      epinephrinedurations    0.4538460378 0.831021121   99.30515
# 79 median_sysbp     epinephrinedurations    0.0107602580 0.006011695  119.81391
# 80 median_tempc     epinephrinedurations    0.1832981296 0.236055001   36.01696
# 81 mean_diasbp      dobutaminedurations     0.1843358247 0.095418887   59.10461
# 82 mean_glucose     dobutaminedurations     0.7115388431 0.909390867  161.51724
# 83 mean_heartrate   dobutaminedurations     0.1669475267 0.147255109   92.65694
# 84 mean_meanbp      dobutaminedurations     0.5813541182 0.969837842   77.21548
# 85 mean_resprate    dobutaminedurations     0.6187810077 0.762934739   18.51169
# 86 mean_spo2        dobutaminedurations     0.2911683229 0.192233076   97.37154
# 87 mean_sysbp       dobutaminedurations     0.7178404318 0.304018135  114.51470
# 88 mean_tempc       dobutaminedurations     0.4168553554 0.160382764   36.38346
# 89 median_diasbp    dobutaminedurations     0.1682488274 0.083093170   59.03788
# 90 median_glucose   dobutaminedurations     0.7115388431 0.909390867  161.51724
# 91 median_heartrate dobutaminedurations     0.1803161265 0.160592046   92.52273
# 92 median_meanbp    dobutaminedurations     0.5547289414 0.844648561   77.18308
# 93 median_resprate  dobutaminedurations     0.6690932337 0.805612797   18.54478
# 94 median_spo2      dobutaminedurations     0.2307857167 0.147355676   97.45522
# 95 median_sysbp     dobutaminedurations     0.7721214051 0.344488781  114.67045
# 96 median_tempc     dobutaminedurations     0.4316945396 0.168715331   36.38535
#    GROUP2    DIFF         COMPARE    significant
# 1   53.69076   2.12023012 FALSE-TRUE  TRUE
# 2  151.60551  11.10288021 FALSE-TRUE FALSE
# 3   91.46629  -2.70903315 FALSE-TRUE  TRUE
# 4   67.47999   3.07806070 FALSE-TRUE  TRUE
# 5   20.43339  -1.23317687 FALSE-TRUE  TRUE
# 6   96.71670   0.40738285 FALSE-TRUE  TRUE
# 7  100.78033   4.82670330 FALSE-TRUE  TRUE
# 8   36.63706  -0.08295573 FALSE-TRUE FALSE
# 9   53.49656   2.15013441 FALSE-TRUE  TRUE
# 10 151.60551  11.13515315 FALSE-TRUE FALSE
# 11  91.47629  -2.72947198 FALSE-TRUE  TRUE
# 12  67.24576   2.98766801 FALSE-TRUE  TRUE
# 13  20.40303  -1.24990689 FALSE-TRUE  TRUE
# 14  96.78491   0.41525779 FALSE-TRUE  TRUE
# 15 100.62638   4.66216173 FALSE-TRUE  TRUE
# 16  36.63559  -0.08139018 FALSE-TRUE FALSE
# 17  53.15433   0.25159364 FALSE-TRUE FALSE
# 18 178.99802 -12.47175325 FALSE-TRUE FALSE
# 19  80.49933   1.07778808 FALSE-TRUE FALSE
# 20  69.44362   0.58497556 FALSE-TRUE FALSE
# 21  18.65386   0.01734632 FALSE-TRUE FALSE
# 22  96.36623  -0.13249944 FALSE-TRUE FALSE
# 23 105.05806   2.20346919 FALSE-TRUE FALSE
# 24  36.21335   0.16575834 FALSE-TRUE FALSE
# 25  52.86600   0.27019922 FALSE-TRUE FALSE
# 26 178.99802 -12.47175325 FALSE-TRUE FALSE
# 27  80.42490   1.02414340 FALSE-TRUE FALSE
# 28  68.90054   0.84848484 FALSE-TRUE FALSE
# 29  18.59943  -0.03563596 FALSE-TRUE FALSE
# 30  96.48577  -0.07536280 FALSE-TRUE FALSE
# ⋮  ⋮         ⋮            ⋮          ⋮
# 67  93.08030  -7.5027867  FALSE-TRUE  TRUE
# 68  70.10114   9.6387874  FALSE-TRUE  TRUE
# 69  15.93261  -1.9797392  FALSE-TRUE  TRUE
# 70  98.73519   0.4890702  FALSE-TRUE FALSE
# 71 108.24083  11.6770795  FALSE-TRUE  TRUE
# 72  36.46456  -0.4469821  FALSE-TRUE FALSE
# 73  53.68421   5.7330827  FALSE-TRUE  TRUE
# 74 160.97727 -21.1378788  FALSE-TRUE FALSE
# 75  93.20000  -7.3278195  FALSE-TRUE  TRUE
# 76  70.90000   8.4070175  FALSE-TRUE  TRUE
# 77  15.70238  -1.8879155  FALSE-TRUE  TRUE
# 78  98.80556   0.4995915  FALSE-TRUE FALSE
# 79 109.57895  10.2349624  FALSE-TRUE  TRUE
# 80  36.45556  -0.4385961  FALSE-TRUE FALSE
# 81  62.37027  -3.2656617  FALSE-TRUE FALSE
# 82 170.64706  -9.1298174  FALSE-TRUE FALSE
# 83  87.64487   5.0120726  FALSE-TRUE FALSE
# 84  78.86065  -1.6451770  FALSE-TRUE FALSE
# 85  19.13462  -0.6229238  FALSE-TRUE FALSE
# 86  96.81532   0.5562199  FALSE-TRUE FALSE
# 87 112.85901   1.6556916  FALSE-TRUE FALSE
# 88  36.65876  -0.2752996  FALSE-TRUE FALSE
# 89  62.39865  -3.3607699  FALSE-TRUE FALSE
# 90 170.64706  -9.1298174  FALSE-TRUE FALSE
# 91  87.65385   4.8688811  FALSE-TRUE FALSE
# 92  78.95495  -1.7718671  FALSE-TRUE FALSE
# 93  19.08333  -0.5385572  FALSE-TRUE FALSE
# 94  96.82432   0.6308996  FALSE-TRUE FALSE
# 95 113.33108   1.3393735  FALSE-TRUE FALSE
# 96  36.65306  -0.2677021  FALSE-TRUE FALSE

# %% [markdown]
# ### ANCOVA for significant differences summarized

# %% [markdown]
# Total pressors

# %%
ancova_significance_df <- computeANCOVA(melt_results_df) %>% mutate(
    response_significant = RESPONSE < 0.05, 
    interaction_interaction = INTERACTION < 0.05) %>%
    rename(response_pvalue = RESPONSE, interaction_pvalue = INTERACTION, vital_sign = ID)
ancova_significance_df
# Out:
#    vital_sign       response_pvalue interaction_pvalue response_significant
# 1  mean_heartrate   5.961964e-134   5.046172e-04        TRUE
# 2  mean_sysbp       5.942932e-110   8.620336e-02        TRUE
# 3  mean_diasbp       1.825862e-11   1.657407e-01        TRUE
# 4  mean_meanbp       3.567647e-40   2.388032e-01        TRUE
# 5  mean_resprate    2.104938e-177   6.048216e-01        TRUE
# 6  mean_tempc        4.812561e-01   9.785645e-01       FALSE
# 7  mean_spo2         4.189830e-95   2.649890e-06        TRUE
# 8  mean_glucose      6.287661e-33   6.558040e-03        TRUE
# 9  median_heartrate 5.240860e-134   4.944930e-04        TRUE
# 10 median_sysbp     5.276590e-108   8.941695e-02        TRUE
# 11 median_diasbp     9.556956e-12   1.191279e-01        TRUE
# 12 median_meanbp     8.481807e-40   1.998433e-01        TRUE
# 13 median_resprate  3.388680e-178   5.914249e-01        TRUE
# 14 median_tempc      4.725661e-01   9.741596e-01       FALSE
# 15 median_spo2       3.593085e-94   1.380734e-05        TRUE
# 16 median_glucose    4.546459e-33   6.321872e-03        TRUE
#    interaction_interaction
# 1   TRUE
# 2  FALSE
# 3  FALSE
# 4  FALSE
# 5  FALSE
# 6  FALSE
# 7   TRUE
# 8   TRUE
# 9   TRUE
# 10 FALSE
# 11 FALSE
# 12 FALSE
# 13 FALSE
# 14 FALSE
# 15  TRUE
# 16  TRUE

# %%
ancova_significance_df %>% write.csv(file.path(PLOT_DIR, "ancovasignificance.csv"))

# %% [markdown]
# Pressors by type

# %%
pressors_vitals_rr_list <- list()
for(pressor_choice in pressor_choices){
    pressors_vitals_rr_list[[pressor_choice]] <- melt_results_df %>%
        filter(grepl(pressor_choice, pressor)) %>%
        computeANCOVA() %>%
        mutate(
            response_significant = RESPONSE < 0.05, 
            interaction_interaction = INTERACTION < 0.05)
}

pressors_vitals_rr_df <- bind_rows(pressors_vitals_rr_list, .id="pressor")

# %%
ancova_significance_eachpressor_df <- pressors_vitals_rr_df %>%
    rename(response_pvalue = RESPONSE, interaction_pvalue = INTERACTION, vital_sign = ID)
ancova_significance_eachpressor_df
# Out:
#    pressor                 vital_sign       response_pvalue interaction_pvalue
# 1  norepinephrinedurations mean_heartrate   4.967742e-34    2.316237e-04
# 2  norepinephrinedurations mean_sysbp       2.415438e-15    7.786015e-01
# 3  norepinephrinedurations mean_diasbp      5.585522e-01    1.081975e-02
# 4  norepinephrinedurations mean_meanbp      2.578338e-02    1.706577e-01
# 5  norepinephrinedurations mean_resprate    1.342474e-30    4.752885e-02
# 6  norepinephrinedurations mean_tempc       1.956959e-02    4.795913e-01
# 7  norepinephrinedurations mean_spo2        2.295970e-11    2.465466e-05
# 8  norepinephrinedurations mean_glucose     1.744276e-01    5.946501e-01
# 9  norepinephrinedurations median_heartrate 6.240282e-34    2.428656e-04
# 10 norepinephrinedurations median_sysbp     3.098966e-15    8.253883e-01
# 11 norepinephrinedurations median_diasbp    6.130433e-01    7.716120e-03
# 12 norepinephrinedurations median_meanbp    2.059953e-02    1.497376e-01
# 13 norepinephrinedurations median_resprate  1.811313e-30    5.105618e-02
# 14 norepinephrinedurations median_tempc     1.948344e-02    4.760003e-01
# 15 norepinephrinedurations median_spo2      8.765791e-11    4.775385e-05
# 16 norepinephrinedurations median_glucose   1.647721e-01    5.871766e-01
# 17 dopaminedurations       mean_heartrate   1.548276e-44    7.384334e-01
# 18 dopaminedurations       mean_sysbp       3.294210e-20    2.317535e-01
# 19 dopaminedurations       mean_diasbp      3.361494e-02    4.448810e-01
# 20 dopaminedurations       mean_meanbp      2.092103e-07    3.205233e-01
# 21 dopaminedurations       mean_resprate    6.824437e-11    4.827165e-01
# 22 dopaminedurations       mean_tempc       4.657900e-01    9.887465e-01
# 23 dopaminedurations       mean_spo2        7.572161e-09    3.623562e-01
# 24 dopaminedurations       mean_glucose     7.381763e-04    8.362870e-02
# 25 dopaminedurations       median_heartrate 1.062580e-44    6.991584e-01
# 26 dopaminedurations       median_sysbp     6.516255e-20    2.095727e-01
# 27 dopaminedurations       median_diasbp    3.468566e-02    4.279247e-01
# 28 dopaminedurations       median_meanbp    2.003231e-07    3.663744e-01
# 29 dopaminedurations       median_resprate  1.031728e-10    5.419627e-01
# 30 dopaminedurations       median_tempc     4.700602e-01    9.887741e-01
# ⋮  ⋮                       ⋮                ⋮               ⋮
# 67 epinephrinedurations    mean_diasbp      5.103073e-01    0.0046936480
# 68 epinephrinedurations    mean_meanbp      5.224897e-02    0.0743238635
# 69 epinephrinedurations    mean_resprate    2.986644e-23    0.0100106091
# 70 epinephrinedurations    mean_tempc       1.318613e-02    0.4117006881
# 71 epinephrinedurations    mean_spo2        5.994727e-10    0.0002520398
# 72 epinephrinedurations    mean_glucose     2.040895e-01    0.3555549406
# 73 epinephrinedurations    median_heartrate 5.032390e-32    0.0012429369
# 74 epinephrinedurations    median_sysbp     3.018770e-17    0.8811870707
# 75 epinephrinedurations    median_diasbp    5.535624e-01    0.0036229899
# 76 epinephrinedurations    median_meanbp    4.329405e-02    0.0740662535
# 77 epinephrinedurations    median_resprate  4.454951e-23    0.0104476455
# 78 epinephrinedurations    median_tempc     1.333840e-02    0.4127603594
# 79 epinephrinedurations    median_spo2      2.344124e-09    0.0004618261
# 80 epinephrinedurations    median_glucose   1.842149e-01    0.3424343880
# 81 dobutaminedurations     mean_heartrate   1.459392e-01    0.9851038328
# 82 dobutaminedurations     mean_sysbp       6.862264e-08    0.0541340725
# 83 dobutaminedurations     mean_diasbp      6.449587e-03    0.1590383766
# 84 dobutaminedurations     mean_meanbp      1.197751e-03    0.0094051564
# 85 dobutaminedurations     mean_resprate    3.534740e-01    0.5397716476
# 86 dobutaminedurations     mean_tempc       9.051434e-01    0.1118737691
# 87 dobutaminedurations     mean_spo2        1.420650e-01    0.1937910694
# 88 dobutaminedurations     mean_glucose     1.664549e-01    0.5286628184
# 89 dobutaminedurations     median_heartrate 1.379814e-01    0.9610003134
# 90 dobutaminedurations     median_sysbp     5.364651e-08    0.0436413831
# 91 dobutaminedurations     median_diasbp    6.477287e-03    0.1253734265
# 92 dobutaminedurations     median_meanbp    7.102030e-04    0.0062327373
# 93 dobutaminedurations     median_resprate  3.825351e-01    0.6121885334
# 94 dobutaminedurations     median_tempc     9.140816e-01    0.1143493400
# 95 dobutaminedurations     median_spo2      2.119268e-01    0.2258318416
# 96 dobutaminedurations     median_glucose   1.641387e-01    0.5339505544
#    response_significant interaction_interaction
# 1   TRUE                 TRUE
# 2   TRUE                FALSE
# 3  FALSE                 TRUE
# 4   TRUE                FALSE
# 5   TRUE                 TRUE
# 6   TRUE                FALSE
# 7   TRUE                 TRUE
# 8  FALSE                FALSE
# 9   TRUE                 TRUE
# 10  TRUE                FALSE
# 11 FALSE                 TRUE
# 12  TRUE                FALSE
# 13  TRUE                FALSE
# 14  TRUE                FALSE
# 15  TRUE                 TRUE
# 16 FALSE                FALSE
# 17  TRUE                FALSE
# 18  TRUE                FALSE
# 19  TRUE                FALSE
# 20  TRUE                FALSE
# 21  TRUE                FALSE
# 22 FALSE                FALSE
# 23  TRUE                FALSE
# 24  TRUE                FALSE
# 25  TRUE                FALSE
# 26  TRUE                FALSE
# 27  TRUE                FALSE
# 28  TRUE                FALSE
# 29  TRUE                FALSE
# 30 FALSE                FALSE
# ⋮  ⋮                    ⋮
# 67 FALSE                 TRUE
# 68 FALSE                FALSE
# 69  TRUE                 TRUE
# 70  TRUE                FALSE
# 71  TRUE                 TRUE
# 72 FALSE                FALSE
# 73  TRUE                 TRUE
# 74  TRUE                FALSE
# 75 FALSE                 TRUE
# 76  TRUE                FALSE
# 77  TRUE                 TRUE
# 78  TRUE                FALSE
# 79  TRUE                 TRUE
# 80 FALSE                FALSE
# 81 FALSE                FALSE
# 82  TRUE                FALSE
# 83  TRUE                FALSE
# 84  TRUE                 TRUE
# 85 FALSE                FALSE
# 86 FALSE                FALSE
# 87 FALSE                FALSE
# 88 FALSE                FALSE
# 89 FALSE                FALSE
# 90  TRUE                 TRUE
# 91  TRUE                FALSE
# 92  TRUE                 TRUE
# 93 FALSE                FALSE
# 94 FALSE                FALSE
# 95 FALSE                FALSE
# 96 FALSE                FALSE

# %%
ancova_significance_eachpressor_df %>% write.csv(file.path(PLOT_DIR, "ancovasignificance_eachpressor.csv"))

# %% [markdown]
# # Figure 2 ANCOVA Plotting

# %% [markdown]
# Total pressors

# %%
FANCY_VITAL_ORDER <- c('MAP', 'HR', 'RR', 'SpO2', 'Temperature', 'Glucose')

# %%
FANCY_VITAL_DICT <- c(
    'mean_meanbp' = 'MAP', 
    'mean_heartrate' = 'HR', 
    'mean_resprate' = 'RR', 
    'mean_spo2' = 'SpO2', 
    'mean_tempc' = 'Temperature', 
    'mean_glucose' = 'Glucose')

# %%
PRESSORHOURS_COLORS <- c(
"Prolonged or multiple vasopressor" = '#2F4F4F',
"No prolonged or multiple vasopressor" = '#D3D3D3'
)

# %%
toplot <- melt_results_df %>%
    mutate(INTERVAL = -INTERVAL) %>%
    drop_na(VALUE) %>%
    filter(grepl("mean_", ID), ID != "mean_diasbp", ID != "mean_sysbp")

# %%
toplot <- toplot %>%
    rowwise() %>%
    mutate(ID = as.character(ID)) %>%
    mutate(FANCY_VITAL = FANCY_VITAL_DICT[ID]) %>%
    mutate(FANCY_VITAL = factor(FANCY_VITAL, levels=FANCY_VITAL_ORDER)) %>%
    mutate(FANCY_RESPONSE = if(RESPONSE){"Prolonged or multiple vasopressor"}else{"No prolonged or multiple vasopressor"})

# %%
options(repr.plot.width=7, repr.plot.height=2.5)

p <- toplot %>%
    ggplot(aes(x=INTERVAL, y=VALUE, color=FANCY_RESPONSE)) +
        geom_smooth(method=lm, aes(fill=FANCY_RESPONSE)) + 
        xlab("Hours before vasopressors") + ylab("Vital Sign") +
        scale_x_continuous(limits=c(-10,0), breaks=seq(-10,0,5)) +
        base_theme() + 
        scale_color_manual(values=PRESSORHOURS_COLORS)+
        scale_fill_manual(values=PRESSORHOURS_COLORS)+
        theme(legend.title = element_blank()) +
        theme(legend.position="bottom") +
        facet_wrap(. ~ FANCY_VITAL, scale="free", nrow=1)
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, "ancova_vitals.pdf"), 7,2.5)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# Pressors by type

# %%
pressor_choices
# Out:
# [1] "norepinephrinedurations" "dopaminedurations"
# [3] "phenylephrinedurations"  "vasopressindurations"
# [5] "epinephrinedurations"    "dobutaminedurations"

# %%
options(repr.plot.width=7, repr.plot.height=2.5)
for(pressor_choice in pressor_choices){
    toplot <- melt_results_df %>%
        filter(!grepl(",", pressor)) %>%
        mutate(INTERVAL = -INTERVAL) %>%
        drop_na(VALUE) %>%
        filter(pressor == pressor_choice, grepl("mean_", ID), ID != "mean_diasbp", ID != "mean_sysbp") %>%
        rowwise() %>%
        mutate(ID = as.character(ID)) %>%
        mutate(FANCY_VITAL = FANCY_VITAL_DICT[ID]) %>%
        mutate(FANCY_VITAL = factor(FANCY_VITAL, levels=FANCY_VITAL_ORDER)) %>%
        mutate(FANCY_RESPONSE = if(RESPONSE){"Prolonged or multiple vasopressor"}else{"No prolonged or multiple vasopressor"})

    p <- ggplot(toplot, aes(x=INTERVAL, y=VALUE, color=FANCY_RESPONSE)) +
        geom_smooth(method=lm, aes(fill=FANCY_RESPONSE)) + 
        xlab("Hours before vasopressors") + ylab("Vitals") +
        scale_x_continuous(limits=c(-10,0), breaks=seq(-10,0,5)) +
        base_theme() + 
        scale_color_manual(values=PRESSORHOURS_COLORS)+
        scale_fill_manual(values=PRESSORHOURS_COLORS)+
        theme(legend.title = element_blank()) +
        theme(legend.position="bottom") +
        facet_wrap(. ~ FANCY_VITAL, scale="free", nrow=1)
    
#     if(pressor_choice == 'phenylephrinedurations'){
#         p <- p + theme(legend.position="bottom")
#     }
    
    plot(p)
    
    pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_ancova_vitals.pdf")), 7,2.5)
    plot(p)
    dev.off()
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # LR Summary

# %%
set.seed(100)

# %%
lr_summary_list <- list()

# %%
LR_CATEGORICAL_COEFFICIENT_DICT <- c(
'genderM' = "Male Gender",
'intubTRUE' = "Intubated",
'simple_diagnosisINFECTION' = "Infectious Diagnosis",   
'simple_diagnosisSEPSIS' = "Sepsis Diagnosis",
'simple_diagnosisOTHER DIAGNOSIS' = "Other Diagnosis",
'pressorphenylephrinedurations' = 'phenylephrine',
'pressornorepinephrinedurations' = 'norepinephrine',
'first_careunitCSRU' = 'CSRU',
'first_careunitSICU' = 'SICU',
'first_careunitMICU' = 'MICU',
'first_careunitTSICU' = 'TSICU'
)

# %%
LR_CONTINUOUS_COEFFICIENT_DICT <- c(
'age_cohort' = 'Age',
'mean_meanbp' = 'MAP',
'mean_resprate' = 'RR',
'mean_heartrate' = 'HR',
'mean_tempc' = 'Temperature',
'mean_spo2' = 'SpO2',
'mean_glucose' = 'Glucose'
)

# %% [markdown]
# ### ROC curve with CI

# %%
roc_with_ci <- function(obj) {
  ciobj <- ci.se(obj, specificities = seq(0, 1, l = 25))
  dat.ci <- data.frame(x = as.numeric(rownames(ciobj)),
                       lower = ciobj[, 1],
                       upper = ciobj[, 3])
  
  ggroc(obj) +
    base_theme() +
    theme(axis.title=element_text(size=10)) +
    geom_abline(
      slope = 1,
      intercept = 1,
      linetype = "dashed",
      alpha = 0.7,
      color = '#2F4F4F'
    ) + coord_equal() +
    geom_ribbon(
      data = dat.ci,
      aes(x = x, ymin = lower, ymax = upper),
      fill = '#2F4F4F',
      alpha = 0.2
    ) 
}

# %% [markdown]
# # LR Model for Total
# - Ran into problems with missing data for glucose, spo2 and tempc, hence the selection of criteria as variables

# %%
model_input_df <- melt_results_df %>%
    filter(INTERVAL == 2) %>%
    select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    rowwise() %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE,
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
             contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate") ,
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 15285    12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model)
# Out:
#                  GVIF     Df GVIF^(1/(2*Df))
# first_careunit   2.156076 4  1.100799
# intub            1.130508 1  1.063253
# simple_diagnosis 1.585638 3  1.079860
# age_cohort       1.151027 1  1.072859
# gender           1.089497 1  1.043790
# mean_meanbp      1.083903 1  1.041107
# mean_resprate    1.452612 1  1.205243
# mean_heartrate   1.363866 1  1.167847
# mean_tempc       1.337124 1  1.156341
# mean_spo2        1.147993 1  1.071444
# mean_glucose     1.109041 1  1.053110

# %%
lr_summary_list[['TOTAL']] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[['TOTAL']]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 0.6603611 0.03198653 0.6432651 0.02660415

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2477    99.49 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2517   101.11 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2534   101.77 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2553   102.55 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |    0.255   102.40 |

# %%
dim(model_input_df)
# Out:
# [1] 15285    12

# %%
dim(model_input_df)
# Out:
# [1] 14637    12

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %% [markdown]
# #### Model parameter significance

# %%
summary(model)
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.7866  -1.1296   0.8327   1.1057   1.7512
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                     -0.4437934  0.2068444  -2.146 0.031909 *
# mean_meanbp                     -0.0039561  0.0014028  -2.820 0.004801 **
# mean_resprate                    0.0132195  0.0039247   3.368 0.000756 ***
# mean_heartrate                   0.0043260  0.0011982   3.611 0.000306 ***
# mean_tempc                       0.0043113  0.0091776   0.470 0.638520
# mean_spo2                       -0.0077686  0.0033670  -2.307 0.021039 *
# mean_glucose                     0.0016239  0.0004101   3.960 7.49e-05 ***
# first_careunitCSRU              -0.6775064  0.0577750 -11.727  < 2e-16 ***
# first_careunitMICU               0.0223535  0.0606855   0.368 0.712612
# first_careunitSICU              -0.2245422  0.0694324  -3.234 0.001221 **
# first_careunitTSICU             -0.2798301  0.0760674  -3.679 0.000234 ***
# intubTRUE                        0.8657076  0.0490380  17.654  < 2e-16 ***
# simple_diagnosisINFECTION        0.0353813  0.0895532   0.395 0.692779
# simple_diagnosisOTHER DIAGNOSIS  0.0121238  0.0461730   0.263 0.792880
# simple_diagnosisSEPSIS           0.2594903  0.0863689   3.004 0.002661 **
# age_cohort                       0.0027753  0.0012033   2.306 0.021090 *
# genderM                         -0.0347047  0.0352583  -0.984 0.324968
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 20233  on 14636  degrees of freedom
# Residual deviance: 19573  on 14620  degrees of freedom
#   (648 observations deleted due to missingness)
# AIC: 19607
#
# Number of Fisher Scoring iterations: 4

# %%
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, "modelestimates.csv"))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))  %>% data.frame()
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio  %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, "categoricalmodeleodds.csv"))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>% 
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <-oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, "continuousmodeleodds.csv"))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # LR Model for norepinephrine
# - Running into problems with missing data for glucose, spo2 and tempc.

# %%
pressor_choice <- 'norepinephrinedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(grepl(pressor_choice, pressor), INTERVAL == 1) %>% select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(grepl(pressor_choice, pressor))  %>%
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
              contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 6301   12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model) %>% print()
# Out:
#                      GVIF Df GVIF^(1/(2*Df))
# first_careunit   2.131583  4        1.099228
# intub            1.225904  1        1.107205
# simple_diagnosis 1.732193  3        1.095888
# age_cohort       1.118266  1        1.057481
# gender           1.063029  1        1.031033
# mean_meanbp      1.124821  1        1.060576
# mean_resprate    1.469106  1        1.212067
# mean_heartrate   1.149744  1        1.072261
# mean_tempc       1.148566  1        1.071712
# mean_spo2        1.169424  1        1.081399
# mean_glucose     1.060639  1        1.029874

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 0.7205195 0.06787473 0.7775198 0.04533567

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1962   102.00 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1949   101.32 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1961   101.94 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1966   102.19 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1968   102.29 |

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %%
summary(model) %>% print()
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6769  -0.9727   0.6244   0.7533   1.7199
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      6.7799125  1.6152166   4.198 2.70e-05 ***
# mean_meanbp                     -0.0108197  0.0021622  -5.004 5.62e-07 ***
# mean_resprate                    0.0137274  0.0065210   2.105 0.035283 *
# mean_heartrate                   0.0144375  0.0018545   7.785 6.97e-15 ***
# mean_tempc                      -0.0847995  0.0370355  -2.290 0.022040 *
# mean_spo2                       -0.0372631  0.0083809  -4.446 8.74e-06 ***
# mean_glucose                    -0.0010373  0.0005787  -1.793 0.073052 .
# first_careunitCSRU               0.0839756  0.1271044   0.661 0.508816
# first_careunitMICU              -0.3486573  0.1051489  -3.316 0.000914 ***
# first_careunitSICU              -0.0178082  0.1282428  -0.139 0.889558
# first_careunitTSICU             -0.1365094  0.1385577  -0.985 0.324518
# intubTRUE                        1.0550852  0.0750383  14.061  < 2e-16 ***
# simple_diagnosisINFECTION       -0.6796746  0.1567241  -4.337 1.45e-05 ***
# simple_diagnosisOTHER DIAGNOSIS -0.3616261  0.1237851  -2.921 0.003485 **
# simple_diagnosisSEPSIS          -0.5116254  0.1487932  -3.439 0.000585 ***
# age_cohort                       0.0005666  0.0021178   0.268 0.789040
# genderM                         -0.0118805  0.0631425  -0.188 0.850755
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 6806.3  on 5973  degrees of freedom
# Residual deviance: 6336.7  on 5957  degrees of freedom
#   (327 observations deleted due to missingness)
# AIC: 6370.7
#
# Number of Fisher Scoring iterations: 4

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio  %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodeleodds.csv")))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodeleodds.csv")))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # LR Model for dopamine
# - Running into problems with missing data for glucose, spo2 and tempc.

# %%
pressor_choice <- 'dopaminedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(grepl(pressor_choice, pressor), INTERVAL == 1) %>% select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(grepl(pressor_choice, pressor))  %>%
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
              contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 2790   12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model) %>% print()
# Out:
#                      GVIF Df GVIF^(1/(2*Df))
# first_careunit   2.357441  4        1.113154
# intub            1.509336  1        1.228551
# simple_diagnosis 1.121208  3        1.019251
# age_cohort       1.283326  1        1.132840
# gender           1.374393  1        1.172345
# mean_meanbp      1.134520  1        1.065139
# mean_resprate    1.300793  1        1.140523
# mean_heartrate   1.435470  1        1.198111
# mean_tempc       1.074239  1        1.036455
# mean_spo2        1.133670  1        1.064740
# mean_glucose     1.227572  1        1.107959

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC    MEAN_ACC  SD_ACC
# 1 0.7805717 0.1453586 0.9007653 0.06182213

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2096   100.65 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2107   101.19 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2124   102.00 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |    0.213   102.30 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |    0.213   102.25 |

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %%
summary(model) %>% print()
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4967  -1.0140   0.5915   0.7549   1.9034
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      5.9866850  2.6249327   2.281   0.0226 *
# mean_meanbp                     -0.0149072  0.0034700  -4.296 1.74e-05 ***
# mean_resprate                    0.0153909  0.0105284   1.462   0.1438
# mean_heartrate                   0.0157609  0.0029707   5.306 1.12e-07 ***
# mean_tempc                      -0.1607589  0.0628121  -2.559   0.0105 *
# mean_spo2                       -0.0121466  0.0105315  -1.153   0.2488
# mean_glucose                    -0.0002420  0.0008522  -0.284   0.7764
# first_careunitCSRU               0.7435534  0.1817093   4.092 4.28e-05 ***
# first_careunitMICU               0.2434468  0.1136680   2.142   0.0322 *
# first_careunitSICU               0.4742406  0.1953384   2.428   0.0152 *
# first_careunitTSICU              0.5630518  0.2255413   2.496   0.0125 *
# intubTRUE                        1.3823914  0.0984811  14.037  < 2e-16 ***
# simple_diagnosisINFECTION       -0.2895083  0.2479030  -1.168   0.2429
# simple_diagnosisOTHER DIAGNOSIS -0.3060715  0.1342507  -2.280   0.0226 *
# simple_diagnosisSEPSIS          -0.1029151  0.2264876  -0.454   0.6495
# age_cohort                       0.0060400  0.0034497   1.751   0.0800 .
# genderM                          0.1457872  0.0950315   1.534   0.1250
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 3090.9  on 2577  degrees of freedom
# Residual deviance: 2755.9  on 2561  degrees of freedom
#   (212 observations deleted due to missingness)
# AIC: 2789.9
#
# Number of Fisher Scoring iterations: 4

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio %>% data.frame()  %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodeleodds.csv")))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <-oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodeleodds.csv")))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # LR Model for phenylephrine
# - Running into problems with missing data for glucose, spo2 and tempc.

# %%
pressor_choice <- 'phenylephrinedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(grepl(pressor_choice, pressor), INTERVAL == 1) %>% select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(grepl(pressor_choice, pressor))  %>%
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
              contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 9384   12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model) %>% print()
# Out:
#                      GVIF Df GVIF^(1/(2*Df))
# first_careunit   1.596191  4        1.060195
# intub            1.084010  1        1.041158
# simple_diagnosis 1.244869  3        1.037180
# age_cohort       1.104367  1        1.050889
# gender           1.043890  1        1.021709
# mean_meanbp      1.078996  1        1.038747
# mean_resprate    1.355140  1        1.164105
# mean_heartrate   1.241829  1        1.114374
# mean_tempc       1.193189  1        1.092332
# mean_spo2        1.185060  1        1.088605
# mean_glucose     1.059904  1        1.029516

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 0.6542585 0.03637891 0.6189835 0.02898075

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2429    97.72 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2444    98.33 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2445    98.37 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2458    98.88 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2454    98.70 |

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %%
summary(model) %>% print()
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6621  -1.0921   0.6005   1.1424   1.8363
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      6.5279149  1.3862070   4.709 2.49e-06 ***
# mean_meanbp                     -0.0052147  0.0018174  -2.869 0.004113 **
# mean_resprate                    0.0179088  0.0053195   3.367 0.000761 ***
# mean_heartrate                   0.0113950  0.0015500   7.352 1.96e-13 ***
# mean_tempc                      -0.1376723  0.0301729  -4.563 5.05e-06 ***
# mean_spo2                       -0.0305182  0.0078409  -3.892 9.93e-05 ***
# mean_glucose                     0.0021243  0.0005907   3.597 0.000322 ***
# first_careunitCSRU              -0.8541878  0.0872366  -9.792  < 2e-16 ***
# first_careunitMICU               0.1611542  0.1037728   1.553 0.120435
# first_careunitSICU              -0.4816550  0.1000566  -4.814 1.48e-06 ***
# first_careunitTSICU             -0.5688552  0.1073905  -5.297 1.18e-07 ***
# intubTRUE                        0.6565840  0.0774817   8.474  < 2e-16 ***
# simple_diagnosisINFECTION        0.2580516  0.1390001   1.856 0.063384 .
# simple_diagnosisOTHER DIAGNOSIS  0.0999756  0.0553864   1.805 0.071066 .
# simple_diagnosisSEPSIS           1.1161496  0.1783573   6.258 3.90e-10 ***
# age_cohort                       0.0047894  0.0016019   2.990 0.002791 **
# genderM                         -0.0511859  0.0462687  -1.106 0.268607
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 12615  on 9132  degrees of freedom
# Residual deviance: 11800  on 9116  degrees of freedom
#   (251 observations deleted due to missingness)
# AIC: 11834
#
# Number of Fisher Scoring iterations: 4

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodeleodds.csv")))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <-oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodeleodds.csv")))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # Output AUC table

# %%
auc_output_df <- bind_rows(lr_summary_list, .id="PRESSOR")
auc_output_df
# Out:
#   PRESSOR                 MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 TOTAL                   0.6603611 0.03198653 0.6432651 0.02660415
# 2 norepinephrinedurations 0.7205195 0.06787473 0.7775198 0.04533567
# 3 dopaminedurations       0.7805717 0.14535856 0.9007653 0.06182213
# 4 phenylephrinedurations  0.6542585 0.03637891 0.6189835 0.02898075

# %%
auc_output_df  %>% write.csv(file.path(PLOT_DIR, "summary_auc.csv"))
