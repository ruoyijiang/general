# %% [markdown]
# # Pressor Distributions
# - Ruoyi Jiang
# - July 19, 2019
# - Evaluation of the different pressor combinations used in MIMIC

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(fasttime)

# RR analysis
library(epitools)

# ROC (and plotting)
library(boot)
library(pROC)

# imputation
library(randomForest)

# VIF analysis
library(car)

library(glmnet)
library(pls)

# %%
sessionInfo()
# Out:
# R version 3.6.0 (2019-04-26)
# Platform: x86_64-apple-darwin18.5.0 (64-bit)
# Running under: macOS Mojave 10.14.3
#
# Matrix products: default
# BLAS/LAPACK: /usr/local/Cellar/openblas/0.3.6_1/lib/libopenblasp-r0.3.6.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] pls_2.7-1           glmnet_2.0-18       foreach_1.4.7
#  [4] Matrix_1.2-17       car_3.0-3           carData_3.0-2
#  [7] randomForest_4.6-14 pROC_1.15.3         boot_1.3-22
# [10] epitools_0.5-10     fasttime_1.0-2      ggplot2_3.2.0
# [13] tidyr_0.8.3         dplyr_0.8.1
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-3      tidyselect_0.2.5  repr_1.0.1        reshape2_1.4.3
#  [5] purrr_0.3.2       haven_2.1.1       lattice_0.20-38   colorspace_1.4-1
#  [9] vctrs_0.2.0       htmltools_0.3.6   base64enc_0.1-3   rlang_0.4.0
# [13] pillar_1.4.0      foreign_0.8-71    glue_1.3.1        withr_2.1.2
# [17] readxl_1.3.1      uuid_0.1-2        plyr_1.8.4        stringr_1.4.0
# [21] munsell_0.5.0     gtable_0.3.0      cellranger_1.1.0  zip_2.0.4
# [25] codetools_0.2-16  evaluate_0.13     labeling_0.3      rio_0.5.16
# [29] forcats_0.4.0     curl_4.0          IRdisplay_0.7.0   Rcpp_1.0.1
# [33] scales_1.0.0      backports_1.1.4   IRkernel_1.0.1    jsonlite_1.6
# [37] abind_1.4-5       hms_0.5.0         digest_0.6.18     stringi_1.4.3
# [41] openxlsx_4.1.0.1  grid_3.6.0        tools_3.6.0       magrittr_1.5
# [45] lazyeval_0.2.2    tibble_2.1.1      crayon_1.3.4      pkgconfig_2.0.2
# [49] zeallot_0.1.0     data.table_1.12.2 assertthat_0.2.1  iterators_1.0.12
# [53] R6_2.4.0          compiler_3.6.0

# %%
### Plotting base_theme
base_theme <- function(){ theme_bw() + 
            theme(text=element_text(size=8)) +
            theme(plot.title=element_text(size=8)) +
            theme(plot.background=element_blank(),
                  panel.grid.major=element_blank(), 
                  panel.grid.minor=element_blank()) +
            theme(strip.background=element_blank(),
                  strip.text=element_text(size=7, face='bold')) +
            theme(axis.title=element_text(size=8, vjust=0.25),
                  axis.text.x=element_text(size=8, vjust=0.5, hjust=0.5),
                  axis.text.y=element_text(size=8)) +
            theme(legend.text=element_text(size=7),
                  legend.title=element_text(size=7),
                  legend.key.height=grid::unit(10, "points"), 
                  legend.key.width=grid::unit(10, "points"))}

# %% [markdown]
# ### Load data and take quick peek at select "pressors"  (e.g. vent and central line)

# %%
pressors_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/pressors.csv')

# %%
dim(pressors_df)
# Out:
# [1] 227645     11

# %%
pressors_df %>%
    filter(pressor == "central_line_durations") %>% head()
# Out:
#   X     level_0                level_1 duration_hours endtime
# 1 30584 central_line_durations 0        70.91667      2181-11-28 20:59:00
# 2 30585 central_line_durations 1       134.00000      2199-08-08 15:00:00
# 3 30586 central_line_durations 2        37.75000      2189-12-02 08:00:00
# 4 30587 central_line_durations 3        19.68333      2132-08-05 20:36:00
# 5 30588 central_line_durations 4        23.76667      2114-12-27 22:46:00
# 6 30589 central_line_durations 5         9.30000      2127-03-04 01:18:00
#   icustay_id num pressor                starttime           vasonum ventnum
# 1 200001     NA  central_line_durations 2181-11-25 22:04:00 NA      NA
# 2 200003     NA  central_line_durations 2199-08-03 01:00:00 NA      NA
# 3 200009     NA  central_line_durations 2189-11-30 18:15:00 NA      NA
# 4 200010     NA  central_line_durations 2132-08-05 00:55:00 NA      NA
# 5 200021     NA  central_line_durations 2114-12-26 23:00:00 NA      NA
# 6 200024     NA  central_line_durations 2127-03-03 16:00:00 NA      NA

# %%
pressors_df %>%
    filter(pressor == "ventdurations") %>% head()
# Out:
#   X      level_0       level_1 duration_hours endtime             icustay_id
# 1 189130 ventdurations 0       91.00000       2199-08-07 13:00:00 200003
# 2 189131 ventdurations 1       14.83333       2159-09-04 03:50:00 200006
# 3 189132 ventdurations 2       15.83333       2189-12-01 10:00:00 200009
# 4 189133 ventdurations 3        3.00000       2188-08-06 04:00:00 200011
# 5 189134 ventdurations 4       18.75000       2105-02-17 18:00:00 200014
# 6 189135 ventdurations 5       83.00000       2138-03-21 09:00:00 200017
#   num pressor       starttime           vasonum ventnum
# 1 NA  ventdurations 2199-08-03 18:00:00 NA      1
# 2 NA  ventdurations 2159-09-03 13:00:00 NA      1
# 3 NA  ventdurations 2189-11-30 18:10:00 NA      1
# 4 NA  ventdurations 2188-08-06 01:00:00 NA      1
# 5 NA  ventdurations 2105-02-16 23:15:00 NA      1
# 6 NA  ventdurations 2138-03-17 22:00:00 NA      1

# %%
pressors_df %>%
    group_by(pressor) %>%
    summarize(COUNT = n())
# Out:
#    pressor                 COUNT
# 1  adenosinedurations        160
# 2  arterial_line_durations 30424
# 3  central_line_durations  38211
# 4  crrtdurations            5918
# 5  dobutaminedurations      1792
# 6  dopaminedurations        6524
# 7  epinephrinedurations     3126
# 8  isupreldurations           24
# 9  milrinonedurations       3600
# 10 norepinephrinedurations 23188
# 11 phenylephrinedurations  33141
# 12 vasopressindurations     4190
# 13 vasopressordurations    38832
# 14 ventdurations           38515

# %% [markdown]
# ### Available pressor (and other infusions) choices
# - Make choices
# - Quick check of dataset balancing

# %%
pressor_choices <- c("norepinephrinedurations", "dopaminedurations", 
                     "phenylephrinedurations", "vasopressindurations", 'epinephrinedurations', 'dobutaminedurations')

# %%
FANCY_PRESSOR_ORDER <- c("Norepinephrine", "Dopamine", "Phenylephrine", "Vasopressin", "Epinephrine", "Dobutamine")

# %%
FANCY_PRESSOR_DICT <- c(
'dopaminedurations' = 'Dopamine',
'norepinephrinedurations' = 'Norepinephrine',  
'phenylephrinedurations' = 'Phenylephrine',
"vasopressindurations" = "Vasopressin",
'epinephrinedurations' = "Epinephrine",
'dobutaminedurations' = "Dobutamine"
)

# %%
PLOT_DIR <- "~/Google Drive/vasopressors/figures_v3"

# %%
pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    filter((pressor == 'phenylephrinedurations' & duration_hours > 0.5) |
           (pressor == 'epinephrinedurations' & duration_hours > 0.5) |
           !(pressor %in% c('phenylephrinedurations', 'phenylephrinedurations'))
          ) %>%
    mutate(MORETHAN24HOURS = duration_hours > 24) %>%
    group_by(MORETHAN24HOURS, pressor) %>% 
    summarize(COUNT = n())
# Out:
#    MORETHAN24HOURS pressor                 COUNT
# 1  FALSE           dobutaminedurations      1412
# 2  FALSE           dopaminedurations        5422
# 3  FALSE           epinephrinedurations     2797
# 4  FALSE           norepinephrinedurations 19811
# 5  FALSE           phenylephrinedurations  26872
# 6  FALSE           vasopressindurations     2537
# 7   TRUE           dobutaminedurations       380
# 8   TRUE           dopaminedurations        1102
# 9   TRUE           epinephrinedurations      329
# 10  TRUE           norepinephrinedurations  3377
# 11  TRUE           phenylephrinedurations   2711
# 12  TRUE           vasopressindurations     1653

# %% [markdown]
# ### Join with icustay metadata (pressors_df + lengthstay_df -> input_df)
# ### Also remove <0.5 hr epinephrine and phenyelphrine doses

# %%
lengthstay_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/length_stay.csv') %>%
    rename(icustarttime = START, icuendtime = END)

# %%
lengthstay_df %>% head()
# Out:
#   X icustay_id icustarttime        icuendtime          DIFF
# 1 1 200001     2181-11-25 19:06:00 2181-11-28 20:00:00  72.90000
# 2 2 200003     2199-08-02 19:15:00 2199-08-08 15:00:00 139.75000
# 3 3 200006     2159-09-03 12:30:00 2159-09-04 17:00:00  28.50000
# 4 4 200007     2109-02-17 09:00:00 2109-02-18 09:15:00  24.25000
# 5 5 200009     2189-11-30 11:43:00 2189-12-02 13:00:00  49.28333
# 6 6 200010     2132-08-05 00:39:00 2132-08-05 21:17:00  20.63333

# %%
# filter by pressor and left join with lengthstay_df
input_df <- pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    filter((pressor == 'phenylephrinedurations' & duration_hours > 0.5) |
           (pressor == 'epinephrinedurations' & duration_hours > 0.5) |
           !(pressor %in% c('phenylephrinedurations', 'epinephrinedurations'))
          ) %>%
    left_join(lengthstay_df, by = "icustay_id") %>%
    mutate(starttime = fastPOSIXct(starttime), endtime = fastPOSIXct(endtime), 
           icustarttime = fastPOSIXct(icustarttime), icuendtime = fastPOSIXct(icuendtime))

# %% [markdown]
# # Filters

# %% [markdown]
# #### Collapse pressor courses based on length of intervening time (<24 hrs)
# - Any two courses with less than intervening 24 hours will be collapsed into a single course within an icustay

# %%
max_intervening_hrs <- 24

# find the intervening time between courses (endtime of next course - endtime of course - duration of course)
# then determine if that length of time is >24 or <24 and mark it with a 0 if true, else a 1
# use a cumsum to create a new id separating courses that are separated by more than >24

input_df <- input_df %>%
        group_by(icustay_id) %>%
        arrange(starttime) %>%
        mutate(intervening_hours = difftime(endtime, lag(endtime), units="hours") - duration_hours) %>%
        rowwise() %>%
        mutate(increasing = if(intervening_hours < max_intervening_hrs | is.na(intervening_hours)){0}else(1)) %>%
        ungroup() %>%
        group_by(icustay_id) %>%
        mutate(continuous_course = cumsum(increasing)) %>% select(-intervening_hours, -increasing)

# %%
# max_intervening_hrs <- 24

# # find the intervening time between courses (endtime of next course - endtime of course - duration of course)
# # then determine if that length of time is >24 or <24 and mark it with a 0 if true, else a 1
# # use a cumsum to create a new id separating courses that are separated by more than >24
# input_list <- list()
# for(pressor_choice in pressor_choices){
#     input_list[[pressor_choice]] <- input_df %>%
#         filter(pressor == pressor_choice) %>%
#         group_by(icustay_id) %>%
#         mutate(intervening_hours = difftime(endtime, lag(endtime), units="hours") - duration_hours) %>%
#         rowwise() %>%
#         mutate(increasing = if(intervening_hours < max_intervening_hrs | is.na(intervening_hours)){0}else(1)) %>%
#         ungroup() %>%
#         group_by(icustay_id) %>%
#         mutate(continuous_course = cumsum(increasing)) %>% select(-intervening_hours, -increasing)
#     cat(pressor_choice, '\n')
# }

# %%
# input_df <- bind_rows(input_list, .id="pressor_choice")

# %% [markdown]
# - the combination of **continuous course** and **icustay_id** (e.g. 200024, 0 for first row) now defines each pressor course

# %% [markdown]
# - assign boolean assessments after <24 hour intervals between pressors are removed
#     1. more or less than 24 hours of pressor duration?
#     2. is this the first pressor course?
#     3. are pressors administered <1 hr of the icustay?

# %%
# 1. more or less than 24 hours?
input_df <- input_df %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(MORETHAN24HOURS = sum(duration_hours) > 24, 
           STATUS = if(sum(duration_hours) > 24){"MORETHAN24HOURS"}
           else if(sum(duration_hours) <= 24 & sum(duration_hours) > 6){"LESSTHAN24HOURS"}
           else if(sum(duration_hours) <= 6){"LESSTHAN6HOURS"}
               )

# %%
# 2. first pressor course? (groupby icustay, filter min starttime == starttime)
input_df <- input_df %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(coursestarttime = min(starttime)) %>%
    group_by(icustay_id) %>%
    mutate(FIRSTCOURSE = min(coursestarttime) == coursestarttime)

# %%
# 3. pressors within 1 hr of icustay_id? (groupby icustay, filter max starttime - unique icustarttime > 1)
input_df <- input_df %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(coursestarttime = min(starttime)) %>%
    group_by(icustay_id) %>%
    mutate(LESS1HOUR = difftime(min(coursestarttime), 
                         min(icustarttime)) < 1)

# %%
# grouped by icustay_id + continuous_course + separate_course
input_df %>%
    group_by(LESS1HOUR, FIRSTCOURSE, MORETHAN24HOURS) %>%
    summarize(COUNT = n())
# Out:
#    LESS1HOUR FIRSTCOURSE MORETHAN24HOURS COUNT
# 1  FALSE     FALSE       FALSE            2217
# 2  FALSE     FALSE        TRUE            7872
# 3  FALSE      TRUE       FALSE           14401
# 4  FALSE      TRUE        TRUE           37122
# 5   TRUE     FALSE       FALSE             111
# 6   TRUE     FALSE        TRUE             284
# 7   TRUE      TRUE       FALSE             891
# 8   TRUE      TRUE        TRUE            2010
# 9     NA     FALSE       FALSE             151
# 10    NA     FALSE        TRUE             575
# 11    NA      TRUE       FALSE             187
# 12    NA      TRUE        TRUE            1083
# 13    NA        NA       FALSE             302
# 14    NA        NA        TRUE            1058

# %%
# With filters grouped by icustay_id + continuous_course
input_df %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(LESS1HOUR, FIRSTCOURSE, MORETHAN24HOURS) %>%
    summarize(COUNT = length(unique(course_id)))
# Out:
#    LESS1HOUR FIRSTCOURSE MORETHAN24HOURS COUNT
# 1  FALSE     FALSE       FALSE           1392
# 2  FALSE     FALSE        TRUE           1356
# 3  FALSE      TRUE       FALSE           8623
# 4  FALSE      TRUE        TRUE           6768
# 5   TRUE     FALSE       FALSE             68
# 6   TRUE     FALSE        TRUE             64
# 7   TRUE      TRUE       FALSE            580
# 8   TRUE      TRUE        TRUE            432
# 9     NA     FALSE       FALSE             98
# 10    NA     FALSE        TRUE            109
# 11    NA      TRUE       FALSE            115
# 12    NA      TRUE        TRUE            176
# 13    NA        NA       FALSE            178
# 14    NA        NA        TRUE            143

# %% [markdown]
# ### Introduce other predictor values for each course (like RACE, Diagnosis type) -> nonvitals_predictor_df

# %%
races <- c("ASIAN", "BLACK", "HISPANIC", "WHITE", "OTHER")

simplifyRace <- function(ethnicity){
    if(grepl("ASIAN", ethnicity)){return("ASIAN")}
    else if(grepl("BLACK", ethnicity)){return("BLACK")}
    else if(grepl("HISPANIC", ethnicity)){return("HISPANIC")}
    else if(grepl("WHITE", ethnicity)){return("WHITE")}
    else{return("OTHER")}
}

# %%
sepsis_regex <- c('SEPSIS', 'SEPTIC', 'CHOLANGITIS', 'UROSEPSIS')

infection_regex <- c('PNEUMONIA', 'INFECTION',  
  'CELULLITIS', 'FASCITIS', 'INFECTED', 'BACTER', 'PNEMONIA', 'ABSCESS', 'NEPHRITIS')

cardiac_regex <- c('HEART', 'CORONARY', 'VENTRICULAR')

simplifyDiagnosis <- function(diagnosis){
    if(any(sapply(sepsis_regex, function(x) grepl(x, diagnosis)))){return("SEPSIS")}
    else if(any(sapply(infection_regex, function(x) grepl(x, diagnosis)))){return("INFECTION")}
    else if(any(sapply(cardiac_regex, function(x) grepl(x, diagnosis)))){return("CARDIAC")}
    else{return("OTHER DIAGNOSIS")}
}

# %%
icustays_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/icustays.csv')

# %%
admissions_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/admissions.csv')

# %%
patients_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/patients.csv')

# %%
severity_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/sofa.csv') %>% select(icustay_id, sofa) %>%
    left_join(read.csv('~/Projects/Haimovich_Pressors/collection/out/oasis.csv') %>% select(icustay_id, oasis), by = 'icustay_id') %>%
    left_join(read.csv('~/Projects/Haimovich_Pressors/collection/out/qsofa.csv') %>% select(icustay_id, qsofa), by = 'icustay_id')

# %%
intub_df <- pressors_df %>%
    filter(pressor == "ventdurations") 

cvc_df <- pressors_df %>%
    filter(pressor == "central_line_durations")

# %%
# 3 mins
nonvitals_predictor_df <- icustays_df %>%
    select(hadm_id, icustay_id, first_careunit, last_careunit) %>%
    left_join(admissions_df, by = 'hadm_id') %>%
    left_join(patients_df, by = 'subject_id') %>%
    left_join(severity_df, by = 'icustay_id') %>%
    mutate(intub = icustay_id %in% intub_df$icustay_id, cvc = icustay_id %in% cvc_df$icustay_id) %>%
    mutate(deathtime = fastPOSIXct(deathtime), admittime = fastPOSIXct(admittime), dob = fastPOSIXct(dob)) %>%
    mutate(age = difftime(admittime, dob, units="weeks")/52.25, 
           age_cohort = as.numeric(round(age, digits = -1))) %>% 
    rowwise() %>%
    mutate(simple_race = simplifyRace(ethnicity)) %>%
    mutate(simple_diagnosis = simplifyDiagnosis(diagnosis))

# %% [markdown]
# ### Mortality filter
# - Remove patients who stopped using pressors because death (merge with pressors_df by icustay_id, filter if pressor course end time == or is close to deathtime)
# - Also quantify some unusual cases of death documentation

# %%
#NA means the stay did not end in death
#ICUSTAYS where patient was discharged after death? (TRUE)
nonvitals_predictor_df  %>%
    mutate(MORTALITYERROR = difftime(deathtime, dischtime, units = "mins") < 0) %>%
    group_by(MORTALITYERROR) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   MORTALITYERROR COUNT
# 1 FALSE             40
# 2  TRUE           6422
# 3    NA          55070

# %%
#NA means the stay did not end in death
#ICUSTAYS where patient was admitted after death? (TRUE)
nonvitals_predictor_df  %>%
    mutate(MORTALITYERROR = difftime(deathtime, admittime, units = "mins") < 0) %>%
    group_by(MORTALITYERROR) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   MORTALITYERROR COUNT
# 1 FALSE           6384
# 2  TRUE             78
# 3    NA          55070

# %%
#Examples (admitted after death)
nonvitals_predictor_df  %>%
    filter(difftime(deathtime, admittime, units = "mins") < 0) %>%
    head(5)
# Out:
#   hadm_id icustay_id first_careunit last_careunit X.x  row_id.x subject_id
# 1 102631  246694     CSRU           CSRU           456  237      181
# 2 138015  298263     NICU           NICU          1911 1640     1334
# 3 181430  291798     SICU           SICU          1970 1699     1381
# 4 187482  213831     MICU           MICU           693  644      516
# 5 190088  293048     CCU            CCU           3624 3447     2858
#   admittime           dischtime           deathtime           ⋯ expire_flag
# 1 2153-10-12 05:49:00 2153-10-12 06:29:00 2153-10-12 02:29:00 ⋯ 1
# 2 2137-09-02 10:43:00 2137-09-02 12:00:00 2137-09-02 08:00:00 ⋯ 1
# 3 2189-01-02 09:25:00 2189-01-02 12:00:00 2189-01-02 07:00:00 ⋯ 1
# 4 2197-07-31 16:18:00 2197-07-31 01:10:00 2197-07-30 21:10:00 ⋯ 1
# 5 2108-09-25 11:29:00 2108-09-25 12:00:00 2108-09-25 08:00:00 ⋯ 1
#   sofa oasis qsofa intub cvc   age               age_cohort simple_race
# 1  2   17    0     FALSE FALSE 65.12757082 weeks 70         WHITE
# 2 10   24    0      TRUE FALSE  0.00167654 weeks  0         WHITE
# 3  5   54    2      TRUE FALSE 81.36049404 weeks 80         WHITE
# 4  2   17    0     FALSE FALSE 70.88679654 weeks 70         OTHER
# 5 12   50    2      TRUE FALSE 82.42418356 weeks 80         WHITE
#   simple_diagnosis
# 1 OTHER DIAGNOSIS
# 2 OTHER DIAGNOSIS
# 3 OTHER DIAGNOSIS
# 4 OTHER DIAGNOSIS
# 5 OTHER DIAGNOSIS

# %%
# Icustays where patients received pressors after death (TRUE)
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    mutate(STOPMORTALITY = difftime(deathtime, endtime, units = "mins")) %>% 
    group_by(STOPMORTALITY < 0) %>%
    summarize(COUNT = length(unique(icustay_id)))
# Out:
#   STOPMORTALITY < 0 COUNT
# 1 FALSE              3439
# 2  TRUE               694
# 3    NA             13368

# %% [markdown]
# ### Test out some mortality filters

# %%
### if I do not ignore for unusual cases (pressors after death)
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = STOPMORTALITY < 5) %>%
    group_by(STOPMORTALITY) %>%
    summarize(COUNT = n())
# Out:
#   STOPMORTALITY COUNT
# 1 FALSE         18873
# 2  TRUE          4427
# 3    NA         44964

# %%
### if I do ignore these unusual cases
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = STOPMORTALITY > 0 &  STOPMORTALITY < 5) %>%
    group_by(STOPMORTALITY) %>%
    summarize(COUNT = n())
# Out:
#   STOPMORTALITY COUNT
# 1 FALSE         23033
# 2  TRUE           267
# 3    NA         44964

# %% [markdown]
# ### Create filters for mortality: input_df -> input_death_df

# %%
# # ignore NAs (patient did not die), or patient death did not correspond to end of pressor course
# # do not remove unusual cases
# input_death_df <- input_df %>%
#     ungroup() %>%
#     left_join(nonvitals_predictor_df, by = "icustay_id") %>%
#     group_by(icustay_id, continuous_course, pressor) %>%
#     mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
#     mutate(STOPMORTALITY = !(!(STOPMORTALITY < 5) | is.na(STOPMORTALITY)))

# %%
# ignore NAs (patient did not die), or patient death did not correspond to end of pressor course
# remove unusual cases
input_death_df <- input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = !(!(STOPMORTALITY > 0 &  STOPMORTALITY < 5) | is.na(STOPMORTALITY)))

# %% [markdown]
# ### Exclude NICU (all NICU was already excluded by pressor usage): : input_death_df -> input_death_df

# %%
input_death_df %>%
    mutate(NICUSTAY = first_careunit == "NICU") %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(LESS1HOUR, FIRSTCOURSE, STOPMORTALITY, MORETHAN24HOURS, NICUSTAY) %>%
    summarize(COUNT = length(unique(course_id)))
# Out:
#    LESS1HOUR FIRSTCOURSE STOPMORTALITY MORETHAN24HOURS NICUSTAY COUNT
# 1  FALSE     FALSE       FALSE         FALSE           FALSE    1384
# 2  FALSE     FALSE       FALSE         FALSE            TRUE       7
# 3  FALSE     FALSE       FALSE          TRUE           FALSE    1330
# 4  FALSE     FALSE       FALSE          TRUE            TRUE      19
# 5  FALSE     FALSE        TRUE         FALSE           FALSE       1
# 6  FALSE     FALSE        TRUE          TRUE           FALSE       7
# 7  FALSE      TRUE       FALSE         FALSE           FALSE    8520
# 8  FALSE      TRUE       FALSE         FALSE            TRUE      87
# 9  FALSE      TRUE       FALSE          TRUE           FALSE    6636
# 10 FALSE      TRUE       FALSE          TRUE            TRUE     115
# 11 FALSE      TRUE        TRUE         FALSE           FALSE      15
# 12 FALSE      TRUE        TRUE         FALSE            TRUE       1
# 13 FALSE      TRUE        TRUE          TRUE           FALSE      17
# 14  TRUE     FALSE       FALSE         FALSE           FALSE      68
# 15  TRUE     FALSE       FALSE          TRUE           FALSE      64
# 16  TRUE      TRUE       FALSE         FALSE           FALSE     577
# 17  TRUE      TRUE       FALSE         FALSE            TRUE       1
# 18  TRUE      TRUE       FALSE          TRUE           FALSE     429
# 19  TRUE      TRUE       FALSE          TRUE            TRUE       2
# 20  TRUE      TRUE        TRUE         FALSE           FALSE       2
# 21  TRUE      TRUE        TRUE          TRUE           FALSE       1
# 22    NA     FALSE       FALSE         FALSE           FALSE      96
# 23    NA     FALSE       FALSE         FALSE            TRUE       1
# 24    NA     FALSE       FALSE         FALSE              NA       1
# 25    NA     FALSE       FALSE          TRUE           FALSE     105
# 26    NA     FALSE       FALSE          TRUE            TRUE       3
# 27    NA     FALSE       FALSE          TRUE              NA       1
# 28    NA      TRUE       FALSE         FALSE           FALSE     111
# 29    NA      TRUE       FALSE         FALSE            TRUE       3
# 30    NA      TRUE       FALSE         FALSE              NA       1
# 31    NA      TRUE       FALSE          TRUE           FALSE     159
# 32    NA      TRUE       FALSE          TRUE            TRUE      16
# 33    NA      TRUE        TRUE          TRUE           FALSE       1
# 34    NA        NA       FALSE         FALSE           FALSE     177
# 35    NA        NA       FALSE         FALSE            TRUE       1
# 36    NA        NA       FALSE          TRUE           FALSE     140
# 37    NA        NA       FALSE          TRUE            TRUE       3

# %%
input_death_df <- input_death_df %>%
    filter(first_careunit != "NICU")

# %% [markdown]
# ### Use filters, clean predictors: input_death_df -> output_df

# %%
output_df <- input_death_df %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(course_id) %>%
    mutate(starttime = min(starttime), endtime = max(endtime)) %>%
    filter(!LESS1HOUR, FIRSTCOURSE, !STOPMORTALITY)

# %%
# collapse so each row is a course_id
output_df <- output_df %>%
    group_by(course_id) %>%
    summarize(
            PATIENT = unique(subject_id)[1],
            STATUS = unique(STATUS)[1], 
            MORETHAN24HOURS = unique(MORETHAN24HOURS)[1], 
            simple_diagnosis = unique(simple_diagnosis)[1], 
            simple_race = unique(simple_race)[1], 
            age = unique(age)[1], 
            age_cohort = unique(age_cohort)[1], 
            cvc = unique(cvc)[1],
            intub = unique(intub)[1],
            first_careunit = unique(first_careunit)[1],
            gender = unique(gender)[1],
            icustay_id = unique(icustay_id)[1],
            starttime = min(starttime), 
            endtime = max(endtime),
            pressor = paste(unique(pressor), collapse=","),
            sofa = unique(sofa)[1],
            qsofa = unique(qsofa)[1],
            oasis = unique(oasis)[1],
    ) %>% 
    mutate(duration = difftime(endtime, 
                       starttime, units="hours"))

# %% [markdown]
# ### If more than 1 pressor is used, MORETHAN24HOURS is TRUE

# %%
output_df <- output_df %>%
    rowwise() %>%
    mutate(RESPONSE = MORETHAN24HOURS | grepl(",", pressor))

# %% [markdown]
# ### Age filter > 18

# %%
output_df <- output_df %>%
    filter(age >= 18 | is.na(age))

# %% [markdown]
# # Analysis

# %% [markdown]
# ### For text, description of meta-data

# %%
length(unique(output_df$PATIENT))
# Out:
# [1] 13489

# %%
length(unique(output_df$icustay_id))
# Out:
# [1] 15136

# %%
length(unique(output_df$course_id))
# Out:
# [1] 15136

# %%
# minimum age
min(output_df$age, na.rm=TRUE)
# Out:
# [1] 18.22476

# %%
output_df %>%
    mutate(MINOR = age < 18) %>%
    group_by(MINOR, first_careunit) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    MINOR first_careunit COUNT
# 1  FALSE CCU            1938
# 2  FALSE CSRU           5755
# 3  FALSE MICU           3818
# 4  FALSE SICU           1738
# 5  FALSE TSICU          1239
# 6     NA CCU             137
# 7     NA CSRU             76
# 8     NA MICU            310
# 9     NA SICU             70
# 10    NA TSICU            55

# %%
dim(output_df)
# Out:
# [1] 15136    18

# %%
output_df %>%
    group_by(STATUS) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   STATUS          COUNT
# 1 LESSTHAN24HOURS 5003
# 2 LESSTHAN6HOURS  3509
# 3 MORETHAN24HOURS 6624

# %%
output_df %>%
    group_by(STATUS, pressor) %>%
    summarize(COUNT = length(unique(PATIENT))) %>%
    filter(!grepl(",", pressor))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    STATUS          pressor                 COUNT
# 1  LESSTHAN24HOURS dobutaminedurations       57
# 2  LESSTHAN24HOURS dopaminedurations        388
# 3  LESSTHAN24HOURS epinephrinedurations     115
# 4  LESSTHAN24HOURS norepinephrinedurations  916
# 5  LESSTHAN24HOURS phenylephrinedurations  2372
# 6  LESSTHAN24HOURS vasopressindurations      18
# 7  LESSTHAN6HOURS  dobutaminedurations       37
# 8  LESSTHAN6HOURS  dopaminedurations        407
# 9  LESSTHAN6HOURS  epinephrinedurations      71
# 10 LESSTHAN6HOURS  norepinephrinedurations  687
# 11 LESSTHAN6HOURS  phenylephrinedurations  2052
# 12 LESSTHAN6HOURS  vasopressindurations      14
# 13 MORETHAN24HOURS dobutaminedurations       52
# 14 MORETHAN24HOURS dopaminedurations        319
# 15 MORETHAN24HOURS epinephrinedurations      10
# 16 MORETHAN24HOURS norepinephrinedurations  858
# 17 MORETHAN24HOURS phenylephrinedurations  1489
# 18 MORETHAN24HOURS vasopressindurations      24

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS" & !grepl(",", pressor)) %>%
    summarize(COUNT =n()) %>% 
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE COUNT FREQ
# 1 FALSE    11838 0.7821089
# 2  TRUE     3298 0.2178911

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS" & !grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE  755  0.2289266
# 2 TRUE      TRUE 2543  0.7710734

# %%
# Less than 24 hours AND only one vasopressor
output_df %>%
    group_by(RESPONSE = STATUS != "MORETHAN24HOURS" & !grepl(",", pressor)) %>%
    summarize(COUNT = n()) %>% 
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE COUNT FREQ
# 1 FALSE    7916  0.5229915
# 2  TRUE    7220  0.4770085

# %%
output_df %>%
    group_by(RESPONSE = STATUS != "MORETHAN24HOURS" & !grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE 1583  0.2192521
# 2 TRUE      TRUE 5637  0.7807479

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "MORETHAN24HOURS", cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE  547  0.0825785
# 2 TRUE      TRUE 6077  0.9174215

# %%
output_df %>%
    group_by(RESPONSE = grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>%
    filter(RESPONSE)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 TRUE     FALSE  459  0.09040772
# 2 TRUE      TRUE 4618  0.90959228

# %% [markdown]
# #### All courses

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- output_df %>%
    filter(!grepl(',', pressor)) %>%
    ggplot(aes(x=duration)) +
        base_theme() +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(aes(y = ..count..), alpha=0.6, fill="gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Count")+
        xlim(0, 60) +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="#2F4F4F")
plot(p)
# Out:
# Warning message:
# “Removed 898 rows containing non-finite values (stat_density).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "histo_durations.pdf"), 2, 2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 898 rows containing non-finite values (stat_density).”
# pdf
#   2

# %% [markdown]
# #### Courses involving any of these pressors

# %%
options(repr.plot.width=5, repr.plot.height=4)
p <- output_df %>%
    filter(!grepl(',', pressor)) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=duration)) +
        base_theme() +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(aes(y = ..count..), alpha=0.6, fill="gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Count")+
        xlim(0, 60) +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="#2F4F4F") +
        facet_wrap(. ~fancy_pressor, nrow=2, ncol=3, scale = "free")
plot(p)
# Out:
# Warning message:
# “Removed 898 rows containing non-finite values (stat_density).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "histo_individual_durations.pdf"), 5, 4)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 898 rows containing non-finite values (stat_density).”
# pdf
#   2

# %% [markdown]
# ### Figure X. CVC associated with longer pressor courses

# %%
CVC_COLORS <- c(
"CVC" = '#2F4F4F',
"No CVC" = '#D3D3D3'
)

# %%
# <6 hour course
output_df %>%
    filter(!grepl(",", pressor)) %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS", cvc) %>%
    summarize(COUNT = n(), DURATION = mean(duration)) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT DURATION        FREQ
# 1 FALSE    FALSE 1122  23.076857 hours 0.1659518
# 2 FALSE     TRUE 5639  37.483732 hours 0.8340482
# 3  TRUE    FALSE  755   2.964062 hours 0.2289266
# 4  TRUE     TRUE 2543   3.384297 hours 0.7710734

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "MORETHAN24HOURS", cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 FALSE    FALSE 1789  0.2101739
# 2 FALSE     TRUE 6723  0.7898261
# 3  TRUE    FALSE  547  0.0825785
# 4  TRUE     TRUE 6077  0.9174215

# %%
output_df %>%
    group_by(RESPONSE = grepl(",", pressor), cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   RESPONSE cvc   COUNT FREQ
# 1 FALSE    FALSE 1877  0.18659907
# 2 FALSE     TRUE 8182  0.81340093
# 3  TRUE    FALSE  459  0.09040772
# 4  TRUE     TRUE 4618  0.90959228

# %%
pairwise.wilcox.test(as.numeric(output_df$duration), output_df$cvc)
# Out:
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(output_df$duration) and output_df$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- output_df %>%
    rowwise() %>%
    mutate(cvc_fancy = if(cvc){"CVC"}else{"No CVC"}) %>%
    mutate(cvc_fancy = factor(cvc_fancy, levels = names(CVC_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=cvc_fancy, y=duration)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("Duration (hours)") +
        geom_violin(aes(fill=cvc_fancy), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,72)) +
        geom_boxplot(width=0.05, outlier.shape = NA)+
        stat_summary(fun.y=median, geom="point", size=2, color="firebrick")
        #+ facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Warning message:
# “Removed 2064 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 2064 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 2064 rows containing non-finite values (stat_summary).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "cvcduration.pdf"), 2,2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 2064 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 2064 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 2064 rows containing non-finite values (stat_summary).”
# pdf
#   2

# %%
for(presor_choice in pressor_choices){
    pairwise.wilcox.test(as.numeric(filter(output_df,pressor==pressor_choice)$duration), 
                     filter(output_df,pressor==pressor_choice)$cvc) %>% 
    print()
}
# Out:
# Error: object 'pressor_choice' not found
# Traceback:
#
# 1. pairwise.wilcox.test(as.numeric(filter(output_df, pressor ==
#  .     pressor_choice)$duration), filter(output_df, pressor == pressor_choice)$cvc) %>%
#  .     print()
# 2. eval(lhs, parent, parent)
# 3. eval(lhs, parent, parent)
# 4. pairwise.wilcox.test(as.numeric(filter(output_df, pressor ==
#  .     pressor_choice)$duration), filter(output_df, pressor == pressor_choice)$cvc)
# 5. factor(g)
# 6. filter(output_df, pressor == pressor_choice)
# 7. filter.tbl_df(output_df, pressor == pressor_choice)
# 8. filter_impl(.data, quo)

# %%
options(repr.plot.width=7, repr.plot.height=2)
p <- output_df %>%
    filter(!grepl(",", pressor)) %>%
    rowwise() %>%
    mutate(cvc_fancy = if(cvc){"CVC"}else{"No CVC"}) %>%
    mutate(cvc_fancy = factor(cvc_fancy, levels = names(CVC_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=cvc_fancy, y=duration)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("Duration (hours)") +
        geom_violin(aes(fill=cvc_fancy), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,72)) +
        geom_boxplot(width=0.05, outlier.shape = NA) +
        stat_summary(fun.y=median, geom="point", size=2, color="firebrick") +
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Warning message:
# “Removed 637 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 637 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 637 rows containing non-finite values (stat_summary).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "cvcduration_eachpressor.pdf"), 4,2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 637 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 637 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 637 rows containing non-finite values (stat_summary).”
# pdf
#   2

# %% [markdown]
# ### Table 1 Demographics

# %%
t1_df <- output_df %>% 
    group_by(STATUS) %>%
    summarize(n = paste(round(as.numeric(n()),2), paste0('(', 100*(n()/nrow(output_df)) %>% round(3), '%)')), 
            Age = paste(round(as.numeric(mean(age, na.rm=TRUE)),2), paste0('(SD=', sd(age, na.rm=TRUE) %>% round(2),')')), 
            Male = paste(sum(gender == 'M'), paste0('(',100*round(sum(gender == 'M')/n(),3),'%)')),
            MICU = paste(sum(first_careunit == 'MICU'), paste0('(',100*round(sum(first_careunit == 'MICU')/n(),3),'%)')),
            SICU = paste(sum(first_careunit == 'SICU'), paste0('(',100*round(sum(first_careunit == 'SICU')/n(),3),'%)')),
            CCU = paste(sum(first_careunit == 'CCU'), paste0('(',100*round(sum(first_careunit == 'CCU')/n(),3),'%)')),
            TSICU = paste(sum(first_careunit == 'TSICU'), paste0('(',100*round(sum(first_careunit == 'TSICU')/n(),3),'%)')),
            CSRU = paste(sum(first_careunit == 'CSRU'), paste0('(',100*round(sum(first_careunit == 'CSRU')/n(),3),'%)')),
            Sepsis = paste(sum(simple_diagnosis == "SEPSIS"), paste0('(',100*round(sum(simple_diagnosis == "SEPSIS")/n(),3),'%)')),
            Infectious = paste(sum(simple_diagnosis == "INFECTION"), paste0('(',100*round(sum(simple_diagnosis == "INFECTION")/n(),3),'%)')),
            Cardiac = paste(sum(simple_diagnosis == "CARDIAC"), paste0('(',100*round(sum(simple_diagnosis == "CARDIAC")/n(),3),'%)')),
            CVC = paste(sum(cvc == "TRUE"), paste0('(',100*round(sum(cvc == "TRUE")/n(),3),'%)')),
            Intubated = paste(sum(intub == "TRUE"), paste0('(',100*round(sum(intub == "TRUE")/n(),3),'%)'))
             ) %>% t()
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
colnames(t1_df) <- t1_df[1,]

# %%
t1_df
# Out:
#            LESSTHAN24HOURS  LESSTHAN6HOURS   MORETHAN24HOURS
# STATUS     LESSTHAN24HOURS  LESSTHAN6HOURS   MORETHAN24HOURS
# n          5003 (33.1%)     3509 (23.2%)     6624 (43.8%)
# Age        65.58 (SD=13.83) 66.22 (SD=13.84) 65.8 (SD=14.13)
# Male       3067 (61.3%)     2079 (59.2%)     3907 (59%)
# MICU       1250 (25%)       785 (22.4%)      2093 (31.6%)
# SICU       571 (11.4%)      392 (11.2%)      845 (12.8%)
# CCU        644 (12.9%)      455 (13%)        976 (14.7%)
# TSICU      420 (8.4%)       292 (8.3%)       582 (8.8%)
# CSRU       2118 (42.3%)     1585 (45.2%)     2128 (32.1%)
# Sepsis     333 (6.7%)       150 (4.3%)       520 (7.9%)
# Infectious 240 (4.8%)       161 (4.6%)       447 (6.7%)
# Cardiac    1244 (24.9%)     916 (26.1%)      1350 (20.4%)
# CVC        4024 (80.4%)     2699 (76.9%)     6077 (91.7%)
# Intubated  4001 (80%)       2760 (78.7%)     5697 (86%)

# %%
t1_multi_df <- output_df %>% 
    rowwise() %>%
    mutate(MULTI = if(grepl(",", pressor)){'MULTI'}else{'NOT MULTI'}) %>%
    group_by(MULTI) %>%
        summarize(n = paste(round(as.numeric(n()),2), paste0('(', 100*(n()/nrow(output_df)) %>% round(3), '%)')), 
            Age = paste(round(as.numeric(mean(age, na.rm=TRUE)),2), paste0('(SD=', sd(age, na.rm=TRUE) %>% round(2),')')), 
            Male = paste(sum(gender == 'M'), paste0('(',100*round(sum(gender == 'M')/n(),3),'%)')),
            MICU = paste(sum(first_careunit == 'MICU'), paste0('(',100*round(sum(first_careunit == 'MICU')/n(),3),'%)')),
            SICU = paste(sum(first_careunit == 'SICU'), paste0('(',100*round(sum(first_careunit == 'SICU')/n(),3),'%)')),
            CCU = paste(sum(first_careunit == 'CCU'), paste0('(',100*round(sum(first_careunit == 'CCU')/n(),3),'%)')),
            TSICU = paste(sum(first_careunit == 'TSICU'), paste0('(',100*round(sum(first_careunit == 'TSICU')/n(),3),'%)')),
            CSRU = paste(sum(first_careunit == 'CSRU'), paste0('(',100*round(sum(first_careunit == 'CSRU')/n(),3),'%)')),
            Sepsis = paste(sum(simple_diagnosis == "SEPSIS"), paste0('(',100*round(sum(simple_diagnosis == "SEPSIS")/n(),3),'%)')),
            Infectious = paste(sum(simple_diagnosis == "INFECTION"), paste0('(',100*round(sum(simple_diagnosis == "INFECTION")/n(),3),'%)')),
            Cardiac = paste(sum(simple_diagnosis == "CARDIAC"), paste0('(',100*round(sum(simple_diagnosis == "CARDIAC")/n(),3),'%)')),
            CVC = paste(sum(cvc == "TRUE"), paste0('(',100*round(sum(cvc == "TRUE")/n(),3),'%)')),
            Intubated = paste(sum(intub == "TRUE"), paste0('(',100*round(sum(intub == "TRUE")/n(),3),'%)'))
             ) %>% t()
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
colnames(t1_multi_df) <- t1_multi_df[1,]

# %%
t1_multi_df
# Out:
#            MULTI            NOT MULTI
# MULTI      MULTI            NOT MULTI
# n          5077 (33.5%)     10059 (66.5%)
# Age        66.44 (SD=14.14) 65.51 (SD=13.86)
# Male       3010 (59.3%)     6043 (60.1%)
# MICU       1632 (32.1%)     2496 (24.8%)
# SICU       558 (11%)        1250 (12.4%)
# CCU        798 (15.7%)      1277 (12.7%)
# TSICU      387 (7.6%)       907 (9%)
# CSRU       1702 (33.5%)     4129 (41%)
# Sepsis     409 (8.1%)       594 (5.9%)
# Infectious 304 (6%)         544 (5.4%)
# Cardiac    1050 (20.7%)     2460 (24.5%)
# CVC        4618 (91%)       8182 (81.3%)
# Intubated  4517 (89%)       7941 (78.9%)

# %%
cbind(t1_df, t1_multi_df) %>% write.csv(file.path(PLOT_DIR, "response_demographics.csv"))

# %% [markdown]
# ### Supplement Table (solo agents)

# %%
s1_3_df <- output_df %>% 
    filter(!grepl(",", pressor)) %>%
    group_by(STATUS, pressor) %>%
        summarize(n = paste(round(as.numeric(n()),2), paste0('(', 100*(n()/nrow(output_df)) %>% round(3), '%)')), 
            Age = paste(round(as.numeric(mean(age, na.rm=TRUE)),2), paste0('(SD=', sd(age, na.rm=TRUE) %>% round(2),')')), 
            Male = paste(sum(gender == 'M'), paste0('(',100*round(sum(gender == 'M')/n(),3),'%)')),
            MICU = paste(sum(first_careunit == 'MICU'), paste0('(',100*round(sum(first_careunit == 'MICU')/n(),3),'%)')),
            SICU = paste(sum(first_careunit == 'SICU'), paste0('(',100*round(sum(first_careunit == 'SICU')/n(),3),'%)')),
            CCU = paste(sum(first_careunit == 'CCU'), paste0('(',100*round(sum(first_careunit == 'CCU')/n(),3),'%)')),
            TSICU = paste(sum(first_careunit == 'TSICU'), paste0('(',100*round(sum(first_careunit == 'TSICU')/n(),3),'%)')),
            CSRU = paste(sum(first_careunit == 'CSRU'), paste0('(',100*round(sum(first_careunit == 'CSRU')/n(),3),'%)')),
            Sepsis = paste(sum(simple_diagnosis == "SEPSIS"), paste0('(',100*round(sum(simple_diagnosis == "SEPSIS")/n(),3),'%)')),
            Infectious = paste(sum(simple_diagnosis == "INFECTION"), paste0('(',100*round(sum(simple_diagnosis == "INFECTION")/n(),3),'%)')),
            Cardiac = paste(sum(simple_diagnosis == "CARDIAC"), paste0('(',100*round(sum(simple_diagnosis == "CARDIAC")/n(),3),'%)')),
            CVC = paste(sum(cvc == "TRUE"), paste0('(',100*round(sum(cvc == "TRUE")/n(),3),'%)')),
            Intubated = paste(sum(intub == "TRUE"), paste0('(',100*round(sum(intub == "TRUE")/n(),3),'%)'))
             )
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
s1_3_df <- output_df %>% 
    filter(!grepl(",", pressor)) %>%
    group_by(STATUS, pressor) %>%
        summarize(n = n(), 
            Age = paste(round(as.numeric(mean(age, na.rm=TRUE)),2), paste0('(SD=', sd(age, na.rm=TRUE) %>% round(2),')')), 
            Male = paste(sum(gender == 'M'), paste0('(',100*round(sum(gender == 'M')/n(),3),'%)')),
            MICU = paste(sum(first_careunit == 'MICU'), paste0('(',100*round(sum(first_careunit == 'MICU')/n(),3),'%)')),
            SICU = paste(sum(first_careunit == 'SICU'), paste0('(',100*round(sum(first_careunit == 'SICU')/n(),3),'%)')),
            CCU = paste(sum(first_careunit == 'CCU'), paste0('(',100*round(sum(first_careunit == 'CCU')/n(),3),'%)')),
            TSICU = paste(sum(first_careunit == 'TSICU'), paste0('(',100*round(sum(first_careunit == 'TSICU')/n(),3),'%)')),
            CSRU = paste(sum(first_careunit == 'CSRU'), paste0('(',100*round(sum(first_careunit == 'CSRU')/n(),3),'%)')),
            Sepsis = paste(sum(simple_diagnosis == "SEPSIS"), paste0('(',100*round(sum(simple_diagnosis == "SEPSIS")/n(),3),'%)')),
            Infectious = paste(sum(simple_diagnosis == "INFECTION"), paste0('(',100*round(sum(simple_diagnosis == "INFECTION")/n(),3),'%)')),
            Cardiac = paste(sum(simple_diagnosis == "CARDIAC"), paste0('(',100*round(sum(simple_diagnosis == "CARDIAC")/n(),3),'%)')),
            CVC = paste(sum(cvc == "TRUE"), paste0('(',100*round(sum(cvc == "TRUE")/n(),3),'%)')),
            Intubated = paste(sum(intub == "TRUE"), paste0('(',100*round(sum(intub == "TRUE")/n(),3),'%)'))
             )
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
for(pressor_choice in pressor_choices){
    out_df <- s1_3_df %>%
        filter(pressor == pressor_choice) %>%
        ungroup() %>%
        mutate(n = paste0(n, ' (', (n/sum(n)) %>% round(3), '%)')) %>%
        t()
    colnames(out_df) <- out_df[1,]
    out_df %>% 
        data.frame() %>%
        select(LESSTHAN6HOURS, LESSTHAN24HOURS, MORETHAN24HOURS) %>%
        write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_demographics.csv")))
}

# %% [markdown]
# # Categorical Predictors

# %%
# This function, given a dataframe with the appropriate columns, will compute RR statistics and return as a table 
calculatePredictors <- function(df){
    all_rr_list <- list()

    # gender
    output <- df %>%
        group_by(RESPONSE, gender) %>%
        summarize(COUNT = n()) %>%
        spread(RESPONSE, COUNT) %>%
        tibble::column_to_rownames("gender") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['MALE_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'M') %>%
            mutate(ID = "M", p = output$p.value["M","fisher.exact"])


#     # race
#     rr_list <- list()
#     for(race in races){
#        output <- df %>%
#             rowwise() %>%
#             group_by(RESPONSE, simple_race) %>%
#             summarize(COUNT = n()) %>%
#             mutate(RACE_BOOL = simple_race == race) %>%
#             group_by(RACE_BOOL, RESPONSE) %>%
#             summarize(COUNT = sum(COUNT)) %>%
#             spread(RESPONSE, COUNT) %>%
#             tibble::column_to_rownames("RACE_BOOL") %>%
#             as.matrix() %>% riskratio() 
#         rr_list[[race]] <- output$measure %>%
#             data.frame() %>%
#             tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
#             mutate(ID = race, p = output$p.value["TRUE","fisher.exact"])
#     }


#     all_rr_list[['RACE_RR']] <- bind_rows(rr_list)


    # age
    age_df <- df %>%
        group_by(RESPONSE, age_cohort) %>%
        summarize(COUNT = n()) %>%
        drop_na(age_cohort)

    rr_list <- list()
    for(ac in unique(age_df$age_cohort)){
       if(ac != 0){
           output <- age_df %>%
                mutate(AGE_BOOL = age_cohort == ac) %>%
                group_by(AGE_BOOL, RESPONSE) %>%
                summarize(COUNT = sum(COUNT)) %>%
                spread(RESPONSE, COUNT) %>%
                tibble::column_to_rownames("AGE_BOOL") %>%
                as.matrix() %>% riskratio() 

            rr_list[[ac]] <- output$measure %>%
                data.frame() %>%
                tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
                mutate(ID = as.character(ac), p = output$p.value["TRUE","fisher.exact"])
       }  
    }

    all_rr_list[['AGE_RR']] <- bind_rows(rr_list)


    # diagnosis
    diagnosis_df <- df %>%
        rowwise() %>%
        group_by(simple_diagnosis, RESPONSE) %>%
        summarize(COUNT = n()) 

    rr_list <- list()
    for(s_d in unique(diagnosis_df$simple_diagnosis)){
       output <- diagnosis_df %>%
            mutate(DX_BOOL = simple_diagnosis == s_d) %>%
            group_by(DX_BOOL, RESPONSE) %>%
            summarize(COUNT = sum(COUNT)) %>%
            spread(RESPONSE, COUNT) %>%
            tibble::column_to_rownames("DX_BOOL") %>%
            as.matrix() %>% riskratio() 
        rr_list[[s_d]] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = s_d, p = output$p.value["TRUE","fisher.exact"])
    }

    all_rr_list[['DIAGNOSIS_RR']] <- bind_rows(rr_list)


    # careunit
    careunit_df <- df %>%
        group_by(RESPONSE, first_careunit) %>%
        summarize(COUNT = n())

    rr_list <- list()
    for(cu in unique(careunit_df$first_careunit)){
       output <- careunit_df%>%
            mutate(CU_BOOL = first_careunit == cu) %>%
            group_by(CU_BOOL, RESPONSE) %>%
            summarize(COUNT = sum(COUNT)) %>%
            spread(RESPONSE, COUNT) %>%
            tibble::column_to_rownames("CU_BOOL") %>%
            as.matrix() %>% riskratio() 
        rr_list[[cu]] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = cu, p = output$p.value["TRUE","fisher.exact"])
    }

    all_rr_list[['CAREUNIT_RR']] <- bind_rows(rr_list)


    # intub
    output <- df %>%
        group_by(RESPONSE, intub) %>%
        summarize(COUNT = n()) %>%
        spread(RESPONSE, COUNT) %>%
        tibble::column_to_rownames("intub") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['INTUB_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = "INTUB", p = output$p.value["TRUE","fisher.exact"])

#     # cvc
#     output <- df %>%
#         group_by(RESPONSE, cvc) %>%
#         summarize(COUNT = n()) %>%
#         spread(RESPONSE, COUNT) %>%
#         tibble::column_to_rownames("cvc") %>%
#         as.matrix() %>% riskratio()

#     all_rr_list[['CVC_RR']] <- output$measure %>%
#             data.frame() %>%
#             tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
#             mutate(ID = "CVC", p = output$p.value["TRUE","fisher.exact"])


    # combined
    all_rr_df <- bind_rows(all_rr_list, .id="TYPE") %>%
        mutate(significant = p < 0.05)
    
    return(all_rr_df)
}

# %% [markdown]
# # Table 1 (RR significance)

# %%
rr_df <- calculatePredictors(output_df) %>%
    rowwise() %>%
    mutate(ID = if(ID == "M"){"MALE"}else{ID}) %>% select(-FILTER)
rr_df
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    TYPE         estimate  lower     upper     ID              p
# 1  MALE_RR      0.9526903 0.9238489 0.9824321 MALE            2.138664e-03
# 2  AGE_RR       0.9503516 0.8032454 1.1243988 20              5.515101e-01
# 3  AGE_RR       1.0399437 0.9371338 1.1540324 30              4.879422e-01
# 4  AGE_RR       1.0449525 0.9740602 1.1210043 40              2.404807e-01
# 5  AGE_RR       0.9645564 0.9201279 1.0111301 50              1.290005e-01
# 6  AGE_RR       0.9742233 0.9379326 1.0119182 60              1.747521e-01
# 7  AGE_RR       0.9778820 0.9435909 1.0134192 70              2.206118e-01
# 8  AGE_RR       1.0602263 1.0238492 1.0978959 80              1.247789e-03
# 9  AGE_RR       0.9884288 0.9199328 1.0620248 90              7.616862e-01
# 10 DIAGNOSIS_RR 0.8735374 0.8402034 0.9081938 CARDIAC         1.448423e-12
# 11 DIAGNOSIS_RR 1.1408452 1.0764884 1.2090496 INFECTION       3.414178e-05
# 12 DIAGNOSIS_RR 1.0274041 0.9949678 1.0608978 OTHER DIAGNOSIS 9.889422e-02
# 13 DIAGNOSIS_RR 1.1576934 1.0978696 1.2207771 SEPSIS          5.392325e-07
# 14 CAREUNIT_RR  1.0905916 1.0464124 1.1366359 CCU             7.735403e-05
# 15 CAREUNIT_RR  0.7894537 0.7634716 0.8163199 CSRU            8.571178e-47
# 16 CAREUNIT_RR  1.2137255 1.1763547 1.2522835 MICU            3.353192e-31
# 17 CAREUNIT_RR  1.0270276 0.9809354 1.0752855 SICU            2.696293e-01
# 18 CAREUNIT_RR  1.0101057 0.9570659 1.0660848 TSICU           7.269803e-01
# 19 INTUB_RR     1.2842812 1.2253264 1.3460726 INTUB           1.166020e-29
#    significant
# 1   TRUE
# 2  FALSE
# 3  FALSE
# 4  FALSE
# 5  FALSE
# 6  FALSE
# 7  FALSE
# 8   TRUE
# 9  FALSE
# 10  TRUE
# 11  TRUE
# 12 FALSE
# 13  TRUE
# 14  TRUE
# 15  TRUE
# 16  TRUE
# 17 FALSE
# 18 FALSE
# 19  TRUE

# %%
rr_df %>% 
    write.csv(file.path(PLOT_DIR, "relativerisk.csv"))

# %% [markdown]
# # Continuous Predictors

# %%
PRESSORHOURS_DICT <- c(
'TRUE' = "Prolonged or multiple vasopressor",
'FALSE' = "No prolonged or multiple vasopressor"
)

# %%
PRESSORHOURS_DICT['TRUE']
# Out:
#                                TRUE
# "Prolonged or multiple vasopressor"

# %%
severity_output_df <- output_df %>%
    head() %>%
    rowwise() %>%
    mutate(PRESSORHOURS = PRESSORHOURS_DICT[RESPONSE])
# Out:
# Error: Column `PRESSORHOURS` must be length 1 (the group size), not 2
# Traceback:
#
# 1. output_df %>% head() %>% rowwise() %>% mutate(PRESSORHOURS = PRESSORHOURS_DICT[RESPONSE])
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. mutate(., PRESSORHOURS = PRESSORHOURS_DICT[RESPONSE])
# 10. mutate.tbl_df(., PRESSORHOURS = PRESSORHOURS_DICT[RESPONSE])
# 11. mutate_impl(.data, dots, caller_env())

# %%
output_df %>%
    head() %>%
    rowwise() %>%
    mutate(PRESSORHOURS = PRESSORHOURS_DICT[RESPONSE]) %>%
# Out:
# Error in parse(text = x, srcfile = src): <text>:5:0: unexpected end of input
# 3:     rowwise() %>%
# 4:     mutate(PRESSORHOURS = PRESSORHOURS_DICT[RESPONSE]) %>%
#   ^
# Traceback:

# %%
PRESSORHOURS_COLORS <- c(
"Prolonged or multiple vasopressor" = '#2F4F4F',
"No prolonged or multiple vasopressor" = '#D3D3D3'
)

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- output_df %>%
    ggplot(aes(x=RESPONSE, y=sofa)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("SOFA") +
        geom_violin(aes(fill=RESPONSE), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        #scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,40)) +
        geom_boxplot(width=0.05, outlier.shape = NA) #+
        #stat_summary(fun.y=median, geom="point", size=2, color="firebrick")
plot(p)
# Out:
# plot without title

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- output_df %>%
    ggplot(aes(x=RESPONSE, y=qsofa)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("QSOFA") +
        geom_violin(aes(fill=RESPONSE), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        #scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,10)) +
        geom_boxplot(width=0.05, outlier.shape = NA) #+
        #stat_summary(fun.y=median, geom="point", size=2, color="firebrick")
plot(p)
# Out:
# plot without title

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- output_df %>%
    ggplot(aes(x=RESPONSE, y=oasis)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("OASIS") +
        geom_violin(aes(fill=RESPONSE), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        #scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,80)) +
        geom_boxplot(width=0.05, outlier.shape = NA) #+
        #stat_summary(fun.y=median, geom="point", size=2, color="firebrick")
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Supplement (single agents)
# - Insufficient numbers for RR analysis for epinephrine and vasopressin

# %%
pressor_rr_list <- list()
for(pressor_choice in c('norepinephrinedurations', 'dopaminedurations', 'phenylephrinedurations')){
    pressor_rr_list[[pressor_choice]] <- output_df %>%
        filter(grepl(pressor_choice, pressor)) %>%
        calculatePredictors()
}
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message in chisq.test(xx, correct = correction):
# “Chi-squared approximation may be incorrect”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
pressor_rr_df <- bind_rows(pressor_rr_list, .id="pressor")  %>% select(-FILTER)

# %%
pressor_rr_df
# Out:
#    pressor                 TYPE         estimate  lower     upper
# 1  norepinephrinedurations MALE_RR      1.0169094 0.9864643 1.0482941
# 2  norepinephrinedurations AGE_RR       0.9313320 0.7889696 1.0993825
# 3  norepinephrinedurations AGE_RR       1.0172188 0.9268047 1.1164532
# 4  norepinephrinedurations AGE_RR       1.0188776 0.9532874 1.0889806
# 5  norepinephrinedurations AGE_RR       1.0072750 0.9640331 1.0524565
# 6  norepinephrinedurations AGE_RR       0.9835992 0.9468824 1.0217397
# 7  norepinephrinedurations AGE_RR       1.0150243 0.9800530 1.0512436
# 8  norepinephrinedurations AGE_RR       1.0043187 0.9699042 1.0399544
# 9  norepinephrinedurations AGE_RR       0.9580776 0.8935936 1.0272149
# 10 norepinephrinedurations DIAGNOSIS_RR 1.1427516 1.1005463 1.1865755
# 11 norepinephrinedurations DIAGNOSIS_RR 0.9239189 0.8722867 0.9786074
# 12 norepinephrinedurations DIAGNOSIS_RR 1.0382512 1.0051936 1.0723960
# 13 norepinephrinedurations DIAGNOSIS_RR 0.8627754 0.8181348 0.9098517
# 14 norepinephrinedurations CAREUNIT_RR  1.0781821 1.0365555 1.1214804
# 15 norepinephrinedurations CAREUNIT_RR  1.1237883 1.0864369 1.1624238
# 16 norepinephrinedurations CAREUNIT_RR  0.8787170 0.8521426 0.9061202
# 17 norepinephrinedurations CAREUNIT_RR  1.0299420 0.9869452 1.0748120
# 18 norepinephrinedurations CAREUNIT_RR  1.0271660 0.9777988 1.0790256
# 19 norepinephrinedurations INTUB_RR     1.4526874 1.3758934 1.5337676
# 20 dopaminedurations       MALE_RR      1.0438143 0.9928899 1.0973505
# 21 dopaminedurations       AGE_RR       1.0851963 0.8048884 1.4631233
# 22 dopaminedurations       AGE_RR       1.0692616 0.8801153 1.2990574
# 23 dopaminedurations       AGE_RR       0.9647114 0.8467721 1.0990776
# 24 dopaminedurations       AGE_RR       0.9826497 0.9063212 1.0654065
# 25 dopaminedurations       AGE_RR       0.9632231 0.9016126 1.0290438
# 26 dopaminedurations       AGE_RR       0.9639891 0.9077651 1.0236954
# 27 dopaminedurations       AGE_RR       1.0597817 1.0054017 1.1171030
# 28 dopaminedurations       AGE_RR       1.0306824 0.9395545 1.1306487
# 29 dopaminedurations       DIAGNOSIS_RR 1.0137238 0.9499140 1.0818200
# 30 dopaminedurations       DIAGNOSIS_RR 1.0481159 0.9531374 1.1525589
# 31 dopaminedurations       DIAGNOSIS_RR 0.9558791 0.9071316 1.0072462
# 32 dopaminedurations       DIAGNOSIS_RR 1.0760309 0.9860516 1.1742211
# 33 dopaminedurations       CAREUNIT_RR  0.8451058 0.8001117 0.8926302
# 34 dopaminedurations       CAREUNIT_RR  1.2108487 1.1406793 1.2853345
# 35 dopaminedurations       CAREUNIT_RR  1.0307402 0.9802647 1.0838147
# 36 dopaminedurations       CAREUNIT_RR  1.0743973 0.9865195 1.1701032
# 37 dopaminedurations       CAREUNIT_RR  1.1418805 1.0495239 1.2423644
# 38 dopaminedurations       INTUB_RR     1.6355320 1.5209507 1.7587454
# 39 phenylephrinedurations  MALE_RR      0.9140894 0.8798118 0.9497025
# 40 phenylephrinedurations  AGE_RR       0.8941866 0.7171515 1.1149244
# 41 phenylephrinedurations  AGE_RR       1.0010874 0.8706923 1.1510105
# 42 phenylephrinedurations  AGE_RR       1.0831204 0.9957508 1.1781560
# 43 phenylephrinedurations  AGE_RR       0.9511006 0.8969938 1.0084711
# 44 phenylephrinedurations  AGE_RR       0.9625502 0.9183409 1.0088878
# 45 phenylephrinedurations  AGE_RR       0.9704506 0.9288730 1.0138894
# 46 phenylephrinedurations  AGE_RR       1.0842419 1.0383168 1.1321983
# 47 phenylephrinedurations  AGE_RR       1.0147622 0.9245586 1.1137663
# 48 phenylephrinedurations  DIAGNOSIS_RR 0.7934313 0.7570806 0.8315274
# 49 phenylephrinedurations  DIAGNOSIS_RR 1.2933784 1.2003070 1.3936665
# 50 phenylephrinedurations  DIAGNOSIS_RR 1.0704227 1.0280234 1.1145707
# 51 phenylephrinedurations  DIAGNOSIS_RR 1.5747339 1.4911554 1.6629970
# 52 phenylephrinedurations  CAREUNIT_RR  1.2490789 1.1830218 1.3188245
# 53 phenylephrinedurations  CAREUNIT_RR  0.6992141 0.6727077 0.7267649
# 54 phenylephrinedurations  CAREUNIT_RR  1.5221186 1.4672320 1.5790585
# 55 phenylephrinedurations  CAREUNIT_RR  1.0410351 0.9864629 1.0986264
# 56 phenylephrinedurations  CAREUNIT_RR  0.9733418 0.9103317 1.0407132
# 57 phenylephrinedurations  INTUB_RR     1.0529520 0.9873959 1.1228606
#    ID              p            significant
# 1  M               2.812881e-01 FALSE
# 2  20              3.910097e-01 FALSE
# 3  30              7.797122e-01 FALSE
# 4  40              6.398994e-01 FALSE
# 5  50              7.630698e-01 FALSE
# 6  60              4.033400e-01 FALSE
# 7  70              4.262796e-01 FALSE
# 8  80              8.381776e-01 FALSE
# 9  90              2.062079e-01 FALSE
# 10 CARDIAC         1.764715e-09  TRUE
# 11 INFECTION       4.091248e-03  TRUE
# 12 OTHER DIAGNOSIS 2.240190e-02  TRUE
# 13 SEPSIS          1.692154e-09  TRUE
# 14 CCU             5.057092e-04  TRUE
# 15 CSRU            7.950518e-10  TRUE
# 16 MICU            5.881408e-17  TRUE
# 17 SICU            1.989649e-01 FALSE
# 18 TSICU           3.225942e-01 FALSE
# 19 INTUB           3.193036e-61  TRUE
# 20 M               9.896523e-02 FALSE
# 21 20              7.673076e-01 FALSE
# 22 30              6.998431e-01 FALSE
# 23 40              5.885435e-01 FALSE
# 24 50              6.776418e-01 FALSE
# 25 60              2.646106e-01 FALSE
# 26 70              2.206772e-01 FALSE
# 27 80              3.884444e-02  TRUE
# 28 90              6.100743e-01 FALSE
# 29 CARDIAC         7.357495e-01 FALSE
# 30 INFECTION       3.850576e-01 FALSE
# 31 OTHER DIAGNOSIS 1.075708e-01 FALSE
# 32 SEPSIS          1.341521e-01 FALSE
# 33 CCU             3.075595e-10  TRUE
# 34 CSRU            2.451130e-07  TRUE
# 35 MICU            2.430032e-01 FALSE
# 36 SICU            1.437863e-01 FALSE
# 37 TSICU           8.699429e-03  TRUE
# 38 INTUB           1.115635e-57  TRUE
# 39 M               5.196315e-06  TRUE
# 40 20              3.371045e-01 FALSE
# 41 30              1.000000e+00 FALSE
# 42 40              7.699394e-02 FALSE
# 43 50              8.851851e-02 FALSE
# 44 60              1.121788e-01 FALSE
# 45 70              1.767901e-01 FALSE
# 46 80              3.639886e-04  TRUE
# 47 90              7.989436e-01 FALSE
# 48 CARDIAC         1.547119e-24  TRUE
# 49 INFECTION       1.162791e-08  TRUE
# 50 OTHER DIAGNOSIS 8.780662e-04  TRUE
# 51 SEPSIS          1.114991e-28  TRUE
# 52 CCU             1.032678e-12  TRUE
# 53 CSRU            2.797366e-76  TRUE
# 54 MICU            2.734950e-80  TRUE
# 55 SICU            1.563068e-01 FALSE
# 56 TSICU           4.350134e-01 FALSE
# 57 INTUB           1.086690e-01 FALSE

# %%
pressor_rr_df %>% 
    write.csv(file.path(PLOT_DIR, "relativerisk_eachpressor.csv"))

# %% [markdown]
# # Figure 1 Plotting RR

# %%
SIGNIFICANT_COLORS <- c(
"Significant" = '#2F4F4F',
"Not Significant" = '#D3D3D3'
)

# %%
ID_DICT <- c(
'M' = "Male Gender",
'INTUB' = "Intubated",
#'CVC' = "CVC Placed",
'20' = "Age 15-25",
'30' = "Age 25-35",
'40' = "Age 35-45",
'50' = "Age 45-55",
'60' = "Age 55-65",
'70' = "Age 65-75",
'80' = "Age 75-85",
'90' = "Age 85-95",
'CARDIAC' = "Cardiac Diagnosis",
'INFECTION' = "Infectious Diagnosis",
'SEPSIS' = "Sepsis Diagnosis",
'OTHER DIAGNOSIS' = "Other Diagnosis",
'CCU' = 'CCU',
'CSRU' = 'CSRU',
'MICU' = 'MICU',
'SICU' = 'SICU',
'TSICU' = 'TSICU'
)

# %%
options(repr.plot.width=3.5, repr.plot.height=4)
p <- calculatePredictors(output_df)  %>%
    rowwise() %>%
    mutate(ID = ID_DICT[ID]) %>% 
    mutate(ID = factor(ID, levels=rev(ID_DICT))) %>%
    mutate(significant = if(significant){'Significant'}else{'Not Significant'}) %>%
    mutate(legend = factor(significant, levels=names(SIGNIFICANT_COLORS))) %>%
    ggplot(aes(x = ID,y = estimate, ymin = lower, ymax = upper ))+
        base_theme() +
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Risk ratio of prolonged/multiple pressor 95% CI")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=significant),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "relativerisk.pdf"), 3.5,4)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
options(repr.plot.width=7, repr.plot.height=4)
p <- pressor_rr_df  %>%
    rowwise() %>%
    mutate(ID = ID_DICT[ID]) %>% 
    mutate(ID = factor(ID, levels=rev(ID_DICT))) %>%
    mutate(significant = if(significant){'Significant'}else{'Not Significant'}) %>%
    mutate(legend = factor(significant, levels=names(SIGNIFICANT_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x = ID,y = estimate, ymin = lower, ymax = upper ))+
        base_theme() +
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Risk ratio of prolonged/multiple pressor 95% CI")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=significant),width=0.5,cex=1)+ 
        coord_flip() + 
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, "relativerisk_eachpressor.pdf"), 7,4)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # Vitals

# %% [markdown]
# ### Pre-processing (30 minutes): read in vitals_df, join with output_df of courses and compute mean vitals information each hour -> results_df

# %%
vitals_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/vitals.csv')

# %%
# takes 6 mins to run (because of difftime)

vitals_merged_df <- vitals_df %>%
    mutate(charttime = fastPOSIXct(charttime)) %>%
    filter(icustay_id %in% output_df$icustay_id) %>%
    left_join(select(output_df, icustay_id, course_id, pressor, starttime, endtime, MORETHAN24HOURS, RESPONSE, STATUS), by = "icustay_id") %>%
    rowwise() %>%
    mutate(diff = difftime(charttime, 
                       starttime, units="hours"))

# %%
# for 10 hours prior to pressor initiation
intervals <- 1:10

# %%
results_list <- list()

# %%
# takes 40 mins to run overall
for(interval in intervals){
    # 4 mins to run each
    results_list[[interval]] <- vitals_merged_df %>%
        filter(diff < 0) %>%
        filter(diff < -(interval - 1) & diff > -interval) %>%
        group_by(MORETHAN24HOURS, RESPONSE, STATUS, course_id, pressor) %>%
        summarize(mean_heartrate = mean(heartrate, na.rm=T), 
                  mean_sysbp = mean(sysbp, na.rm=T),
                  mean_diasbp = mean(diasbp, na.rm=T),
                  mean_meanbp = mean(meanbp, na.rm=T), 
                  mean_resprate = mean(resprate, na.rm=T), 
                  mean_tempc = mean(tempc, na.rm=T), 
                  mean_spo2 = mean(spo2, na.rm=T), 
                  mean_glucose = mean(glucose, na.rm=T), 

                  median_heartrate = median(heartrate, na.rm=T), 
                  median_sysbp = median(sysbp, na.rm=T),
                  median_diasbp = median(diasbp, na.rm=T),
                  median_meanbp = median(meanbp, na.rm=T), 
                  median_resprate = median(resprate, na.rm=T), 
                  median_tempc = median(tempc, na.rm=T), 
                  median_spo2 = median(spo2, na.rm=T), 
                  median_glucose = median(glucose, na.rm=T),

                 ) %>%
        mutate(INTERVAL = interval)

}
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
results_df <- bind_rows(results_list)

# %%
melt_results_df <- results_df %>% 
    gather("ID", "VALUE", -course_id, -pressor, -MORETHAN24HOURS, -INTERVAL, -STATUS, -RESPONSE)

# %%
melt_results_df %>% write.csv('~/Projects/Haimovich_Pressors/collection/out/melt_summarized_vitals.csv')

# %% [markdown]
# ### Read-in directly

# %%
melt_results_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/melt_summarized_vitals.csv')

# %% [markdown]
# ### ANCOVA analysis using intervals
# - MORETHAN24HOURS P-value tells you if this vital sign is a predictor (BP, HR, RR, TEMP)
# - INTERVAL P-value tells you if these values change depending on the interval being measured (most values)
# - MORETHAN24HOURS:INTERVAL P-value tells you if vital sign interacts with the interval being measured, that is, the extent of predictive value differs with time (BP especially, others are borderline significant)

# %%
computeANCOVA <- function(df) {
    vitals_result_list <- list()
    for(vital in unique(melt_results_df$ID)){
        #cat("####", vital, "####")
        totest <- df %>%
             filter(ID == vital)
        test <- summary(aov(VALUE ~ RESPONSE*INTERVAL, data = totest))[[1]]

        vitals_result_list[[vital]] <- data.frame(RESPONSE = test["RESPONSE", "Pr(>F)"],
                                                RESPONSE_F = test["RESPONSE", "F value"],
                                                 INTERACTION = test["RESPONSE:INTERVAL", "Pr(>F)"],
                                                 INTERACTION_F = test["RESPONSE:INTERVAL", "F value"])
    }
    vitals_result_df <- bind_rows(vitals_result_list, .id="ID")
    
    return(vitals_result_df)
}

# %% [markdown]
# # Table 2 (Wilcox and ANCOVA Vitals)

# %%
computeTest <- function(d, value="VALUE", comparison="GROUP"){
    paired_df <- d %>% 
        select(!!rlang::sym(comparison), !!rlang::sym(value)) 
    
    items <- unique(unlist(d[,comparison]))

    result_unpair <- t.test(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, 
       filter(d, !!rlang::sym(comparison) == items[2])$VALUE, paired = FALSE)
    result_wilcox <- wilcox.test(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, 
       filter(d, !!rlang::sym(comparison) == items[2])$VALUE, paired = FALSE)
    
    diff = mean(filter(d, !!rlang::sym(comparison) == items[1])$VALUE) -  
        mean(filter(d, !!rlang::sym(comparison) == items[2])$VALUE)
    
    return(data.frame(list(
                           'P_UNPAIR' = result_unpair$p.value, 
                           'P_WILCOX' = result_wilcox$p.value,
                            'GROUP1' = mean(filter(d, !!rlang::sym(comparison) == items[1])$VALUE),
                            'GROUP2' = mean(filter(d, !!rlang::sym(comparison) == items[2])$VALUE),
                            'DIFF' = diff,
                            'COMPARE' = paste(items[1], items[2], sep ='-'))))
}

# %% [markdown]
# ### Table 2. mean and standard deviation of vitals  for different time status

# %%
# means
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS) %>%
    summarize(MEAN = mean(VALUE)) %>%
    spread(STATUS, MEAN)
# Out:
#    ID               LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# 1  mean_diasbp       55.37966        57.02170       54.88502
# 2  mean_glucose     145.64881       144.03042      152.78562
# 3  mean_heartrate    87.71849        85.71852       91.80982
# 4  mean_meanbp       71.73020        73.67933       70.56299
# 5  mean_resprate     17.33357        17.14258       18.48052
# 6  mean_spo2         97.55004        97.79911       97.11622
# 7  mean_sysbp       106.17763       109.57650      103.90468
# 8  mean_tempc        36.44443        36.37388       36.43804
# 9  median_diasbp     55.24362        56.80476       54.67415
# 10 median_glucose   145.63674       143.99505      152.80349
# 11 median_heartrate  87.70208        85.68816       91.77289
# 12 median_meanbp     71.41839        73.33203       70.25501
# 13 median_resprate   17.25735        17.05766       18.41628
# 14 median_spo2       97.65287        97.89713       97.24013
# 15 median_sysbp     105.96437       109.31425      103.65562
# 16 median_tempc      36.44502        36.37351       36.43825

# %%
# standard deviations
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS) %>%
    summarize(SD = sd(VALUE)) %>%
    spread(STATUS, SD)
# Out:
#    ID               LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# 1  mean_diasbp      12.552749       13.761871      13.408412
# 2  mean_glucose     58.338457       57.500606      69.328346
# 3  mean_heartrate   18.737427       18.728210      20.679580
# 4  mean_meanbp      14.249944       15.220714      15.445095
# 5  mean_resprate     5.649351        5.498053       6.065156
# 6  mean_spo2         4.958758        4.385836       4.727884
# 7  mean_sysbp       18.839911       20.608968      20.081573
# 8  mean_tempc        1.105529        1.135525       1.158223
# 9  median_diasbp    12.719450       13.918746      13.571861
# 10 median_glucose   58.356987       57.515807      69.333590
# 11 median_heartrate 18.930283       18.961408      20.813142
# 12 median_meanbp    14.298101       15.449464      15.595919
# 13 median_resprate   5.735273        5.565805       6.165269
# 14 median_spo2       4.913357        4.318235       4.684994
# 15 median_sysbp     19.418759       21.042429      20.540423
# 16 median_tempc      1.106104        1.136751       1.159280

# %%
# means
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    filter(!grepl(",", pressor)) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS, pressor) %>%
    summarize(MEAN = mean(VALUE)) %>%
    ungroup() %>%
    filter(pressor %in% pressor_choices) %>%
    spread(STATUS, MEAN) %>% arrange(pressor)
# Out:
#    ID               pressor                LESSTHAN24HOURS LESSTHAN6HOURS
# 1  mean_diasbp      dobutaminedurations     58.70938        59.58478
# 2  mean_glucose     dobutaminedurations    155.41176       176.44444
# 3  mean_heartrate   dobutaminedurations     91.60143        96.52326
# 4  mean_meanbp      dobutaminedurations     76.91452        76.16215
# 5  mean_resprate    dobutaminedurations     17.85625        19.48090
# 6  mean_spo2        dobutaminedurations     97.76225        96.31319
# 7  mean_sysbp       dobutaminedurations    118.73148       109.49094
# 8  mean_tempc       dobutaminedurations     36.35992        36.35514
# 9  median_diasbp    dobutaminedurations     58.68750        59.54348
# 10 median_glucose   dobutaminedurations    155.41176       176.44444
# 11 median_heartrate dobutaminedurations     91.62857        96.18750
# 12 median_meanbp    dobutaminedurations     76.98571        76.21528
# 13 median_resprate  dobutaminedurations     17.90278        19.45833
# 14 median_spo2      dobutaminedurations     97.88235        96.36538
# 15 median_sysbp     dobutaminedurations    119.15972       109.52174
# 16 median_tempc     dobutaminedurations     36.36429        36.35556
# 17 mean_diasbp      dopaminedurations       52.61859        54.49779
# 18 mean_glucose     dopaminedurations      180.39103       150.63211
# 19 mean_heartrate   dopaminedurations       80.27786        82.37076
# 20 mean_meanbp      dopaminedurations       69.80272        70.51865
# 21 mean_resprate    dopaminedurations       18.43014        18.70692
# 22 mean_spo2        dopaminedurations       96.24040        96.33417
# 23 mean_sysbp       dopaminedurations      107.61782       107.05742
# 24 mean_tempc       dopaminedurations       36.43495        36.34089
# 25 median_diasbp    dopaminedurations       52.45520        54.19145
# 26 median_glucose   dopaminedurations      180.39103       150.63211
# 27 median_heartrate dopaminedurations       80.14407        82.35535
# 28 median_meanbp    dopaminedurations       69.51169        70.29386
# 29 median_resprate  dopaminedurations       18.31873        18.62109
# 30 median_spo2      dopaminedurations       96.35893        96.55973
# ⋮  ⋮                ⋮                      ⋮               ⋮
# 67 mean_heartrate   phenylephrinedurations  86.87091        84.70235
# 68 mean_meanbp      phenylephrinedurations  73.61111        74.75822
# 69 mean_resprate    phenylephrinedurations  16.06754        16.01271
# 70 mean_spo2        phenylephrinedurations  98.40664        98.58763
# 71 mean_sysbp       phenylephrinedurations 107.46262       110.63710
# 72 mean_tempc       phenylephrinedurations  36.45276        36.40157
# 73 median_diasbp    phenylephrinedurations  56.30206        57.36382
# 74 median_glucose   phenylephrinedurations 136.09811       136.25657
# 75 median_heartrate phenylephrinedurations  86.83504        84.64747
# 76 median_meanbp    phenylephrinedurations  73.27724        74.47566
# 77 median_resprate  phenylephrinedurations  15.97784        15.92991
# 78 median_spo2      phenylephrinedurations  98.51342        98.65901
# 79 median_sysbp     phenylephrinedurations 107.28402       110.50616
# 80 median_tempc     phenylephrinedurations  36.45352        36.40104
# 81 mean_diasbp      vasopressindurations    51.20486        57.77273
# 82 mean_glucose     vasopressindurations   115.66667       165.50000
# 83 mean_heartrate   vasopressindurations    92.11806        89.28030
# 84 mean_meanbp      vasopressindurations    65.94908        72.81061
# 85 mean_resprate    vasopressindurations    19.60606        18.34028
# 86 mean_spo2        vasopressindurations    98.15972        97.90909
# 87 mean_sysbp       vasopressindurations    98.87847       112.71212
# 88 mean_tempc       vasopressindurations    36.89444        37.01587
# 89 median_diasbp    vasopressindurations    51.50000        56.95455
# 90 median_glucose   vasopressindurations   115.66667       165.50000
# 91 median_heartrate vasopressindurations    92.29167        89.27273
# 92 median_meanbp    vasopressindurations    66.16667        72.81818
# 93 median_resprate  vasopressindurations    19.81818        18.33333
# 94 median_spo2      vasopressindurations    98.20833        97.95455
# 95 median_sysbp     vasopressindurations    99.04167       112.11364
# 96 median_tempc     vasopressindurations    36.88333        37.01587
#    MORETHAN24HOURS
# 1   62.75588
# 2  152.00000
# 3   87.13380
# 4   79.06404
# 5   19.11520
# 6   96.73232
# 7  112.66029
# 8   36.69593
# 9   62.72794
# 10 152.00000
# 11  87.12500
# 12  79.27450
# 13  19.06618
# 14  96.74242
# 15 113.09559
# 16  36.69118
# 17  53.00808
# 18 174.20320
# 19  80.48769
# 20  69.25356
# 21  18.62621
# 22  96.35540
# 23 105.15319
# 24  36.18671
# 25  52.73840
# 26 174.20320
# 27  80.40208
# 28  68.73050
# 29  18.58735
# 30  96.48093
# ⋮  ⋮
# 67  87.49435
# 68  74.33597
# 69  16.67769
# 70  98.31806
# 71 107.91318
# 72  36.49484
# 73  56.90864
# 74 132.34038
# 75  87.47291
# 76  74.00231
# 77  16.59988
# 78  98.43052
# 79 107.81278
# 80  36.49518
# 81  51.99206
# 82 148.70000
# 83  91.68417
# 84  69.75615
# 85  20.31579
# 86  96.15833
# 87 109.40159
# 88  36.67361
# 89  52.50000
# 90 148.70000
# 91  92.32500
# 92  69.94738
# 93  20.25000
# 94  96.02500
# 95 109.16667
# 96  36.67361

# %%
# standard deviations
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    filter(!grepl(",", pressor)) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS, pressor) %>%
    summarize(SD = sd(VALUE)) %>%
    ungroup() %>%
    filter(pressor %in% pressor_choices) %>%
    spread(STATUS, SD) %>% arrange(pressor)
# Out:
#    ID               pressor                LESSTHAN24HOURS LESSTHAN6HOURS
# 1  mean_diasbp      dobutaminedurations    12.3005203       9.2782151
# 2  mean_glucose     dobutaminedurations    73.9552727      60.2725292
# 3  mean_heartrate   dobutaminedurations    19.2187087      32.5464116
# 4  mean_meanbp      dobutaminedurations    10.7398188      14.8522410
# 5  mean_resprate    dobutaminedurations     5.8928085       6.0879968
# 6  mean_spo2        dobutaminedurations     2.5836292       4.7763053
# 7  mean_sysbp       dobutaminedurations    14.5315004      24.3617581
# 8  mean_tempc       dobutaminedurations     0.9798862       0.6647991
# 9  median_diasbp    dobutaminedurations    12.1749707       9.3004314
# 10 median_glucose   dobutaminedurations    73.9552727      60.2725292
# 11 median_heartrate dobutaminedurations    19.2607277      32.5916142
# 12 median_meanbp    dobutaminedurations    10.6095569      15.0194297
# 13 median_resprate  dobutaminedurations     5.9890608       6.0323704
# 14 median_spo2      dobutaminedurations     2.5317943       4.7255850
# 15 median_sysbp     dobutaminedurations    14.8762938      24.9943077
# 16 median_tempc     dobutaminedurations     0.9820293       0.6690287
# 17 mean_diasbp      dopaminedurations      12.7906202      15.7193492
# 18 mean_glucose     dopaminedurations      87.3779909      61.5104168
# 19 mean_heartrate   dopaminedurations      20.0150240      21.1486787
# 20 mean_meanbp      dopaminedurations      14.0409250      16.7832830
# 21 mean_resprate    dopaminedurations       4.6882819       5.1137079
# 22 mean_spo2        dopaminedurations       5.1616965       5.6001365
# 23 mean_sysbp       dopaminedurations      21.5790203      22.2784202
# 24 mean_tempc       dopaminedurations       1.0107987       1.0255523
# 25 median_diasbp    dopaminedurations      12.8542871      15.7292885
# 26 median_glucose   dopaminedurations      87.3779909      61.5104168
# 27 median_heartrate dopaminedurations      20.3669673      21.3212506
# 28 median_meanbp    dopaminedurations      14.2671859      17.2761957
# 29 median_resprate  dopaminedurations       4.7696058       5.2321484
# 30 median_spo2      dopaminedurations       5.1727081       5.3093368
# ⋮  ⋮                ⋮                      ⋮               ⋮
# 67 mean_heartrate   phenylephrinedurations 17.089438       16.550291
# 68 mean_meanbp      phenylephrinedurations 13.024974       13.734074
# 69 mean_resprate    phenylephrinedurations  5.192481        4.993810
# 70 mean_spo2        phenylephrinedurations  3.809158        2.799607
# 71 mean_sysbp       phenylephrinedurations 16.921493       18.824185
# 72 mean_tempc       phenylephrinedurations  1.014468        1.073734
# 73 median_diasbp    phenylephrinedurations 11.214849       12.030033
# 74 median_glucose   phenylephrinedurations 43.205247       40.478412
# 75 median_heartrate phenylephrinedurations 17.262723       16.693027
# 76 median_meanbp    phenylephrinedurations 12.936581       13.916938
# 77 median_resprate  phenylephrinedurations  5.273209        5.014860
# 78 median_spo2      phenylephrinedurations  3.719288        2.772244
# 79 median_sysbp     phenylephrinedurations 17.636728       19.314597
# 80 median_tempc     phenylephrinedurations  1.016170        1.075012
# 81 mean_diasbp      vasopressindurations   10.964409       13.161713
# 82 mean_glucose     vasopressindurations   13.428825       29.962477
# 83 mean_heartrate   vasopressindurations   17.373949       27.900375
# 84 mean_meanbp      vasopressindurations   13.304983       13.329899
# 85 mean_resprate    vasopressindurations    6.770144        5.632972
# 86 mean_spo2        vasopressindurations    1.983664        1.881730
# 87 mean_sysbp       vasopressindurations   19.694201       20.134112
# 88 mean_tempc       vasopressindurations    1.057790        0.568112
# 89 median_diasbp    vasopressindurations   10.662168       13.660993
# 90 median_glucose   vasopressindurations   13.428825       29.962477
# 91 median_heartrate vasopressindurations   17.551817       27.915375
# 92 median_meanbp    vasopressindurations   13.096951       14.064624
# 93 median_resprate  vasopressindurations    6.983096        5.682242
# 94 median_spo2      vasopressindurations    2.016504        1.929437
# 95 median_sysbp     vasopressindurations   19.515097       20.292660
# 96 median_tempc     vasopressindurations    1.072999        0.568112
#    MORETHAN24HOURS
# 1  11.648832
# 2  72.324615
# 3  16.601731
# 4  14.781387
# 5   6.091060
# 6   2.387009
# 7  24.566587
# 8   1.443482
# 9  11.512241
# 10 72.324615
# 11 16.607389
# 12 14.853757
# 13  6.108647
# 14  2.378685
# 15 24.694345
# 16  1.450310
# 17 14.887271
# 18 93.133008
# 19 20.019903
# 20 14.790651
# 21  5.204288
# 22  5.206102
# 23 21.497256
# 24  1.013863
# 25 14.941717
# 26 93.133008
# 27 20.230518
# 28 14.948340
# 29  5.225331
# 30  5.245531
# ⋮  ⋮
# 67 18.9546334
# 68 14.9750047
# 69  5.3505344
# 70  3.1149527
# 71 19.3312091
# 72  0.9782889
# 73 11.8859910
# 74 38.8409873
# 75 19.1079489
# 76 15.1045998
# 77  5.4515319
# 78  3.0543796
# 79 19.9673113
# 80  0.9776329
# 81 12.5303494
# 82 55.3868215
# 83 16.5187555
# 84 13.0521376
# 85  5.4961111
# 86  4.4319002
# 87 20.2971275
# 88  0.3382171
# 89 13.1937485
# 90 55.3868215
# 91 17.6696849
# 92 13.0606430
# 93  5.4128191
# 94  4.7751412
# 95 19.9695602
# 96  0.3382171

# %% [markdown]
# ### Wilcox for significant difference at <1 hr before start of pressors

# %% [markdown]
# All pressors

# %%
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID) %>%
    do(computeTest(.,value="VALUE", comparison="RESPONSE")) %>%
    mutate(significant = P_WILCOX < 0.05)
# Out:
#    ID               P_UNPAIR     P_WILCOX     GROUP1    GROUP2    DIFF
# 1  mean_diasbp      1.450885e-09 1.006781e-12  56.34149  54.81394   1.52754415
# 2  mean_glucose     1.867479e-12 6.461873e-08 142.51932 153.72534 -11.20601837
# 3  mean_heartrate   7.944865e-52 2.131873e-52  86.10890  91.74134  -5.63244165
# 4  mean_meanbp      2.779775e-18 4.430731e-25  72.97178  70.47783   2.49395531
# 5  mean_resprate    1.210049e-42 1.737892e-40  17.02837  18.48252  -1.45415393
# 6  mean_spo2        1.533949e-28 7.745203e-33  97.93619  96.93714   0.99904660
# 7  mean_sysbp       1.461957e-31 1.459154e-40 108.28353 103.85166   4.43187285
# 8  mean_tempc       3.414032e-01 1.903144e-01  36.43977  36.41047   0.02929607
# 9  median_diasbp    3.588475e-10 2.549194e-13  56.19288  54.59027   1.60260689
# 10 median_glucose   1.551139e-12 5.841493e-08 142.49221 153.74148 -11.24927956
# 11 median_heartrate 3.009560e-51 3.621300e-52  86.07137  91.72088  -5.64950112
# 12 median_meanbp    3.548458e-18 1.351931e-25  72.66054  70.15287   2.50767030
# 13 median_resprate  4.315559e-42 3.006981e-39  16.94924  18.41509  -1.46584473
# 14 median_spo2      2.347107e-27 3.026827e-31  98.03025  97.06373   0.96652456
# 15 median_sysbp     4.872148e-31 2.143347e-40 108.07913 103.57818   4.50095384
# 16 median_tempc     3.421019e-01 1.908002e-01  36.43996  36.41068   0.02927798
#    COMPARE    significant
# 1  FALSE-TRUE  TRUE
# 2  FALSE-TRUE  TRUE
# 3  FALSE-TRUE  TRUE
# 4  FALSE-TRUE  TRUE
# 5  FALSE-TRUE  TRUE
# 6  FALSE-TRUE  TRUE
# 7  FALSE-TRUE  TRUE
# 8  FALSE-TRUE FALSE
# 9  FALSE-TRUE  TRUE
# 10 FALSE-TRUE  TRUE
# 11 FALSE-TRUE  TRUE
# 12 FALSE-TRUE  TRUE
# 13 FALSE-TRUE  TRUE
# 14 FALSE-TRUE  TRUE
# 15 FALSE-TRUE  TRUE
# 16 FALSE-TRUE FALSE

# %% [markdown]
# Pressors by type

# %%
melt_results_df %>%
    filter(!grepl(",", pressor)) %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    mutate(pressor = factor(pressor, levels=pressor_choices)) %>%
    group_by(ID, pressor) %>%
    do(computeTest(.,value="VALUE", comparison="RESPONSE")) %>%
    mutate(significant = P_WILCOX < 0.05) %>%
    arrange(pressor)
# Out:
# Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”Warning message in wilcox.test.default(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, :
# “cannot compute exact p-value with ties”
#    ID               pressor                 P_UNPAIR     P_WILCOX     GROUP1
# 1  mean_diasbp      norepinephrinedurations 8.627919e-03 1.045164e-03  55.77303
# 2  mean_glucose     norepinephrinedurations 5.318814e-02 5.178592e-02 163.16307
# 3  mean_heartrate   norepinephrinedurations 1.732808e-02 7.070951e-03  88.63319
# 4  mean_meanbp      norepinephrinedurations 2.053741e-04 2.405803e-06  70.52472
# 5  mean_resprate    norepinephrinedurations 6.860357e-04 1.754619e-04  19.18622
# 6  mean_spo2        norepinephrinedurations 6.458184e-02 1.294864e-02  97.14306
# 7  mean_sysbp       norepinephrinedurations 2.253928e-06 1.389227e-08 105.74318
# 8  mean_tempc       norepinephrinedurations 4.271811e-01 5.255670e-01  36.55380
# 9  median_diasbp    norepinephrinedurations 8.831397e-03 1.358616e-03  55.59104
# 10 median_glucose   norepinephrinedurations 5.276367e-02 5.034953e-02 163.17954
# 11 median_heartrate norepinephrinedurations 1.701393e-02 6.121657e-03  88.61508
# 12 median_meanbp    norepinephrinedurations 3.842053e-04 6.107568e-06  70.17743
# 13 median_resprate  norepinephrinedurations 7.052306e-04 1.439719e-04  19.13488
# 14 median_spo2      norepinephrinedurations 5.846589e-02 6.099529e-03  97.21737
# 15 median_sysbp     norepinephrinedurations 5.887781e-06 4.647101e-08 105.43991
# 16 median_tempc     norepinephrinedurations 4.387924e-01 5.297151e-01  36.55407
# 17 mean_diasbp      dopaminedurations       6.016325e-01 4.078679e-01  53.60156
# 18 mean_glucose     dopaminedurations       4.685738e-01 8.883478e-01 165.13958
# 19 mean_heartrate   dopaminedurations       5.691568e-01 7.222752e-01  81.36357
# 20 mean_meanbp      dopaminedurations       4.264725e-01 3.165691e-01  70.17668
# 21 mean_resprate    dopaminedurations       8.944565e-01 9.541054e-01  18.57510
# 22 mean_spo2        dopaminedurations       8.691430e-01 9.657344e-01  96.28835
# 23 mean_sysbp       dopaminedurations       1.928270e-01 1.188964e-01 107.32469
# 24 mean_tempc       dopaminedurations       1.444551e-01 8.715804e-02  36.38618
# 25 median_diasbp    dopaminedurations       5.836740e-01 4.219175e-01  53.36339
# 26 median_glucose   dopaminedurations       4.685738e-01 8.883478e-01 165.13958
# 27 median_heartrate dopaminedurations       5.676398e-01 7.544454e-01  81.29119
# 28 median_meanbp    dopaminedurations       3.126281e-01 2.466811e-01  69.92025
# 29 median_resprate  dopaminedurations       7.766051e-01 8.754589e-01  18.47709
# 30 median_spo2      dopaminedurations       9.620160e-01 9.795696e-01  96.46161
# ⋮  ⋮                ⋮                       ⋮            ⋮            ⋮
# 67 mean_heartrate   epinephrinedurations    0.1840719864 0.11325501    85.42924
# 68 mean_meanbp      epinephrinedurations    0.1021671420 0.31307090    79.99134
# 69 mean_resprate    epinephrinedurations    0.2726410629 0.17015846    13.82813
# 70 mean_spo2        epinephrinedurations    0.0001872458 0.21971214    99.28864
# 71 mean_sysbp       epinephrinedurations    0.9556849014 0.90769293   120.36976
# 72 mean_tempc       epinephrinedurations    0.0088389008 0.01831916    35.88333
# 73 median_diasbp    epinephrinedurations    0.1948319176 0.41678848    59.43119
# 74 median_glucose   epinephrinedurations    0.6405356242 0.72170281   139.64286
# 75 median_heartrate epinephrinedurations    0.2032368059 0.14158475    85.59174
# 76 median_meanbp    epinephrinedurations    0.1281470501 0.32701857    79.48012
# 77 median_resprate  epinephrinedurations    0.2342242986 0.18435693    13.68321
# 78 median_spo2      epinephrinedurations    0.0003768517 0.34901078    99.30435
# 79 median_sysbp     epinephrinedurations    0.9089718505 0.86645940   120.07110
# 80 median_tempc     epinephrinedurations    0.0087443579 0.01828430    35.88354
# 81 mean_diasbp      dobutaminedurations     0.1381413201 0.09852842    59.05064
# 82 mean_glucose     dobutaminedurations     0.6818991639 0.59487263   162.69231
# 83 mean_heartrate   dobutaminedurations     0.1364251780 0.20142632    93.60353
# 84 mean_meanbp      dobutaminedurations     0.4177724513 0.90157587    76.60848
# 85 mean_resprate    dobutaminedurations     0.6405290808 0.69375461    18.50611
# 86 mean_spo2        dobutaminedurations     0.5290808256 0.14731305    97.13433
# 87 mean_sysbp       dobutaminedurations     0.6167935499 0.24726753   115.12924
# 88 mean_tempc       dobutaminedurations     0.3886663651 0.15479496    36.35838
# 89 median_diasbp    dobutaminedurations     0.1340733299 0.09064888    59.02119
# 90 median_glucose   dobutaminedurations     0.6818991639 0.59487263   162.69231
# 91 median_heartrate dobutaminedurations     0.1435259089 0.22096201    93.48305
# 92 median_meanbp    dobutaminedurations     0.3924813846 0.76780320    76.67232
# 93 median_resprate  dobutaminedurations     0.6792680886 0.75257240    18.52500
# 94 median_spo2      dobutaminedurations     0.4466259555 0.11220009    97.22500
# 95 median_sysbp     dobutaminedurations     0.6435712937 0.25221269   115.40254
# 96 median_tempc     dobutaminedurations     0.4016569116 0.16435461    36.36147
#    GROUP2    DIFF        COMPARE    significant
# 1   53.87910  1.89393032 FALSE-TRUE  TRUE
# 2  152.05244 11.11062868 FALSE-TRUE FALSE
# 3   90.81910 -2.18591184 FALSE-TRUE  TRUE
# 4   67.60699  2.91772613 FALSE-TRUE  TRUE
# 5   20.10123 -0.91500249 FALSE-TRUE  TRUE
# 6   96.72060  0.42246337 FALSE-TRUE  TRUE
# 7  100.95061  4.79257450 FALSE-TRUE  TRUE
# 8   36.62525 -0.07144869 FALSE-TRUE FALSE
# 9   53.68101  1.91002808 FALSE-TRUE  TRUE
# 10 152.05244 11.12709818 FALSE-TRUE FALSE
# 11  90.82211 -2.20702898 FALSE-TRUE  TRUE
# 12  67.38786  2.78956688 FALSE-TRUE  TRUE
# 13  20.05603 -0.92115183 FALSE-TRUE  TRUE
# 14  96.78191  0.43545834 FALSE-TRUE  TRUE
# 15 100.77522  4.66468902 FALSE-TRUE  TRUE
# 16  36.62380 -0.06972256 FALSE-TRUE FALSE
# 17  53.00808  0.59347215 FALSE-TRUE FALSE
# 18 174.20320 -9.06361301 FALSE-TRUE FALSE
# 19  80.48769  0.87588710 FALSE-TRUE FALSE
# 20  69.25356  0.92311933 FALSE-TRUE FALSE
# 21  18.62621 -0.05111760 FALSE-TRUE FALSE
# 22  96.35540 -0.06705377 FALSE-TRUE FALSE
# 23 105.15319  2.17149333 FALSE-TRUE FALSE
# 24  36.18671  0.19947056 FALSE-TRUE FALSE
# 25  52.73840  0.62499369 FALSE-TRUE FALSE
# 26 174.20320 -9.06361301 FALSE-TRUE FALSE
# 27  80.40208  0.88910753 FALSE-TRUE FALSE
# 28  68.73050  1.18975150 FALSE-TRUE FALSE
# 29  18.58735 -0.11026265 FALSE-TRUE FALSE
# 30  96.48093 -0.01932662 FALSE-TRUE FALSE
# ⋮  ⋮         ⋮           ⋮          ⋮
# 67  91.03571 -5.6064717  FALSE-TRUE FALSE
# 68  74.59524  5.3961027  FALSE-TRUE FALSE
# 69  14.70833 -0.8802072  FALSE-TRUE FALSE
# 70  99.92857 -0.6399351  FALSE-TRUE FALSE
# 71 120.71429 -0.3445234  FALSE-TRUE FALSE
# 72  36.96667 -1.0833331  FALSE-TRUE  TRUE
# 73  55.85714  3.5740498  FALSE-TRUE FALSE
# 74 145.87500 -6.2321429  FALSE-TRUE FALSE
# 75  90.92857 -5.3368283  FALSE-TRUE FALSE
# 76  74.50000  4.9801222  FALSE-TRUE FALSE
# 77  14.58333 -0.9001272  FALSE-TRUE FALSE
# 78  99.92857 -0.6242236  FALSE-TRUE FALSE
# 79 120.78571 -0.7146134  FALSE-TRUE FALSE
# 80  36.96667 -1.0831229  FALSE-TRUE  TRUE
# 81  62.75588 -3.7052468  FALSE-TRUE FALSE
# 82 152.00000 10.6923077  FALSE-TRUE FALSE
# 83  87.13380  6.4697348  FALSE-TRUE FALSE
# 84  79.06404 -2.4555697  FALSE-TRUE FALSE
# 85  19.11520 -0.6090850  FALSE-TRUE FALSE
# 86  96.73232  0.4020022  FALSE-TRUE FALSE
# 87 112.66029  2.4689432  FALSE-TRUE FALSE
# 88  36.69593 -0.3375478  FALSE-TRUE FALSE
# 89  62.72794 -3.7067547  FALSE-TRUE FALSE
# 90 152.00000 10.6923077  FALSE-TRUE FALSE
# 91  87.12500  6.3580508  FALSE-TRUE FALSE
# 92  79.27450 -2.6021859  FALSE-TRUE FALSE
# 93  19.06618 -0.5411765  FALSE-TRUE FALSE
# 94  96.74242  0.4825758  FALSE-TRUE FALSE
# 95 113.09559  2.3069541  FALSE-TRUE FALSE
# 96  36.69118 -0.3297070  FALSE-TRUE FALSE

# %% [markdown]
# ### ANCOVA for significant differences summarized

# %% [markdown]
# Total pressors

# %%
ancova_significance_df <- computeANCOVA(melt_results_df) %>% mutate(
    response_significant = RESPONSE < 0.05, 
    interaction_interaction = INTERACTION < 0.05) %>%
    rename(response_pvalue = RESPONSE, interaction_pvalue = INTERACTION, vital_sign = ID)
ancova_significance_df
# Out:
#                      Df   Sum Sq Mean Sq  F value    Pr(>F)
# RESPONSE              1   202838  202838 489.5694 < 2.2e-16 ***
# INTERVAL              1     1426    1426   3.4421   0.06356 .
# RESPONSE:INTERVAL     1     7025    7025  16.9563 3.832e-05 ***
# Residuals         42231 17497105     414
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df   Sum Sq Mean Sq   F value  Pr(>F)
# RESPONSE              1   240872  240872  510.8539 < 2e-16 ***
# INTERVAL              1   603064  603064 1279.0071 < 2e-16 ***
# RESPONSE:INTERVAL     1     1681    1681    3.5652 0.05901 .
# Residuals         41796 19707200     472
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df  Sum Sq Mean Sq  F value    Pr(>F)
# RESPONSE              1   10363   10363  51.8940 5.957e-13 ***
# INTERVAL              1   77840   77840 389.8004 < 2.2e-16 ***
# RESPONSE:INTERVAL     1     483     483   2.4175      0.12
# Residuals         41778 8342715     200
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df   Sum Sq Mean Sq  F value Pr(>F)
# RESPONSE              1    51429   51429 197.9355 <2e-16 ***
# INTERVAL              1   159786  159786 614.9748 <2e-16 ***
# RESPONSE:INTERVAL     1      252     252   0.9698 0.3247
# Residuals         41937 10896293     260
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df  Sum Sq Mean Sq   F value Pr(>F)
# RESPONSE              1   33488   33488  819.7905 <2e-16 ***
# INTERVAL              1   41869   41869 1024.9526 <2e-16 ***
# RESPONSE:INTERVAL     1       0       0    0.0076 0.9307
# Residuals         44119 1802228      41
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df  Sum Sq Mean Sq  F value Pr(>F)
# RESPONSE              1     1.5    1.55   1.1707 0.2793
# INTERVAL              1   448.8  448.82 339.7613 <2e-16 ***
# RESPONSE:INTERVAL     1     0.3    0.30   0.2250 0.6353
# Residuals         18674 24667.9    1.32
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df Sum Sq Mean Sq F value    Pr(>F)
# RESPONSE              1   7804  7804.0 439.138 < 2.2e-16 ***
# INTERVAL              1    681   680.9  38.315 6.075e-10 ***
# RESPONSE:INTERVAL     1    354   354.0  19.920 8.095e-06 ***
# Residuals         41601 739300    17.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df    Sum Sq Mean Sq F value    Pr(>F)
# RESPONSE              1    464398  464398 134.751 < 2.2e-16 ***
# INTERVAL              1    150457  150457  43.657 3.976e-11 ***
# RESPONSE:INTERVAL     1     22959   22959   6.662  0.009854 **
# Residuals         30991 106805335    3446
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df   Sum Sq Mean Sq  F value    Pr(>F)
# RESPONSE              1   204668  204668 490.7512 < 2.2e-16 ***
# INTERVAL              1     1250    1250   2.9983   0.08336 .
# RESPONSE:INTERVAL     1     7180    7180  17.2173  3.34e-05 ***
# Residuals         42231 17612494     417
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df   Sum Sq Mean Sq  F value Pr(>F)
# RESPONSE              1   242377  242377  502.654 <2e-16 ***
# INTERVAL              1   630766  630766 1308.114 <2e-16 ***
# RESPONSE:INTERVAL     1     1677    1677    3.478 0.0622 .
# Residuals         41796 20153805     482
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df  Sum Sq Mean Sq  F value    Pr(>F)
# RESPONSE              1   10727   10727  53.1764 3.103e-13 ***
# INTERVAL              1   84950   84950 421.1205 < 2.2e-16 ***
# RESPONSE:INTERVAL     1     597     597   2.9619   0.08526 .
# Residuals         41778 8427607     202
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df   Sum Sq Mean Sq  F value Pr(>F)
# RESPONSE              1    50830   50830 194.3968 <2e-16 ***
# INTERVAL              1   176437  176437 674.7802 <2e-16 ***
# RESPONSE:INTERVAL     1      280     280   1.0695 0.3011
# Residuals         41937 10965425     261
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df  Sum Sq Mean Sq   F value Pr(>F)
# RESPONSE              1   34195   34195  823.8341 <2e-16 ***
# INTERVAL              1   43319   43319 1043.6454 <2e-16 ***
# RESPONSE:INTERVAL     1       0       0    0.0059 0.9387
# Residuals         44119 1831257      42
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df  Sum Sq Mean Sq  F value Pr(>F)
# RESPONSE              1     1.6    1.58   1.1955 0.2742
# INTERVAL              1   449.0  449.03 339.6092 <2e-16 ***
# RESPONSE:INTERVAL     1     0.3    0.29   0.2192 0.6396
# Residuals         18674 24690.5    1.32
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df Sum Sq Mean Sq F value    Pr(>F)
# RESPONSE              1   7647  7646.8 433.368 < 2.2e-16 ***
# INTERVAL              1   1027  1027.2  58.214 2.402e-14 ***
# RESPONSE:INTERVAL     1    302   301.9  17.111 3.532e-05 ***
# Residuals         41601 734054    17.6
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                      Df    Sum Sq Mean Sq F value    Pr(>F)
# RESPONSE              1    466516  466516 135.333 < 2.2e-16 ***
# INTERVAL              1    149612  149612  43.401  4.53e-11 ***
# RESPONSE:INTERVAL     1     23162   23162   6.719  0.009543 **
# Residuals         30991 106831083    3447
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#    vital_sign       response_pvalue RESPONSE_F interaction_pvalue INTERACTION_F
# 1  mean_heartrate   NA              NA         3.832221e-05       16.956331928
# 2  mean_sysbp       NA              NA         5.901048e-02        3.565173841
# 3  mean_diasbp      NA              NA         1.199958e-01        2.417474043
# 4  mean_meanbp      NA              NA         3.247459e-01        0.969759283
# 5  mean_resprate    NA              NA         9.307471e-01        0.007552550
# 6  mean_tempc       NA              NA         6.352710e-01        0.224987842
# 7  mean_spo2        NA              NA         8.095237e-06       19.920248565
# 8  mean_glucose     NA              NA         9.853562e-03        6.662003826
# 9  median_heartrate NA              NA         3.340387e-05       17.217299815
# 10 median_sysbp     NA              NA         6.219515e-02        3.478045633
# 11 median_diasbp    NA              NA         8.525508e-02        2.961900749
# 12 median_meanbp    NA              NA         3.010751e-01        1.069452530
# 13 median_resprate  NA              NA         9.387319e-01        0.005908114
# 14 median_tempc     NA              NA         6.396301e-01        0.219233428
# 15 median_spo2      NA              NA         3.531728e-05       17.111506905
# 16 median_glucose   NA              NA         9.543440e-03        6.719027280
#    response_significant interaction_interaction
# 1  NA                    TRUE
# 2  NA                   FALSE
# 3  NA                   FALSE
# 4  NA                   FALSE
# 5  NA                   FALSE
# 6  NA                   FALSE
# 7  NA                    TRUE
# 8  NA                    TRUE
# 9  NA                    TRUE
# 10 NA                   FALSE
# 11 NA                   FALSE
# 12 NA                   FALSE
# 13 NA                   FALSE
# 14 NA                   FALSE
# 15 NA                    TRUE
# 16 NA                    TRUE

# %%
ancova_significance_df
# Out:
#    vital_sign       response_pvalue RESPONSE_F interaction_pvalue INTERACTION_F
# 1  mean_heartrate   NA              NA         3.832221e-05       16.956331928
# 2  mean_sysbp       NA              NA         5.901048e-02        3.565173841
# 3  mean_diasbp      NA              NA         1.199958e-01        2.417474043
# 4  mean_meanbp      NA              NA         3.247459e-01        0.969759283
# 5  mean_resprate    NA              NA         9.307471e-01        0.007552550
# 6  mean_tempc       NA              NA         6.352710e-01        0.224987842
# 7  mean_spo2        NA              NA         8.095237e-06       19.920248565
# 8  mean_glucose     NA              NA         9.853562e-03        6.662003826
# 9  median_heartrate NA              NA         3.340387e-05       17.217299815
# 10 median_sysbp     NA              NA         6.219515e-02        3.478045633
# 11 median_diasbp    NA              NA         8.525508e-02        2.961900749
# 12 median_meanbp    NA              NA         3.010751e-01        1.069452530
# 13 median_resprate  NA              NA         9.387319e-01        0.005908114
# 14 median_tempc     NA              NA         6.396301e-01        0.219233428
# 15 median_spo2      NA              NA         3.531728e-05       17.111506905
# 16 median_glucose   NA              NA         9.543440e-03        6.719027280
#    response_significant interaction_interaction
# 1  NA                    TRUE
# 2  NA                   FALSE
# 3  NA                   FALSE
# 4  NA                   FALSE
# 5  NA                   FALSE
# 6  NA                   FALSE
# 7  NA                    TRUE
# 8  NA                    TRUE
# 9  NA                    TRUE
# 10 NA                   FALSE
# 11 NA                   FALSE
# 12 NA                   FALSE
# 13 NA                   FALSE
# 14 NA                   FALSE
# 15 NA                    TRUE
# 16 NA                    TRUE

# %%
ancova_significance_df %>% write.csv(file.path(PLOT_DIR, "ancovasignificance.csv"))

# %% [markdown]
# Pressors by type

# %%
pressors_vitals_rr_list <- list()
for(pressor_choice in pressor_choices){
    pressors_vitals_rr_list[[pressor_choice]] <- melt_results_df %>%
        filter(grepl(pressor_choice, pressor)) %>%
        computeANCOVA() %>%
        mutate(
            response_significant = RESPONSE < 0.05, 
            interaction_interaction = INTERACTION < 0.05)
}

pressors_vitals_rr_df <- bind_rows(pressors_vitals_rr_list, .id="pressor")

# %%
ancova_significance_eachpressor_df <- pressors_vitals_rr_df %>%
    rename(response_pvalue = RESPONSE, interaction_pvalue = INTERACTION, vital_sign = ID)
ancova_significance_eachpressor_df
# Out:
#    pressor                 vital_sign       response_pvalue RESPONSE_F
# 1  norepinephrinedurations mean_heartrate   NA              NA
# 2  norepinephrinedurations mean_sysbp       NA              NA
# 3  norepinephrinedurations mean_diasbp      NA              NA
# 4  norepinephrinedurations mean_meanbp      NA              NA
# 5  norepinephrinedurations mean_resprate    NA              NA
# 6  norepinephrinedurations mean_tempc       NA              NA
# 7  norepinephrinedurations mean_spo2        NA              NA
# 8  norepinephrinedurations mean_glucose     NA              NA
# 9  norepinephrinedurations median_heartrate NA              NA
# 10 norepinephrinedurations median_sysbp     NA              NA
# 11 norepinephrinedurations median_diasbp    NA              NA
# 12 norepinephrinedurations median_meanbp    NA              NA
# 13 norepinephrinedurations median_resprate  NA              NA
# 14 norepinephrinedurations median_tempc     NA              NA
# 15 norepinephrinedurations median_spo2      NA              NA
# 16 norepinephrinedurations median_glucose   NA              NA
# 17 dopaminedurations       mean_heartrate   NA              NA
# 18 dopaminedurations       mean_sysbp       NA              NA
# 19 dopaminedurations       mean_diasbp      NA              NA
# 20 dopaminedurations       mean_meanbp      NA              NA
# 21 dopaminedurations       mean_resprate    NA              NA
# 22 dopaminedurations       mean_tempc       NA              NA
# 23 dopaminedurations       mean_spo2        NA              NA
# 24 dopaminedurations       mean_glucose     NA              NA
# 25 dopaminedurations       median_heartrate NA              NA
# 26 dopaminedurations       median_sysbp     NA              NA
# 27 dopaminedurations       median_diasbp    NA              NA
# 28 dopaminedurations       median_meanbp    NA              NA
# 29 dopaminedurations       median_resprate  NA              NA
# 30 dopaminedurations       median_tempc     NA              NA
# ⋮  ⋮                       ⋮                ⋮               ⋮
# 67 epinephrinedurations    mean_diasbp      NA              NA
# 68 epinephrinedurations    mean_meanbp      NA              NA
# 69 epinephrinedurations    mean_resprate    NA              NA
# 70 epinephrinedurations    mean_tempc       NA              NA
# 71 epinephrinedurations    mean_spo2        NA              NA
# 72 epinephrinedurations    mean_glucose     NA              NA
# 73 epinephrinedurations    median_heartrate NA              NA
# 74 epinephrinedurations    median_sysbp     NA              NA
# 75 epinephrinedurations    median_diasbp    NA              NA
# 76 epinephrinedurations    median_meanbp    NA              NA
# 77 epinephrinedurations    median_resprate  NA              NA
# 78 epinephrinedurations    median_tempc     NA              NA
# 79 epinephrinedurations    median_spo2      NA              NA
# 80 epinephrinedurations    median_glucose   NA              NA
# 81 dobutaminedurations     mean_heartrate   NA              NA
# 82 dobutaminedurations     mean_sysbp       NA              NA
# 83 dobutaminedurations     mean_diasbp      NA              NA
# 84 dobutaminedurations     mean_meanbp      NA              NA
# 85 dobutaminedurations     mean_resprate    NA              NA
# 86 dobutaminedurations     mean_tempc       NA              NA
# 87 dobutaminedurations     mean_spo2        NA              NA
# 88 dobutaminedurations     mean_glucose     NA              NA
# 89 dobutaminedurations     median_heartrate NA              NA
# 90 dobutaminedurations     median_sysbp     NA              NA
# 91 dobutaminedurations     median_diasbp    NA              NA
# 92 dobutaminedurations     median_meanbp    NA              NA
# 93 dobutaminedurations     median_resprate  NA              NA
# 94 dobutaminedurations     median_tempc     NA              NA
# 95 dobutaminedurations     median_spo2      NA              NA
# 96 dobutaminedurations     median_glucose   NA              NA
#    interaction_pvalue INTERACTION_F response_significant
# 1  2.358507e-05       17.88461885   NA
# 2  8.036499e-01        0.06181682   NA
# 3  2.138758e-02        5.29585552   NA
# 4  3.264173e-01        0.96311146   NA
# 5  4.299485e-02        4.09615570   NA
# 6  4.881797e-01        0.48058553   NA
# 7  2.018309e-05       18.18167233   NA
# 8  6.609313e-01        0.19240594   NA
# 9  2.268763e-05       17.95852709   NA
# 10 7.827144e-01        0.07605877   NA
# 11 1.779885e-02        5.61687048   NA
# 12 3.204223e-01        0.98727590   NA
# 13 4.356890e-02        4.07373634   NA
# 14 4.840193e-01        0.48984475   NA
# 15 3.751672e-05       17.00160183   NA
# 16 6.543678e-01        0.20044991   NA
# 17 4.255011e-01        0.63514176   NA
# 18 4.470219e-01        0.57825470   NA
# 19 5.341394e-01        0.38654731   NA
# 20 2.881204e-01        1.12854871   NA
# 21 2.664728e-01        1.23499721   NA
# 22 8.320255e-01        0.04499708   NA
# 23 6.251776e-01        0.23867821   NA
# 24 8.935830e-02        2.88774894   NA
# 25 4.141168e-01        0.66702559   NA
# 26 4.717496e-01        0.51792896   NA
# 27 5.433204e-01        0.36945516   NA
# 28 3.455280e-01        0.88992862   NA
# 29 2.949040e-01        1.09724982   NA
# 30 8.327242e-01        0.04461788   NA
# ⋮  ⋮                  ⋮             ⋮
# 67 0.0138140881        6.06285961   NA
# 68 0.2563772925        1.28829035   NA
# 69 0.0069186507        7.29544751   NA
# 70 0.4158770531        0.66200623   NA
# 71 0.0004726610       12.22476381   NA
# 72 0.4564465333        0.55462638   NA
# 73 0.0001315155       14.62578574   NA
# 74 0.5180951435        0.41769898   NA
# 75 0.0121640337        6.28799155   NA
# 76 0.2773751555        1.17997224   NA
# 77 0.0066591330        7.36418961   NA
# 78 0.4153669076        0.66345630   NA
# 79 0.0008735080       11.08164545   NA
# 80 0.4416754348        0.59196079   NA
# 81 0.3493832494        0.87610876   NA
# 82 0.0748054751        3.17767303   NA
# 83 0.1464814040        2.11018718   NA
# 84 0.0377428082        4.32242373   NA
# 85 0.8149056913        0.05481769   NA
# 86 0.1849722097        1.75983739   NA
# 87 0.4065026710        0.68931222   NA
# 88 0.7124921307        0.13585169   NA
# 89 0.3818726087        0.76500397   NA
# 90 0.0588305362        3.57420941   NA
# 91 0.1084745975        2.57865603   NA
# 92 0.0258603819        4.97287896   NA
# 93 0.7307951775        0.11841456   NA
# 94 0.1895494890        1.72365011   NA
# 95 0.4832264531        0.49176593   NA
# 96 0.7196406199        0.12888560   NA
#    interaction_interaction
# 1   TRUE
# 2  FALSE
# 3   TRUE
# 4  FALSE
# 5   TRUE
# 6  FALSE
# 7   TRUE
# 8  FALSE
# 9   TRUE
# 10 FALSE
# 11  TRUE
# 12 FALSE
# 13  TRUE
# 14 FALSE
# 15  TRUE
# 16 FALSE
# 17 FALSE
# 18 FALSE
# 19 FALSE
# 20 FALSE
# 21 FALSE
# 22 FALSE
# 23 FALSE
# 24 FALSE
# 25 FALSE
# 26 FALSE
# 27 FALSE
# 28 FALSE
# 29 FALSE
# 30 FALSE
# ⋮  ⋮
# 67  TRUE
# 68 FALSE
# 69  TRUE
# 70 FALSE
# 71  TRUE
# 72 FALSE
# 73  TRUE
# 74 FALSE
# 75  TRUE
# 76 FALSE
# 77  TRUE
# 78 FALSE
# 79  TRUE
# 80 FALSE
# 81 FALSE
# 82 FALSE
# 83 FALSE
# 84  TRUE
# 85 FALSE
# 86 FALSE
# 87 FALSE
# 88 FALSE
# 89 FALSE
# 90 FALSE
# 91 FALSE
# 92  TRUE
# 93 FALSE
# 94 FALSE
# 95 FALSE
# 96 FALSE

# %%
ancova_significance_eachpressor_df %>% write.csv(file.path(PLOT_DIR, "ancovasignificance_eachpressor.csv"))

# %% [markdown]
# # Figure 2 ANCOVA Plotting

# %% [markdown]
# Total pressors

# %%
FANCY_VITAL_ORDER <- c('MAP (mmHg)', 'HR (beats/min)', 'RR (breaths/min)', 'SpO2 (%)', 'Temperature (F)', 'Glucose (mg/dL)')

# %%
FANCY_VITAL_DICT <- c(
    'mean_meanbp' = 'MAP (mmHg)', 
    'mean_heartrate' = 'HR (beats/min)', 
    'mean_resprate' = 'RR (breaths/min)', 
    'mean_spo2' = 'SpO2 (%)', 
    'mean_tempc' = 'Temperature (F)', 
    'mean_glucose' = 'Glucose (mg/dL)')

# %%
PRESSORHOURS_COLORS <- c(
"Prolonged or multiple vasopressor" = '#2F4F4F',
"No prolonged or multiple vasopressor" = '#D3D3D3'
)

# %%
toplot <- melt_results_df %>%
    mutate(INTERVAL = -INTERVAL) %>%
    drop_na(VALUE) %>%
    filter(grepl("mean_", ID), ID != "mean_diasbp", ID != "mean_sysbp")

# %%
# 3-5 mins
toplot <- toplot %>%
    rowwise() %>%
    mutate(ID = as.character(ID)) %>%
    mutate(FANCY_VITAL = FANCY_VITAL_DICT[ID]) %>%
    mutate(FANCY_VITAL = factor(FANCY_VITAL, levels=FANCY_VITAL_ORDER)) %>%
    mutate(FANCY_RESPONSE = if(RESPONSE){"Prolonged or multiple vasopressor"}else{"No prolonged or multiple vasopressor"})

# %%
options(repr.plot.width=7, repr.plot.height=2.5)

p <- toplot %>%
    ggplot(aes(x=INTERVAL, y=VALUE, color=FANCY_RESPONSE)) +
        geom_smooth(method=lm, aes(fill=FANCY_RESPONSE)) + 
        xlab("Hours before vasopressors") + ylab("Vital Sign") +
        scale_x_continuous(limits=c(-10,0), breaks=seq(-10,0,5)) +
        base_theme() + 
        scale_color_manual(values=PRESSORHOURS_COLORS)+
        scale_fill_manual(values=PRESSORHOURS_COLORS)+
        theme(legend.title = element_blank()) +
        theme(legend.position="bottom") +
        facet_wrap(. ~ FANCY_VITAL, scale="free", nrow=1)
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, "ancova_vitals.pdf"), 7,2.5)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# Pressors by type

# %%
pressor_choices
# Out:
# [1] "norepinephrinedurations" "dopaminedurations"
# [3] "phenylephrinedurations"  "vasopressindurations"
# [5] "epinephrinedurations"    "dobutaminedurations"

# %%
options(repr.plot.width=7, repr.plot.height=2.5)
for(pressor_choice in pressor_choices){
    toplot <- melt_results_df %>%
        filter(!grepl(",", pressor)) %>%
        mutate(INTERVAL = -INTERVAL) %>%
        drop_na(VALUE) %>%
        filter(pressor == pressor_choice, grepl("mean_", ID), ID != "mean_diasbp", ID != "mean_sysbp") %>%
        rowwise() %>%
        mutate(ID = as.character(ID)) %>%
        mutate(FANCY_VITAL = FANCY_VITAL_DICT[ID]) %>%
        mutate(FANCY_VITAL = factor(FANCY_VITAL, levels=FANCY_VITAL_ORDER)) %>%
        mutate(FANCY_RESPONSE = if(RESPONSE){"Prolonged or multiple vasopressor"}else{"No prolonged or multiple vasopressor"})

    p <- ggplot(toplot, aes(x=INTERVAL, y=VALUE, color=FANCY_RESPONSE)) +
        geom_smooth(method=lm, aes(fill=FANCY_RESPONSE)) + 
        xlab("Hours before vasopressors") + ylab("Vitals") +
        scale_x_continuous(limits=c(-10,0), breaks=seq(-10,0,5)) +
        base_theme() + 
        scale_color_manual(values=PRESSORHOURS_COLORS)+
        scale_fill_manual(values=PRESSORHOURS_COLORS)+
        theme(legend.title = element_blank()) +
        theme(legend.position="bottom") +
        facet_wrap(. ~ FANCY_VITAL, scale="free", nrow=1)
    
#     if(pressor_choice == 'phenylephrinedurations'){
#         p <- p + theme(legend.position="bottom")
#     }
    
    plot(p)
    
    pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_ancova_vitals.pdf")), 7,2.5)
    plot(p)
    dev.off()
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # LR Summary

# %%
set.seed(100)

# %%
lr_summary_list <- list()

# %%
LR_CATEGORICAL_COEFFICIENT_DICT <- c(
'genderM' = "Male Gender",
'intubTRUE' = "Intubated",
'simple_diagnosisINFECTION' = "Infectious Diagnosis",   
'simple_diagnosisSEPSIS' = "Sepsis Diagnosis",
'simple_diagnosisOTHER DIAGNOSIS' = "Other Diagnosis",
'pressorphenylephrinedurations' = 'phenylephrine',
'pressornorepinephrinedurations' = 'norepinephrine',
'first_careunitCSRU' = 'CSRU',
'first_careunitSICU' = 'SICU',
'first_careunitMICU' = 'MICU',
'first_careunitTSICU' = 'TSICU'
)

# %%
LR_CONTINUOUS_COEFFICIENT_DICT <- c(
'age_cohort' = 'Age',
'mean_meanbp' = 'MAP',
'mean_resprate' = 'RR',
'mean_heartrate' = 'HR',
'mean_tempc' = 'Temperature',
'mean_spo2' = 'SpO2',
'mean_glucose' = 'Glucose'
)

# %% [markdown]
# ### ROC curve with CI

# %%
roc_with_ci <- function(obj) {
  ciobj <- ci.se(obj, specificities = seq(0, 1, l = 25))
  dat.ci <- data.frame(x = as.numeric(rownames(ciobj)),
                       lower = ciobj[, 1],
                       upper = ciobj[, 3])
  
  ggroc(obj) +
    base_theme() +
    theme(axis.title=element_text(size=10)) +
    geom_abline(
      slope = 1,
      intercept = 1,
      linetype = "dashed",
      alpha = 0.7,
      color = '#2F4F4F'
    ) + coord_equal() +
    geom_ribbon(
      data = dat.ci,
      aes(x = x, ymin = lower, ymax = upper),
      fill = '#2F4F4F',
      alpha = 0.2
    ) 
}

# %% [markdown]
# # LR Model for Total
# - Ran into problems with missing data for glucose, spo2 and tempc, hence the selection of criteria as variables

# %%
model_input_df <- melt_results_df %>%
    filter(INTERVAL == 2) %>%
    select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    rowwise() %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE,
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
             contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate") ,
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 15136    12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model)
# Out:
#                  GVIF     Df GVIF^(1/(2*Df))
# first_careunit   2.196318 4  1.103346
# intub            1.104792 1  1.051091
# simple_diagnosis 1.667135 3  1.088918
# age_cohort       1.138105 1  1.066820
# gender           1.055657 1  1.027452
# mean_meanbp      1.074804 1  1.036728
# mean_resprate    1.488434 1  1.220014
# mean_heartrate   1.376784 1  1.173364
# mean_tempc       1.318197 1  1.148128
# mean_spo2        1.146865 1  1.070918
# mean_glucose     1.076565 1  1.037577

# %%
lr_summary_list[['TOTAL']] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[['TOTAL']]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 0.6672464 0.03375225 0.6547424 0.02141298

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2492    99.91 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2535   101.63 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2536   101.67 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2544   101.98 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2542   101.88 |

# %%
dim(model_input_df)
# Out:
# [1] 15136    12

# %%
dim(model_input_df)
# Out:
# [1] 15136    12

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %% [markdown]
# #### Model parameter significance

# %%
summary(model)
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.8568  -1.1247   0.8385   1.1302   1.7785
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                     -0.1829553  0.3047429  -0.600 0.548267
# mean_meanbp                     -0.0056297  0.0013997  -4.022 5.77e-05 ***
# mean_resprate                    0.0108941  0.0040095   2.717 0.006586 **
# mean_heartrate                   0.0030479  0.0011874   2.567 0.010261 *
# mean_tempc                       0.0005672  0.0081761   0.069 0.944690
# mean_spo2                       -0.0070770  0.0034738  -2.037 0.041625 *
# mean_glucose                     0.0019752  0.0004226   4.674 2.95e-06 ***
# first_careunitCSRU              -0.6468778  0.0577780 -11.196  < 2e-16 ***
# first_careunitMICU               0.0518214  0.0605842   0.855 0.392352
# first_careunitSICU              -0.2142448  0.0693567  -3.089 0.002008 **
# first_careunitTSICU             -0.2881913  0.0762759  -3.778 0.000158 ***
# intubTRUE                        0.8211208  0.0489889  16.761  < 2e-16 ***
# simple_diagnosisINFECTION        0.0640631  0.0895802   0.715 0.474517
# simple_diagnosisOTHER DIAGNOSIS -0.0053319  0.0464045  -0.115 0.908524
# simple_diagnosisSEPSIS           0.2401363  0.0865810   2.774 0.005545 **
# age_cohort                       0.0030804  0.0012116   2.542 0.011009 *
# genderM                         -0.0523996  0.0353204  -1.484 0.137928
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 20056  on 14487  degrees of freedom
# Residual deviance: 19451  on 14471  degrees of freedom
#   (648 observations deleted due to missingness)
# AIC: 19485
#
# Number of Fisher Scoring iterations: 4

# %%
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, "modelestimates.csv"))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))  %>% data.frame()
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio  %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, "categoricalmodeleodds.csv"))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>% 
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <-oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, "continuousmodeleodds.csv"))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # LR Model for norepinephrine
# - Running into problems with missing data for glucose, spo2 and tempc.

# %%
pressor_choice <- 'norepinephrinedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(grepl(pressor_choice, pressor), INTERVAL == 1) %>% select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(grepl(pressor_choice, pressor))  %>%
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
              contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 6173   12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model) %>% print()
# Out:
#                      GVIF Df GVIF^(1/(2*Df))
# first_careunit   2.069317  4        1.095162
# intub            1.269786  1        1.126848
# simple_diagnosis 1.784651  3        1.101350
# age_cohort       1.064987  1        1.031982
# gender           1.082827  1        1.040590
# mean_meanbp      1.115799  1        1.056314
# mean_resprate    1.477607  1        1.215568
# mean_heartrate   1.158001  1        1.076105
# mean_tempc       1.157085  1        1.075679
# mean_spo2        1.214517  1        1.102051
# mean_glucose     1.070927  1        1.034856

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 0.7019877 0.05199641 0.7768477 0.02916914

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1975   101.40 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1986   101.96 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1986   101.97 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1981   101.72 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.1984   101.86 |

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %%
summary(model) %>% print()
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7080  -1.0232   0.6336   0.7626   1.7437
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      7.0328765  1.6645733   4.225 2.39e-05 ***
# mean_meanbp                     -0.0116062  0.0021569  -5.381 7.41e-08 ***
# mean_resprate                    0.0105895  0.0064643   1.638 0.101389
# mean_heartrate                   0.0150217  0.0018857   7.966 1.64e-15 ***
# mean_tempc                      -0.0835174  0.0380505  -2.195 0.028170 *
# mean_spo2                       -0.0401081  0.0085144  -4.711 2.47e-06 ***
# mean_glucose                    -0.0008688  0.0005758  -1.509 0.131337
# first_careunitCSRU               0.0121335  0.1260546   0.096 0.923317
# first_careunitMICU              -0.3880036  0.1042795  -3.721 0.000199 ***
# first_careunitSICU              -0.0759635  0.1284060  -0.592 0.554126
# first_careunitTSICU             -0.1711691  0.1396832  -1.225 0.220421
# intubTRUE                        1.0343222  0.0749934  13.792  < 2e-16 ***
# simple_diagnosisINFECTION       -0.5840217  0.1559293  -3.745 0.000180 ***
# simple_diagnosisOTHER DIAGNOSIS -0.3528768  0.1221684  -2.888 0.003872 **
# simple_diagnosisSEPSIS          -0.5043715  0.1476693  -3.416 0.000637 ***
# age_cohort                       0.0009954  0.0021360   0.466 0.641199
# genderM                         -0.0141305  0.0633482  -0.223 0.823488
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 6725.5  on 5842  degrees of freedom
# Residual deviance: 6266.1  on 5826  degrees of freedom
#   (330 observations deleted due to missingness)
# AIC: 6300.1
#
# Number of Fisher Scoring iterations: 4

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio  %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodeleodds.csv")))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodeleodds.csv")))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # LR Model for dopamine
# - Running into problems with missing data for glucose, spo2 and tempc.

# %%
pressor_choice <- 'dopaminedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(grepl(pressor_choice, pressor), INTERVAL == 1) %>% select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(grepl(pressor_choice, pressor))  %>%
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
              contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 2689   12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model) %>% print()
# Out:
#                      GVIF Df GVIF^(1/(2*Df))
# first_careunit   1.703139  4        1.068824
# intub            1.518773  1        1.232385
# simple_diagnosis 1.101100  3        1.016181
# age_cohort       1.249021  1        1.117596
# gender           1.224010  1        1.106350
# mean_meanbp      1.176721  1        1.084768
# mean_resprate    1.342189  1        1.158529
# mean_heartrate   1.413210  1        1.188785
# mean_tempc       1.175610  1        1.084256
# mean_spo2        1.206689  1        1.098494
# mean_glucose     1.273072  1        1.128305

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC    MEAN_ACC  SD_ACC
# 1 0.7377331 0.1014067 0.8318841 0.03349049

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2115   100.82 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2119   101.02 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2149   102.45 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2158   102.89 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2158   102.88 |

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %%
summary(model) %>% print()
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4774  -1.0126   0.5898   0.7653   1.8625
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      2.7653429  2.7404051   1.009  0.31293
# mean_meanbp                     -0.0144786  0.0035150  -4.119 3.80e-05 ***
# mean_resprate                    0.0204088  0.0108615   1.879  0.06024 .
# mean_heartrate                   0.0147698  0.0029861   4.946 7.57e-07 ***
# mean_tempc                      -0.0750508  0.0665188  -1.128  0.25921
# mean_spo2                       -0.0137730  0.0107245  -1.284  0.19905
# mean_glucose                     0.0001023  0.0008459   0.121  0.90373
# first_careunitCSRU               0.8414761  0.1886048   4.462 8.14e-06 ***
# first_careunitMICU               0.3067866  0.1151355   2.665  0.00771 **
# first_careunitSICU               0.5069176  0.1977109   2.564  0.01035 *
# first_careunitTSICU              0.6661808  0.2326028   2.864  0.00418 **
# intubTRUE                        1.3627083  0.0995687  13.686  < 2e-16 ***
# simple_diagnosisINFECTION       -0.2417629  0.2535577  -0.953  0.34035
# simple_diagnosisOTHER DIAGNOSIS -0.2961445  0.1361031  -2.176  0.02956 *
# simple_diagnosisSEPSIS           0.0172060  0.2335298   0.074  0.94127
# age_cohort                       0.0077296  0.0034995   2.209  0.02719 *
# genderM                          0.1462769  0.0968003   1.511  0.13076
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 2989.2  on 2478  degrees of freedom
# Residual deviance: 2657.1  on 2462  degrees of freedom
#   (210 observations deleted due to missingness)
# AIC: 2691.1
#
# Number of Fisher Scoring iterations: 4

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio %>% data.frame()  %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodeleodds.csv")))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <-oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodeleodds.csv")))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # LR Model for phenylephrine
# - Running into problems with missing data for glucose, spo2 and tempc.

# %%
pressor_choice <- 'phenylephrinedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(grepl(pressor_choice, pressor), INTERVAL == 1) %>% select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = ID, COURSE = course_id) %>%
    #mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(grepl(pressor_choice, pressor))  %>%
            select(-pressor) %>%
            select(RESPONSE, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -RESPONSE, -course_id) %>%
            rename(COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE) %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
              contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
             contains("mean_tempc"),
             contains("mean_spo2"),
             contains("mean_glucose")
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
dim(model_input_df) %>% print()
# Out:
# [1] 9503   12

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_cleaned_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_cleaned_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=learn)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
car::vif(model) %>% print()
# Out:
#                      GVIF Df GVIF^(1/(2*Df))
# first_careunit   1.586596  4        1.059396
# intub            1.082537  1        1.040450
# simple_diagnosis 1.274407  3        1.041241
# age_cohort       1.103107  1        1.050289
# gender           1.046640  1        1.023054
# mean_meanbp      1.072095  1        1.035420
# mean_resprate    1.363930  1        1.167874
# mean_heartrate   1.269865  1        1.126883
# mean_tempc       1.187401  1        1.089679
# mean_spo2        1.184593  1        1.088390
# mean_glucose     1.068131  1        1.033504

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))
lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC SD_ACC
# 1 0.6281342 0.03019193 0.597345 0.03550612

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
# imputation: 30 mins
model_input_imputed_df <- 
    rfImpute(RESPONSE ~ . , family=binomial(link='logit'), data=model_input_df %>% select(contains("mean"), RESPONSE)) %>%
    cbind(model_input_df %>% select(-contains("mean"), -RESPONSE))
# Out:
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2454    98.51 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2445    98.16 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2468    99.08 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2465    98.97 |
# Warning message in randomForest.default(xf, y, ntree = ntree, ..., do.trace = ntree, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#  300 |   0.2471    99.20 |

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_imputed_df)

# %%
summary(model) %>% print()
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_imputed_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5905  -1.0885   0.5917   1.1597   1.7955
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      7.1936521  1.3743986   5.234 1.66e-07 ***
# mean_meanbp                     -0.0062574  0.0017943  -3.487 0.000488 ***
# mean_resprate                    0.0176194  0.0052068   3.384 0.000715 ***
# mean_heartrate                   0.0104598  0.0015299   6.837 8.10e-12 ***
# mean_tempc                      -0.1511820  0.0300060  -5.038 4.69e-07 ***
# mean_spo2                       -0.0297675  0.0076882  -3.872 0.000108 ***
# mean_glucose                     0.0019349  0.0005826   3.321 0.000896 ***
# first_careunitCSRU              -0.8375717  0.0854350  -9.804  < 2e-16 ***
# first_careunitMICU               0.1427688  0.1008191   1.416 0.156750
# first_careunitSICU              -0.4862946  0.0980844  -4.958 7.13e-07 ***
# first_careunitTSICU             -0.6206991  0.1058036  -5.867 4.45e-09 ***
# intubTRUE                        0.5757622  0.0767388   7.503 6.24e-14 ***
# simple_diagnosisINFECTION        0.2111751  0.1356489   1.557 0.119523
# simple_diagnosisOTHER DIAGNOSIS  0.0557556  0.0551094   1.012 0.311669
# simple_diagnosisSEPSIS           0.9935315  0.1703975   5.831 5.52e-09 ***
# age_cohort                       0.0049790  0.0015943   3.123 0.001790 **
# genderM                         -0.0742452  0.0457721  -1.622 0.104790
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 12783  on 9240  degrees of freedom
# Residual deviance: 12007  on 9224  degrees of freedom
#   (262 observations deleted due to missingness)
# AIC: 12041
#
# Number of Fisher Scoring iterations: 4

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
oddsratio_categorical <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CATEGORICAL_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CATEGORICAL_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CATEGORICAL_COEFFICIENT_DICT)))

oddsratio_categorical %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodeleodds.csv")))

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
p <- oddsratio_categorical %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_categoricalmodelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
oddsratio_continuous <-oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_CONTINUOUS_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_CONTINUOUS_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_CONTINUOUS_COEFFICIENT_DICT)))

oddsratio_continuous %>% write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodeleodds.csv")))

# %%
options(repr.plot.width=3, repr.plot.height=2.7)
p <- oddsratio_continuous %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_continuousmodelodds.pdf")), 3.1,2.7)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # Output AUC table

# %%
auc_output_df <- bind_rows(lr_summary_list, .id="PRESSOR")
auc_output_df
# Out:
#   PRESSOR                 MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 TOTAL                   0.6672464 0.03375225 0.6547424 0.02141298
# 2 norepinephrinedurations 0.7019877 0.05199641 0.7768477 0.02916914
# 3 dopaminedurations       0.7377331 0.10140665 0.8318841 0.03349049
# 4 phenylephrinedurations  0.6281342 0.03019193 0.5973450 0.03550612

# %%
auc_output_df  %>% write.csv(file.path(PLOT_DIR, "summary_auc.csv"))
