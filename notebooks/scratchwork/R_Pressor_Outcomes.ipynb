# %% [markdown]
# # Pressor Distributions
# - Ruoyi Jiang
# - July 19, 2019
# - Evaluation of the different pressor combinations used in MIMIC

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(fasttime)
library(epitools)
library(boot)
library(pROC)

library(glmnet)
library(pls)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Type 'citation("pROC")' for a citation.
#
# Attaching package: ‘pROC’
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
# Loading required package: Matrix
#
# Attaching package: ‘Matrix’
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# Loading required package: foreach
# Loaded glmnet 2.0-18
#
#
# Attaching package: ‘glmnet’
#
# The following object is masked from ‘package:pROC’:
#
#     auc
#
#
# Attaching package: ‘pls’
#
# The following object is masked from ‘package:stats’:
#
#     loadings

# %%
### Plotting base_theme
base_theme <- function(){ theme_bw() + 
            theme(text=element_text(size=8)) +
            theme(plot.title=element_text(size=8)) +
            theme(plot.background=element_blank(),
                  panel.grid.major=element_blank(), 
                  panel.grid.minor=element_blank()) +
            theme(strip.background=element_blank(),
                  strip.text=element_text(size=7, face='bold')) +
            theme(axis.title=element_text(size=8, vjust=0.25),
                  axis.text.x=element_text(size=8, vjust=0.5, hjust=0.5),
                  axis.text.y=element_text(size=8)) +
            theme(legend.text=element_text(size=7),
                  legend.title=element_text(size=7),
                  legend.key.height=grid::unit(10, "points"), 
                  legend.key.width=grid::unit(10, "points"))}

# %% [markdown]
# ### Load data and take quick peek at select "pressors"  (e.g. vent and central line)

# %%
pressors_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/pressors.csv')

# %%
pressors_df %>%
    group_by(pressor) %>% summarize(count = n())
# Out:
#    pressor                 count
# 1  adenosinedurations        160
# 2  arterial_line_durations 30424
# 3  central_line_durations  38211
# 4  crrtdurations            5918
# 5  dobutaminedurations      1792
# 6  dopaminedurations        6524
# 7  epinephrinedurations     3126
# 8  isupreldurations           24
# 9  milrinonedurations       3600
# 10 norepinephrinedurations 23188
# 11 phenylephrinedurations  33141
# 12 vasopressindurations     4190
# 13 vasopressordurations    38832
# 14 ventdurations           38515

# %%
dim(pressors_df)
# Out:
# [1] 227645     11

# %%
pressors_df %>%
    filter(pressor == "central_line_durations") %>% head()
# Out:
#   X     level_0                level_1 duration_hours endtime
# 1 30584 central_line_durations 0        70.91667      2181-11-28 20:59:00
# 2 30585 central_line_durations 1       134.00000      2199-08-08 15:00:00
# 3 30586 central_line_durations 2        37.75000      2189-12-02 08:00:00
# 4 30587 central_line_durations 3        19.68333      2132-08-05 20:36:00
# 5 30588 central_line_durations 4        23.76667      2114-12-27 22:46:00
# 6 30589 central_line_durations 5         9.30000      2127-03-04 01:18:00
#   icustay_id num pressor                starttime           vasonum ventnum
# 1 200001     NA  central_line_durations 2181-11-25 22:04:00 NA      NA
# 2 200003     NA  central_line_durations 2199-08-03 01:00:00 NA      NA
# 3 200009     NA  central_line_durations 2189-11-30 18:15:00 NA      NA
# 4 200010     NA  central_line_durations 2132-08-05 00:55:00 NA      NA
# 5 200021     NA  central_line_durations 2114-12-26 23:00:00 NA      NA
# 6 200024     NA  central_line_durations 2127-03-03 16:00:00 NA      NA

# %%
pressors_df %>%
    filter(pressor == "ventdurations") %>% head()
# Out:
#   X      level_0       level_1 duration_hours endtime             icustay_id
# 1 189130 ventdurations 0       91.00000       2199-08-07 13:00:00 200003
# 2 189131 ventdurations 1       14.83333       2159-09-04 03:50:00 200006
# 3 189132 ventdurations 2       15.83333       2189-12-01 10:00:00 200009
# 4 189133 ventdurations 3        3.00000       2188-08-06 04:00:00 200011
# 5 189134 ventdurations 4       18.75000       2105-02-17 18:00:00 200014
# 6 189135 ventdurations 5       83.00000       2138-03-21 09:00:00 200017
#   num pressor       starttime           vasonum ventnum
# 1 NA  ventdurations 2199-08-03 18:00:00 NA      1
# 2 NA  ventdurations 2159-09-03 13:00:00 NA      1
# 3 NA  ventdurations 2189-11-30 18:10:00 NA      1
# 4 NA  ventdurations 2188-08-06 01:00:00 NA      1
# 5 NA  ventdurations 2105-02-16 23:15:00 NA      1
# 6 NA  ventdurations 2138-03-17 22:00:00 NA      1

# %% [markdown]
# ### Available pressor (and other infusions) choices
# - Make choices
# - Quick check of dataset balancing

# %%
unique(pressors_df$pressor)
# Out:
#  [1] adenosinedurations      arterial_line_durations central_line_durations
#  [4] crrtdurations           dobutaminedurations     dopaminedurations
#  [7] epinephrinedurations    isupreldurations        milrinonedurations
# [10] norepinephrinedurations phenylephrinedurations  vasopressindurations
# [13] vasopressordurations    ventdurations
# 14 Levels: adenosinedurations ... ventdurations

# %%
pressor_choices <- c("norepinephrinedurations", "dopaminedurations", "phenylephrinedurations")

# %%
FANCY_PRESSOR_ORDER <- c("Norepinephrine", "Dopamine", "Phenylephrine")

# %%
FANCY_PRESSOR_DICT <- c(
'dopaminedurations' = 'Dopamine',
'norepinephrinedurations' = 'Norepinephrine',  
'phenylephrinedurations' = 'Phenylephrine'
)

# %%
PLOT_DIR <- "~/Google Drive/vasopressors/figures"

# %%
pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    mutate(MORETHAN24HOURS = duration_hours > 24) %>%
    group_by(MORETHAN24HOURS, pressor) %>% 
    summarize(COUNT = n())
# Out:
#   MORETHAN24HOURS pressor                 COUNT
# 1 FALSE           dopaminedurations        5422
# 2 FALSE           norepinephrinedurations 19811
# 3 FALSE           phenylephrinedurations  30430
# 4  TRUE           dopaminedurations        1102
# 5  TRUE           norepinephrinedurations  3377
# 6  TRUE           phenylephrinedurations   2711

# %% [markdown]
# ### Histograms of pressor durations for all 3 pressors of interest

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    mutate(DIFF = 
              difftime(fastPOSIXct(endtime), 
               fastPOSIXct(starttime), units="hours")) %>%
    ggplot(aes(x=DIFF)) +
        geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6)+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="Histogram",x="Hours", y = "Density")+
        theme_classic()
plot(p)
# Out:
# Don't know how to automatically pick scale for object of type difftime. Defaulting to continuous.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# “Removed 1254 rows containing non-finite values (stat_bin).”Warning message:
# “Removed 1254 rows containing non-finite values (stat_density).”
# plot without title

# %% [markdown]
# ### Figure X. all pressors

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    mutate(DIFF = 
              difftime(fastPOSIXct(endtime), 
               fastPOSIXct(starttime), units="hours")) %>%
    filter(DIFF < 48) %>%
    ggplot(aes(x=DIFF)) +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6, fill = "gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Density")+
        base_theme() +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="cornflowerblue")
plot(p)
# Out:
# Don't know how to automatically pick scale for object of type difftime. Defaulting to continuous.
# plot without title

# %%
# pdf(file.path(PLOT_DIR, "histo_durations.pdf"), 2, 2)
# plot(p)
# dev.off()

# %%
options(repr.plot.width=5, repr.plot.height=2)
p <- pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    mutate(DIFF = 
              difftime(fastPOSIXct(endtime), 
               fastPOSIXct(starttime), units="hours")) %>%
    rowwise() %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    filter(DIFF < 48) %>%
    ggplot(aes(x=DIFF)) +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6, fill = "gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Density")+
        base_theme() +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="cornflowerblue") +
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Don't know how to automatically pick scale for object of type difftime. Defaulting to continuous.
# plot without title

# %%
# pdf(file.path(PLOT_DIR, "histo_individual_durations.pdf"), 5, 2)
# plot(p)
# dev.off()

# %% [markdown]
# ### Join with icustay metadata (pressors_df + lengthstay_df -> input_df)

# %%
lengthstay_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/length_stay.csv') %>%
    rename(icustarttime = START, icuendtime = END)

# %%
lengthstay_df %>% head()
# Out:
#   X icustay_id icustarttime        icuendtime          DIFF
# 1 1 200001     2181-11-25 19:06:00 2181-11-28 20:00:00  72.90000
# 2 2 200003     2199-08-02 19:15:00 2199-08-08 15:00:00 139.75000
# 3 3 200006     2159-09-03 12:30:00 2159-09-04 17:00:00  28.50000
# 4 4 200007     2109-02-17 09:00:00 2109-02-18 09:15:00  24.25000
# 5 5 200009     2189-11-30 11:43:00 2189-12-02 13:00:00  49.28333
# 6 6 200010     2132-08-05 00:39:00 2132-08-05 21:17:00  20.63333

# %%
# filter by pressor and left join with lengthstay_df
input_df <- pressors_df %>%
    filter(pressor %in% pressor_choices)  %>%
    left_join(lengthstay_df, by = "icustay_id") %>%
    mutate(starttime = fastPOSIXct(starttime), endtime = fastPOSIXct(endtime), 
           icustarttime = fastPOSIXct(icustarttime), icuendtime = fastPOSIXct(icuendtime))

# %% [markdown]
# # Filters

# %% [markdown]
# #### Collapse pressor courses based on length of intervening time (<24 hrs)
# - Any two courses with less than intervening 24 hours will be collapsed into a single course within an icustay

# %%
# max_intervening_hrs <- 24

# # find the intervening time between courses (endtime of next course - endtime of course - duration of course)
# # then determine if that length of time is >24 or <24 and mark it with a 0 if true, else a 1
# # use a cumsum to create a new id separating courses that are separated by more than >24

# input_df <- input_df %>%
#         group_by(icustay_id) %>%
#         mutate(intervening_hours = difftime(endtime, lag(endtime), units="hours") - duration_hours) %>%
#         rowwise() %>%
#         mutate(increasing = if(intervening_hours < max_intervening_hrs | is.na(intervening_hours)){0}else(1)) %>%
#         ungroup() %>%
#         group_by(icustay_id) %>%
#         mutate(continuous_course = cumsum(increasing)) %>% select(-intervening_hours, -increasing)

# %%
max_intervening_hrs <- 24

# find the intervening time between courses (endtime of next course - endtime of course - duration of course)
# then determine if that length of time is >24 or <24 and mark it with a 0 if true, else a 1
# use a cumsum to create a new id separating courses that are separated by more than >24
input_list <- list()
for(pressor_choice in pressor_choices){
    input_list[[pressor_choice]] <- input_df %>%
        filter(pressor == pressor_choice) %>%
        group_by(icustay_id) %>%
        mutate(intervening_hours = difftime(endtime, lag(endtime), units="hours") - duration_hours) %>%
        rowwise() %>%
        mutate(increasing = if(intervening_hours < max_intervening_hrs | is.na(intervening_hours)){0}else(1)) %>%
        ungroup() %>%
        group_by(icustay_id) %>%
        mutate(continuous_course = cumsum(increasing)) %>% select(-intervening_hours, -increasing)
    cat(pressor_choice, '\n')
}
# Out:
# norepinephrinedurations
# dopaminedurations
# phenylephrinedurations

# %%
input_df <- bind_rows(input_list, .id="pressor_choice")

# %% [markdown]
# - the combination of **continuous course** and **icustay_id** (e.g. 200024, 0 for first row) now defines each pressor course

# %% [markdown]
# - assign boolean assessments after <24 hour intervals between pressors are removed
#     1. more or less than 24 hours of pressor duration?
#     2. is this the first pressor course?
#     3. are pressors administered <1 hr of the icustay?

# %%
# 1. more or less than 24 hours?
input_df <- input_df %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(MORETHAN24HOURS = sum(duration_hours) > 24, 
           STATUS = if(sum(duration_hours) > 24){"MORETHAN24HOURS"}
           else if(sum(duration_hours) <= 24 & sum(duration_hours) > 6){"LESSTHAN24HOURS"}
           else if(sum(duration_hours) <= 6){"LESSTHAN6HOURS"}
               )

# %%
# 2. first pressor course? (groupby icustay, filter min starttime == starttime)
input_df <- input_df %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(coursestarttime = min(starttime)) %>%
    group_by(icustay_id) %>%
    mutate(FIRSTCOURSE = min(coursestarttime) == coursestarttime)

# %%
# 3. pressors within 1 hr of icustay_id? (groupby icustay, filter max starttime - unique icustarttime > 1)
input_df <- input_df %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(coursestarttime = min(starttime)) %>%
    group_by(icustay_id) %>%
    mutate(LESS1HOUR = difftime(min(coursestarttime), 
                         min(icustarttime)) < 1)

# %%
# grouped by icustay_id + continuous_course + separate_course
input_df %>%
    group_by(LESS1HOUR, FIRSTCOURSE, MORETHAN24HOURS, pressor) %>%
    summarize(COUNT = n())
# Out:
#    LESS1HOUR FIRSTCOURSE MORETHAN24HOURS pressor                 COUNT
# 1  FALSE     FALSE       FALSE           dopaminedurations         740
# 2  FALSE     FALSE       FALSE           norepinephrinedurations  2340
# 3  FALSE     FALSE       FALSE           phenylephrinedurations   2994
# 4  FALSE     FALSE        TRUE           dopaminedurations         838
# 5  FALSE     FALSE        TRUE           norepinephrinedurations  6513
# 6  FALSE     FALSE        TRUE           phenylephrinedurations   5674
# 7  FALSE      TRUE       FALSE           dopaminedurations        2124
# 8  FALSE      TRUE       FALSE           norepinephrinedurations  3782
# 9  FALSE      TRUE       FALSE           phenylephrinedurations  11821
# 10 FALSE      TRUE        TRUE           dopaminedurations        1880
# 11 FALSE      TRUE        TRUE           norepinephrinedurations  7931
# 12 FALSE      TRUE        TRUE           phenylephrinedurations  10223
# 13  TRUE     FALSE       FALSE           dopaminedurations          46
# 14  TRUE     FALSE       FALSE           norepinephrinedurations   147
# 15  TRUE     FALSE       FALSE           phenylephrinedurations    197
# 16  TRUE     FALSE        TRUE           dopaminedurations          31
# 17  TRUE     FALSE        TRUE           norepinephrinedurations   307
# 18  TRUE     FALSE        TRUE           phenylephrinedurations    184
# 19  TRUE      TRUE       FALSE           dopaminedurations         304
# 20  TRUE      TRUE       FALSE           norepinephrinedurations   355
# 21  TRUE      TRUE       FALSE           phenylephrinedurations    434
# 22  TRUE      TRUE        TRUE           dopaminedurations         240
# 23  TRUE      TRUE        TRUE           norepinephrinedurations   455
# 24  TRUE      TRUE        TRUE           phenylephrinedurations    256
# 25    NA     FALSE       FALSE           dopaminedurations          28
# 26    NA     FALSE       FALSE           norepinephrinedurations    86
# 27    NA     FALSE       FALSE           phenylephrinedurations    136
# 28    NA     FALSE        TRUE           dopaminedurations          23
# 29    NA     FALSE        TRUE           norepinephrinedurations   403
# 30    NA     FALSE        TRUE           phenylephrinedurations    253
# 31    NA      TRUE       FALSE           dopaminedurations          32
# 32    NA      TRUE       FALSE           norepinephrinedurations    71
# 33    NA      TRUE       FALSE           phenylephrinedurations    141
# 34    NA      TRUE        TRUE           dopaminedurations          78
# 35    NA      TRUE        TRUE           norepinephrinedurations   302
# 36    NA      TRUE        TRUE           phenylephrinedurations    230
# 37    NA        NA       FALSE           dopaminedurations          63
# 38    NA        NA       FALSE           norepinephrinedurations   113
# 39    NA        NA       FALSE           phenylephrinedurations    258
# 40    NA        NA        TRUE           dopaminedurations          97
# 41    NA        NA        TRUE           norepinephrinedurations   383
# 42    NA        NA        TRUE           phenylephrinedurations    340

# %%
# With filters grouped by icustay_id + continuous_course
input_df %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(LESS1HOUR, FIRSTCOURSE, MORETHAN24HOURS, pressor) %>%
    summarize(COUNT = length(unique(course_id)))
# Out:
#    LESS1HOUR FIRSTCOURSE MORETHAN24HOURS pressor                 COUNT
# 1  FALSE     FALSE       FALSE           dopaminedurations        571
# 2  FALSE     FALSE       FALSE           norepinephrinedurations 1592
# 3  FALSE     FALSE       FALSE           phenylephrinedurations  1859
# 4  FALSE     FALSE        TRUE           dopaminedurations        302
# 5  FALSE     FALSE        TRUE           norepinephrinedurations 1482
# 6  FALSE     FALSE        TRUE           phenylephrinedurations  1097
# 7  FALSE      TRUE       FALSE           dopaminedurations       1694
# 8  FALSE      TRUE       FALSE           norepinephrinedurations 2611
# 9  FALSE      TRUE       FALSE           phenylephrinedurations  6812
# 10 FALSE      TRUE        TRUE           dopaminedurations        735
# 11 FALSE      TRUE        TRUE           norepinephrinedurations 1847
# 12 FALSE      TRUE        TRUE           phenylephrinedurations  2380
# 13  TRUE     FALSE       FALSE           dopaminedurations         35
# 14  TRUE     FALSE       FALSE           norepinephrinedurations  103
# 15  TRUE     FALSE       FALSE           phenylephrinedurations   122
# 16  TRUE     FALSE        TRUE           dopaminedurations         13
# 17  TRUE     FALSE        TRUE           norepinephrinedurations   90
# 18  TRUE     FALSE        TRUE           phenylephrinedurations    55
# 19  TRUE      TRUE       FALSE           dopaminedurations        238
# 20  TRUE      TRUE       FALSE           norepinephrinedurations  267
# 21  TRUE      TRUE       FALSE           phenylephrinedurations   275
# 22  TRUE      TRUE        TRUE           dopaminedurations         86
# 23  TRUE      TRUE        TRUE           norepinephrinedurations  135
# 24  TRUE      TRUE        TRUE           phenylephrinedurations    81
# 25    NA     FALSE       FALSE           dopaminedurations         22
# 26    NA     FALSE       FALSE           norepinephrinedurations   58
# 27    NA     FALSE       FALSE           phenylephrinedurations    98
# 28    NA     FALSE        TRUE           dopaminedurations         13
# 29    NA     FALSE        TRUE           norepinephrinedurations   87
# 30    NA     FALSE        TRUE           phenylephrinedurations    52
# 31    NA      TRUE       FALSE           dopaminedurations         25
# 32    NA      TRUE       FALSE           norepinephrinedurations   55
# 33    NA      TRUE       FALSE           phenylephrinedurations    79
# 34    NA      TRUE        TRUE           dopaminedurations         36
# 35    NA      TRUE        TRUE           norepinephrinedurations   53
# 36    NA      TRUE        TRUE           phenylephrinedurations    51
# 37    NA        NA       FALSE           dopaminedurations         45
# 38    NA        NA       FALSE           norepinephrinedurations   79
# 39    NA        NA       FALSE           phenylephrinedurations   143
# 40    NA        NA        TRUE           dopaminedurations         24
# 41    NA        NA        TRUE           norepinephrinedurations   67
# 42    NA        NA        TRUE           phenylephrinedurations    60

# %%
options(repr.plot.width=2, repr.plot.height=2)
p <- input_df %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    summarize(duration_hours = sum(duration_hours)) %>%
    ggplot(aes(x=duration_hours)) +
        base_theme() +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6, fill="gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Density")+
        xlim(0, 72) +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="#2F4F4F")
plot(p)
# Out:
# Warning message:
# “Removed 2521 rows containing non-finite values (stat_density).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "histo_durations.pdf"), 2, 2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 2521 rows containing non-finite values (stat_density).”
# pdf
#   2

# %%
options(repr.plot.width=4.5, repr.plot.height=2)
p <- input_df %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    summarize(duration_hours = sum(duration_hours)) %>%
    rowwise() %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=duration_hours)) +
        base_theme() +
        #geom_histogram(aes(y=..density..), position="identity", alpha=0.5)+
        geom_density(alpha=0.6, fill="gray")+
        scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
        labs(title="",x="Hours", y = "Density")+
        xlim(0, 72) +
        geom_vline(xintercept = 6, linetype= "dashed", color="firebrick") +
        geom_vline(xintercept = 24, linetype= "dashed", color="#2F4F4F") +
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Warning message:
# “Removed 2521 rows containing non-finite values (stat_density).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "histo_individual_durations.pdf"), 4.5, 2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 2521 rows containing non-finite values (stat_density).”
# pdf
#   2

# %% [markdown]
# ### Introduce other predictor values for each course (like RACE, Diagnosis type) -> nonvitals_predictor_df

# %%
races <- c("ASIAN", "BLACK", "HISPANIC", "WHITE", "OTHER")

simplifyRace <- function(ethnicity){
    if(grepl("ASIAN", ethnicity)){return("ASIAN")}
    else if(grepl("BLACK", ethnicity)){return("BLACK")}
    else if(grepl("HISPANIC", ethnicity)){return("HISPANIC")}
    else if(grepl("WHITE", ethnicity)){return("WHITE")}
    else{return("OTHER")}
}

# %%
sepsis_regex <- c('SEPSIS', 'SEPTIC', 'CHOLANGITIS', 'UROSEPSIS')

infection_regex <- c('PNEUMONIA', 'INFECTION',  
  'CELULLITIS', 'FASCITIS', 'INFECTED', 'BACTER', 'PNEMONIA', 'ABSCESS', 'NEPHRITIS')

cardiac_regex <- c('HEART', 'CORONARY', 'VENTRICULAR')

simplifyDiagnosis <- function(diagnosis){
    if(any(sapply(sepsis_regex, function(x) grepl(x, diagnosis)))){return("SEPSIS")}
    else if(any(sapply(infection_regex, function(x) grepl(x, diagnosis)))){return("INFECTION")}
    else if(any(sapply(cardiac_regex, function(x) grepl(x, diagnosis)))){return("CARDIAC")}
    else{return("OTHER DIAGNOSIS")}
}

# %%
icustays_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/icustays.csv')

# %%
admissions_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/admissions.csv')

# %%
patients_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/patients.csv')

# %%
intub_df <- pressors_df %>%
    filter(pressor == "ventdurations") 

cvc_df <- pressors_df %>%
    filter(pressor == "central_line_durations")

# %%
nonvitals_predictor_df <- icustays_df %>%
    select(hadm_id, icustay_id, first_careunit, last_careunit) %>%
    left_join(admissions_df, by = 'hadm_id') %>%
    left_join(patients_df, by = 'subject_id') %>%
    mutate(intub = icustay_id %in% intub_df$icustay_id, cvc = icustay_id %in% cvc_df$icustay_id) %>%
    mutate(deathtime = fastPOSIXct(deathtime), admittime = fastPOSIXct(admittime), dob = fastPOSIXct(dob)) %>%
    mutate(age = difftime(admittime, dob, units="weeks")/52.25, 
           age_cohort = as.numeric(round(age, digits = -1))) %>% 
    rowwise() %>%
    mutate(simple_race = simplifyRace(ethnicity)) %>%
    mutate(simple_diagnosis = simplifyDiagnosis(diagnosis))

# %% [markdown]
# ### Mortality filter
# - Remove patients who stopped using pressors because death (merge with pressors_df by icustay_id, filter if pressor course end time == or is close to deathtime)
# - Also quantify some unusual cases of death documentation

# %%
#NA means the stay did not end in death
#ICUSTAYS where patient was discharged after death? (TRUE)
nonvitals_predictor_df  %>%
    mutate(MORTALITYERROR = difftime(deathtime, dischtime, units = "mins") < 0) %>%
    group_by(MORTALITYERROR) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   MORTALITYERROR COUNT
# 1 FALSE             40
# 2  TRUE           6422
# 3    NA          55070

# %%
#NA means the stay did not end in death
#ICUSTAYS where patient was admitted after death? (TRUE)
nonvitals_predictor_df  %>%
    mutate(MORTALITYERROR = difftime(deathtime, admittime, units = "mins") < 0) %>%
    group_by(MORTALITYERROR) %>%
    summarize(COUNT = n())
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   MORTALITYERROR COUNT
# 1 FALSE           6384
# 2  TRUE             78
# 3    NA          55070

# %%
#Examples (admitted after death)
nonvitals_predictor_df  %>%
    filter(difftime(deathtime, admittime, units = "mins") < 0) %>%
    head(5)
# Out:
#   hadm_id icustay_id first_careunit last_careunit X.x  row_id.x subject_id
# 1 102631  246694     CSRU           CSRU           456  237      181
# 2 138015  298263     NICU           NICU          1911 1640     1334
# 3 181430  291798     SICU           SICU          1970 1699     1381
# 4 187482  213831     MICU           MICU           693  644      516
# 5 190088  293048     CCU            CCU           3624 3447     2858
#   admittime           dischtime           deathtime           ⋯ dod
# 1 2153-10-12 05:49:00 2153-10-12 06:29:00 2153-10-12 02:29:00 ⋯ 2153-10-12
# 2 2137-09-02 10:43:00 2137-09-02 12:00:00 2137-09-02 08:00:00 ⋯ 2137-09-02
# 3 2189-01-02 09:25:00 2189-01-02 12:00:00 2189-01-02 07:00:00 ⋯ 2189-01-02
# 4 2197-07-31 16:18:00 2197-07-31 01:10:00 2197-07-30 21:10:00 ⋯ 2197-07-31
# 5 2108-09-25 11:29:00 2108-09-25 12:00:00 2108-09-25 08:00:00 ⋯ 2108-09-25
#   dod_hosp   dod_ssn    expire_flag intub cvc   age               age_cohort
# 1 2153-10-12 2153-10-12 1           FALSE FALSE 65.12757082 weeks 70
# 2 2137-09-02            1            TRUE FALSE  0.00167654 weeks  0
# 3 2189-01-02 2189-01-02 1            TRUE FALSE 81.36049404 weeks 80
# 4 2197-07-31 2197-07-31 1           FALSE FALSE 70.88679654 weeks 70
# 5 2108-09-25 2108-09-25 1            TRUE FALSE 82.42418356 weeks 80
#   simple_race simple_diagnosis
# 1 WHITE       OTHER DIAGNOSIS
# 2 WHITE       OTHER DIAGNOSIS
# 3 WHITE       OTHER DIAGNOSIS
# 4 OTHER       OTHER DIAGNOSIS
# 5 WHITE       OTHER DIAGNOSIS

# %%
# Icustays where patients received pressors after death (TRUE)
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    mutate(STOPMORTALITY = difftime(deathtime, endtime, units = "mins")) %>% 
    group_by(STOPMORTALITY < 0) %>%
    summarize(COUNT = length(unique(icustay_id)))
# Out:
#   STOPMORTALITY < 0 COUNT
# 1 FALSE              3416
# 2  TRUE               658
# 3    NA             13640

# %% [markdown]
# ### Test out some mortality filters

# %%
### if I do not ignore for unusual cases (pressors after death)
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = STOPMORTALITY < 5) %>%
    group_by(STOPMORTALITY) %>%
    summarize(COUNT = n())
# Out:
#   STOPMORTALITY COUNT
# 1 FALSE         16598
# 2  TRUE          3584
# 3    NA         42671

# %%
### if I do ignore these unusual cases
input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = STOPMORTALITY > 0 &  STOPMORTALITY < 5) %>%
    group_by(STOPMORTALITY) %>%
    summarize(COUNT = n())
# Out:
#   STOPMORTALITY COUNT
# 1 FALSE         19985
# 2  TRUE           197
# 3    NA         42671

# %% [markdown]
# ### Create filters for mortality: input_df -> input_death_df

# %%
# # ignore NAs (patient did not die), or patient death did not correspond to end of pressor course
# # do not remove unusual cases
# input_death_df <- input_df %>%
#     ungroup() %>%
#     left_join(nonvitals_predictor_df, by = "icustay_id") %>%
#     group_by(icustay_id, continuous_course, pressor) %>%
#     mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
#     mutate(STOPMORTALITY = !(!(STOPMORTALITY < 5) | is.na(STOPMORTALITY)))

# %%
# ignore NAs (patient did not die), or patient death did not correspond to end of pressor course
# remove unusual cases
input_death_df <- input_df %>%
    ungroup() %>%
    left_join(nonvitals_predictor_df, by = "icustay_id") %>%
    group_by(icustay_id, continuous_course, pressor) %>%
    mutate(STOPMORTALITY = difftime(deathtime, max(endtime), units = "mins")) %>% 
    mutate(STOPMORTALITY = !(!(STOPMORTALITY > 0 &  STOPMORTALITY < 5) | is.na(STOPMORTALITY)))

# %% [markdown]
# ### Exclude NICU (all NICU was already excluded by pressor usage): : input_death_df -> input_death_df

# %%
input_death_df %>%
    mutate(NICUSTAY = first_careunit == "NICU") %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(LESS1HOUR, FIRSTCOURSE, STOPMORTALITY, MORETHAN24HOURS, NICUSTAY) %>%
    summarize(COUNT = length(unique(course_id)))
# Out:
#    LESS1HOUR FIRSTCOURSE STOPMORTALITY MORETHAN24HOURS NICUSTAY COUNT
# 1  FALSE     FALSE       FALSE         FALSE           FALSE     3696
# 2  FALSE     FALSE       FALSE         FALSE            TRUE        6
# 3  FALSE     FALSE       FALSE          TRUE           FALSE     2677
# 4  FALSE     FALSE       FALSE          TRUE            TRUE       18
# 5  FALSE     FALSE        TRUE         FALSE           FALSE       21
# 6  FALSE     FALSE        TRUE          TRUE           FALSE       17
# 7  FALSE      TRUE       FALSE         FALSE           FALSE    10778
# 8  FALSE      TRUE       FALSE         FALSE            TRUE       90
# 9  FALSE      TRUE       FALSE          TRUE           FALSE     4785
# 10 FALSE      TRUE       FALSE          TRUE            TRUE      112
# 11 FALSE      TRUE        TRUE         FALSE           FALSE       19
# 12 FALSE      TRUE        TRUE         FALSE            TRUE        1
# 13 FALSE      TRUE        TRUE          TRUE           FALSE        2
# 14  TRUE     FALSE       FALSE         FALSE           FALSE      239
# 15  TRUE     FALSE       FALSE          TRUE           FALSE      150
# 16  TRUE     FALSE        TRUE         FALSE           FALSE        1
# 17  TRUE     FALSE        TRUE          TRUE           FALSE        1
# 18  TRUE      TRUE       FALSE         FALSE           FALSE      731
# 19  TRUE      TRUE       FALSE         FALSE            TRUE        1
# 20  TRUE      TRUE       FALSE          TRUE           FALSE      290
# 21  TRUE      TRUE       FALSE          TRUE            TRUE        2
# 22  TRUE      TRUE        TRUE         FALSE           FALSE        2
# 23  TRUE      TRUE        TRUE          TRUE           FALSE        1
# 24    NA     FALSE       FALSE         FALSE           FALSE      161
# 25    NA     FALSE       FALSE         FALSE            TRUE        1
# 26    NA     FALSE       FALSE         FALSE              NA        2
# 27    NA     FALSE       FALSE          TRUE           FALSE      137
# 28    NA     FALSE       FALSE          TRUE            TRUE        3
# 29    NA     FALSE       FALSE          TRUE              NA        1
# 30    NA      TRUE       FALSE         FALSE           FALSE      152
# 31    NA      TRUE       FALSE         FALSE            TRUE        3
# 32    NA      TRUE       FALSE         FALSE              NA        1
# 33    NA      TRUE       FALSE          TRUE           FALSE      121
# 34    NA      TRUE       FALSE          TRUE            TRUE       16
# 35    NA      TRUE        TRUE          TRUE           FALSE        1
# 36    NA        NA       FALSE         FALSE           FALSE      226
# 37    NA        NA       FALSE         FALSE            TRUE        1
# 38    NA        NA       FALSE          TRUE           FALSE      123
# 39    NA        NA       FALSE          TRUE            TRUE        3

# %%
input_death_df <- input_death_df %>%
    filter(first_careunit != "NICU")

# %% [markdown]
# ### Use filters, clean predictors: input_death_df -> output_df

# %%
output_df <- input_death_df %>%
    mutate(course_id = paste(icustay_id, continuous_course, sep = ",")) %>%
    group_by(course_id, pressor) %>%
    mutate(starttime = min(starttime), endtime = max(endtime)) %>%
    filter(!LESS1HOUR, FIRSTCOURSE, !STOPMORTALITY)

# %%
# collapse so each row is a course_id
output_df <- output_df %>%
    group_by(course_id, pressor) %>%
    summarize(
            STATUS = unique(STATUS)[1], 
            MORETHAN24HOURS = unique(MORETHAN24HOURS)[1], 
            simple_diagnosis = unique(simple_diagnosis)[1], 
            simple_race = unique(simple_race)[1], 
            age = unique(age)[1], 
            age_cohort = unique(age_cohort)[1], 
            cvc = unique(cvc)[1],
            intub = unique(intub)[1],
            first_careunit = unique(first_careunit)[1],
            gender = unique(gender)[1],
            icustay_id = unique(icustay_id)[1],
            starttime = min(starttime), 
            endtime = max(endtime)
    ) %>% 
    mutate(duration = difftime(endtime, 
                       starttime, units="hours"))

# %%
dim(output_df)
# Out:
# [1] 15853    16

# %%
unique(output_df$icustay_id) %>% length()
# Out:
# [1] 15434

# %% [markdown]
# # Analysis

# %% [markdown]
# ### For text, description of meta-data

# %%
# minimum age
min(output_df$age, na.rm=TRUE)
# Out:
# [1] 15.15073

# %%
dim(output_df)
# Out:
# [1] 15853    16

# %%
output_df %>%
    group_by(STATUS) %>%
    summarize(COUNT = n())
# Out:
#   STATUS          COUNT
# 1 LESSTHAN24HOURS 5598
# 2 LESSTHAN6HOURS  5407
# 3 MORETHAN24HOURS 4848

# %%
output_df %>%
    group_by(STATUS, pressor) %>%
    summarize(COUNT = n())
# Out:
#   STATUS          pressor                 COUNT
# 1 LESSTHAN24HOURS dopaminedurations        697
# 2 LESSTHAN24HOURS norepinephrinedurations 1548
# 3 LESSTHAN24HOURS phenylephrinedurations  3353
# 4 LESSTHAN6HOURS  dopaminedurations        903
# 5 LESSTHAN6HOURS  norepinephrinedurations 1053
# 6 LESSTHAN6HOURS  phenylephrinedurations  3451
# 7 MORETHAN24HOURS dopaminedurations        623
# 8 MORETHAN24HOURS norepinephrinedurations 1846
# 9 MORETHAN24HOURS phenylephrinedurations  2379

# %%
output_df %>%
    group_by(STATUS == "LESSTHAN6HOURS") %>%
    summarize(COUNT = n()) %>% 
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
#   STATUS == "LESSTHAN6HOURS" COUNT FREQ
# 1 FALSE                      10446 0.6589289
# 2  TRUE                       5407 0.3410711

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS", cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
#   RESPONSE cvc   COUNT FREQ
# 1 FALSE    FALSE 1372  0.1313421
# 2 FALSE     TRUE 9074  0.8686579
# 3  TRUE    FALSE 1072  0.1982615
# 4  TRUE     TRUE 4335  0.8017385

# %%
output_df %>%
    group_by(STATUS == "MORETHAN24HOURS") %>%
    summarize(COUNT = n()) %>% 
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
#   STATUS == "MORETHAN24HOURS" COUNT FREQ
# 1 FALSE                       11005 0.6941904
# 2  TRUE                        4848 0.3058096

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "MORETHAN24HOURS", cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(RESPONSE) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
#   RESPONSE cvc   COUNT FREQ
# 1 FALSE    FALSE 2070  0.18809632
# 2 FALSE     TRUE 8935  0.81190368
# 3  TRUE    FALSE  374  0.07714521
# 4  TRUE     TRUE 4474  0.92285479

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "LESSTHAN6HOURS", pressor) %>%
    summarize(COUNT = n()) %>% 
    group_by(pressor) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>% filter(RESPONSE)
# Out:
#   RESPONSE pressor                 COUNT FREQ
# 1 TRUE     dopaminedurations        903  0.4062078
# 2 TRUE     norepinephrinedurations 1053  0.2367888
# 3 TRUE     phenylephrinedurations  3451  0.3758031

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "MORETHAN24HOURS", pressor) %>%
    summarize(COUNT = n()) %>% 
    group_by(pressor) %>%
    mutate(FREQ = COUNT/sum(COUNT)) %>% filter(!RESPONSE)
# Out:
#   RESPONSE pressor                 COUNT FREQ
# 1 FALSE    dopaminedurations       1600  0.7197481
# 2 FALSE    norepinephrinedurations 2601  0.5848887
# 3 FALSE    phenylephrinedurations  6804  0.7409343

# %% [markdown]
# ### Figure X. CVC associated with longer pressor courses

# %%
CVC_COLORS <- c(
"CVC" = '#2F4F4F',
"No CVC" = '#D3D3D3'
)

# %%
output_df %>%
    group_by(RESPONSE = STATUS == "MORETHAN24HOURS", cvc) %>%
    summarize(COUNT = n()) %>% 
    group_by(cvc) %>%
    mutate(FREQ = COUNT/sum(COUNT))
# Out:
#   RESPONSE cvc   COUNT FREQ
# 1 FALSE    FALSE 2070  0.8469722
# 2 FALSE     TRUE 8935  0.6663435
# 3  TRUE    FALSE  374  0.1530278
# 4  TRUE     TRUE 4474  0.3336565

# %%
pairwise.wilcox.test(as.numeric(output_df$duration), output_df$cvc)
# Out:
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(output_df$duration) and output_df$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm

# %%
options(repr.plot.width=1.5, repr.plot.height=2)
p <- output_df %>%
    rowwise() %>%
    mutate(cvc_fancy = if(cvc){"CVC"}else{"No CVC"}) %>%
    mutate(cvc_fancy = factor(cvc_fancy, levels = names(CVC_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=cvc_fancy, y=duration)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("Duration (hours)") +
        geom_violin(aes(fill=cvc_fancy), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,72)) +
        geom_boxplot(width=0.05, outlier.shape = NA)+
        stat_summary(fun.y=median, geom="point", size=2, color="firebrick")
        #+ facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Warning message:
# “Removed 1354 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_summary).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "cvcduration.pdf"), 1.5,2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 1354 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_summary).”
# pdf
#   2

# %%
for(presor_choice in pressor_choices){
    pairwise.wilcox.test(as.numeric(filter(output_df,pressor==pressor_choice)$duration), 
                     filter(output_df,pressor==pressor_choice)$cvc) %>% 
    print()
}
# Out:
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm
#
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm
#
# 	Pairwise comparisons using Wilcoxon rank sum test
#
# data:  as.numeric(filter(output_df, pressor == pressor_choice)$duration) and filter(output_df, pressor == pressor_choice)$cvc
#
#      FALSE
# TRUE <2e-16
#
# P value adjustment method: holm

# %%
options(repr.plot.width=4, repr.plot.height=2)
p <- output_df %>%
    rowwise() %>%
    mutate(cvc_fancy = if(cvc){"CVC"}else{"No CVC"}) %>%
    mutate(cvc_fancy = factor(cvc_fancy, levels = names(CVC_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x=cvc_fancy, y=duration)) +
        base_theme() + 
        theme(legend.position="none") +
        xlab("") +
        ylab("Duration (hours)") +
        geom_violin(aes(fill=cvc_fancy), alpha=0.4, scale="width", trim=TRUE, adjust=2, width=0.5) +
        scale_fill_manual(values=CVC_COLORS) +
        scale_y_continuous(limits=c(0,72)) +
        geom_boxplot(width=0.05, outlier.shape = NA) +
        stat_summary(fun.y=median, geom="point", size=2, color="firebrick") +
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# Warning message:
# “Removed 1354 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_summary).”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "cvcduration_eachpressor.pdf"), 4,2)
plot(p)
dev.off()
# Out:
# Warning message:
# “Removed 1354 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 1354 rows containing non-finite values (stat_summary).”
# pdf
#   2

# %% [markdown]
# ### Table 1 (RR Analysis)

# %%
t1_df <- output_df %>% 
    group_by(STATUS) %>%
    summarize(COUNT = n(), 
              AGE_MEAN = as.numeric(mean(age, na.rm=TRUE)), AGE_SD = sd(age, na.rm=TRUE),
              FEMALE_SUM = sum(gender == 'F'),
              FEMALE_FRAC = sum(gender == 'F')/n(),
              WHITE_SUM = sum(simple_race == 'WHITE'),
              WHITE_FRAC = sum(simple_race == 'WHITE')/n(),
              BLACK_SUM = sum(simple_race == 'BLACK'),
              BLACK_FRAC = sum(simple_race == 'BLACK')/n(),
              HISPANIC_SUM = sum(simple_race == 'HISPANIC'),
              HISPANIC_FRAC = sum(simple_race == 'HISPANIC')/n(),
              ASIAN_SUM = sum(simple_race == 'ASIAN'),
              ASIAN_FRAC = sum(simple_race == 'ASIAN')/n(),
              MICU_SUM = sum(first_careunit == 'MICU'),
              MICU_FRAC = sum(first_careunit == 'MICU')/n(),
              SICU_SUM = sum(first_careunit == 'SICU'),
              SICU_FRAC = sum(first_careunit == 'SICU')/n(),
              CCU_SUM = sum(first_careunit == 'CCU'),
              CCU_FRAC = sum(first_careunit == 'CCU')/n(),
              TSICU_SUM = sum(first_careunit == 'TSICU'),
              TSICU_FRAC = sum(first_careunit == 'TSICU')/n(),
              CSRU_SUM = sum(first_careunit == 'CSRU'),
              CSRU_FRAC = sum(first_careunit == 'CSRU')/n(),
              SEPSIS_SUM = sum(simple_diagnosis == "SEPSIS"),
              SEPSIS_FRAC = sum(simple_diagnosis == "SEPSIS")/n(),
              INFX_SUM = sum(simple_diagnosis == "INFECTION"),
              INFX_FRAC = sum(simple_diagnosis == "INFECTION")/n(),
              CARDIAC_SUM = sum(simple_diagnosis == "CARDIAC"),
              CARDIAC_FRAC = sum(simple_diagnosis == "CARDIAC")/n(),
              CVC_SUM = sum(cvc == "TRUE", na.rm=TRUE),
              CVC_FRAC = sum(cvc == "TRUE", na.rm=TRUE)/n(),
              INTUB_SUM = sum(intub == "TRUE", na.rm=TRUE),
              INTUB_FRAC = sum(intub == "TRUE", na.rm=TRUE)/n()
             ) %>% t()

# %%
colnames(t1_df) <- t1_df[1,]

# %%
t1_df
# Out:
#               LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# STATUS        LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# COUNT         5598            5407           4848
# AGE_MEAN      65.71429        66.29365       65.21121
# AGE_SD        14.33112        14.47993       14.48098
# FEMALE_SUM    2133            2258           2002
# FEMALE_FRAC   0.3810289       0.4176068      0.4129538
# WHITE_SUM     4008            3889           3439
# WHITE_FRAC    0.7159700       0.7192528      0.7093647
# BLACK_SUM     323             364            319
# BLACK_FRAC    0.05769918      0.06732014     0.06580033
# HISPANIC_SUM  139             155            109
# HISPANIC_FRAC 0.02483030      0.02866654     0.02248350
# ASIAN_SUM     152             124             98
# ASIAN_FRAC    0.02715255      0.02293323     0.02021452
# MICU_SUM      1454            1299           1524
# MICU_FRAC     0.2597356       0.2402441      0.3143564
# SICU_SUM      674             580            628
# SICU_FRAC     0.1204001       0.1072684      0.1295380
# CCU_SUM       744             705            701
# CCU_FRAC      0.1329046       0.1303865      0.1445957
# TSICU_SUM     464             470            444
# TSICU_FRAC    0.08288675      0.08692436     0.09158416
# CSRU_SUM      2262            2353           1551
# CSRU_FRAC     0.4040729       0.4351766      0.3199257
# SEPSIS_SUM    408             272            386
# SEPSIS_FRAC   0.07288317      0.05030516     0.07962046
# INFX_SUM      283             265            331
# INFX_FRAC     0.05055377      0.04901054     0.06827558
# CARDIAC_SUM   1340            1380            988
# CARDIAC_FRAC  0.2393712       0.2552247      0.2037954
# CVC_SUM       4600            4335           4474
# CVC_FRAC      0.8217220       0.8017385      0.9228548
# INTUB_SUM     4586            4428           4160
# INTUB_FRAC    0.8192212       0.8189384      0.8580858

# %%
t1_df %>% write.csv(file.path(PLOT_DIR, "response_demographics.csv"))

# %% [markdown]
# ### Supplement 1-3

# %%
s1_3_df <- output_df %>% 
    group_by(STATUS, pressor) %>%
    summarize(COUNT = n(), 
              AGE_MEAN = as.numeric(mean(age, na.rm=TRUE)), AGE_SD = sd(age, na.rm=TRUE),
              FEMALE_SUM = sum(gender == 'F'),
              FEMALE_FRAC = sum(gender == 'F')/n(),
              WHITE_SUM = sum(simple_race == 'WHITE'),
              WHITE_FRAC = sum(simple_race == 'WHITE')/n(),
              BLACK_SUM = sum(simple_race == 'BLACK'),
              BLACK_FRAC = sum(simple_race == 'BLACK')/n(),
              HISPANIC_SUM = sum(simple_race == 'HISPANIC'),
              HISPANIC_FRAC = sum(simple_race == 'HISPANIC')/n(),
              ASIAN_SUM = sum(simple_race == 'ASIAN'),
              ASIAN_FRAC = sum(simple_race == 'ASIAN')/n(),
              MICU_SUM = sum(first_careunit == 'MICU'),
              MICU_FRAC = sum(first_careunit == 'MICU')/n(),
              SICU_SUM = sum(first_careunit == 'SICU'),
              SICU_FRAC = sum(first_careunit == 'SICU')/n(),
              CCU_SUM = sum(first_careunit == 'CCU'),
              CCU_FRAC = sum(first_careunit == 'CCU')/n(),
              TSICU_SUM = sum(first_careunit == 'TSICU'),
              TSICU_FRAC = sum(first_careunit == 'TSICU')/n(),
              CSRU_SUM = sum(first_careunit == 'CSRU'),
              CSRU_FRAC = sum(first_careunit == 'CSRU')/n(),
              SEPSIS_SUM = sum(simple_diagnosis == "SEPSIS"),
              SEPSIS_FRAC = sum(simple_diagnosis == "SEPSIS")/n(),
              INFX_SUM = sum(simple_diagnosis == "INFECTION"),
              INFX_FRAC = sum(simple_diagnosis == "INFECTION")/n(),
              CARDIAC_SUM = sum(simple_diagnosis == "CARDIAC"),
              CARDIAC_FRAC = sum(simple_diagnosis == "CARDIAC")/n(),
              CVC_SUM = sum(cvc == "TRUE", na.rm=TRUE),
              CVC_FRAC = sum(cvc == "TRUE", na.rm=TRUE)/n(),
              INTUB_SUM = sum(intub == "TRUE", na.rm=TRUE),
              INTUB_FRAC = sum(intub == "TRUE", na.rm=TRUE)/n()
             ) %>% t()

# %%
colnames(s1_3_df) <- s1_3_df[1,]

# %%
s1_3_df
# Out:
#               LESSTHAN24HOURS   LESSTHAN24HOURS         LESSTHAN24HOURS
# STATUS        LESSTHAN24HOURS   LESSTHAN24HOURS         LESSTHAN24HOURS
# pressor       dopaminedurations norepinephrinedurations phenylephrinedurations
# COUNT          697              1548                    3353
# AGE_MEAN      67.92663          66.15543                65.09732
# AGE_SD        14.44968          14.74278                14.07711
# FEMALE_SUM     335               659                    1139
# FEMALE_FRAC   0.4806313         0.4257106               0.3396958
# WHITE_SUM      491              1075                    2442
# WHITE_FRAC    0.7044476         0.6944444               0.7283030
# BLACK_SUM      56               128                     139
# BLACK_FRAC    0.08034433        0.08268734              0.04145541
# HISPANIC_SUM   13                45                      81
# HISPANIC_FRAC 0.01865136        0.02906977              0.02415747
# ASIAN_SUM     23                50                      79
# ASIAN_FRAC    0.03299857        0.03229974              0.02356099
# MICU_SUM      275               754                     425
# MICU_FRAC     0.3945481         0.4870801               0.1267522
# SICU_SUM       54               178                     442
# SICU_FRAC     0.07747489        0.11498708              0.13182225
# CCU_SUM       302               180                     262
# CCU_FRAC      0.43328551        0.11627907              0.07813898
# TSICU_SUM      26               128                     310
# TSICU_FRAC    0.03730273        0.08268734              0.09245452
# CSRU_SUM        40               308                    1914
# CSRU_FRAC     0.05738881        0.19896641              0.57083209
# SEPSIS_SUM     60               256                      92
# SEPSIS_FRAC   0.08608321        0.16537468              0.02743812
# INFX_SUM       34               143                     106
# INFX_FRAC     0.04878049        0.09237726              0.03161348
# CARDIAC_SUM    108               185                    1047
# CARDIAC_FRAC  0.1549498         0.1195090               0.3122577
# CVC_SUM        511              1375                    2714
# CVC_FRAC      0.7331420         0.8882429               0.8094244
# INTUB_SUM      439              1164                    2983
# INTUB_FRAC    0.6298422         0.7519380               0.8896511
#               LESSTHAN6HOURS    LESSTHAN6HOURS          LESSTHAN6HOURS
# STATUS        LESSTHAN6HOURS    LESSTHAN6HOURS          LESSTHAN6HOURS
# pressor       dopaminedurations norepinephrinedurations phenylephrinedurations
# COUNT          903              1053                    3451
# AGE_MEAN      67.78580          66.04628                65.99762
# AGE_SD        14.11339          15.36275                14.28056
# FEMALE_SUM     431               471                    1356
# FEMALE_FRAC   0.4772979         0.4472934               0.3929296
# WHITE_SUM      623               746                    2520
# WHITE_FRAC    0.6899225         0.7084520               0.7302231
# BLACK_SUM      77               106                     181
# BLACK_FRAC    0.08527132        0.10066477              0.05244857
# HISPANIC_SUM   23                27                     105
# HISPANIC_FRAC 0.02547065        0.02564103              0.03042596
# ASIAN_SUM     14                28                      82
# ASIAN_FRAC    0.01550388        0.02659069              0.02376123
# MICU_SUM      385               520                     394
# MICU_FRAC     0.4263566         0.4938272               0.1141698
# SICU_SUM       60               109                     411
# SICU_FRAC     0.06644518        0.10351377              0.11909591
# CCU_SUM       346               136                     223
# CCU_FRAC      0.38316722        0.12915480              0.06461895
# TSICU_SUM      61                94                     315
# TSICU_FRAC    0.06755260        0.08926876              0.09127789
# CSRU_SUM        51               194                    2108
# CSRU_FRAC     0.05647841        0.18423552              0.61083744
# SEPSIS_SUM     64               138                      70
# SEPSIS_FRAC   0.07087486        0.13105413              0.02028398
# INFX_SUM       65               102                      98
# INFX_FRAC     0.07198228        0.09686610              0.02839757
# CARDIAC_SUM    128               110                    1142
# CARDIAC_FRAC  0.1417497         0.1044634               0.3309186
# CVC_SUM        662               889                    2784
# CVC_FRAC      0.7331118         0.8442545               0.8067227
# INTUB_SUM      526               744                    3158
# INTUB_FRAC    0.5825028         0.7065527               0.9150971
#               MORETHAN24HOURS   MORETHAN24HOURS         MORETHAN24HOURS
# STATUS        MORETHAN24HOURS   MORETHAN24HOURS         MORETHAN24HOURS
# pressor       dopaminedurations norepinephrinedurations phenylephrinedurations
# COUNT          623              1846                    2379
# AGE_MEAN      69.47552          64.32555                64.82908
# AGE_SD        13.03657          15.07623                14.18046
# FEMALE_SUM     257               803                     942
# FEMALE_FRAC   0.4125201         0.4349946               0.3959647
# WHITE_SUM      422              1328                    1689
# WHITE_FRAC    0.6773676         0.7193933               0.7099622
# BLACK_SUM      49               166                     104
# BLACK_FRAC    0.07865169        0.08992416              0.04371585
# HISPANIC_SUM   11                43                      55
# HISPANIC_FRAC 0.01765650        0.02329361              0.02311896
# ASIAN_SUM     12                40                      46
# ASIAN_FRAC    0.01926164        0.02166847              0.01933586
# MICU_SUM      212               981                     331
# MICU_FRAC     0.3402889         0.5314193               0.1391341
# SICU_SUM       40               202                     386
# SICU_FRAC     0.06420546        0.10942579              0.16225305
# CCU_SUM       299               215                     187
# CCU_FRAC      0.47993579        0.11646804              0.07860446
# TSICU_SUM      29               167                     248
# TSICU_FRAC    0.04654896        0.09046587              0.10424548
# CSRU_SUM        43               281                    1227
# CSRU_FRAC     0.06902087        0.15222102              0.51576293
# SEPSIS_SUM     27               301                      58
# SEPSIS_FRAC   0.04333868        0.16305525              0.02437999
# INFX_SUM       35               205                      91
# INFX_FRAC     0.05617978        0.11105092              0.03825137
# CARDIAC_SUM    131               196                     661
# CARDIAC_FRAC  0.2102729         0.1061755               0.2778478
# CVC_SUM        540              1755                    2179
# CVC_FRAC      0.8667737         0.9507042               0.9159311
# INTUB_SUM      446              1577                    2137
# INTUB_FRAC    0.7158909         0.8542795               0.8982766

# %%
s1_3_df %>% write.csv(file.path(PLOT_DIR, "response_eachpressor_demographics.csv"))

# %% [markdown]
# # Categorical Predictors

# %%
# This function, given a dataframe with the appropriate columns, will compute RR statistics and return as a table 
calculatePredictors <- function(df){
    all_rr_list <- list()

    # gender
    output <- df %>%
        group_by(MORETHAN24HOURS, gender) %>%
        summarize(COUNT = n()) %>%
        spread(MORETHAN24HOURS, COUNT) %>%
        tibble::column_to_rownames("gender") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['MALE_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'M') %>%
            mutate(ID = "M", p = output$p.value["M","fisher.exact"])


#     # race
#     rr_list <- list()
#     for(race in races){
#        output <- df %>%
#             rowwise() %>%
#             group_by(MORETHAN24HOURS, simple_race) %>%
#             summarize(COUNT = n()) %>%
#             mutate(RACE_BOOL = simple_race == race) %>%
#             group_by(RACE_BOOL, MORETHAN24HOURS) %>%
#             summarize(COUNT = sum(COUNT)) %>%
#             spread(MORETHAN24HOURS, COUNT) %>%
#             tibble::column_to_rownames("RACE_BOOL") %>%
#             as.matrix() %>% riskratio() 
#         rr_list[[race]] <- output$measure %>%
#             data.frame() %>%
#             tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
#             mutate(ID = race, p = output$p.value["TRUE","fisher.exact"])
#     }


#     all_rr_list[['RACE_RR']] <- bind_rows(rr_list)


    # age
    age_df <- df %>%
        group_by(MORETHAN24HOURS, age_cohort) %>%
        summarize(COUNT = n()) %>%
        drop_na(age_cohort)

    rr_list <- list()
    for(ac in unique(age_df$age_cohort)){
       if(ac != 0){
           output <- age_df %>%
                mutate(AGE_BOOL = age_cohort == ac) %>%
                group_by(AGE_BOOL, MORETHAN24HOURS) %>%
                summarize(COUNT = sum(COUNT)) %>%
                spread(MORETHAN24HOURS, COUNT) %>%
                tibble::column_to_rownames("AGE_BOOL") %>%
                as.matrix() %>% riskratio() 

            rr_list[[ac]] <- output$measure %>%
                data.frame() %>%
                tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
                mutate(ID = as.character(ac), p = output$p.value["TRUE","fisher.exact"])
       }  
    }

    all_rr_list[['AGE_RR']] <- bind_rows(rr_list)


    # diagnosis
    diagnosis_df <- df %>%
        rowwise() %>%
        group_by(simple_diagnosis, MORETHAN24HOURS) %>%
        summarize(COUNT = n()) 

    rr_list <- list()
    for(s_d in unique(diagnosis_df$simple_diagnosis)){
       output <- diagnosis_df %>%
            mutate(DX_BOOL = simple_diagnosis == s_d) %>%
            group_by(DX_BOOL, MORETHAN24HOURS) %>%
            summarize(COUNT = sum(COUNT)) %>%
            spread(MORETHAN24HOURS, COUNT) %>%
            tibble::column_to_rownames("DX_BOOL") %>%
            as.matrix() %>% riskratio() 
        rr_list[[s_d]] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = s_d, p = output$p.value["TRUE","fisher.exact"])
    }

    all_rr_list[['DIAGNOSIS_RR']] <- bind_rows(rr_list)


    # careunit
    careunit_df <- df %>%
        group_by(MORETHAN24HOURS, first_careunit) %>%
        summarize(COUNT = n())

    rr_list <- list()
    for(cu in unique(careunit_df$first_careunit)){
       output <- careunit_df%>%
            mutate(CU_BOOL = first_careunit == cu) %>%
            group_by(CU_BOOL, MORETHAN24HOURS) %>%
            summarize(COUNT = sum(COUNT)) %>%
            spread(MORETHAN24HOURS, COUNT) %>%
            tibble::column_to_rownames("CU_BOOL") %>%
            as.matrix() %>% riskratio() 
        rr_list[[cu]] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = cu, p = output$p.value["TRUE","fisher.exact"])
    }

    all_rr_list[['CAREUNIT_RR']] <- bind_rows(rr_list)


    # intub
    output <- df %>%
        group_by(MORETHAN24HOURS, intub) %>%
        summarize(COUNT = n()) %>%
        spread(MORETHAN24HOURS, COUNT) %>%
        tibble::column_to_rownames("intub") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['INTUB_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = "INTUB", p = output$p.value["TRUE","fisher.exact"])

    # cvc
    output <- df %>%
        group_by(MORETHAN24HOURS, cvc) %>%
        summarize(COUNT = n()) %>%
        spread(MORETHAN24HOURS, COUNT) %>%
        tibble::column_to_rownames("cvc") %>%
        as.matrix() %>% riskratio()

    all_rr_list[['CVC_RR']] <- output$measure %>%
            data.frame() %>%
            tibble::rownames_to_column("FILTER") %>% filter(FILTER == 'TRUE') %>%
            mutate(ID = "CVC", p = output$p.value["TRUE","fisher.exact"])


    # combined
    all_rr_df <- bind_rows(all_rr_list, .id="TYPE") %>%
        mutate(significant = p < 0.05)
    
    return(all_rr_df)
}

# %% [markdown]
# # Table 1 (RR significance)

# %%
rr_df <- calculatePredictors(output_df) %>%
    rowwise() %>%
    mutate(ID = if(ID == "M"){"MALE"}else{ID}) %>% select(-FILTER)
rr_df
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    TYPE         estimate  lower     upper     ID              p
# 1  MALE_RR      0.9606925 0.9160746 1.0074835 MALE            1.022581e-01
# 2  AGE_RR       1.0222441 0.8183056 1.2770083 20              8.682009e-01
# 3  AGE_RR       1.1039998 0.9449763 1.2897843 30              2.211771e-01
# 4  AGE_RR       1.0585757 0.9503296 1.1791513 40              3.041662e-01
# 5  AGE_RR       1.0639489 0.9935335 1.1393549 50              8.162781e-02
# 6  AGE_RR       1.0223690 0.9657030 1.0823600 60              4.469965e-01
# 7  AGE_RR       0.9690306 0.9171697 1.0238239 70              2.631335e-01
# 8  AGE_RR       0.9897123 0.9360450 1.0464565 80              7.287582e-01
# 9  AGE_RR       0.8322938 0.7367126 0.9402758 90              2.108572e-03
# 10 DIAGNOSIS_RR 0.8383540 0.7899882 0.8896809 CARDIAC         2.111132e-09
# 11 DIAGNOSIS_RR 1.2483227 1.1426129 1.3638122 INFECTION       4.175389e-06
# 12 DIAGNOSIS_RR 1.0216422 0.9726088 1.0731475 OTHER DIAGNOSIS 3.977454e-01
# 13 DIAGNOSIS_RR 1.1999982 1.1040183 1.3043224 SEPSIS          4.792360e-05
# 14 CAREUNIT_RR  1.0773608 1.0086790 1.1507193 CCU             3.037345e-02
# 15 CAREUNIT_RR  0.7390582 0.7021646 0.7778902 CSRU            9.960264e-33
# 16 CAREUNIT_RR  1.2409184 1.1810355 1.3038375 MICU            8.897093e-17
# 17 CAREUNIT_RR  1.1047272 1.0314449 1.1832162 SICU            5.575056e-03
# 18 CAREUNIT_RR  1.0590221 0.9771674 1.1477335 TSICU           1.686619e-01
# 19 INTUB_RR     1.2295889 1.1474384 1.3176210 INTUB           1.057292e-09
# 20 CVC_RR       2.1803649 1.9802102 2.4007508 CVC             8.058297e-79
#    significant
# 1  FALSE
# 2  FALSE
# 3  FALSE
# 4  FALSE
# 5  FALSE
# 6  FALSE
# 7  FALSE
# 8  FALSE
# 9   TRUE
# 10  TRUE
# 11  TRUE
# 12 FALSE
# 13  TRUE
# 14  TRUE
# 15  TRUE
# 16  TRUE
# 17  TRUE
# 18 FALSE
# 19  TRUE
# 20  TRUE

# %%
rr_df %>% 
    write.csv(file.path(PLOT_DIR, "relativerisk.csv"))

# %% [markdown]
# ### Supplement 1-3

# %%
pressor_rr_list <- list()
for(pressor_choice in pressor_choices){
    pressor_rr_list[[pressor_choice]] <- output_df %>%
        filter(pressor == pressor_choice) %>%
        calculatePredictors()
}
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message in chisq.test(xx, correct = correction):
# “Chi-squared approximation may be incorrect”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
pressor_rr_df <- bind_rows(pressor_rr_list, .id="pressor")  %>% select(-FILTER)

# %%
pressor_rr_df
# Out:
#    pressor                 TYPE         estimate  lower     upper
# 1  norepinephrinedurations MALE_RR      0.9987007 0.9308398 1.0715088
# 2  norepinephrinedurations AGE_RR       1.0694181 0.7971248 1.4347252
# 3  norepinephrinedurations AGE_RR       1.1233746 0.9165693 1.3768413
# 4  norepinephrinedurations AGE_RR       1.0942546 0.9431415 1.2695795
# 5  norepinephrinedurations AGE_RR       1.1130040 1.0111660 1.2250985
# 6  norepinephrinedurations AGE_RR       1.0310668 0.9466765 1.1229801
# 7  norepinephrinedurations AGE_RR       1.0196759 0.9392326 1.1070091
# 8  norepinephrinedurations AGE_RR       0.8889863 0.8148738 0.9698394
# 9  norepinephrinedurations AGE_RR       0.8222276 0.6891269 0.9810359
# 10 norepinephrinedurations DIAGNOSIS_RR 0.9570771 0.8534493 1.0732875
# 11 norepinephrinedurations DIAGNOSIS_RR 1.1096012 0.9963871 1.2356792
# 12 norepinephrinedurations DIAGNOSIS_RR 0.9484433 0.8829776 1.0187627
# 13 norepinephrinedurations DIAGNOSIS_RR 1.0517585 0.9581056 1.1545658
# 14 norepinephrinedurations CAREUNIT_RR  0.9721486 0.8712521 1.0847295
# 15 norepinephrinedurations CAREUNIT_RR  0.8402058 0.7596035 0.9293609
# 16 norepinephrinedurations CAREUNIT_RR  1.1024195 1.0278831 1.1823610
# 17 norepinephrinedurations CAREUNIT_RR  0.9945268 0.8892166 1.1123089
# 18 norepinephrinedurations CAREUNIT_RR  1.0375958 0.9200013 1.1702212
# 19 norepinephrinedurations INTUB_RR     1.6182727 1.4528960 1.8024735
# 20 norepinephrinedurations CVC_RR       2.0538158 1.7058003 2.4728330
# 21 dopaminedurations       MALE_RR      1.2140661 1.0597246 1.3908865
# 22 dopaminedurations       AGE_RR       0.7087719 0.2047918 2.4530162
# 23 dopaminedurations       AGE_RR       0.5647887 0.2294280 1.3903550
# 24 dopaminedurations       AGE_RR       0.6666667 0.4266082 1.0418095
# 25 dopaminedurations       AGE_RR       0.9330652 0.7445539 1.1693051
# 26 dopaminedurations       AGE_RR       0.9339080 0.7809376 1.1168424
# 27 dopaminedurations       AGE_RR       1.0336173 0.8815558 1.2119082
# 28 dopaminedurations       AGE_RR       1.1975309 1.0361492 1.3840480
# 29 dopaminedurations       AGE_RR       0.8963400 0.6815942 1.1787444
# 30 dopaminedurations       DIAGNOSIS_RR 1.3465364 1.1510881 1.5751707
# 31 dopaminedurations       DIAGNOSIS_RR 0.9279495 0.6923494 1.2437222
# 32 dopaminedurations       DIAGNOSIS_RR 0.9246610 0.8013095 1.0670011
# 33 dopaminedurations       DIAGNOSIS_RR 0.6216276 0.4387267 0.8807782
# 34 dopaminedurations       CAREUNIT_RR  1.2434458 1.0888062 1.4200484
# 35 dopaminedurations       CAREUNIT_RR  1.1557771 0.8948808 1.4927361
# 36 dopaminedurations       CAREUNIT_RR  0.7991585 0.6932353 0.9212662
# 37 dopaminedurations       CAREUNIT_RR  0.9217883 0.6999111 1.2140023
# 38 dopaminedurations       CAREUNIT_RR  0.8867845 0.6423441 1.2242454
# 39 dopaminedurations       INTUB_RR     1.4500755 1.2465886 1.6867785
# 40 dopaminedurations       CVC_RR       1.9369949 1.5718917 2.3869006
# 41 phenylephrinedurations  MALE_RR      0.9124725 0.8503900 0.9790872
# 42 phenylephrinedurations  AGE_RR       0.9777485 0.7042924 1.3573796
# 43 phenylephrinedurations  AGE_RR       1.1008038 0.8740542 1.3863774
# 44 phenylephrinedurations  AGE_RR       1.0871682 0.9294534 1.2716450
# 45 phenylephrinedurations  AGE_RR       1.0350575 0.9347806 1.1460913
# 46 phenylephrinedurations  AGE_RR       1.0521191 0.9696992 1.1415443
# 47 phenylephrinedurations  AGE_RR       0.9465459 0.8738639 1.0252731
# 48 phenylephrinedurations  AGE_RR       1.0085745 0.9287487 1.0952614
# 49 phenylephrinedurations  AGE_RR       0.7633706 0.6214612 0.9376846
# 50 phenylephrinedurations  DIAGNOSIS_RR 0.8549544 0.7907561 0.9243646
# 51 phenylephrinedurations  DIAGNOSIS_RR 1.1983051 1.0064620 1.4267156
# 52 phenylephrinedurations  DIAGNOSIS_RR 1.1203385 1.0410407 1.2056766
# 53 phenylephrinedurations  DIAGNOSIS_RR 1.0180839 0.8140947 1.2731870
# 54 phenylephrinedurations  CAREUNIT_RR  1.0804692 0.9516122 1.2267746
# 55 phenylephrinedurations  CAREUNIT_RR  0.7982701 0.7450681 0.8552710
# 56 phenylephrinedurations  CAREUNIT_RR  1.1289585 1.0232628 1.2455717
# 57 phenylephrinedurations  CAREUNIT_RR  1.2417894 1.1336859 1.3602011
# 58 phenylephrinedurations  CAREUNIT_RR  1.1077838 0.9909138 1.2384377
# 59 phenylephrinedurations  INTUB_RR     0.9654112 0.8615220 1.0818281
# 60 phenylephrinedurations  CVC_RR       2.1372763 1.8694982 2.4434096
#    ID              p            significant
# 1  M               9.755196e-01 FALSE
# 2  20              6.839022e-01 FALSE
# 3  30              2.813284e-01 FALSE
# 4  40              2.634795e-01 FALSE
# 5  50              3.466969e-02  TRUE
# 6  60              4.943105e-01 FALSE
# 7  70              6.629963e-01 FALSE
# 8  80              7.352456e-03  TRUE
# 9  90              2.241649e-02  TRUE
# 10 CARDIAC         4.665713e-01 FALSE
# 11 INFECTION       6.933697e-02 FALSE
# 12 OTHER DIAGNOSIS 1.556196e-01 FALSE
# 13 SEPSIS          2.951754e-01 FALSE
# 14 CCU             6.389374e-01 FALSE
# 15 CSRU            4.351771e-04  TRUE
# 16 MICU            6.745405e-03  TRUE
# 17 SICU            9.612122e-01 FALSE
# 18 TSICU           5.539912e-01 FALSE
# 19 INTUB           1.474211e-22  TRUE
# 20 CVC             2.093992e-20  TRUE
# 21 M               5.180518e-03  TRUE
# 22 20              7.346566e-01 FALSE
# 23 30              2.616730e-01 FALSE
# 24 40              6.295895e-02 FALSE
# 25 50              5.889057e-01 FALSE
# 26 60              4.596630e-01 FALSE
# 27 70              6.892268e-01 FALSE
# 28 80              1.781296e-02  TRUE
# 29 90              4.657266e-01 FALSE
# 30 CARDIAC         4.578836e-04  TRUE
# 31 INFECTION       6.915844e-01 FALSE
# 32 OTHER DIAGNOSIS 2.996594e-01 FALSE
# 33 SEPSIS          3.523830e-03  TRUE
# 34 CCU             1.382691e-03  TRUE
# 35 CSRU            2.766032e-01 FALSE
# 36 MICU            1.953148e-03  TRUE
# 37 SICU            6.419621e-01 FALSE
# 38 TSICU           5.242609e-01 FALSE
# 39 INTUB           5.539918e-07  TRUE
# 40 CVC             3.541230e-12  TRUE
# 41 M               1.126540e-02  TRUE
# 42 20              1.000000e+00 FALSE
# 43 30              4.470649e-01 FALSE
# 44 40              3.072753e-01 FALSE
# 45 50              5.212136e-01 FALSE
# 46 60              2.303664e-01 FALSE
# 47 70              1.770099e-01 FALSE
# 48 80              8.422522e-01 FALSE
# 49 90              6.771699e-03  TRUE
# 50 CARDIAC         6.571794e-05  TRUE
# 51 INFECTION       5.035759e-02 FALSE
# 52 OTHER DIAGNOSIS 2.360354e-03  TRUE
# 53 SEPSIS          8.763190e-01 FALSE
# 54 CCU             2.348228e-01 FALSE
# 55 CSRU            2.034023e-10  TRUE
# 56 MICU            1.929838e-02  TRUE
# 57 SICU            7.983619e-06  TRUE
# 58 TSICU           8.075626e-02 FALSE
# 59 INTUB           5.490388e-01 FALSE
# 60 CVC             3.362615e-38  TRUE

# %%
pressor_rr_df %>% 
    write.csv(file.path(PLOT_DIR, "relativerisk_eachpressor.csv"))

# %% [markdown]
# # Figure 1 Plotting RR

# %%
SIGNIFICANT_COLORS <- c(
"Significant" = '#2F4F4F',
"Not Significant" = '#D3D3D3'
)

# %%
ID_DICT <- c(
'M' = "Male Gender",
'INTUB' = "Intubated",
'CVC' = "CVC Placed",
'20' = "Age 15-25",
'30' = "Age 25-35",
'40' = "Age 35-45",
'50' = "Age 45-55",
'60' = "Age 55-65",
'70' = "Age 65-75",
'80' = "Age 75-85",
'90' = "Age 85-95",
'CARDIAC' = "Cardiac Diagnosis",
'INFECTION' = "Infectious Diagnosis",
'SEPSIS' = "Sepsis Diagnosis",
'OTHER DIAGNOSIS' = "Other Diagnosis",
'CCU' = 'CCU',
'CSRU' = 'CSRU',
'MICU' = 'MICU',
'SICU' = 'SICU',
'TSICU' = 'TSICU'
)

# %%
options(repr.plot.width=3.5, repr.plot.height=4)
p <- calculatePredictors(output_df)  %>%
    rowwise() %>%
    mutate(ID = ID_DICT[ID]) %>% 
    mutate(ID = factor(ID, levels=rev(ID_DICT))) %>%
    mutate(significant = if(significant){'Significant'}else{'Not Significant'}) %>%
    mutate(legend = factor(significant, levels=names(SIGNIFICANT_COLORS))) %>%
    ggplot(aes(x = ID,y = estimate, ymin = lower, ymax = upper ))+
        base_theme() +
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Risk Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=significant),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
# plot without title

# %%
pdf(file.path(PLOT_DIR, "relativerisk.pdf"), 3.5,4)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
options(repr.plot.width=7, repr.plot.height=4)
p <- pressor_rr_df  %>%
    rowwise() %>%
    mutate(ID = ID_DICT[ID]) %>% 
    mutate(ID = factor(ID, levels=rev(ID_DICT))) %>%
    mutate(significant = if(significant){'Significant'}else{'Not Significant'}) %>%
    mutate(legend = factor(significant, levels=names(SIGNIFICANT_COLORS))) %>%
    mutate(fancy_pressor = FANCY_PRESSOR_DICT[as.character(pressor)]) %>%
    mutate(fancy_pressor = factor(fancy_pressor, levels=FANCY_PRESSOR_ORDER)) %>%
    ggplot(aes(x = ID,y = estimate, ymin = lower, ymax = upper ))+
        base_theme() +
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Risk Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=significant),width=0.5,cex=1)+ 
        coord_flip() + 
        facet_grid(. ~fancy_pressor)
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, "relativerisk_eachpressor.pdf"), 7,4)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # Vitals

# %% [markdown]
# ### Pre-processing (30 minutes): read in vitals_df, join with output_df of courses and compute mean vitals information each hour -> results_df

# %%
vitals_df <- read.csv('~/Projects/Haimovich_Pressors/collection/out/vitals.csv')

# %%
# takes 6 mins to run (because of difftime)

vitals_merged_df <- vitals_df %>%
    mutate(charttime = fastPOSIXct(charttime)) %>%
    filter(icustay_id %in% output_df$icustay_id) %>%
    left_join(select(output_df, icustay_id, course_id, pressor, starttime, endtime, MORETHAN24HOURS, STATUS), by = "icustay_id") %>%
    rowwise() %>%
    mutate(diff = difftime(charttime, 
                       starttime, units="hours"))

# %%
intervals <- 1:10

# %%
results_list <- list()

# %%
# takes 30 mins to run overall
for(interval in intervals){
    # 2 mins to run each
    results_list[[interval]] <- vitals_merged_df %>%
        filter(diff < 0) %>%
        filter(diff < -(interval - 1) & diff > -interval) %>%
        group_by(MORETHAN24HOURS, STATUS, course_id, pressor) %>%
        summarize(mean_heartrate = mean(heartrate, na.rm=T), 
                  mean_sysbp = mean(sysbp, na.rm=T),
                  mean_diasbp = mean(diasbp, na.rm=T),
                  mean_meanbp = mean(meanbp, na.rm=T), 
                  mean_resprate = mean(resprate, na.rm=T), 
                  mean_tempc = mean(tempc, na.rm=T), 
                  mean_spo2 = mean(spo2, na.rm=T), 
                  mean_glucose = mean(glucose, na.rm=T), 

                  median_heartrate = median(heartrate, na.rm=T), 
                  median_sysbp = median(sysbp, na.rm=T),
                  median_diasbp = median(diasbp, na.rm=T),
                  median_meanbp = median(meanbp, na.rm=T), 
                  median_resprate = median(resprate, na.rm=T), 
                  median_tempc = median(tempc, na.rm=T), 
                  median_spo2 = median(spo2, na.rm=T), 
                  median_glucose = median(glucose, na.rm=T),

                 ) %>%
        mutate(INTERVAL = interval)

}
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
results_df <- bind_rows(results_list)

# %%
melt_results_df <- results_df %>% 
    gather("ID", "VALUE", -course_id, -pressor, -MORETHAN24HOURS, -INTERVAL, -STATUS)

# %%
head(melt_results_df)
# Out:
#   MORETHAN24HOURS STATUS          course_id pressor                 INTERVAL
# 1 FALSE           LESSTHAN24HOURS 200028,0  norepinephrinedurations 1
# 2 FALSE           LESSTHAN24HOURS 200030,0  norepinephrinedurations 1
# 3 FALSE           LESSTHAN24HOURS 200033,0  phenylephrinedurations  1
# 4 FALSE           LESSTHAN24HOURS 200065,0  norepinephrinedurations 1
# 5 FALSE           LESSTHAN24HOURS 200075,0  norepinephrinedurations 1
# 6 FALSE           LESSTHAN24HOURS 200078,0  phenylephrinedurations  1
#   ID             VALUE
# 1 mean_heartrate  70.00000
# 2 mean_heartrate  84.33333
# 3 mean_heartrate 118.00000
# 4 mean_heartrate 121.50000
# 5 mean_heartrate  83.50000
# 6 mean_heartrate 100.00000

# %% [markdown]
# ### ANCOVA analysis using intervals
# - MORETHAN24HOURS P-value tells you if this vital sign is a predictor (BP, HR, RR, TEMP)
# - INTERVAL P-value tells you if these values change depending on the interval being measured (most values)
# - MORETHAN24HOURS:INTERVAL P-value tells you if vital sign interacts with the interval being measured, that is, the extent of predictive value differs with time (BP especially, others are borderline significant)

# %%
computeANCOVA <- function(df) {
    vitals_result_list <- list()
    for(vital in unique(melt_results_df$ID)){
        #cat("####", vital, "####")
        totest <- df %>%
             filter(ID == vital)
        test <- summary(aov(VALUE ~ MORETHAN24HOURS*INTERVAL, data = totest))[[1]]

        vitals_result_list[[vital]] <- data.frame(MORETHAN24HOURS = test["MORETHAN24HOURS ", "Pr(>F)"], 
                                                 INTERACTION = test["MORETHAN24HOURS:INTERVAL", "Pr(>F)"])
    }
    vitals_result_df <- bind_rows(vitals_result_list, .id="ID")
    
    return(vitals_result_df)
}

# %% [markdown]
# # Table 2 (Wilcox and ANCOVA Vitals)

# %%
computeTest <- function(d, value="VALUE", comparison="GROUP"){
    paired_df <- d %>% 
        select(!!rlang::sym(comparison), !!rlang::sym(value)) 
    
    items <- unique(unlist(d[,comparison]))

    result_unpair <- t.test(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, 
       filter(d, !!rlang::sym(comparison) == items[2])$VALUE, paired = FALSE)
    result_wilcox <- wilcox.test(filter(d, !!rlang::sym(comparison) == items[1])$VALUE, 
       filter(d, !!rlang::sym(comparison) == items[2])$VALUE, paired = FALSE)
    
    diff = mean(filter(d, !!rlang::sym(comparison) == items[1])$VALUE) -  
        mean(filter(d, !!rlang::sym(comparison) == items[2])$VALUE)
    
    return(data.frame(list(
                           'P_UNPAIR' = result_unpair$p.value, 
                           'P_WILCOX' = result_wilcox$p.value,
                            'GROUP1' = mean(filter(d, !!rlang::sym(comparison) == items[1])$VALUE),
                            'GROUP2' = mean(filter(d, !!rlang::sym(comparison) == items[2])$VALUE),
                            'DIFF' = diff,
                            'COMPARE' = paste(items[1], items[2], sep ='-'))))
}

# %% [markdown]
# ### Table 2. mean and standard deviation of vitals  for different time status

# %%
# means
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS) %>%
    summarize(MEAN = mean(VALUE)) %>%
    spread(STATUS, MEAN)
# Out:
#    ID               LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# 1  mean_diasbp       55.22917        56.44289       55.32072
# 2  mean_glucose     148.90861       147.99218      150.25696
# 3  mean_heartrate    89.10626        87.34313       91.08273
# 4  mean_meanbp       71.51656        73.01946       71.07429
# 5  mean_resprate     17.46904        17.30728       18.46853
# 6  mean_spo2         97.48808        97.44695       97.11629
# 7  mean_sysbp       105.49908       108.54064      104.49804
# 8  mean_tempc        36.43361        36.31429       36.45664
# 9  median_diasbp     55.09159        56.20398       55.13805
# 10 median_glucose   148.87318       147.99213      150.27649
# 11 median_heartrate  89.05190        87.29230       91.08666
# 12 median_meanbp     71.16991        72.63257       70.77192
# 13 median_resprate   17.40331        17.21211       18.40350
# 14 median_spo2       97.60722        97.57348       97.23029
# 15 median_sysbp     105.31451       108.19844      104.29260
# 16 median_tempc      36.43491        36.31407       36.45703

# %%
# standard deviations
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS) %>%
    summarize(SD = sd(VALUE)) %>%
    spread(STATUS, SD)
# Out:
#    ID               LESSTHAN24HOURS LESSTHAN6HOURS MORETHAN24HOURS
# 1  mean_diasbp      12.754692       13.747756      13.377874
# 2  mean_glucose     64.971211       62.926642      69.631472
# 3  mean_heartrate   19.471682       19.563885      20.624659
# 4  mean_meanbp      14.495720       15.430592      15.698844
# 5  mean_resprate     5.690783        5.654486       6.015169
# 6  mean_spo2         4.964570        5.063171       4.751042
# 7  mean_sysbp       18.818804       20.928887      20.454842
# 8  mean_tempc        1.074207        1.189952       1.168407
# 9  median_diasbp    12.934652       13.923542      13.536256
# 10 median_glucose   64.903029       62.962681      69.672695
# 11 median_heartrate 19.653321       19.802647      20.732528
# 12 median_meanbp    14.563420       15.667128      15.731678
# 13 median_resprate   5.772015        5.739547       6.128967
# 14 median_spo2       4.903432        4.980593       4.740536
# 15 median_sysbp     19.368001       21.425186      20.867338
# 16 median_tempc      1.075066        1.190788       1.168908

# %%
# means
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS, pressor) %>%
    summarize(MEAN = mean(VALUE)) %>%
    ungroup() %>%
    filter(pressor %in% pressor_choices) %>%
    spread(STATUS, MEAN) %>% arrange(pressor)
# Out:
#    ID               pressor                 LESSTHAN24HOURS LESSTHAN6HOURS
# 1  mean_diasbp      dopaminedurations        52.51638        52.91710
# 2  mean_glucose     dopaminedurations       198.98734       182.86860
# 3  mean_heartrate   dopaminedurations        85.27362        89.25072
# 4  mean_meanbp      dopaminedurations        69.03345        68.07169
# 5  mean_resprate    dopaminedurations        18.91443        20.06488
# 6  mean_spo2        dopaminedurations        96.13067        95.54895
# 7  mean_sysbp       dopaminedurations       104.28148       102.04466
# 8  mean_tempc       dopaminedurations        36.41958        36.35060
# 9  median_diasbp    dopaminedurations        52.28919        52.58877
# 10 median_glucose   dopaminedurations       198.84810       182.88935
# 11 median_heartrate dopaminedurations        85.17370        89.15948
# 12 median_meanbp    dopaminedurations        68.70252        67.67522
# 13 median_resprate  dopaminedurations        18.82062        19.96122
# 14 median_spo2      dopaminedurations        96.25157        95.76179
# 15 median_sysbp     dopaminedurations       103.95792       101.52148
# 16 median_tempc     dopaminedurations        36.41998        36.35010
# 17 mean_diasbp      norepinephrinedurations  54.51887        56.54753
# 18 mean_glucose     norepinephrinedurations 165.77251       166.80428
# 19 mean_heartrate   norepinephrinedurations  91.39891        90.80920
# 20 mean_meanbp      norepinephrinedurations  69.08987        71.53837
# 21 mean_resprate    norepinephrinedurations  19.16110        19.20073
# 22 mean_spo2        norepinephrinedurations  96.61589        96.39998
# 23 mean_sysbp       norepinephrinedurations 102.66620       106.65840
# 24 mean_tempc       norepinephrinedurations  36.51824        36.34595
# 25 median_diasbp    norepinephrinedurations  54.41533        56.25892
# 26 median_glucose   norepinephrinedurations 165.75730       166.84553
# 27 median_heartrate norepinephrinedurations  91.35335        90.82830
# 28 median_meanbp    norepinephrinedurations  68.71134        71.18316
# 29 median_resprate  norepinephrinedurations  19.15591        19.10437
# 30 median_spo2      norepinephrinedurations  96.74110        96.49467
# 31 median_sysbp     norepinephrinedurations 102.50133       106.20420
# 32 median_tempc     norepinephrinedurations  36.51919        36.34490
# 33 mean_diasbp      phenylephrinedurations   56.13597        57.37855
# 34 mean_glucose     phenylephrinedurations  138.78835       139.27236
# 35 mean_heartrate   phenylephrinedurations   88.84121        85.68933
# 36 mean_meanbp      phenylephrinedurations   73.18249        74.84103
# 37 mean_resprate    phenylephrinedurations   16.38428        16.01426
# 38 mean_spo2        phenylephrinedurations   98.16114        98.26026
# 39 mean_sysbp       phenylephrinedurations  107.09168       110.93225
# 40 mean_tempc       phenylephrinedurations   36.40146        36.29961
# 41 median_diasbp    phenylephrinedurations   56.00126        57.18013
# 42 median_glucose   phenylephrinedurations  138.75605       139.26080
# 43 median_heartrate phenylephrinedurations   88.79252        85.62738
# 44 median_meanbp    phenylephrinedurations   72.84763        74.44663
# 45 median_resprate  phenylephrinedurations   16.29599        15.92167
# 46 median_spo2      phenylephrinedurations   98.27715        98.37413
# 47 median_sysbp     phenylephrinedurations  106.92720       110.67577
# 48 median_tempc     phenylephrinedurations   36.40302        36.29967
#    MORETHAN24HOURS
# 1   52.49037
# 2  197.37073
# 3   82.46981
# 4   68.43626
# 5   19.24126
# 6   95.80932
# 7  103.10880
# 8   36.25883
# 9   52.10127
# 10 197.37073
# 11  82.43197
# 12  68.03295
# 13  19.16613
# 14  95.94125
# 15 102.79745
# 16  36.25981
# 17  54.23575
# 18 163.63953
# 19  95.44150
# 20  68.15919
# 21  20.24327
# 22  96.31018
# 23 100.84525
# 24  36.53375
# 25  54.06702
# 26 163.68328
# 27  95.42347
# 28  67.97673
# 29  20.20515
# 30  96.39340
# 31 100.68012
# 32  36.53441
# 33  56.91517
# 34 136.80189
# 35  89.77436
# 36  74.08884
# 37  16.89128
# 38  98.05359
# 39 107.78944
# 40  36.43682
# 41  56.77389
# 42 136.81135
# 43  89.80684
# 44  73.71533
# 45  16.80777
# 46  98.18688
# 47 107.57856
# 48  36.43694

# %%
# standard deviations
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID, STATUS, pressor) %>%
    summarize(SD = sd(VALUE)) %>%
    ungroup() %>%
    filter(pressor %in% pressor_choices) %>%
    spread(STATUS, SD) %>% arrange(pressor)
# Out:
#    ID               pressor                 LESSTHAN24HOURS LESSTHAN6HOURS
# 1  mean_diasbp      dopaminedurations        13.509050       15.819260
# 2  mean_glucose     dopaminedurations       103.469725      102.119984
# 3  mean_heartrate   dopaminedurations        21.427894       23.278467
# 4  mean_meanbp      dopaminedurations        15.322372       16.746069
# 5  mean_resprate    dopaminedurations         5.155841        5.663237
# 6  mean_spo2        dopaminedurations         5.204071        6.154325
# 7  mean_sysbp       dopaminedurations        21.107817       21.934367
# 8  mean_tempc       dopaminedurations         1.113871        1.313373
# 9  median_diasbp    dopaminedurations        13.540743       16.040870
# 10 median_glucose   dopaminedurations       103.233699      102.195709
# 11 median_heartrate dopaminedurations        21.775451       23.581126
# 12 median_meanbp    dopaminedurations        15.441239       17.106171
# 13 median_resprate  dopaminedurations         5.230305        5.798233
# 14 median_spo2      dopaminedurations         5.147802        6.009987
# 15 median_sysbp     dopaminedurations        21.400299       22.295749
# 16 median_tempc     dopaminedurations         1.113686        1.313900
# 17 mean_diasbp      norepinephrinedurations  14.692852       15.784005
# 18 mean_glucose     norepinephrinedurations  84.400038       85.852351
# 19 mean_heartrate   norepinephrinedurations  20.145970       21.463081
# 20 mean_meanbp      norepinephrinedurations  15.373790       16.876472
# 21 mean_resprate    norepinephrinedurations   5.798344        5.959811
# 22 mean_spo2        norepinephrinedurations   6.194965        6.466938
# 23 mean_sysbp       norepinephrinedurations  19.598013       22.863286
# 24 mean_tempc       norepinephrinedurations   1.160672        1.372900
# 25 median_diasbp    norepinephrinedurations  14.862687       15.974108
# 26 median_glucose   norepinephrinedurations  84.305906       85.776286
# 27 median_heartrate norepinephrinedurations  20.259855       21.841333
# 28 median_meanbp    norepinephrinedurations  15.335914       17.171942
# 29 median_resprate  norepinephrinedurations   5.867807        6.004996
# 30 median_spo2      norepinephrinedurations   6.162067        6.473637
# 31 median_sysbp     norepinephrinedurations  20.047117       23.084154
# 32 median_tempc     norepinephrinedurations   1.160852        1.374587
# 33 mean_diasbp      phenylephrinedurations   11.445185       12.198548
# 34 mean_glucose     phenylephrinedurations   47.536764       45.289136
# 35 mean_heartrate   phenylephrinedurations   18.537334       17.479728
# 36 mean_meanbp      phenylephrinedurations   13.635115       14.183301
# 37 mean_resprate    phenylephrinedurations    5.483714        5.114147
# 38 mean_spo2        phenylephrinedurations    4.087249        3.949246
# 39 mean_sysbp       phenylephrinedurations   17.731825       19.517006
# 40 mean_tempc       phenylephrinedurations    1.031151        1.112669
# 41 median_diasbp    phenylephrinedurations   11.667838       12.346821
# 42 median_glucose   phenylephrinedurations   47.514833       45.355378
# 43 median_heartrate phenylephrinedurations   18.711983       17.640955
# 44 median_meanbp    phenylephrinedurations   13.744647       14.365910
# 45 median_resprate  phenylephrinedurations    5.564250        5.208003
# 46 median_spo2      phenylephrinedurations    4.002165        3.848239
# 47 median_sysbp     phenylephrinedurations   18.401468       20.139628
# 48 median_tempc     phenylephrinedurations    1.032481        1.113296
#    MORETHAN24HOURS
# 1   13.927454
# 2  111.857982
# 3   20.609729
# 4   14.538947
# 5    5.588813
# 6    5.734098
# 7   21.355673
# 8    1.251552
# 9   14.089353
# 10 111.857982
# 11  20.792588
# 12  14.777112
# 13   5.677671
# 14   5.726291
# 15  21.640621
# 16   1.252453
# 17  14.517265
# 18  86.757472
# 19  20.658235
# 20  15.986073
# 21   6.086227
# 22   5.259985
# 23  20.440117
# 24   1.296255
# 25  14.650642
# 26  86.817319
# 27  20.775515
# 28  16.044029
# 29   6.203085
# 30   5.297151
# 31  20.782137
# 32   1.297933
# 33  12.010542
# 34  42.819288
# 35  19.714932
# 36  15.183713
# 37   5.628965
# 38   3.793130
# 39  19.690817
# 40   1.057439
# 41  12.179184
# 42  42.862805
# 43  19.800635
# 44  15.174139
# 45   5.743814
# 46   3.720654
# 47  20.213256
# 48   1.056922

# %% [markdown]
# ### Wilcox for significant difference at <1 hr before start of pressors

# %% [markdown]
# All pressors

# %%
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    group_by(ID) %>%
    do(computeTest(.,value="VALUE", comparison="MORETHAN24HOURS")) %>%
    mutate(significant = P_WILCOX < 0.05)
# Out:
#    ID               P_UNPAIR     P_WILCOX     GROUP1    GROUP2    DIFF
# 1  mean_diasbp      6.138732e-02 4.060692e-03  55.82784  55.32072  0.50712280
# 2  mean_glucose     3.284543e-01 8.168638e-01 148.45337 150.25696 -1.80358930
# 3  mean_heartrate   4.098007e-12 1.209843e-14  88.23731  91.08273 -2.84541295
# 4  mean_meanbp      1.647502e-04 4.993955e-08  72.25716  71.07429  1.18286758
# 5  mean_resprate    9.060219e-21 2.637535e-23  17.38850  18.46853 -1.08002430
# 6  mean_spo2        3.771532e-04 1.784907e-13  97.46784  97.11629  0.35154329
# 7  mean_sysbp       1.384325e-09 8.150123e-16 106.99935 104.49804  2.50130684
# 8  mean_tempc       1.641980e-02 4.810184e-02  36.37568  36.45664 -0.08096468
# 9  median_diasbp    6.721541e-02 6.127488e-03  55.64028  55.13805  0.50223075
# 10 median_glucose   3.187099e-01 8.161534e-01 148.43552 150.27649 -1.84097659
# 11 median_heartrate 2.162290e-12 3.617872e-15  88.18469  91.08666 -2.90196339
# 12 median_meanbp    3.880259e-04 3.358084e-07  71.89068  70.77192  1.11876025
# 13 median_resprate  1.228184e-20 8.387766e-23  17.30812  18.40350 -1.09537948
# 14 median_spo2      2.454691e-04 2.653099e-13  97.59061  97.23029  0.36032192
# 15 median_sysbp     6.877873e-09 1.318969e-14 106.73703 104.29260  2.44442887
# 16 median_tempc     1.671190e-02 4.890028e-02  36.37624  36.45703 -0.08078913
#    COMPARE    significant
# 1  FALSE-TRUE  TRUE
# 2  FALSE-TRUE FALSE
# 3  FALSE-TRUE  TRUE
# 4  FALSE-TRUE  TRUE
# 5  FALSE-TRUE  TRUE
# 6  FALSE-TRUE  TRUE
# 7  FALSE-TRUE  TRUE
# 8  FALSE-TRUE  TRUE
# 9  FALSE-TRUE  TRUE
# 10 FALSE-TRUE FALSE
# 11 FALSE-TRUE  TRUE
# 12 FALSE-TRUE  TRUE
# 13 FALSE-TRUE  TRUE
# 14 FALSE-TRUE  TRUE
# 15 FALSE-TRUE  TRUE
# 16 FALSE-TRUE  TRUE

# %% [markdown]
# Pressors by type

# %%
melt_results_df %>%
    filter(INTERVAL == 1) %>%
    drop_na(VALUE) %>%
    mutate(pressor = factor(pressor, levels=pressor_choices)) %>%
    group_by(ID, pressor) %>%
    do(computeTest(.,value="VALUE", comparison="MORETHAN24HOURS")) %>%
    mutate(significant = P_WILCOX < 0.05) %>%
    arrange(pressor)
# Out:
#    ID               pressor                 P_UNPAIR     P_WILCOX     GROUP1
# 1  mean_diasbp      norepinephrinedurations 3.331572e-02 1.472646e-02  55.35264
# 2  mean_glucose     norepinephrinedurations 5.724678e-01 5.858557e-01 166.18769
# 3  mean_heartrate   norepinephrinedurations 4.209055e-09 3.892865e-10  91.15775
# 4  mean_meanbp      norepinephrinedurations 6.390642e-04 3.120962e-05  70.09268
# 5  mean_resprate    norepinephrinedurations 2.237160e-07 1.198224e-07  19.17722
# 6  mean_spo2        norepinephrinedurations 2.908707e-01 1.596030e-04  96.52805
# 7  mean_sysbp       norepinephrinedurations 2.525364e-06 5.879073e-08 104.30735
# 8  mean_tempc       norepinephrinedurations 2.014236e-01 2.669722e-01  36.44807
# 9  median_diasbp    norepinephrinedurations 3.693948e-02 1.822012e-02  55.17304
# 10 median_glucose   norepinephrinedurations 5.779514e-01 5.801517e-01 166.19520
# 11 median_heartrate norepinephrinedurations 5.486708e-09 3.989468e-10  91.13863
# 12 median_meanbp    norepinephrinedurations 2.136346e-03 1.363083e-04  69.72371
# 13 median_resprate  norepinephrinedurations 3.072441e-07 1.873175e-07  19.13494
# 14 median_spo2      norepinephrinedurations 2.313382e-01 1.021348e-04  96.64085
# 15 median_sysbp     norepinephrinedurations 7.726146e-06 2.093109e-07 104.02354
# 16 median_tempc     norepinephrinedurations 1.991825e-01 2.630162e-01  36.44820
# 17 mean_diasbp      dopaminedurations       7.491091e-01 7.725921e-01  52.74566
# 18 mean_glucose     dopaminedurations       4.325789e-01 7.471496e-01 189.25146
# 19 mean_heartrate   dopaminedurations       1.748709e-05 1.520699e-04  87.54812
# 20 mean_meanbp      dopaminedurations       9.559600e-01 8.936010e-01  68.48293
# 21 mean_resprate    dopaminedurations       2.659670e-01 1.537316e-01  19.57734
# 22 mean_spo2        dopaminedurations       9.746676e-01 6.726861e-01  95.79885
# 23 mean_sysbp       dopaminedurations       9.293400e-01 7.158132e-01 103.00194
# 24 mean_tempc       dopaminedurations       3.151158e-01 3.499326e-01  36.38069
# 25 median_diasbp    dopaminedurations       6.561762e-01 7.357121e-01  52.46060
# 26 median_glucose   dopaminedurations       4.301107e-01 7.467036e-01 189.20886
# 27 median_heartrate dopaminedurations       2.628016e-05 2.368706e-04  87.45316
# 28 median_meanbp    dopaminedurations       9.243621e-01 8.888838e-01  68.11450
# 29 median_resprate  dopaminedurations       3.102800e-01 1.768835e-01  19.47785
# 30 median_spo2      dopaminedurations       9.247667e-01 6.416407e-01  95.97220
# 31 median_sysbp     dopaminedurations       8.486049e-01 7.914691e-01 102.56419
# 32 median_tempc     dopaminedurations       3.197196e-01 3.564291e-01  36.38058
# 33 mean_diasbp      phenylephrinedurations  6.573965e-01 8.676829e-01  56.76535
# 34 mean_glucose     phenylephrinedurations  1.344892e-01 2.113312e-01 139.03491
# 35 mean_heartrate   phenylephrinedurations  3.247646e-06 6.922868e-07  87.24458
# 36 mean_meanbp      phenylephrinedurations  8.740591e-01 5.400202e-01  74.02249
# 37 mean_resprate    phenylephrinedurations  3.013890e-06 1.778886e-06  16.19393
# 38 mean_spo2        phenylephrinedurations  1.452008e-01 1.768035e-04  98.21138
# 39 mean_sysbp       phenylephrinedurations  2.313974e-02 2.925267e-04 109.03696
# 40 mean_tempc       phenylephrinedurations  3.330833e-02 1.637219e-01  36.35048
# 41 median_diasbp    phenylephrinedurations  6.084885e-01 8.137525e-01  56.59836
# 42 median_glucose   phenylephrinedurations  1.403573e-01 2.126709e-01 139.01317
# 43 median_heartrate phenylephrinedurations  1.672181e-06 2.454187e-07  87.18917
# 44 median_meanbp    phenylephrinedurations  8.902907e-01 5.754652e-01  73.65748
# 45 median_resprate  phenylephrinedurations  3.714072e-06 5.784566e-06  16.10343
# 46 median_spo2      phenylephrinedurations  1.889189e-01 4.820328e-04  98.32630
# 47 median_sysbp     phenylephrinedurations  2.722533e-02 5.642785e-04 108.82588
# 48 median_tempc     phenylephrinedurations  3.471570e-02 1.666755e-01  36.35129
#    GROUP2    DIFF        COMPARE    significant
# 1   54.23575  1.11688226 FALSE-TRUE  TRUE
# 2  163.63953  2.54815444 FALSE-TRUE FALSE
# 3   95.44150 -4.28375570 FALSE-TRUE  TRUE
# 4   68.15919  1.93349593 FALSE-TRUE  TRUE
# 5   20.24327 -1.06605115 FALSE-TRUE  TRUE
# 6   96.31018  0.21787028 FALSE-TRUE  TRUE
# 7  100.84525  3.46209502 FALSE-TRUE  TRUE
# 8   36.53375 -0.08568111 FALSE-TRUE FALSE
# 9   54.06702  1.10601563 FALSE-TRUE  TRUE
# 10 163.68328  2.51192378 FALSE-TRUE FALSE
# 11  95.42347 -4.28483402 FALSE-TRUE  TRUE
# 12  67.97673  1.74697520 FALSE-TRUE  TRUE
# 13  20.20515 -1.07021547 FALSE-TRUE  TRUE
# 14  96.39340  0.24744598 FALSE-TRUE  TRUE
# 15 100.68012  3.34341818 FALSE-TRUE  TRUE
# 16  36.53441 -0.08620188 FALSE-TRUE FALSE
# 17  52.49037  0.25528178 FALSE-TRUE FALSE
# 18 197.37073 -8.11926451 FALSE-TRUE FALSE
# 19  82.46981  5.07830922 FALSE-TRUE  TRUE
# 20  68.43626  0.04667180 FALSE-TRUE FALSE
# 21  19.24126  0.33607723 FALSE-TRUE FALSE
# 22  95.80932 -0.01047334 FALSE-TRUE FALSE
# 23 103.10880 -0.10685946 FALSE-TRUE FALSE
# 24  36.25883  0.12186085 FALSE-TRUE FALSE
# 25  52.10127  0.35932391 FALSE-TRUE FALSE
# 26 197.37073 -8.16187102 FALSE-TRUE FALSE
# 27  82.43197  5.02119073 FALSE-TRUE  TRUE
# 28  68.03295  0.08154980 FALSE-TRUE FALSE
# 29  19.16613  0.31172412 FALSE-TRUE FALSE
# 30  95.94125  0.03095031 FALSE-TRUE FALSE
# 31 102.79745 -0.23325879 FALSE-TRUE FALSE
# 32  36.25981  0.12077555 FALSE-TRUE FALSE
# 33  56.91517 -0.14982833 FALSE-TRUE FALSE
# 34 136.80189  2.23301365 FALSE-TRUE FALSE
# 35  89.77436 -2.52978070 FALSE-TRUE  TRUE
# 36  74.08884 -0.06635117 FALSE-TRUE FALSE
# 37  16.89128 -0.69734208 FALSE-TRUE  TRUE
# 38  98.05359  0.15778891 FALSE-TRUE  TRUE
# 39 107.78944  1.24752164 FALSE-TRUE  TRUE
# 40  36.43682 -0.08633886 FALSE-TRUE FALSE
# 41  56.77389 -0.17553259 FALSE-TRUE FALSE
# 42 136.81135  2.20182043 FALSE-TRUE FALSE
# 43  89.80684 -2.61767110 FALSE-TRUE  TRUE
# 44  73.71533 -0.05785065 FALSE-TRUE FALSE
# 45  16.80777 -0.70434096 FALSE-TRUE  TRUE
# 46  98.18688  0.13942226 FALSE-TRUE  TRUE
# 47 107.57856  1.24731523 FALSE-TRUE  TRUE
# 48  36.43694 -0.08565082 FALSE-TRUE FALSE

# %% [markdown]
# ### ANCOVA for significant differences summarized

# %% [markdown]
# Total pressors

# %%
ancova_significance_df <- computeANCOVA(melt_results_df) %>% mutate(
    morethan24hours_significant = MORETHAN24HOURS < 0.05, 
    interaction_interaction = INTERACTION < 0.05) %>%
    rename(morethan24hours_pvalue = MORETHAN24HOURS, interaction_pvalue = INTERACTION, vital_sign = ID)
ancova_significance_df
# Out:
#    vital_sign       morethan24hours_pvalue interaction_pvalue
# 1  mean_heartrate   1.243038e-30           0.1132776475
# 2  mean_sysbp       7.346551e-44           0.0006181598
# 3  mean_diasbp      9.278100e-07           0.1945913337
# 4  mean_meanbp      2.076218e-15           0.4030909834
# 5  mean_resprate    2.683617e-64           0.0097918982
# 6  mean_tempc       1.659301e-03           0.4450229830
# 7  mean_spo2        2.522526e-16           0.6961708305
# 8  mean_glucose     1.255091e-02           0.9446338630
# 9  median_heartrate 6.473798e-31           0.0976214620
# 10 median_sysbp     6.729966e-42           0.0004474834
# 11 median_diasbp    1.501260e-06           0.2324180628
# 12 median_meanbp    1.026702e-14           0.4113223920
# 13 median_resprate  7.554410e-65           0.0074813473
# 14 median_tempc     1.764836e-03           0.4430676014
# 15 median_spo2      1.796085e-17           0.6552106277
# 16 median_glucose   1.154314e-02           0.9609974831
#    morethan24hours_significant interaction_interaction
# 1  TRUE                        FALSE
# 2  TRUE                         TRUE
# 3  TRUE                        FALSE
# 4  TRUE                        FALSE
# 5  TRUE                         TRUE
# 6  TRUE                        FALSE
# 7  TRUE                        FALSE
# 8  TRUE                        FALSE
# 9  TRUE                        FALSE
# 10 TRUE                         TRUE
# 11 TRUE                        FALSE
# 12 TRUE                        FALSE
# 13 TRUE                         TRUE
# 14 TRUE                        FALSE
# 15 TRUE                        FALSE
# 16 TRUE                        FALSE

# %%
ancova_significance_df %>% write.csv(file.path(PLOT_DIR, "ancovasignificance.csv"))

# %% [markdown]
# Pressors by type

# %%
pressors_vitals_rr_list <- list()
for(pressor_choice in pressor_choices){
    pressors_vitals_rr_list[[pressor_choice]] <- melt_results_df %>%
        filter(pressor == pressor_choice) %>%
        computeANCOVA() %>%
        mutate(
            morethan24hours_significant = MORETHAN24HOURS < 0.05, 
            interaction_interaction = INTERACTION < 0.05)
}

pressors_vitals_rr_df <- bind_rows(pressors_vitals_rr_list, .id="pressor")

# %%
ancova_significance_eachpressor_df <- pressors_vitals_rr_df %>%
    rename(morethan24hours_pvalue = MORETHAN24HOURS, interaction_pvalue = INTERACTION, vital_sign = ID)
ancova_significance_eachpressor_df
# Out:
#    pressor                 vital_sign       morethan24hours_pvalue
# 1  norepinephrinedurations mean_heartrate   1.776750e-16
# 2  norepinephrinedurations mean_sysbp       6.988496e-34
# 3  norepinephrinedurations mean_diasbp      6.919672e-07
# 4  norepinephrinedurations mean_meanbp      5.139855e-15
# 5  norepinephrinedurations mean_resprate    1.309683e-33
# 6  norepinephrinedurations mean_tempc       9.887433e-02
# 7  norepinephrinedurations mean_spo2        1.543707e-01
# 8  norepinephrinedurations mean_glucose     6.711331e-01
# 9  norepinephrinedurations median_heartrate 2.162075e-16
# 10 norepinephrinedurations median_sysbp     6.416914e-33
# 11 norepinephrinedurations median_diasbp    1.053046e-06
# 12 norepinephrinedurations median_meanbp    1.353246e-14
# 13 norepinephrinedurations median_resprate  2.695849e-33
# 14 norepinephrinedurations median_tempc     9.706357e-02
# 15 norepinephrinedurations median_spo2      1.151108e-01
# 16 norepinephrinedurations median_glucose   6.889588e-01
# 17 dopaminedurations       mean_heartrate   1.268115e-13
# 18 dopaminedurations       mean_sysbp       1.041831e-06
# 19 dopaminedurations       mean_diasbp      3.159906e-05
# 20 dopaminedurations       mean_meanbp      4.379296e-05
# 21 dopaminedurations       mean_resprate    4.492678e-03
# 22 dopaminedurations       mean_tempc       2.219280e-03
# 23 dopaminedurations       mean_spo2        1.009652e-02
# 24 dopaminedurations       mean_glucose     9.595716e-02
# 25 dopaminedurations       median_heartrate 1.999532e-13
# 26 dopaminedurations       median_sysbp     2.101864e-06
# 27 dopaminedurations       median_diasbp    4.270308e-05
# 28 dopaminedurations       median_meanbp    7.836731e-05
# 29 dopaminedurations       median_resprate  6.589969e-03
# 30 dopaminedurations       median_tempc     2.233101e-03
# 31 dopaminedurations       median_spo2      5.707412e-03
# 32 dopaminedurations       median_glucose   9.219517e-02
# 33 phenylephrinedurations  mean_heartrate   3.904146e-20
# 34 phenylephrinedurations  mean_sysbp       5.704422e-02
# 35 phenylephrinedurations  mean_diasbp      4.443133e-03
# 36 phenylephrinedurations  mean_meanbp      1.750106e-02
# 37 phenylephrinedurations  mean_resprate    2.411498e-20
# 38 phenylephrinedurations  mean_tempc       6.543383e-04
# 39 phenylephrinedurations  mean_spo2        7.179416e-09
# 40 phenylephrinedurations  mean_glucose     4.796265e-01
# 41 phenylephrinedurations  median_heartrate 1.825305e-20
# 42 phenylephrinedurations  median_sysbp     8.272644e-02
# 43 phenylephrinedurations  median_diasbp    4.413713e-03
# 44 phenylephrinedurations  median_meanbp    1.376262e-02
# 45 phenylephrinedurations  median_resprate  1.500571e-20
# 46 phenylephrinedurations  median_tempc     7.394891e-04
# 47 phenylephrinedurations  median_spo2      2.240062e-09
# 48 phenylephrinedurations  median_glucose   4.898316e-01
#    interaction_pvalue morethan24hours_significant interaction_interaction
# 1  0.0966926912        TRUE                       FALSE
# 2  0.0004413466        TRUE                        TRUE
# 3  0.1772755175        TRUE                       FALSE
# 4  0.0570921050        TRUE                       FALSE
# 5  0.7703809526        TRUE                       FALSE
# 6  0.6052734835       FALSE                       FALSE
# 7  0.2615521256       FALSE                       FALSE
# 8  0.5167688012       FALSE                       FALSE
# 9  0.0885995356        TRUE                       FALSE
# 10 0.0002401908        TRUE                        TRUE
# 11 0.1861921097        TRUE                       FALSE
# 12 0.0438558398        TRUE                        TRUE
# 13 0.7981968677        TRUE                       FALSE
# 14 0.6015624259       FALSE                       FALSE
# 15 0.1985179867       FALSE                       FALSE
# 16 0.5060899041       FALSE                       FALSE
# 17 0.1609527039        TRUE                       FALSE
# 18 0.0061716339        TRUE                        TRUE
# 19 0.1370661704        TRUE                       FALSE
# 20 0.1223211851        TRUE                       FALSE
# 21 0.6452659063        TRUE                       FALSE
# 22 0.7362266919        TRUE                       FALSE
# 23 0.0182803255        TRUE                        TRUE
# 24 0.1280331960       FALSE                       FALSE
# 25 0.1664981438        TRUE                       FALSE
# 26 0.0059613744        TRUE                        TRUE
# 27 0.1773486521        TRUE                       FALSE
# 28 0.1395031315        TRUE                       FALSE
# 29 0.6340465525        TRUE                       FALSE
# 30 0.7447084624        TRUE                       FALSE
# 31 0.0213680780        TRUE                        TRUE
# 32 0.1302293476       FALSE                       FALSE
# 33 0.1743215064        TRUE                       FALSE
# 34 0.6908884878       FALSE                       FALSE
# 35 0.7148210731        TRUE                       FALSE
# 36 0.2930339070        TRUE                       FALSE
# 37 0.0503046554        TRUE                       FALSE
# 38 0.6621371139        TRUE                       FALSE
# 39 0.5892957527        TRUE                       FALSE
# 40 0.3759529967       FALSE                       FALSE
# 41 0.1562447698        TRUE                       FALSE
# 42 0.6979690011       FALSE                       FALSE
# 43 0.6837971722        TRUE                       FALSE
# 44 0.2456037954        TRUE                       FALSE
# 45 0.0444379970        TRUE                        TRUE
# 46 0.6658872022        TRUE                       FALSE
# 47 0.4971016535        TRUE                       FALSE
# 48 0.3820341744       FALSE                       FALSE

# %%
ancova_significance_eachpressor_df %>% write.csv(file.path(PLOT_DIR, "ancovasignificance_eachpressor.csv"))

# %% [markdown]
# # Figure 2 ANCOVA Plotting

# %%
toplot <- melt_results_df %>%
    mutate(INTERVAL = -INTERVAL) %>%
    drop_na(VALUE) %>%
    filter(grepl("mean_", ID), ID != "mean_diasbp", ID != "mean_sysbp")

# %% [markdown]
# Total pressors

# %%
FANCY_VITAL_ORDER <- c('MAP', 'HR', 'RR', 'SpO2', 'Temperature', 'Glucose')

# %%
FANCY_VITAL_DICT <- c(
    'mean_meanbp' = 'MAP', 
    'mean_heartrate' = 'HR', 
    'mean_resprate' = 'RR', 
    'mean_spo2' = 'SpO2', 
    'mean_tempc' = 'Temperature', 
    'mean_glucose' = 'Glucose')

# %%
PRESSORHOURS_COLORS <- c(
">24 hrs pressors" = '#2F4F4F',
"<=24 hrs pressors" = '#D3D3D3'
)

# %%
options(repr.plot.width=7, repr.plot.height=2.5)

p <- toplot %>%
    rowwise() %>%
    mutate(FANCY_VITAL = FANCY_VITAL_DICT[ID]) %>%
    mutate(FANCY_VITAL = factor(FANCY_VITAL, levels=FANCY_VITAL_ORDER)) %>%
    mutate(FANCY_RESPONSE = if(MORETHAN24HOURS){">24 hrs pressors"}else{"<=24 hrs pressors"}) %>%
    ggplot(aes(x=INTERVAL, y=VALUE, color=FANCY_RESPONSE)) +
        geom_smooth(method=lm, aes(fill=FANCY_RESPONSE)) + 
        xlab("Hours before pressors") + ylab("Vital Sign") +
        scale_x_continuous(limits=c(-10,0), breaks=seq(-10,0,5)) +
        base_theme() + 
        scale_color_manual(values=PRESSORHOURS_COLORS)+
        scale_fill_manual(values=PRESSORHOURS_COLORS)+
        theme(legend.title = element_blank()) +
        theme(legend.position="bottom") +
        facet_wrap(. ~ FANCY_VITAL, scale="free", nrow=1)
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, "ancova_vitals.pdf"), 7,2.5)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# Pressors by type

# %%
pressor_choices
# Out:
# [1] "norepinephrinedurations" "dopaminedurations"
# [3] "phenylephrinedurations"

# %%
options(repr.plot.width=7, repr.plot.height=2.5)
for(pressor_choice in pressor_choices){
    toplot <- melt_results_df %>%
        mutate(INTERVAL = -INTERVAL) %>%
        drop_na(VALUE) %>%
        filter(pressor == pressor_choice, grepl("mean_", ID), ID != "mean_diasbp", ID != "mean_sysbp") %>%
        rowwise() %>%
        mutate(FANCY_VITAL = FANCY_VITAL_DICT[ID]) %>%
        mutate(FANCY_VITAL = factor(FANCY_VITAL, levels=FANCY_VITAL_ORDER)) %>%
        mutate(FANCY_RESPONSE = if(MORETHAN24HOURS){">24 hrs pressors"}else{"<=24 hrs pressors"}) 

    p <- ggplot(toplot, aes(x=INTERVAL, y=VALUE, color=FANCY_RESPONSE)) +
        geom_smooth(method=lm, aes(fill=FANCY_RESPONSE)) + 
        xlab("Hours before pressors") + ylab("Vitals") +
        scale_x_continuous(limits=c(-10,0), breaks=seq(-10,0,5)) +
        base_theme() + 
        scale_color_manual(values=PRESSORHOURS_COLORS)+
        scale_fill_manual(values=PRESSORHOURS_COLORS)+
        theme(legend.title = element_blank()) +
        theme(legend.position="bottom") +
        facet_wrap(. ~ FANCY_VITAL, scale="free", nrow=1)
    
#     if(pressor_choice == 'phenylephrinedurations'){
#         p <- p + theme(legend.position="bottom")
#     }
    
    plot(p)
    
    pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_ancova_vitals.pdf")), 7,2.5)
    plot(p)
    dev.off()
}
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # LR Summary

# %%
lr_summary_list <- list()

# %%
LR_COEFFICIENT_DICT <- c(
'genderM' = "Male Gender",
'intubTRUE' = "Intubated",
'age_cohort' = 'Age',
'simple_diagnosisINFECTION' = "Infectious Diagnosis",   
'simple_diagnosisSEPSIS' = "Sepsis Diagnosis",
'simple_diagnosisOTHER DIAGNOSIS' = "Other Diagnosis",
'pressorphenylephrinedurations' = 'phenylephrine',
'pressornorepinephrinedurations' = 'norepinephrine',
'first_careunitCSRU' = 'CSRU',
'first_careunitSICU' = 'SICU',
'first_careunitMICU' = 'MICU',
'first_careunitTSICU' = 'TSICU'
)

# %% [markdown]
# ### ROC curve with CI

# %%
roc_with_ci <- function(obj) {
  ciobj <- ci.se(obj, specificities = seq(0, 1, l = 25))
  dat.ci <- data.frame(x = as.numeric(rownames(ciobj)),
                       lower = ciobj[, 1],
                       upper = ciobj[, 3])
  
  ggroc(obj) +
    base_theme() +
    theme(axis.title=element_text(size=10)) +
    geom_abline(
      slope = 1,
      intercept = 1,
      linetype = "dashed",
      alpha = 0.7,
      color = '#2F4F4F'
    ) + coord_equal() +
    geom_ribbon(
      data = dat.ci,
      aes(x = x, ymin = lower, ymax = upper),
      fill = '#2F4F4F',
      alpha = 0.2
    ) 
}

# %% [markdown]
# # LR Model for Total
# - Ran into problems with missing data for glucose, spo2 and tempc, hence the selection of criteria as variables

# %%
model_input_df <- melt_results_df %>%
    ungroup() %>%
    mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id, RESPONSE = MORETHAN24HOURS) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE, pressor) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            select(MORETHAN24HOURS, pressor, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -MORETHAN24HOURS, -course_id, -pressor) %>%
            rename(RESPONSE = MORETHAN24HOURS, COURSE = course_id) %>%
            distinct(ICUSTAY, VARIABLE, VALUE, pressor, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE)
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”Warning message:
# “Trying to compute distinct() for variables not found in the data:
# - `ICUSTAY`
# This is an error, but only a warning is raised for compatibility reasons.
# The following variables will be used:
# - VARIABLE
# - VALUE
# - pressor”

# %%
# note: selection of input variables in the line below (and RESPONSE)
model_input_df <- model_input_df %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
             pressor,
             contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate")
              )

# %%
dim(model_input_df)
# Out:
# [1] 15853    37

# %%
# exclude missing cases (done automatically by glm but this allows some more fine control)
model_input_df <- model_input_df[which(complete.cases(model_input_df)),]

# %%
dim(model_input_df)
# Out:
# [1] 1264   37

# %%
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)

# %% [markdown]
# #### Model parameter significance

# %%
summary(model)
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6726  -0.9298  -0.7122   1.1866   2.2589
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      0.4592470  0.6875303   0.668 0.504155
# first_careunitCSRU              -0.7010518  0.2582362  -2.715 0.006632 **
# first_careunitMICU              -0.3019865  0.2207068  -1.368 0.171228
# first_careunitSICU              -0.5219248  0.2455059  -2.126 0.033510 *
# first_careunitTSICU             -0.6162778  0.2654786  -2.321 0.020266 *
# intubTRUE                        0.3547462  0.2023553   1.753 0.079587 .
# simple_diagnosisINFECTION       -0.5550922  0.3115043  -1.782 0.074754 .
# simple_diagnosisOTHER DIAGNOSIS -0.4312782  0.2240158  -1.925 0.054203 .
# simple_diagnosisSEPSIS          -0.5260939  0.4119757  -1.277 0.201601
# age_cohort                      -0.0162941  0.0042817  -3.806 0.000142 ***
# genderM                         -0.0711323  0.1262204  -0.564 0.573056
# pressornorepinephrinedurations   0.7856701  0.2207024   3.560 0.000371 ***
# pressorphenylephrinedurations    0.2844066  0.2210764   1.286 0.198282
# mean_meanbp_1                    0.0136032  0.0053787   2.529 0.011436 *
# mean_meanbp_10                  -0.0080748  0.0058418  -1.382 0.166896
# mean_meanbp_2                   -0.0115371  0.0063321  -1.822 0.068456 .
# mean_meanbp_3                   -0.0107669  0.0061563  -1.749 0.080305 .
# mean_meanbp_4                   -0.0027038  0.0060051  -0.450 0.652530
# mean_meanbp_5                    0.0018383  0.0066628   0.276 0.782621
# mean_meanbp_6                    0.0065495  0.0071512   0.916 0.359738
# mean_meanbp_7                   -0.0051727  0.0069665  -0.743 0.457778
# mean_meanbp_8                    0.0142648  0.0064959   2.196 0.028094 *
# mean_meanbp_9                   -0.0049018  0.0060502  -0.810 0.417833
# mean_resprate_1                 -0.0077927  0.0155719  -0.500 0.616772
# mean_resprate_10                 0.0055492  0.0169404   0.328 0.743234
# mean_resprate_2                 -0.0289666  0.0169061  -1.713 0.086642 .
# mean_resprate_3                 -0.0062077  0.0166231  -0.373 0.708823
# mean_resprate_4                  0.0219498  0.0171841   1.277 0.201484
# mean_resprate_5                  0.0166404  0.0181048   0.919 0.358036
# mean_resprate_6                  0.0098410  0.0187020   0.526 0.598749
# mean_resprate_7                 -0.0155825  0.0181615  -0.858 0.390893
# mean_resprate_8                  0.0147886  0.0180488   0.819 0.412578
# mean_resprate_9                  0.0066726  0.0178226   0.374 0.708115
# mean_heartrate_1                -0.0008751  0.0057614  -0.152 0.879277
# mean_heartrate_10                0.0017412  0.0085463   0.204 0.838555
# mean_heartrate_2                 0.0053185  0.0072887   0.730 0.465581
# mean_heartrate_3                 0.0183835  0.0093858   1.959 0.050152 .
# mean_heartrate_4                -0.0063494  0.0093549  -0.679 0.497311
# mean_heartrate_5                -0.0278422  0.0098308  -2.832 0.004624 **
# mean_heartrate_6                -0.0046735  0.0099345  -0.470 0.638048
# mean_heartrate_7                 0.0100310  0.0096638   1.038 0.299271
# mean_heartrate_8                -0.0005026  0.0100229  -0.050 0.960003
# mean_heartrate_9                 0.0077712  0.0107126   0.725 0.468192
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 1646.0  on 1263  degrees of freedom
# Residual deviance: 1540.1  on 1221  degrees of freedom
# AIC: 1626.1
#
# Number of Fisher Scoring iterations: 4

# %%
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, "modelestimates.csv"))

# %%
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
options(repr.plot.height=3, repr.plot.width=3.5)
p <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_COEFFICIENT_DICT))) %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("modelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %%
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])


all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# plot without title

# %%
lr_summary_list[['TOTAL']] <- data.frame(MEAN_AUC = mean(aucs), 
                                         SD_AUC = sd(aucs), 
                                         MEAN_ACC = mean(all.acc), 
                                         SD_ACC = sd(all.acc))

# %%
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)
# Out:
# plot without title

# %%
pdf(file.path(PLOT_DIR, paste0("modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # LR Model for norepinephrine
# - Running into problems with missing data for glucose, spo2 and tempc.

# %%
pressor_choice <- 'norepinephrinedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(pressor == pressor_choice) %>%
    select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id, RESPONSE = MORETHAN24HOURS) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(pressor == pressor_choice) %>%
            select(-pressor) %>%
            select(MORETHAN24HOURS, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -MORETHAN24HOURS, -course_id) %>%
            rename(RESPONSE = MORETHAN24HOURS, COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE)

model_input_df <- model_input_df %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
             contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
# devise the model
model_input_df <- model_input_df[which(complete.cases(model_input_df)),]
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)

# %%
summary(model)
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0330  -0.9938  -0.5935   1.0507   2.1138
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      2.7498870  1.3765513   1.998   0.0458 *
# first_careunitCSRU              -0.7275855  0.5771315  -1.261   0.2074
# first_careunitMICU              -0.5616560  0.4021839  -1.397   0.1626
# first_careunitSICU              -1.0896713  0.4956168  -2.199   0.0279 *
# first_careunitTSICU             -0.4650218  0.5182145  -0.897   0.3695
# intubTRUE                        0.7872093  0.3579567   2.199   0.0279 *
# simple_diagnosisINFECTION       -0.3212686  0.5596176  -0.574   0.5659
# simple_diagnosisOTHER DIAGNOSIS -0.2326112  0.4916356  -0.473   0.6361
# simple_diagnosisSEPSIS           0.3318941  0.6686943   0.496   0.6197
# age_cohort                      -0.0191874  0.0082224  -2.334   0.0196 *
# genderM                         -0.3439224  0.2269489  -1.515   0.1297
# mean_meanbp_1                    0.0103910  0.0103066   1.008   0.3134
# mean_meanbp_10                   0.0015383  0.0098624   0.156   0.8760
# mean_meanbp_2                   -0.0058361  0.0109486  -0.533   0.5940
# mean_meanbp_3                   -0.0212546  0.0116013  -1.832   0.0669 .
# mean_meanbp_4                   -0.0051858  0.0140451  -0.369   0.7120
# mean_meanbp_5                   -0.0211588  0.0114507  -1.848   0.0646 .
# mean_meanbp_6                   -0.0072530  0.0142809  -0.508   0.6115
# mean_meanbp_7                    0.0008953  0.0130527   0.069   0.9453
# mean_meanbp_8                    0.0232796  0.0128981   1.805   0.0711 .
# mean_meanbp_9                   -0.0218527  0.0095513  -2.288   0.0221 *
# mean_resprate_1                 -0.0391176  0.0299811  -1.305   0.1920
# mean_resprate_10                -0.0559497  0.0302898  -1.847   0.0647 .
# mean_resprate_2                 -0.0176686  0.0311114  -0.568   0.5701
# mean_resprate_3                 -0.0086581  0.0296171  -0.292   0.7700
# mean_resprate_4                  0.0162142  0.0331229   0.490   0.6245
# mean_resprate_5                  0.0804902  0.0351285   2.291   0.0219 *
# mean_resprate_6                  0.0110894  0.0313679   0.354   0.7237
# mean_resprate_7                 -0.0400484  0.0339196  -1.181   0.2377
# mean_resprate_8                  0.0584210  0.0338097   1.728   0.0840 .
# mean_resprate_9                  0.0475213  0.0339697   1.399   0.1618
# mean_heartrate_1                 0.0145208  0.0107792   1.347   0.1779
# mean_heartrate_10                0.0233646  0.0157704   1.482   0.1385
# mean_heartrate_2                -0.0063724  0.0155190  -0.411   0.6814
# mean_heartrate_3                 0.0301651  0.0198472   1.520   0.1285
# mean_heartrate_4                -0.0241464  0.0188078  -1.284   0.1992
# mean_heartrate_5                -0.0144339  0.0207367  -0.696   0.4864
# mean_heartrate_6                -0.0028432  0.0207739  -0.137   0.8911
# mean_heartrate_7                 0.0064984  0.0211037   0.308   0.7581
# mean_heartrate_8                -0.0246239  0.0218114  -1.129   0.2589
# mean_heartrate_9                 0.0046368  0.0197192   0.235   0.8141
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 554.41  on 401  degrees of freedom
# Residual deviance: 485.15  on 361  degrees of freedom
# AIC: 567.15
#
# Number of Fisher Scoring iterations: 4

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# compute odds ratios from coefficients
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# compute odds ratios from coefficients
oddsratio <- exp(cbind(coef(model), confint(model)))

# plot odds ratios
options(repr.plot.height=3, repr.plot.width=3.5)
p <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_COEFFICIENT_DICT))) %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)

pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelodds.pdf")), 3.5, 3)
plot(p)
dev.off()
# Out:
# Waiting for profiling to be done...
# pdf
#   2
# plot without title

# %%
# perform 5 fold CV
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])

all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

# compute ROC curves
p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
# plot ROC curve for pressor choices
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)

pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# pdf
#   2
# plot without title

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                     SD_AUC = sd(aucs), 
                                     MEAN_ACC = mean(all.acc), 
                                     SD_ACC = sd(all.acc))

lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 0.7271038 0.04884877 0.6641049 0.04294404

# %% [markdown]
# # LR Model for dopamine

# %%
pressor_choice <- 'dopaminedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(pressor == pressor_choice) %>%
    select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id, RESPONSE = MORETHAN24HOURS) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(pressor == pressor_choice) %>%
            select(-pressor) %>%
            select(MORETHAN24HOURS, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -MORETHAN24HOURS, -course_id) %>%
            rename(RESPONSE = MORETHAN24HOURS, COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE)

model_input_df <- model_input_df %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
             contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
# devise the model
model_input_df <- model_input_df[which(complete.cases(model_input_df)),]
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)

# %%
summary(model)
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.5008  -0.7275  -0.3858   0.4708   2.2745
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      4.379e+00  2.668e+00   1.641   0.1008
# first_careunitCSRU              -8.385e-01  1.082e+00  -0.775   0.4383
# first_careunitMICU               3.886e-02  6.108e-01   0.064   0.9493
# first_careunitSICU               6.025e-01  8.838e-01   0.682   0.4954
# first_careunitTSICU             -1.651e+01  1.100e+03  -0.015   0.9880
# intubTRUE                        3.103e-02  6.256e-01   0.050   0.9604
# simple_diagnosisINFECTION       -1.710e+00  1.167e+00  -1.465   0.1429
# simple_diagnosisOTHER DIAGNOSIS -1.109e+00  7.402e-01  -1.499   0.1340
# simple_diagnosisSEPSIS          -2.029e+00  1.437e+00  -1.412   0.1581
# age_cohort                      -2.664e-02  1.781e-02  -1.496   0.1347
# genderM                         -1.264e-01  5.398e-01  -0.234   0.8149
# mean_meanbp_1                    4.664e-02  2.377e-02   1.962   0.0497 *
# mean_meanbp_10                   8.655e-03  2.605e-02   0.332   0.7397
# mean_meanbp_2                   -3.930e-02  2.949e-02  -1.332   0.1827
# mean_meanbp_3                    1.461e-03  1.829e-02   0.080   0.9363
# mean_meanbp_4                    4.580e-02  3.243e-02   1.412   0.1579
# mean_meanbp_5                   -1.571e-02  3.269e-02  -0.481   0.6308
# mean_meanbp_6                    7.985e-03  3.506e-02   0.228   0.8198
# mean_meanbp_7                    2.747e-03  2.816e-02   0.098   0.9223
# mean_meanbp_8                    4.279e-03  2.133e-02   0.201   0.8410
# mean_meanbp_9                   -7.282e-02  3.417e-02  -2.131   0.0331 *
# mean_resprate_1                 -3.656e-03  7.266e-02  -0.050   0.9599
# mean_resprate_10                 3.798e-02  8.275e-02   0.459   0.6462
# mean_resprate_2                 -1.126e-01  8.518e-02  -1.322   0.1862
# mean_resprate_3                 -2.522e-02  8.467e-02  -0.298   0.7658
# mean_resprate_4                 -8.288e-02  8.667e-02  -0.956   0.3390
# mean_resprate_5                  3.699e-02  8.169e-02   0.453   0.6507
# mean_resprate_6                  1.320e-01  8.951e-02   1.474   0.1404
# mean_resprate_7                  4.384e-02  8.379e-02   0.523   0.6009
# mean_resprate_8                  2.900e-02  8.505e-02   0.341   0.7331
# mean_resprate_9                 -7.522e-02  8.890e-02  -0.846   0.3975
# mean_heartrate_1                 2.116e-02  2.295e-02   0.922   0.3565
# mean_heartrate_10               -7.716e-02  3.180e-02  -2.427   0.0152 *
# mean_heartrate_2                -5.944e-02  4.266e-02  -1.393   0.1635
# mean_heartrate_3                 1.492e-02  4.822e-02   0.309   0.7570
# mean_heartrate_4                 2.921e-02  4.452e-02   0.656   0.5118
# mean_heartrate_5                 1.018e-02  3.622e-02   0.281   0.7786
# mean_heartrate_6                -2.889e-02  4.200e-02  -0.688   0.4915
# mean_heartrate_7                -4.746e-02  3.842e-02  -1.235   0.2168
# mean_heartrate_8                 1.071e-01  4.245e-02   2.523   0.0116 *
# mean_heartrate_9                 1.496e-02  3.693e-02   0.405   0.6854
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 185.60  on 155  degrees of freedom
# Residual deviance: 136.69  on 115  degrees of freedom
# AIC: 218.69
#
# Number of Fisher Scoring iterations: 16

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# compute odds ratios from coefficients
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# compute odds ratios from coefficients
oddsratio <- exp(cbind(coef(model), confint(model)))

# plot odds ratios
options(repr.plot.height=3, repr.plot.width=3.5)
p <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_COEFFICIENT_DICT))) %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)

pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelodds.pdf")), 3.5, 3)
plot(p)
dev.off()
# Out:
# Waiting for profiling to be done...
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# pdf
#   2
# plot without title

# %%
# perform 5 fold CV
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])

all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

# compute ROC curves
p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)

# plot ROC curve for pressor choices
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)

pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# pdf
#   2
# plot without title

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                     SD_AUC = sd(aucs), 
                                     MEAN_ACC = mean(all.acc), 
                                     SD_ACC = sd(all.acc))

lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 0.8273633 0.05399911 0.7949597 0.09262023

# %% [markdown]
# # LR Model for Phenylephrine

# %%
pressor_choice <- 'phenylephrinedurations'

# %%
model_input_df <- melt_results_df %>%
    filter(pressor == pressor_choice) %>%
    select(-pressor) %>%
    ungroup() %>%
    mutate(VARIABLE = paste(ID, INTERVAL, sep = '_'), COURSE = course_id, RESPONSE = MORETHAN24HOURS) %>%
    select(RESPONSE, COURSE, VARIABLE, VALUE) %>%
    mutate(VALUE = as.character(VALUE)) %>%
    bind_rows(
        output_df %>% 
            filter(pressor == pressor_choice) %>%
            select(-pressor) %>%
            select(MORETHAN24HOURS, course_id, first_careunit, cvc, intub, simple_race, simple_diagnosis, gender, age_cohort) %>%
            gather(VARIABLE, VALUE, -MORETHAN24HOURS, -course_id) %>%
            rename(RESPONSE = MORETHAN24HOURS, COURSE = course_id) %>%
            distinct(COURSE, VARIABLE, VALUE, .keep_all = TRUE)
    ) %>%
    drop_na(VALUE) %>%
    spread(VARIABLE, VALUE) %>% 
    select(-COURSE)

model_input_df <- model_input_df %>%
    mutate_at(vars(contains("mean_")), as.numeric, na.rm = TRUE) %>%
    mutate_at(vars(contains("median_")), as.numeric, na.rm = TRUE) %>%
    mutate(age_cohort = as.numeric(age_cohort)) %>%
    select(RESPONSE, 
             first_careunit,
             intub,
             simple_diagnosis,
             age_cohort,
             gender,
             contains("mean_meanbp"),
             contains("mean_resprate"),
             contains("mean_heartrate"),
              )
# Out:
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”

# %%
# devise the model
model_input_df <- model_input_df[which(complete.cases(model_input_df)),]
model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)

# %%
summary(model)
# Out:
# Call:
# glm(formula = RESPONSE ~ ., family = binomial(link = "logit"),
#     data = model_input_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.7381  -0.8638  -0.6759   1.1806   2.5615
#
# Coefficients:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                     -0.6761054  0.9728813  -0.695  0.48709
# first_careunitCSRU              -0.6056444  0.3641590  -1.663  0.09629 .
# first_careunitMICU              -0.1356374  0.3727092  -0.364  0.71592
# first_careunitSICU              -0.5495497  0.3659416  -1.502  0.13316
# first_careunitTSICU             -0.6773461  0.3912782  -1.731  0.08343 .
# intubTRUE                        0.3733584  0.3178479   1.175  0.24014
# simple_diagnosisINFECTION       -0.7214240  0.5119366  -1.409  0.15877
# simple_diagnosisOTHER DIAGNOSIS -0.3883070  0.3029409  -1.282  0.19992
# simple_diagnosisSEPSIS          -2.2604352  1.1304954  -2.000  0.04555 *
# age_cohort                      -0.0129268  0.0058319  -2.217  0.02665 *
# genderM                          0.0490945  0.1780502   0.276  0.78275
# mean_meanbp_1                    0.0163671  0.0073854   2.216  0.02668 *
# mean_meanbp_10                  -0.0127985  0.0086254  -1.484  0.13786
# mean_meanbp_2                   -0.0134440  0.0092277  -1.457  0.14514
# mean_meanbp_3                   -0.0182297  0.0099228  -1.837  0.06619 .
# mean_meanbp_4                   -0.0061274  0.0080897  -0.757  0.44879
# mean_meanbp_5                    0.0127812  0.0101215   1.263  0.20667
# mean_meanbp_6                    0.0091829  0.0097788   0.939  0.34770
# mean_meanbp_7                   -0.0008677  0.0097552  -0.089  0.92913
# mean_meanbp_8                    0.0068179  0.0095773   0.712  0.47654
# mean_meanbp_9                    0.0139538  0.0098984   1.410  0.15863
# mean_resprate_1                  0.0065160  0.0214633   0.304  0.76144
# mean_resprate_10                 0.0365617  0.0238241   1.535  0.12487
# mean_resprate_2                 -0.0379499  0.0238623  -1.590  0.11175
# mean_resprate_3                  0.0064004  0.0235233   0.272  0.78555
# mean_resprate_4                  0.0241673  0.0230376   1.049  0.29416
# mean_resprate_5                  0.0043841  0.0251438   0.174  0.86158
# mean_resprate_6                 -0.0045051  0.0275333  -0.164  0.87003
# mean_resprate_7                 -0.0225428  0.0251694  -0.896  0.37044
# mean_resprate_8                 -0.0003609  0.0246754  -0.015  0.98833
# mean_resprate_9                 -0.0027035  0.0240358  -0.112  0.91044
# mean_heartrate_1                -0.0124518  0.0081987  -1.519  0.12882
# mean_heartrate_10                0.0047431  0.0125389   0.378  0.70523
# mean_heartrate_2                 0.0136564  0.0091957   1.485  0.13752
# mean_heartrate_3                 0.0225167  0.0121764   1.849  0.06443 .
# mean_heartrate_4                -0.0018506  0.0127988  -0.145  0.88503
# mean_heartrate_5                -0.0490621  0.0133184  -3.684  0.00023 ***
# mean_heartrate_6                -0.0008513  0.0127026  -0.067  0.94657
# mean_heartrate_7                 0.0190088  0.0130568   1.456  0.14543
# mean_heartrate_8                 0.0009381  0.0131109   0.072  0.94296
# mean_heartrate_9                 0.0069791  0.0155244   0.450  0.65303
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 879.13  on 705  degrees of freedom
# Residual deviance: 809.60  on 665  degrees of freedom
# AIC: 891.6
#
# Number of Fisher Scoring iterations: 5

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# compute odds ratios from coefficients
oddsratio <- exp(cbind(coef(model), confint(model)))
# Out:
# Waiting for profiling to be done...

# %%
# isolate out model coefficients
summary(model)$coefficients %>% data.frame() %>% 
    tibble::rownames_to_column("Variable") %>%
    rename(P.Value = Pr...z..) %>% 
    mutate(SIGNIFICANT = P.Value < 0.05) %>% 
    write.csv(file.path(PLOT_DIR, paste0(pressor_choice, "_modelestimates.csv")))

# compute odds ratios from coefficients
oddsratio <- exp(cbind(coef(model), confint(model)))

# plot odds ratios
options(repr.plot.height=3, repr.plot.width=3.5)
p <- oddsratio %>% data.frame() %>%
    tibble::rownames_to_column("factor") %>%
    filter(factor != "(Intercept)") %>%
    rename(estimate = V1, lower = X2.5.., upper = X97.5..) %>%
    rowwise() %>%
    mutate(significant = (lower > 1 & upper > 1) | (lower < 1 & upper < 1)) %>%
    mutate(legend = if(significant){'Significant'}else{'Not Significant'}) %>%
    filter(factor %in% names(LR_COEFFICIENT_DICT)) %>%
    mutate(factor = LR_COEFFICIENT_DICT[factor]) %>%
    mutate(factor = factor(factor, levels= rev(LR_COEFFICIENT_DICT))) %>%
    ggplot(aes(x = factor,y = estimate, ymin = lower, ymax = upper ))+
        base_theme()+
        theme(legend.position="bottom")+
        geom_pointrange(aes(col=legend))+
        scale_color_manual(values=SIGNIFICANT_COLORS)+
        geom_hline(yintercept =1, linetype=2, color = "firebrick")+
        xlab('')+ ylab("Odds Ratio (95% CI)")+
        geom_errorbar(aes(ymin=lower, ymax=upper,col=legend),width=0.5,cex=1)+ 
        coord_flip()
plot(p)

pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelodds.pdf")), 3.5,3)
plot(p)
dev.off()
# Out:
# Waiting for profiling to be done...
# pdf
#   2
# plot without title

# %%
# perform 5 fold CV
options(repr.plot.width=3, repr.plot.height=3)
input <- model_input_df
k <- 5
n <- dim(input)[1]
indices <- sample(rep(1:k, ceiling(n/k))[1:n])

all.acc <- all.response <- all.predictor <- aucs <- c()
for (i in 1:k) {
  test = input[indices==i,]
  learn = input[indices!=i,]
  model <- glm(RESPONSE ~ . , family=binomial(link='logit'),data=model_input_df)
  model.pred <- predict(model, newdata=test)
  model.acc <- data.frame(PRED = model.pred > 0, RESPONSE = test$RESPONSE) %>% 
        summarize(ACC = sum(PRED == RESPONSE)/n()) %>% unlist()
  aucs <- c(aucs, roc(test$RESPONSE, model.pred)$auc)
  all.response <- c(all.response, test$RESPONSE)
  all.predictor <- c(all.predictor, model.pred)
  all.acc <- c(all.acc, model.acc)
}

# compute ROC curves
p_out <- roc(all.response, all.predictor, grid=T, legacy.axes=T, ci=TRUE, auc=T)
#plot(p_out, print.auc=TRUE)

# plot ROC curve for pressor choices
options(repr.plot.width=3, repr.plot.height=3)
p <- roc_with_ci(p_out)

plot(p)

pdf(file.path(PLOT_DIR, paste0(pressor_choice, "_modelauc.pdf")), 3,3)
plot(p)
dev.off()
# Out:
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
# pdf
#   2
# plot without title

# %%
lr_summary_list[[pressor_choice]] <- data.frame(MEAN_AUC = mean(aucs), 
                                     SD_AUC = sd(aucs), 
                                     MEAN_ACC = mean(all.acc), 
                                     SD_ACC = sd(all.acc))

lr_summary_list[[pressor_choice]]
# Out:
#   MEAN_AUC SD_AUC     MEAN_ACC  SD_ACC
# 1 0.691562 0.02251183 0.6982419 0.03253391

# %% [markdown]
# # Output AUC table

# %%
auc_output_df <- bind_rows(lr_summary_list, .id="PRESSOR")
auc_output_df
# Out:
#   PRESSOR                 MEAN_AUC  SD_AUC     MEAN_ACC  SD_ACC
# 1 TOTAL                   0.6710370 0.02599524 0.6780256 0.03778072
# 2 norepinephrinedurations 0.7321406 0.05208283 0.6616358 0.01223504
# 3 dopaminedurations       0.8578515 0.11483787 0.7961694 0.14423498
# 4 phenylephrinedurations  0.6816482 0.08261785 0.6983218 0.02551201

# %%
auc_output_df  %>% write.csv(file.path(PLOT_DIR, "summary_auc.csv"))
